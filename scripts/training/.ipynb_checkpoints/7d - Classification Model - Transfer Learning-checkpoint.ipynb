# %% [markdown]
# # Creating dataset

# %% [markdown]
# # Creating classification model

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATASET_PATH = '../../datasets/Classification/Dataset - 7 dias'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
IMG_SIZE = 256

images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)



print(len(images))
# Out:
# 1184

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)
labels = np.array(labels)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.1, stratify=labels)

# %%
print("In training:")
for i in range(0,3):
    print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
print("In test:")
for i in range(0,3):
    print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')
    
# print("Proporção entre classes:")
# Out:
# In training:
# Class 0: 78.97%
# Class 1: 17.0%
# Class 2: 4.04%
# In test:
# Class 0: 78.99%
# Class 1: 16.81%
# Class 2: 4.2%

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
# Trying class weights
# it does not work with one hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

def get_sample_weights(train_labels):
    from sklearn.utils import compute_sample_weight
    
    return compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd
train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels_1d = test_labels

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %%
labels = pd.get_dummies(labels)
labels = pd.DataFrame.to_numpy(labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %%
train_images[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ### Creating the model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras

EPOCHS = 20
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

# %%
METRICDIR = '../metricas/classificacao/7_d/tests/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

def create_model():
       
    base_model = keras.applications.Xception(
        weights='imagenet',  # Load weights pre-trained on ImageNet.
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(IMG_SIZE,IMG_SIZE, 3))
    # We make sure that the base_model is running in inference mode here,
    # by passing `training=False`. This is important for fine-tuning, as you will
    # learn in a few paragraphs.
    x = base_model(inputs)
    # Convert features of shape `base_model.output_shape[1:]` to vectors
    x = keras.layers.GlobalAveragePooling2D()(x)
    # A Dense classifier 
    outputs = keras.layers.Dense(3, activation="sigmoid")(x)

    model = keras.Model(inputs, outputs)

    opt = keras.optimizers.Adam(learning_rate=0.00001)
    # opt = tf.keras.optimizers.Adadelta(learning_rate=0.00001, rho=0.95, epsilon=1e-07, name='Adadelta')

    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)
    
    return model

# %%
def get_model_name(k):
    return '_model_'+str(k)+'.h5'

def plot_metric(metric_name, chart_name, SAVE = False):
    import matplotlib.pyplot as plt
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
from sklearn.model_selection import KFold

num_folds = 10

kfold = KFold(n_splits=num_folds, shuffle=True)

#metrics containers
acc = []
prec = []
rec = []
auc = []

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(train_images, train_labels):

    from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
    
    if fold_no - 1 == 0:
        idx_str = ""
    else:
        idx_str = f"_{fold_no}"
    
    fold_checkpoint = CHECKPOINT_DIR + get_model_name(fold_no)
    
    my_callbacks = [
        ModelCheckpoint(fold_checkpoint, monitor=f"val_precision", verbose=1, save_best_only=True, mode='max', save_freq='epoch'),
        ReduceLROnPlateau(monitor=f'val_precision', factor=0.2, patience=2, min_lr=0.0000001, mode='max'),
    ]
    
    model = create_model()

    # Generate a print
    print('------------------------------------------------------------------------', end="\n\n")
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    history = model.fit(
        train_images[train],
        train_labels[train],
        batch_size = BATCH_SIZE,
        epochs = EPOCHS,
        validation_split=TRAIN_TEST_SPLIT,
        sample_weight=get_sample_weights(train_labels[train]),
        callbacks=[my_callbacks])
    
    model = tf.keras.models.load_model(fold_checkpoint)
    
    NUM_METRICS = len(my_metrics) + 1
    for metric in list(model.history.keys())[:NUM_METRICS]:
        plot_metric(metric, metric + " for soybean classification")
    
    # Generate generalization metrics
    scores = model.evaluate(images[test], labels[test], verbose=0)
    print(f'Scores for fold {fold_no}:')
    for i in range(len(my_metrics)):   
        print(f'{model.metrics_names[i]} of {scores[i]}')
    
    acc.append(scores[1] * 100)
    prec.append(scores[2])
    rec.append(scores[3])
    auc.append(scores[4])

    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
#
# Training for fold 1 ...
# Epoch 1/20
# 23/23 [==============================] - 66s 3s/step - loss: 13.2906 - accuracy: 0.7404 - precision: 0.6353 - recall: 0.7742 - auc: 0.8142 - true_positives: 304.2083 - true_negatives: 618.4583 - false_positives: 175.8750 - false_negatives: 92.9583 - val_loss: 9.3207 - val_accuracy: 0.7542 - val_precision: 0.6053 - val_recall: 0.7667 - val_auc: 0.8031 - val_true_positives: 184.0000 - val_true_negatives: 360.0000 - val_false_positives: 120.0000 - val_false_negatives: 56.0000
#
# Epoch 00001: val_precision improved from -inf to 0.60526, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_1.h5
# Epoch 2/20
# 23/23 [==============================] - 69s 3s/step - loss: 13.1075 - accuracy: 0.7423 - precision: 0.6311 - recall: 0.7393 - auc: 0.8065 - true_positives: 293.0000 - true_negatives: 614.6667 - false_positives: 179.6667 - false_negatives: 104.1667 - val_loss: 7.5225 - val_accuracy: 0.7083 - val_precision: 0.5912 - val_recall: 0.7292 - val_auc: 0.7889 - val_true_positives: 175.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 65.0000
#
# Epoch 00002: val_precision did not improve from 0.60526
# Epoch 3/20
# 23/23 [==============================] - 82s 4s/step - loss: 6.0541 - accuracy: 0.7081 - precision: 0.6085 - recall: 0.6919 - auc: 0.7935 - true_positives: 276.0833 - true_negatives: 612.4167 - false_positives: 181.9167 - false_negatives: 121.0833 - val_loss: 6.3676 - val_accuracy: 0.6792 - val_precision: 0.5833 - val_recall: 0.7000 - val_auc: 0.7762 - val_true_positives: 168.0000 - val_true_negatives: 360.0000 - val_false_positives: 120.0000 - val_false_negatives: 72.0000
#
# Epoch 00003: val_precision did not improve from 0.60526
# Epoch 4/20
# 23/23 [==============================] - 72s 3s/step - loss: 8.1709 - accuracy: 0.6841 - precision: 0.5821 - recall: 0.6728 - auc: 0.7617 - true_positives: 267.3750 - true_negatives: 603.1250 - false_positives: 191.2083 - false_negatives: 129.7917 - val_loss: 6.1216 - val_accuracy: 0.6750 - val_precision: 0.5769 - val_recall: 0.6875 - val_auc: 0.7735 - val_true_positives: 165.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 75.0000
#
# Epoch 00004: val_precision did not improve from 0.60526
# Epoch 5/20
# 23/23 [==============================] - 72s 3s/step - loss: 7.4521 - accuracy: 0.6601 - precision: 0.5748 - recall: 0.6659 - auc: 0.7636 - true_positives: 265.2917 - true_negatives: 603.6667 - false_positives: 190.6667 - false_negatives: 131.8750 - val_loss: 5.9158 - val_accuracy: 0.6667 - val_precision: 0.5694 - val_recall: 0.6667 - val_auc: 0.7709 - val_true_positives: 160.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 80.0000
#
# Epoch 00005: val_precision did not improve from 0.60526
# Epoch 6/20
# 23/23 [==============================] - 73s 3s/step - loss: 6.5934 - accuracy: 0.6923 - precision: 0.5786 - recall: 0.6554 - auc: 0.7739 - true_positives: 262.9167 - true_negatives: 604.4583 - false_positives: 189.8750 - false_negatives: 134.2500 - val_loss: 5.8789 - val_accuracy: 0.6667 - val_precision: 0.5679 - val_recall: 0.6625 - val_auc: 0.7705 - val_true_positives: 159.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 81.0000
#
# Epoch 00006: val_precision did not improve from 0.60526
# Epoch 7/20
# 23/23 [==============================] - 73s 3s/step - loss: 6.8599 - accuracy: 0.6898 - precision: 0.5780 - recall: 0.6763 - auc: 0.7655 - true_positives: 261.2917 - true_negatives: 603.7083 - false_positives: 190.6250 - false_negatives: 135.8750 - val_loss: 5.8316 - val_accuracy: 0.6625 - val_precision: 0.5679 - val_recall: 0.6625 - val_auc: 0.7700 - val_true_positives: 159.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 81.0000
#
# Epoch 00007: val_precision did not improve from 0.60526
# Epoch 8/20
# 23/23 [==============================] - 69s 3s/step - loss: 6.5018 - accuracy: 0.6895 - precision: 0.5861 - recall: 0.6482 - auc: 0.7761 - true_positives: 256.3333 - true_negatives: 607.6250 - false_positives: 186.7083 - false_negatives: 140.8333 - val_loss: 5.8211 - val_accuracy: 0.6625 - val_precision: 0.5679 - val_recall: 0.6625 - val_auc: 0.7699 - val_true_positives: 159.0000 - val_true_negatives: 359.0000 - val_false_positives: 121.0000 - val_false_negatives: 81.0000
#
# Epoch 00008: val_precision did not improve from 0.60526
# Epoch 9/20
# 23/23 [==============================] - 69s 3s/step - loss: 6.7678 - accuracy: 0.6844 - precision: 0.5814 - recall: 0.6499 - auc: 0.7658 - true_positives: 260.2500 - true_negatives: 610.8333 - false_positives: 183.5000 - false_negatives: 136.9167 - val_loss: 5.8112 - val_accuracy: 0.6625 - val_precision: 0.5658 - val_recall: 0.6625 - val_auc: 0.7698 - val_true_positives: 159.0000 - val_true_negatives: 358.0000 - val_false_positives: 122.0000 - val_false_negatives: 81.0000
#
# Epoch 00009: val_precision did not improve from 0.60526
# Epoch 10/20
# 23/23 [==============================] - 66s 3s/step - loss: 5.2405 - accuracy: 0.6840 - precision: 0.5656 - recall: 0.6484 - auc: 0.7631 - true_positives: 259.1250 - true_negatives: 602.8333 - false_positives: 191.5000 - false_negatives: 138.0417 - val_loss: 5.8006 - val_accuracy: 0.6625 - val_precision: 0.5658 - val_recall: 0.6625 - val_auc: 0.7697 - val_true_positives: 159.0000 - val_true_negatives: 358.0000 - val_false_positives: 122.0000 - val_false_negatives: 81.0000
#
# Epoch 00010: val_precision did not improve from 0.60526
# Epoch 11/20
# 23/23 [==============================] - 75s 3s/step - loss: 5.9762 - accuracy: 0.6813 - precision: 0.5800 - recall: 0.6361 - auc: 0.7711 - true_positives: 256.2917 - true_negatives: 611.8750 - false_positives: 182.4583 - false_negatives: 140.8750 - val_loss: 5.7883 - val_accuracy: 0.6625 - val_precision: 0.5658 - val_recall: 0.6625 - val_auc: 0.7695 - val_true_positives: 159.0000 - val_true_negatives: 358.0000 - val_false_positives: 122.0000 - val_false_negatives: 81.0000
#
# Epoch 00011: val_precision did not improve from 0.60526
# Epoch 12/20
# 23/23 [==============================] - 69s 3s/step - loss: 7.0734 - accuracy: 0.6688 - precision: 0.5875 - recall: 0.6730 - auc: 0.7593 - true_positives: 264.0417 - true_negatives: 605.2917 - false_positives: 189.0417 - false_negatives: 133.1250 - val_loss: 5.7769 - val_accuracy: 0.6625 - val_precision: 0.5658 - val_recall: 0.6625 - val_auc: 0.7693 - val_true_positives: 159.0000 - val_true_negatives: 358.0000 - val_false_positives: 122.0000 - val_false_negatives: 81.0000
#
# Epoch 00012: val_precision did not improve from 0.60526
# Epoch 13/20
# 23/23 [==============================] - 71s 3s/step - loss: 6.0676 - accuracy: 0.6872 - precision: 0.5928 - recall: 0.6629 - auc: 0.7825 - true_positives: 263.3333 - true_negatives: 609.8333 - false_positives: 184.5000 - false_negatives: 133.8333 - val_loss: 5.7662 - val_accuracy: 0.6625 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7691 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00013: val_precision did not improve from 0.60526
# Epoch 14/20
# 23/23 [==============================] - 65s 3s/step - loss: 7.2712 - accuracy: 0.6424 - precision: 0.5582 - recall: 0.6417 - auc: 0.7543 - true_positives: 257.9583 - true_negatives: 597.5833 - false_positives: 196.7500 - false_negatives: 139.2083 - val_loss: 5.7544 - val_accuracy: 0.6625 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7690 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00014: val_precision did not improve from 0.60526
# Epoch 15/20
# 23/23 [==============================] - 69s 3s/step - loss: 6.9125 - accuracy: 0.6739 - precision: 0.5873 - recall: 0.6507 - auc: 0.7663 - true_positives: 258.5833 - true_negatives: 612.7083 - false_positives: 181.6250 - false_negatives: 138.5833 - val_loss: 5.7443 - val_accuracy: 0.6625 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7688 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
# Epoch 00015: val_precision did not improve from 0.60526
# Epoch 16/20
# 23/23 [==============================] - 63s 3s/step - loss: 5.9446 - accuracy: 0.6933 - precision: 0.5932 - recall: 0.6785 - auc: 0.7778 - true_positives: 267.1250 - true_negatives: 609.0417 - false_positives: 185.2917 - false_negatives: 130.0417 - val_loss: 5.7338 - val_accuracy: 0.6625 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7687 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00016: val_precision did not improve from 0.60526
# Epoch 17/20
# 23/23 [==============================] - 71s 3s/step - loss: 7.0148 - accuracy: 0.6736 - precision: 0.5887 - recall: 0.6587 - auc: 0.7786 - true_positives: 259.0000 - true_negatives: 610.6667 - false_positives: 183.6667 - false_negatives: 138.1667 - val_loss: 5.7226 - val_accuracy: 0.6625 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7685 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00017: val_precision did not improve from 0.60526
# Epoch 18/20
# 23/23 [==============================] - 77s 3s/step - loss: 7.8272 - accuracy: 0.6751 - precision: 0.5750 - recall: 0.6518 - auc: 0.7533 - true_positives: 259.7917 - true_negatives: 604.4583 - false_positives: 189.8750 - false_negatives: 137.3750 - val_loss: 5.7111 - val_accuracy: 0.6583 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7684 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00018: val_precision did not improve from 0.60526
# Epoch 19/20
# 23/23 [==============================] - 75s 3s/step - loss: 5.8256 - accuracy: 0.6757 - precision: 0.5887 - recall: 0.6449 - auc: 0.7750 - true_positives: 259.0000 - true_negatives: 607.5417 - false_positives: 186.7917 - false_negatives: 138.1667 - val_loss: 5.7009 - val_accuracy: 0.6583 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7682 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00019: val_precision did not improve from 0.60526
# Epoch 20/20
# 23/23 [==============================] - 72s 3s/step - loss: 6.6803 - accuracy: 0.6666 - precision: 0.5684 - recall: 0.6548 - auc: 0.7623 - true_positives: 264.7500 - true_negatives: 600.8750 - false_positives: 193.4583 - false_negatives: 132.4167 - val_loss: 5.6894 - val_accuracy: 0.6583 - val_precision: 0.5638 - val_recall: 0.6625 - val_auc: 0.7680 - val_true_positives: 159.0000 - val_true_negatives: 357.0000 - val_false_positives: 123.0000 - val_false_negatives: 81.0000
#
# Epoch 00020: val_precision did not improve from 0.60526
# Scores for fold 1:
# loss of 1.0428212881088257
# accuracy of 0.7570093274116516
# precision of 0.6363636255264282
# recall of 0.7196261882781982
# auc of 0.7965760827064514
# true_positives of 77.0
# true_negatives of 170.0
# false_positives of 44.0
# ------------------------------------------------------------------------
#
# Training for fold 2 ...
# Epoch 1/20
# 23/23 [==============================] - 157s 6s/step - loss: 35.5862 - accuracy: 0.5521 - precision: 0.5820 - recall: 0.3738 - auc: 0.7096 - true_positives: 219.7917 - true_negatives: 1117.5417 - false_positives: 156.7917 - false_negatives: 417.3750 - val_loss: 33.2178 - val_accuracy: 0.5958 - val_precision: 0.7069 - val_recall: 0.1708 - val_auc: 0.7207 - val_true_positives: 41.0000 - val_true_negatives: 463.0000 - val_false_positives: 17.0000 - val_false_negatives: 199.0000
#
# Epoch 00001: val_precision improved from -inf to 0.70690, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_2.h5
# Epoch 2/20
# 23/23 [==============================] - 104s 5s/step - loss: 24.5017 - accuracy: 0.5744 - precision: 0.6990 - recall: 0.1493 - auc: 0.7025 - true_positives: 58.1667 - true_negatives: 766.7500 - false_positives: 27.5833 - false_negatives: 339.0000 - val_loss: 30.2425 - val_accuracy: 0.5708 - val_precision: 0.7222 - val_recall: 0.1625 - val_auc: 0.6998 - val_true_positives: 39.0000 - val_true_negatives: 465.0000 - val_false_positives: 15.0000 - val_false_negatives: 201.0000
#
# Epoch 00002: val_precision improved from 0.70690 to 0.72222, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_2.h5
# Epoch 3/20
# 23/23 [==============================] - 144s 6s/step - loss: 22.7461 - accuracy: 0.5430 - precision: 0.6603 - recall: 0.1278 - auc: 0.6740 - true_positives: 49.2917 - true_negatives: 766.3333 - false_positives: 28.0000 - false_negatives: 347.8750 - val_loss: 27.3707 - val_accuracy: 0.5500 - val_precision: 0.7174 - val_recall: 0.1375 - val_auc: 0.6794 - val_true_positives: 33.0000 - val_true_negatives: 467.0000 - val_false_positives: 13.0000 - val_false_negatives: 207.0000
#
# Epoch 00003: val_precision did not improve from 0.72222
# Epoch 4/20
# 23/23 [==============================] - 135s 6s/step - loss: 26.9697 - accuracy: 0.4819 - precision: 0.5808 - recall: 0.1124 - auc: 0.6195 - true_positives: 43.5000 - true_negatives: 763.3333 - false_positives: 31.0000 - false_negatives: 353.6667 - val_loss: 24.4937 - val_accuracy: 0.5208 - val_precision: 0.6829 - val_recall: 0.1167 - val_auc: 0.6601 - val_true_positives: 28.0000 - val_true_negatives: 467.0000 - val_false_positives: 13.0000 - val_false_negatives: 212.0000
#
# Epoch 00004: val_precision did not improve from 0.72222
# Epoch 5/20
# 23/23 [==============================] - 134s 6s/step - loss: 24.5487 - accuracy: 0.4790 - precision: 0.5927 - recall: 0.1038 - auc: 0.6192 - true_positives: 39.4583 - true_negatives: 766.9583 - false_positives: 27.3750 - false_negatives: 357.7083 - val_loss: 24.0242 - val_accuracy: 0.5208 - val_precision: 0.7000 - val_recall: 0.1167 - val_auc: 0.6567 - val_true_positives: 28.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 212.0000
#
# Epoch 00005: val_precision did not improve from 0.72222
# Epoch 6/20
# 23/23 [==============================] - 122s 5s/step - loss: 24.7045 - accuracy: 0.4782 - precision: 0.6293 - recall: 0.1158 - auc: 0.6105 - true_positives: 42.8750 - true_negatives: 768.8333 - false_positives: 25.5000 - false_negatives: 354.2917 - val_loss: 23.4952 - val_accuracy: 0.5208 - val_precision: 0.7000 - val_recall: 0.1167 - val_auc: 0.6536 - val_true_positives: 28.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 212.0000
#
# Epoch 00006: val_precision did not improve from 0.72222
# Epoch 7/20
# 23/23 [==============================] - 121s 5s/step - loss: 25.0344 - accuracy: 0.4561 - precision: 0.5889 - recall: 0.0983 - auc: 0.6043 - true_positives: 39.7917 - true_negatives: 768.8333 - false_positives: 25.5000 - false_negatives: 357.3750 - val_loss: 23.3905 - val_accuracy: 0.5208 - val_precision: 0.7000 - val_recall: 0.1167 - val_auc: 0.6533 - val_true_positives: 28.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 212.0000
#
# Epoch 00007: val_precision did not improve from 0.72222
# Epoch 8/20
# 23/23 [==============================] - 123s 5s/step - loss: 17.9939 - accuracy: 0.4570 - precision: 0.6031 - recall: 0.0850 - auc: 0.6060 - true_positives: 34.4583 - true_negatives: 770.8750 - false_positives: 23.4583 - false_negatives: 362.7083 - val_loss: 23.2945 - val_accuracy: 0.5208 - val_precision: 0.7000 - val_recall: 0.1167 - val_auc: 0.6525 - val_true_positives: 28.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 212.0000
#
# Epoch 00008: val_precision did not improve from 0.72222
# Epoch 9/20
# 23/23 [==============================] - 124s 5s/step - loss: 20.7264 - accuracy: 0.4649 - precision: 0.5377 - recall: 0.0855 - auc: 0.6032 - true_positives: 36.2917 - true_negatives: 766.9583 - false_positives: 27.3750 - false_negatives: 360.8750 - val_loss: 23.2695 - val_accuracy: 0.5208 - val_precision: 0.7000 - val_recall: 0.1167 - val_auc: 0.6525 - val_true_positives: 28.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 212.0000
#
# Epoch 00009: val_precision did not improve from 0.72222
# Epoch 10/20
# 23/23 [==============================] - 121s 5s/step - loss: 23.6877 - accuracy: 0.4785 - precision: 0.6367 - recall: 0.1052 - auc: 0.6149 - true_positives: 41.1250 - true_negatives: 771.5833 - false_positives: 22.7500 - false_negatives: 356.0417 - val_loss: 23.2449 - val_accuracy: 0.5208 - val_precision: 0.6923 - val_recall: 0.1125 - val_auc: 0.6523 - val_true_positives: 27.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 213.0000
#
# Epoch 00010: val_precision did not improve from 0.72222
# Epoch 11/20
# 23/23 [==============================] - 126s 6s/step - loss: 28.4274 - accuracy: 0.4559 - precision: 0.5370 - recall: 0.0817 - auc: 0.5943 - true_positives: 33.8750 - true_negatives: 768.6667 - false_positives: 25.6667 - false_negatives: 363.2917 - val_loss: 23.2180 - val_accuracy: 0.5208 - val_precision: 0.6923 - val_recall: 0.1125 - val_auc: 0.6521 - val_true_positives: 27.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 213.0000
#
# Epoch 00011: val_precision did not improve from 0.72222
# Epoch 12/20
# 23/23 [==============================] - 159s 7s/step - loss: 24.7128 - accuracy: 0.4778 - precision: 0.6453 - recall: 0.1085 - auc: 0.6199 - true_positives: 40.6667 - true_negatives: 770.6667 - false_positives: 23.6667 - false_negatives: 356.5000 - val_loss: 23.1924 - val_accuracy: 0.5208 - val_precision: 0.6923 - val_recall: 0.1125 - val_auc: 0.6521 - val_true_positives: 27.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 213.0000
#
# Epoch 00012: val_precision did not improve from 0.72222
# Epoch 13/20
# 23/23 [==============================] - 162s 7s/step - loss: 18.1570 - accuracy: 0.4785 - precision: 0.5762 - recall: 0.0911 - auc: 0.6163 - true_positives: 37.6250 - true_negatives: 769.0417 - false_positives: 25.2917 - false_negatives: 359.5417 - val_loss: 23.1707 - val_accuracy: 0.5208 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6520 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00013: val_precision did not improve from 0.72222
# Epoch 14/20
# 23/23 [==============================] - 148s 6s/step - loss: 18.7257 - accuracy: 0.4632 - precision: 0.6856 - recall: 0.0976 - auc: 0.6133 - true_positives: 39.4167 - true_negatives: 771.8750 - false_positives: 22.4583 - false_negatives: 357.7500 - val_loss: 23.1475 - val_accuracy: 0.5208 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6519 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00014: val_precision did not improve from 0.72222
# Epoch 15/20
# 23/23 [==============================] - 152s 7s/step - loss: 18.8976 - accuracy: 0.4794 - precision: 0.5592 - recall: 0.0820 - auc: 0.6054 - true_positives: 34.2917 - true_negatives: 769.8750 - false_positives: 24.4583 - false_negatives: 362.8750 - val_loss: 23.1237 - val_accuracy: 0.5208 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6517 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00015: val_precision did not improve from 0.72222
# Epoch 16/20
# 23/23 [==============================] - 149s 7s/step - loss: 20.9276 - accuracy: 0.4644 - precision: 0.5837 - recall: 0.0874 - auc: 0.6144 - true_positives: 36.9583 - true_negatives: 770.4167 - false_positives: 23.9167 - false_negatives: 360.2083 - val_loss: 23.0980 - val_accuracy: 0.5208 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6514 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00016: val_precision did not improve from 0.72222
# Epoch 17/20
# 23/23 [==============================] - 157s 7s/step - loss: 25.5636 - accuracy: 0.4545 - precision: 0.6224 - recall: 0.0893 - auc: 0.5978 - true_positives: 37.2083 - true_negatives: 773.0000 - false_positives: 21.3333 - false_negatives: 359.9583 - val_loss: 23.0736 - val_accuracy: 0.5167 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6510 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00017: val_precision did not improve from 0.72222
# Epoch 18/20
# 23/23 [==============================] - 166s 7s/step - loss: 28.3563 - accuracy: 0.4934 - precision: 0.5884 - recall: 0.0973 - auc: 0.6141 - true_positives: 39.3333 - true_negatives: 769.1250 - false_positives: 25.2083 - false_negatives: 357.8333 - val_loss: 23.0492 - val_accuracy: 0.5167 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6510 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00018: val_precision did not improve from 0.72222
# Epoch 19/20
# 23/23 [==============================] - 153s 7s/step - loss: 27.1958 - accuracy: 0.4557 - precision: 0.5277 - recall: 0.0866 - auc: 0.5855 - true_positives: 35.7500 - true_negatives: 766.5000 - false_positives: 27.8333 - false_negatives: 361.4167 - val_loss: 23.0254 - val_accuracy: 0.5167 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6511 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00019: val_precision did not improve from 0.72222
# Epoch 20/20
# 23/23 [==============================] - 152s 7s/step - loss: 24.3076 - accuracy: 0.4372 - precision: 0.6215 - recall: 0.0964 - auc: 0.5963 - true_positives: 39.4167 - true_negatives: 770.6250 - false_positives: 23.7083 - false_negatives: 357.7500 - val_loss: 22.9992 - val_accuracy: 0.5167 - val_precision: 0.6842 - val_recall: 0.1083 - val_auc: 0.6510 - val_true_positives: 26.0000 - val_true_negatives: 468.0000 - val_false_positives: 12.0000 - val_false_negatives: 214.0000
#
# Epoch 00020: val_precision did not improve from 0.72222
# Scores for fold 2:
# loss of 3.258073091506958
# accuracy of 0.5420560836791992
# precision of 0.6399999856948853
# recall of 0.14953270554542542
# auc of 0.6549698710441589
# true_positives of 16.0
# true_negatives of 205.0
# false_positives of 9.0
# ------------------------------------------------------------------------
#
# Training for fold 3 ...
# Epoch 1/20
# 23/23 [==============================] - 153s 6s/step - loss: 28.5527 - accuracy: 0.4930 - precision: 0.6312 - recall: 0.1148 - auc: 0.6724 - true_positives: 73.2083 - true_negatives: 1230.1667 - false_positives: 44.1667 - false_negatives: 563.9583 - val_loss: 24.6410 - val_accuracy: 0.4833 - val_precision: 0.5200 - val_recall: 0.1083 - val_auc: 0.6799 - val_true_positives: 26.0000 - val_true_negatives: 456.0000 - val_false_positives: 24.0000 - val_false_negatives: 214.0000
#
# Epoch 00001: val_precision improved from -inf to 0.52000, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_3.h5
# Epoch 2/20
# 23/23 [==============================] - 85s 4s/step - loss: 27.8642 - accuracy: 0.4605 - precision: 0.5604 - recall: 0.1086 - auc: 0.6751 - true_positives: 40.3750 - true_negatives: 756.3750 - false_positives: 37.9583 - false_negatives: 356.7917 - val_loss: 21.5868 - val_accuracy: 0.4167 - val_precision: 0.4464 - val_recall: 0.1042 - val_auc: 0.6565 - val_true_positives: 25.0000 - val_true_negatives: 449.0000 - val_false_positives: 31.0000 - val_false_negatives: 215.0000
#
# Epoch 00002: val_precision did not improve from 0.52000
# Epoch 3/20
# 23/23 [==============================] - 62s 3s/step - loss: 34.3128 - accuracy: 0.3829 - precision: 0.4345 - recall: 0.0992 - auc: 0.6364 - true_positives: 38.0000 - true_negatives: 744.2917 - false_positives: 50.0417 - false_negatives: 359.1667 - val_loss: 18.7243 - val_accuracy: 0.3875 - val_precision: 0.4286 - val_recall: 0.1000 - val_auc: 0.6357 - val_true_positives: 24.0000 - val_true_negatives: 448.0000 - val_false_positives: 32.0000 - val_false_negatives: 216.0000
#
# Epoch 00003: val_precision did not improve from 0.52000
# Epoch 4/20
# 23/23 [==============================] - 61s 3s/step - loss: 17.6705 - accuracy: 0.3675 - precision: 0.4025 - recall: 0.0956 - auc: 0.6424 - true_positives: 37.4167 - true_negatives: 738.0417 - false_positives: 56.2917 - false_negatives: 359.7500 - val_loss: 18.2354 - val_accuracy: 0.3792 - val_precision: 0.4138 - val_recall: 0.1000 - val_auc: 0.6319 - val_true_positives: 24.0000 - val_true_negatives: 446.0000 - val_false_positives: 34.0000 - val_false_negatives: 216.0000
#
# Epoch 00004: val_precision did not improve from 0.52000
# Epoch 5/20
# 23/23 [==============================] - 63s 3s/step - loss: 23.1216 - accuracy: 0.3501 - precision: 0.4176 - recall: 0.1087 - auc: 0.6172 - true_positives: 38.2083 - true_negatives: 734.8333 - false_positives: 59.5000 - false_negatives: 358.9583 - val_loss: 17.6471 - val_accuracy: 0.3708 - val_precision: 0.4138 - val_recall: 0.1000 - val_auc: 0.6283 - val_true_positives: 24.0000 - val_true_negatives: 446.0000 - val_false_positives: 34.0000 - val_false_negatives: 216.0000
#
# Epoch 00005: val_precision did not improve from 0.52000
# Epoch 6/20
# 23/23 [==============================] - 62s 3s/step - loss: 21.2015 - accuracy: 0.3632 - precision: 0.3413 - recall: 0.0726 - auc: 0.6241 - true_positives: 30.9583 - true_negatives: 733.4583 - false_positives: 60.8750 - false_negatives: 366.2083 - val_loss: 17.5351 - val_accuracy: 0.3708 - val_precision: 0.4138 - val_recall: 0.1000 - val_auc: 0.6278 - val_true_positives: 24.0000 - val_true_negatives: 446.0000 - val_false_positives: 34.0000 - val_false_negatives: 216.0000
#
# Epoch 00006: val_precision did not improve from 0.52000
# Epoch 7/20
# 23/23 [==============================] - 63s 3s/step - loss: 23.1080 - accuracy: 0.3173 - precision: 0.2789 - recall: 0.0716 - auc: 0.5984 - true_positives: 31.0417 - true_negatives: 725.4167 - false_positives: 68.9167 - false_negatives: 366.1250 - val_loss: 17.4263 - val_accuracy: 0.3667 - val_precision: 0.4138 - val_recall: 0.1000 - val_auc: 0.6273 - val_true_positives: 24.0000 - val_true_negatives: 446.0000 - val_false_positives: 34.0000 - val_false_negatives: 216.0000
#
# Epoch 00007: val_precision did not improve from 0.52000
# Epoch 8/20
# 23/23 [==============================] - 81s 4s/step - loss: 22.7515 - accuracy: 0.3406 - precision: 0.3509 - recall: 0.0775 - auc: 0.6148 - true_positives: 31.2083 - true_negatives: 733.6250 - false_positives: 60.7083 - false_negatives: 365.9583 - val_loss: 17.3978 - val_accuracy: 0.3667 - val_precision: 0.4138 - val_recall: 0.1000 - val_auc: 0.6271 - val_true_positives: 24.0000 - val_true_negatives: 446.0000 - val_false_positives: 34.0000 - val_false_negatives: 216.0000
#
# Epoch 00008: val_precision did not improve from 0.52000
# Epoch 9/20
# 23/23 [==============================] - 79s 3s/step - loss: 18.3369 - accuracy: 0.3145 - precision: 0.3256 - recall: 0.0785 - auc: 0.6099 - true_positives: 32.1667 - true_negatives: 729.0833 - false_positives: 65.2500 - false_negatives: 365.0000 - val_loss: 17.3716 - val_accuracy: 0.3667 - val_precision: 0.4068 - val_recall: 0.1000 - val_auc: 0.6271 - val_true_positives: 24.0000 - val_true_negatives: 445.0000 - val_false_positives: 35.0000 - val_false_negatives: 216.0000
#
# Epoch 00009: val_precision did not improve from 0.52000
# Epoch 10/20
# 23/23 [==============================] - 69s 3s/step - loss: 23.2909 - accuracy: 0.3443 - precision: 0.3638 - recall: 0.0815 - auc: 0.6133 - true_positives: 32.7500 - true_negatives: 732.3333 - false_positives: 62.0000 - false_negatives: 364.4167 - val_loss: 17.3412 - val_accuracy: 0.3708 - val_precision: 0.4068 - val_recall: 0.1000 - val_auc: 0.6267 - val_true_positives: 24.0000 - val_true_negatives: 445.0000 - val_false_positives: 35.0000 - val_false_negatives: 216.0000
#
# Epoch 00010: val_precision did not improve from 0.52000
# Epoch 11/20
# 23/23 [==============================] - 76s 3s/step - loss: 24.0107 - accuracy: 0.3272 - precision: 0.3736 - recall: 0.0958 - auc: 0.6143 - true_positives: 36.7917 - true_negatives: 729.9167 - false_positives: 64.4167 - false_negatives: 360.3750 - val_loss: 17.3143 - val_accuracy: 0.3708 - val_precision: 0.4068 - val_recall: 0.1000 - val_auc: 0.6263 - val_true_positives: 24.0000 - val_true_negatives: 445.0000 - val_false_positives: 35.0000 - val_false_negatives: 216.0000
#
# Epoch 00011: val_precision did not improve from 0.52000
# Epoch 12/20
# 23/23 [==============================] - 66s 3s/step - loss: 19.5849 - accuracy: 0.3288 - precision: 0.3184 - recall: 0.0729 - auc: 0.6130 - true_positives: 30.0833 - true_negatives: 733.7500 - false_positives: 60.5833 - false_negatives: 367.0833 - val_loss: 17.2870 - val_accuracy: 0.3708 - val_precision: 0.4068 - val_recall: 0.1000 - val_auc: 0.6260 - val_true_positives: 24.0000 - val_true_negatives: 445.0000 - val_false_positives: 35.0000 - val_false_negatives: 216.0000
#
# Epoch 00012: val_precision did not improve from 0.52000
# Epoch 13/20
# 23/23 [==============================] - 73s 3s/step - loss: 22.0339 - accuracy: 0.3041 - precision: 0.3618 - recall: 0.0832 - auc: 0.6035 - true_positives: 31.7500 - true_negatives: 734.5833 - false_positives: 59.7500 - false_negatives: 365.4167 - val_loss: 17.2595 - val_accuracy: 0.3708 - val_precision: 0.4068 - val_recall: 0.1000 - val_auc: 0.6258 - val_true_positives: 24.0000 - val_true_negatives: 445.0000 - val_false_positives: 35.0000 - val_false_negatives: 216.0000
#
# Epoch 00013: val_precision did not improve from 0.52000
# Epoch 14/20
# 23/23 [==============================] - 64s 3s/step - loss: 21.2523 - accuracy: 0.3527 - precision: 0.3543 - recall: 0.0909 - auc: 0.6184 - true_positives: 33.6250 - true_negatives: 728.3333 - false_positives: 66.0000 - false_negatives: 363.5417 - val_loss: 17.2302 - val_accuracy: 0.3667 - val_precision: 0.4000 - val_recall: 0.1000 - val_auc: 0.6256 - val_true_positives: 24.0000 - val_true_negatives: 444.0000 - val_false_positives: 36.0000 - val_false_negatives: 216.0000
#
# Epoch 00014: val_precision did not improve from 0.52000
# Epoch 15/20
# 23/23 [==============================] - 65s 3s/step - loss: 22.3315 - accuracy: 0.3190 - precision: 0.3148 - recall: 0.0809 - auc: 0.6186 - true_positives: 32.8750 - true_negatives: 726.2500 - false_positives: 68.0833 - false_negatives: 364.2917 - val_loss: 17.2038 - val_accuracy: 0.3667 - val_precision: 0.4000 - val_recall: 0.1000 - val_auc: 0.6253 - val_true_positives: 24.0000 - val_true_negatives: 444.0000 - val_false_positives: 36.0000 - val_false_negatives: 216.0000
#
# Epoch 00015: val_precision did not improve from 0.52000
# Epoch 16/20
# 23/23 [==============================] - 73s 3s/step - loss: 17.5943 - accuracy: 0.3300 - precision: 0.3394 - recall: 0.0879 - auc: 0.6191 - true_positives: 33.6250 - true_negatives: 726.5417 - false_positives: 67.7917 - false_negatives: 363.5417 - val_loss: 17.1759 - val_accuracy: 0.3667 - val_precision: 0.3934 - val_recall: 0.1000 - val_auc: 0.6251 - val_true_positives: 24.0000 - val_true_negatives: 443.0000 - val_false_positives: 37.0000 - val_false_negatives: 216.0000
#
# Epoch 00016: val_precision did not improve from 0.52000
# Epoch 17/20
# 23/23 [==============================] - 73s 3s/step - loss: 22.2436 - accuracy: 0.3484 - precision: 0.3212 - recall: 0.0903 - auc: 0.6203 - true_positives: 34.6250 - true_negatives: 724.0417 - false_positives: 70.2917 - false_negatives: 362.5417 - val_loss: 17.1458 - val_accuracy: 0.3667 - val_precision: 0.3934 - val_recall: 0.1000 - val_auc: 0.6248 - val_true_positives: 24.0000 - val_true_negatives: 443.0000 - val_false_positives: 37.0000 - val_false_negatives: 216.0000
#
# Epoch 00017: val_precision did not improve from 0.52000
# Epoch 18/20
# 23/23 [==============================] - 67s 3s/step - loss: 20.7624 - accuracy: 0.3274 - precision: 0.2976 - recall: 0.0691 - auc: 0.6060 - true_positives: 30.2500 - true_negatives: 728.4583 - false_positives: 65.8750 - false_negatives: 366.9167 - val_loss: 17.1200 - val_accuracy: 0.3667 - val_precision: 0.3934 - val_recall: 0.1000 - val_auc: 0.6247 - val_true_positives: 24.0000 - val_true_negatives: 443.0000 - val_false_positives: 37.0000 - val_false_negatives: 216.0000
#
# Epoch 00018: val_precision did not improve from 0.52000
# Epoch 19/20
# 23/23 [==============================] - 68s 3s/step - loss: 17.6249 - accuracy: 0.3360 - precision: 0.2954 - recall: 0.0725 - auc: 0.6110 - true_positives: 30.7917 - true_negatives: 725.5000 - false_positives: 68.8333 - false_negatives: 366.3750 - val_loss: 17.0893 - val_accuracy: 0.3667 - val_precision: 0.3934 - val_recall: 0.1000 - val_auc: 0.6245 - val_true_positives: 24.0000 - val_true_negatives: 443.0000 - val_false_positives: 37.0000 - val_false_negatives: 216.0000
#
# Epoch 00019: val_precision did not improve from 0.52000
# Epoch 20/20
# 23/23 [==============================] - 68s 3s/step - loss: 21.9251 - accuracy: 0.3345 - precision: 0.3112 - recall: 0.0792 - auc: 0.6126 - true_positives: 32.0000 - true_negatives: 726.7500 - false_positives: 67.5833 - false_negatives: 365.1667 - val_loss: 17.0620 - val_accuracy: 0.3667 - val_precision: 0.3934 - val_recall: 0.1000 - val_auc: 0.6243 - val_true_positives: 24.0000 - val_true_negatives: 443.0000 - val_false_positives: 37.0000 - val_false_negatives: 216.0000
#
# Epoch 00020: val_precision did not improve from 0.52000
# Scores for fold 3:
# loss of 1.8159441947937012
# accuracy of 0.42990654706954956
# precision of 0.625
# recall of 0.14018692076206207
# auc of 0.7034238576889038
# true_positives of 15.0
# true_negatives of 205.0
# false_positives of 9.0
# ------------------------------------------------------------------------
#
# Training for fold 4 ...
# Epoch 1/20
# 23/23 [==============================] - 73s 3s/step - loss: 10.3134 - accuracy: 0.1127 - precision: 0.2484 - recall: 0.3133 - auc: 0.4511 - true_positives: 215.0833 - true_negatives: 609.2083 - false_positives: 665.1250 - false_negatives: 422.0833 - val_loss: 6.4514 - val_accuracy: 0.1167 - val_precision: 0.2490 - val_recall: 0.5292 - val_auc: 0.3167 - val_true_positives: 127.0000 - val_true_negatives: 97.0000 - val_false_positives: 383.0000 - val_false_negatives: 113.0000
#
# Epoch 00001: val_precision improved from -inf to 0.24902, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 2/20
# 23/23 [==============================] - 67s 3s/step - loss: 8.4577 - accuracy: 0.1153 - precision: 0.2353 - recall: 0.4885 - auc: 0.3130 - true_positives: 200.6667 - true_negatives: 161.5833 - false_positives: 632.7500 - false_negatives: 196.5000 - val_loss: 4.8858 - val_accuracy: 0.1292 - val_precision: 0.2554 - val_recall: 0.5458 - val_auc: 0.3317 - val_true_positives: 131.0000 - val_true_negatives: 98.0000 - val_false_positives: 382.0000 - val_false_negatives: 109.0000
#
# Epoch 00002: val_precision improved from 0.24902 to 0.25536, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 3/20
# 23/23 [==============================] - 86s 4s/step - loss: 6.4152 - accuracy: 0.1424 - precision: 0.2530 - recall: 0.5461 - auc: 0.3425 - true_positives: 214.5417 - true_negatives: 158.7917 - false_positives: 635.5417 - false_negatives: 182.6250 - val_loss: 4.0116 - val_accuracy: 0.1375 - val_precision: 0.2640 - val_recall: 0.5708 - val_auc: 0.3424 - val_true_positives: 137.0000 - val_true_negatives: 98.0000 - val_false_positives: 382.0000 - val_false_negatives: 103.0000
#
# Epoch 00003: val_precision improved from 0.25536 to 0.26397, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 4/20
# 23/23 [==============================] - 63s 3s/step - loss: 3.5656 - accuracy: 0.1284 - precision: 0.2593 - recall: 0.5542 - auc: 0.3511 - true_positives: 225.5000 - true_negatives: 164.6667 - false_positives: 629.6667 - false_negatives: 171.6667 - val_loss: 3.3374 - val_accuracy: 0.1500 - val_precision: 0.2689 - val_recall: 0.5917 - val_auc: 0.3545 - val_true_positives: 142.0000 - val_true_negatives: 94.0000 - val_false_positives: 386.0000 - val_false_negatives: 98.0000
#
# Epoch 00004: val_precision improved from 0.26397 to 0.26894, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 5/20
# 23/23 [==============================] - 63s 3s/step - loss: 3.7299 - accuracy: 0.1318 - precision: 0.2695 - recall: 0.5787 - auc: 0.3616 - true_positives: 236.5000 - true_negatives: 169.1250 - false_positives: 625.2083 - false_negatives: 160.6667 - val_loss: 2.9393 - val_accuracy: 0.1667 - val_precision: 0.2775 - val_recall: 0.6208 - val_auc: 0.3668 - val_true_positives: 149.0000 - val_true_negatives: 92.0000 - val_false_positives: 388.0000 - val_false_negatives: 91.0000
#
# Epoch 00005: val_precision improved from 0.26894 to 0.27747, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 6/20
# 23/23 [==============================] - 67s 3s/step - loss: 2.8622 - accuracy: 0.1481 - precision: 0.2788 - recall: 0.6226 - auc: 0.3632 - true_positives: 251.2917 - true_negatives: 154.2500 - false_positives: 640.0833 - false_negatives: 145.8750 - val_loss: 2.7937 - val_accuracy: 0.1875 - val_precision: 0.2836 - val_recall: 0.6417 - val_auc: 0.3768 - val_true_positives: 154.0000 - val_true_negatives: 91.0000 - val_false_positives: 389.0000 - val_false_negatives: 86.0000
#
# Epoch 00006: val_precision improved from 0.27747 to 0.28361, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 7/20
# 23/23 [==============================] - 71s 3s/step - loss: 3.4051 - accuracy: 0.1589 - precision: 0.2892 - recall: 0.6737 - auc: 0.3734 - true_positives: 266.2500 - true_negatives: 141.5833 - false_positives: 652.7500 - false_negatives: 130.9167 - val_loss: 2.6951 - val_accuracy: 0.2125 - val_precision: 0.2836 - val_recall: 0.6500 - val_auc: 0.3872 - val_true_positives: 156.0000 - val_true_negatives: 86.0000 - val_false_positives: 394.0000 - val_false_negatives: 84.0000
#
# Epoch 00007: val_precision improved from 0.28361 to 0.28364, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 8/20
# 23/23 [==============================] - 65s 3s/step - loss: 2.7001 - accuracy: 0.1723 - precision: 0.2985 - recall: 0.6866 - auc: 0.4112 - true_positives: 271.2917 - true_negatives: 151.0833 - false_positives: 643.2500 - false_negatives: 125.8750 - val_loss: 2.6091 - val_accuracy: 0.2292 - val_precision: 0.2883 - val_recall: 0.6667 - val_auc: 0.4007 - val_true_positives: 160.0000 - val_true_negatives: 85.0000 - val_false_positives: 395.0000 - val_false_negatives: 80.0000
#
# Epoch 00008: val_precision improved from 0.28364 to 0.28829, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 9/20
# 23/23 [==============================] - 71s 3s/step - loss: 1.8811 - accuracy: 0.1961 - precision: 0.2919 - recall: 0.6796 - auc: 0.4058 - true_positives: 271.6250 - true_negatives: 140.1250 - false_positives: 654.2083 - false_negatives: 125.5417 - val_loss: 2.5159 - val_accuracy: 0.2375 - val_precision: 0.2923 - val_recall: 0.6833 - val_auc: 0.4132 - val_true_positives: 164.0000 - val_true_negatives: 83.0000 - val_false_positives: 397.0000 - val_false_negatives: 76.0000
#
# Epoch 00009: val_precision improved from 0.28829 to 0.29234, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 10/20
# 23/23 [==============================] - 72s 3s/step - loss: 1.9299 - accuracy: 0.2164 - precision: 0.3011 - recall: 0.7155 - auc: 0.4222 - true_positives: 281.5833 - true_negatives: 133.6667 - false_positives: 660.6667 - false_negatives: 115.5833 - val_loss: 2.4412 - val_accuracy: 0.2458 - val_precision: 0.3002 - val_recall: 0.7042 - val_auc: 0.4244 - val_true_positives: 169.0000 - val_true_negatives: 86.0000 - val_false_positives: 394.0000 - val_false_negatives: 71.0000
#
# Epoch 00010: val_precision improved from 0.29234 to 0.30018, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 11/20
# 23/23 [==============================] - 73s 3s/step - loss: 2.1655 - accuracy: 0.2315 - precision: 0.3050 - recall: 0.7336 - auc: 0.4224 - true_positives: 293.8333 - true_negatives: 133.4167 - false_positives: 660.9167 - false_negatives: 103.3333 - val_loss: 2.3514 - val_accuracy: 0.2583 - val_precision: 0.3027 - val_recall: 0.7125 - val_auc: 0.4345 - val_true_positives: 171.0000 - val_true_negatives: 86.0000 - val_false_positives: 394.0000 - val_false_negatives: 69.0000
# Epoch 00011: val_precision improved from 0.30018 to 0.30265, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 12/20
# 23/23 [==============================] - 71s 3s/step - loss: 2.0359 - accuracy: 0.2617 - precision: 0.3031 - recall: 0.7373 - auc: 0.4477 - true_positives: 291.9583 - true_negatives: 126.1250 - false_positives: 668.2083 - false_negatives: 105.2083 - val_loss: 2.2864 - val_accuracy: 0.2958 - val_precision: 0.3047 - val_recall: 0.7250 - val_auc: 0.4440 - val_true_positives: 174.0000 - val_true_negatives: 83.0000 - val_false_positives: 397.0000 - val_false_negatives: 66.0000
#
# Epoch 00012: val_precision improved from 0.30265 to 0.30473, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 13/20
# 23/23 [==============================] - 79s 3s/step - loss: 1.8994 - accuracy: 0.2948 - precision: 0.3103 - recall: 0.7419 - auc: 0.4654 - true_positives: 296.5833 - true_negatives: 131.3750 - false_positives: 662.9583 - false_negatives: 100.5833 - val_loss: 2.2166 - val_accuracy: 0.3083 - val_precision: 0.3059 - val_recall: 0.7292 - val_auc: 0.4553 - val_true_positives: 175.0000 - val_true_negatives: 83.0000 - val_false_positives: 397.0000 - val_false_negatives: 65.0000
#
# Epoch 00013: val_precision improved from 0.30473 to 0.30594, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 14/20
# 23/23 [==============================] - 77s 3s/step - loss: 1.9558 - accuracy: 0.3053 - precision: 0.3117 - recall: 0.7691 - auc: 0.4605 - true_positives: 305.1250 - true_negatives: 124.7917 - false_positives: 669.5417 - false_negatives: 92.0417 - val_loss: 2.1384 - val_accuracy: 0.3250 - val_precision: 0.3089 - val_recall: 0.7375 - val_auc: 0.4661 - val_true_positives: 177.0000 - val_true_negatives: 84.0000 - val_false_positives: 396.0000 - val_false_negatives: 63.0000
#
# Epoch 00014: val_precision improved from 0.30594 to 0.30890, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 15/20
# 23/23 [==============================] - 63s 3s/step - loss: 1.8102 - accuracy: 0.3143 - precision: 0.3215 - recall: 0.7810 - auc: 0.4717 - true_positives: 310.2500 - true_negatives: 138.6250 - false_positives: 655.7083 - false_negatives: 86.9167 - val_loss: 2.0661 - val_accuracy: 0.3417 - val_precision: 0.3131 - val_recall: 0.7542 - val_auc: 0.4770 - val_true_positives: 181.0000 - val_true_negatives: 83.0000 - val_false_positives: 397.0000 - val_false_negatives: 59.0000
#
# Epoch 00015: val_precision improved from 0.30890 to 0.31315, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 16/20
# 23/23 [==============================] - 68s 3s/step - loss: 1.6833 - accuracy: 0.3651 - precision: 0.3261 - recall: 0.8006 - auc: 0.5025 - true_positives: 314.2917 - true_negatives: 139.2083 - false_positives: 655.1250 - false_negatives: 82.8750 - val_loss: 1.9955 - val_accuracy: 0.3583 - val_precision: 0.3201 - val_recall: 0.7750 - val_auc: 0.4891 - val_true_positives: 186.0000 - val_true_negatives: 85.0000 - val_false_positives: 395.0000 - val_false_negatives: 54.0000
#
# Epoch 00016: val_precision improved from 0.31315 to 0.32014, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 17/20
# 23/23 [==============================] - 72s 3s/step - loss: 1.5779 - accuracy: 0.3233 - precision: 0.3224 - recall: 0.7896 - auc: 0.4779 - true_positives: 312.0000 - true_negatives: 139.0833 - false_positives: 655.2500 - false_negatives: 85.1667 - val_loss: 1.9301 - val_accuracy: 0.3583 - val_precision: 0.3236 - val_recall: 0.7833 - val_auc: 0.5001 - val_true_positives: 188.0000 - val_true_negatives: 87.0000 - val_false_positives: 393.0000 - val_false_negatives: 52.0000
#
# Epoch 00017: val_precision improved from 0.32014 to 0.32358, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 18/20
# 23/23 [==============================] - 73s 3s/step - loss: 1.4511 - accuracy: 0.3405 - precision: 0.3258 - recall: 0.8019 - auc: 0.4931 - true_positives: 319.5417 - true_negatives: 143.1250 - false_positives: 651.2083 - false_negatives: 77.6250 - val_loss: 1.8756 - val_accuracy: 0.3750 - val_precision: 0.3282 - val_recall: 0.8000 - val_auc: 0.5116 - val_true_positives: 192.0000 - val_true_negatives: 87.0000 - val_false_positives: 393.0000 - val_false_negatives: 48.0000
#
# Epoch 00018: val_precision improved from 0.32358 to 0.32821, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 19/20
# 23/23 [==============================] - 80s 4s/step - loss: 1.8057 - accuracy: 0.3535 - precision: 0.3352 - recall: 0.8254 - auc: 0.5182 - true_positives: 328.4583 - true_negatives: 146.9583 - false_positives: 647.3750 - false_negatives: 68.7083 - val_loss: 1.8181 - val_accuracy: 0.3792 - val_precision: 0.3299 - val_recall: 0.8000 - val_auc: 0.5203 - val_true_positives: 192.0000 - val_true_negatives: 90.0000 - val_false_positives: 390.0000 - val_false_negatives: 48.0000
#
# Epoch 00019: val_precision improved from 0.32821 to 0.32990, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_4.h5
# Epoch 20/20
# 23/23 [==============================] - 105s 5s/step - loss: 1.3717 - accuracy: 0.3615 - precision: 0.3392 - recall: 0.8354 - auc: 0.5238 - true_positives: 330.7917 - true_negatives: 150.6667 - false_positives: 643.6667 - false_negatives: 66.3750 - val_loss: 1.7688 - val_accuracy: 0.3875 - val_precision: 0.3294 - val_recall: 0.8042 - val_auc: 0.5296 - val_true_positives: 193.0000 - val_true_negatives: 87.0000 - val_false_positives: 393.0000 - val_false_negatives: 47.0000
#
# Epoch 00020: val_precision did not improve from 0.32990
# Scores for fold 4:
# loss of 1.4916408061981201
# accuracy of 0.29906541109085083
# precision of 0.3197025954723358
# recall of 0.8037382960319519
# auc of 0.48026028275489807
# true_positives of 86.0
# true_negatives of 31.0
# false_positives of 183.0
# ------------------------------------------------------------------------
#
# Training for fold 5 ...
# Epoch 1/20
# 23/23 [==============================] - 150s 6s/step - loss: 46.7519 - accuracy: 0.4749 - precision: 0.3752 - recall: 0.7416 - auc: 0.5773 - true_positives: 469.1667 - true_negatives: 508.2083 - false_positives: 766.1250 - false_negatives: 168.0000 - val_loss: 35.1229 - val_accuracy: 0.4792 - val_precision: 0.4151 - val_recall: 0.7333 - val_auc: 0.5993 - val_true_positives: 176.0000 - val_true_negatives: 232.0000 - val_false_positives: 248.0000 - val_false_negatives: 64.0000
#
# Epoch 00001: val_precision improved from -inf to 0.41509, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_5.h5
# Epoch 2/20
# ...
#
# Epoch 00014: val_precision did not improve from 0.20548
# Epoch 15/20
# 23/23 [==============================] - 121s 5s/step - loss: 6.7855 - accuracy: 0.1779 - precision: 0.2065 - recall: 0.0756 - auc: 0.3745 - true_positives: 33.3750 - true_negatives: 683.6667 - false_positives: 110.8333 - false_negatives: 363.8750 - val_loss: 7.9011 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3265 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00015: val_precision did not improve from 0.20548
# Epoch 16/20
# 23/23 [==============================] - 122s 5s/step - loss: 7.9198 - accuracy: 0.1451 - precision: 0.2423 - recall: 0.0907 - auc: 0.3751 - true_positives: 33.2917 - true_negatives: 687.6250 - false_positives: 106.8750 - false_negatives: 363.9583 - val_loss: 7.8961 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3265 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00016: val_precision did not improve from 0.20548
# Epoch 17/20
# 23/23 [==============================] - 120s 5s/step - loss: 7.4932 - accuracy: 0.1803 - precision: 0.2312 - recall: 0.0761 - auc: 0.3808 - true_positives: 30.8750 - true_negatives: 684.5417 - false_positives: 109.9583 - false_negatives: 366.3750 - val_loss: 7.8914 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3266 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00017: val_precision did not improve from 0.20548
# Epoch 18/20
# 23/23 [==============================] - 121s 5s/step - loss: 7.5533 - accuracy: 0.1575 - precision: 0.2576 - recall: 0.0883 - auc: 0.3784 - true_positives: 33.1250 - true_negatives: 694.0833 - false_positives: 100.4167 - false_negatives: 364.1250 - val_loss: 7.8864 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3267 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00018: val_precision did not improve from 0.20548
# Epoch 19/20
# 23/23 [==============================] - 124s 5s/step - loss: 6.8155 - accuracy: 0.1627 - precision: 0.2120 - recall: 0.0721 - auc: 0.3846 - true_positives: 30.8750 - true_negatives: 689.4167 - false_positives: 105.0833 - false_negatives: 366.3750 - val_loss: 7.8816 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3266 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00019: val_precision did not improve from 0.20548
# Epoch 20/20
# 23/23 [==============================] - 122s 5s/step - loss: 5.1909 - accuracy: 0.1664 - precision: 0.2793 - recall: 0.0943 - auc: 0.3854 - true_positives: 37.3333 - true_negatives: 692.7917 - false_positives: 101.7083 - false_negatives: 359.9167 - val_loss: 7.8768 - val_accuracy: 0.1417 - val_precision: 0.2000 - val_recall: 0.0625 - val_auc: 0.3266 - val_true_positives: 15.0000 - val_true_negatives: 420.0000 - val_false_positives: 60.0000 - val_false_negatives: 225.0000
#
# Epoch 00020: val_precision did not improve from 0.20548
# Scores for fold 9:
# loss of 2.6972384452819824
# accuracy of 0.16981132328510284
# precision of 0.34285715222358704
# recall of 0.11320754885673523
# auc of 0.40285685658454895
# true_positives of 12.0
# true_negatives of 189.0
# false_positives of 23.0
# ------------------------------------------------------------------------
#
# Training for fold 10 ...
# Epoch 1/20
# 23/23 [==============================] - 139s 6s/step - loss: 9.0940 - accuracy: 0.2526 - precision: 0.3070 - recall: 0.2686 - auc: 0.4434 - true_positives: 184.7500 - true_negatives: 869.6667 - false_positives: 404.8333 - false_negatives: 452.5000 - val_loss: 10.4219 - val_accuracy: 0.2750 - val_precision: 0.3366 - val_recall: 0.4250 - val_auc: 0.5008 - val_true_positives: 102.0000 - val_true_negatives: 279.0000 - val_false_positives: 201.0000 - val_false_negatives: 138.0000
#
# Epoch 00001: val_precision improved from -inf to 0.33663, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 2/20
# 23/23 [==============================] - 121s 5s/step - loss: 8.2859 - accuracy: 0.2990 - precision: 0.3391 - recall: 0.4421 - auc: 0.5084 - true_positives: 177.7083 - true_negatives: 456.0833 - false_positives: 338.4167 - false_negatives: 219.5417 - val_loss: 9.6924 - val_accuracy: 0.3250 - val_precision: 0.3729 - val_recall: 0.4708 - val_auc: 0.5253 - val_true_positives: 113.0000 - val_true_negatives: 290.0000 - val_false_positives: 190.0000 - val_false_negatives: 127.0000
#
# Epoch 00002: val_precision improved from 0.33663 to 0.37294, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 3/20
# 23/23 [==============================] - 121s 5s/step - loss: 7.8446 - accuracy: 0.3408 - precision: 0.3808 - recall: 0.4878 - auc: 0.5467 - true_positives: 193.3333 - true_negatives: 478.5833 - false_positives: 315.9167 - false_negatives: 203.9167 - val_loss: 8.9621 - val_accuracy: 0.3542 - val_precision: 0.3758 - val_recall: 0.4792 - val_auc: 0.5440 - val_true_positives: 115.0000 - val_true_negatives: 289.0000 - val_false_positives: 191.0000 - val_false_negatives: 125.0000
#
# Epoch 00003: val_precision improved from 0.37294 to 0.37582, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 4/20
# 23/23 [==============================] - 121s 5s/step - loss: 7.6599 - accuracy: 0.3788 - precision: 0.3988 - recall: 0.4922 - auc: 0.5615 - true_positives: 195.1250 - true_negatives: 492.6667 - false_positives: 301.8333 - false_negatives: 202.1250 - val_loss: 8.2463 - val_accuracy: 0.3583 - val_precision: 0.3816 - val_recall: 0.4833 - val_auc: 0.5571 - val_true_positives: 116.0000 - val_true_negatives: 292.0000 - val_false_positives: 188.0000 - val_false_negatives: 124.0000
#
# Epoch 00004: val_precision improved from 0.37582 to 0.38158, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 5/20
# 23/23 [==============================] - 116s 5s/step - loss: 7.1300 - accuracy: 0.4112 - precision: 0.4008 - recall: 0.5275 - auc: 0.5883 - true_positives: 210.0417 - true_negatives: 488.5000 - false_positives: 306.0000 - false_negatives: 187.2083 - val_loss: 7.5959 - val_accuracy: 0.3833 - val_precision: 0.3836 - val_recall: 0.4875 - val_auc: 0.5700 - val_true_positives: 117.0000 - val_true_negatives: 292.0000 - val_false_positives: 188.0000 - val_false_negatives: 123.0000
#
# Epoch 00005: val_precision improved from 0.38158 to 0.38361, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 6/20
# 23/23 [==============================] - 111s 5s/step - loss: 6.7967 - accuracy: 0.4295 - precision: 0.4243 - recall: 0.5469 - auc: 0.6126 - true_positives: 214.2083 - true_negatives: 499.9167 - false_positives: 294.5833 - false_negatives: 183.0417 - val_loss: 6.8835 - val_accuracy: 0.4167 - val_precision: 0.3885 - val_recall: 0.5083 - val_auc: 0.5805 - val_true_positives: 122.0000 - val_true_negatives: 288.0000 - val_false_positives: 192.0000 - val_false_negatives: 118.0000
#
# Epoch 00006: val_precision improved from 0.38361 to 0.38854, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 7/20
# 23/23 [==============================] - 120s 5s/step - loss: 5.0832 - accuracy: 0.4229 - precision: 0.4228 - recall: 0.5280 - auc: 0.6072 - true_positives: 212.2500 - true_negatives: 505.3750 - false_positives: 289.1250 - false_negatives: 185.0000 - val_loss: 6.2409 - val_accuracy: 0.4167 - val_precision: 0.3892 - val_recall: 0.5125 - val_auc: 0.5865 - val_true_positives: 123.0000 - val_true_negatives: 287.0000 - val_false_positives: 193.0000 - val_false_negatives: 117.0000
#
# Epoch 00007: val_precision improved from 0.38854 to 0.38924, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 8/20
# 23/23 [==============================] - 119s 5s/step - loss: 6.1672 - accuracy: 0.4559 - precision: 0.4325 - recall: 0.5659 - auc: 0.6198 - true_positives: 221.2500 - true_negatives: 503.5000 - false_positives: 291.0000 - false_negatives: 176.0000 - val_loss: 5.6005 - val_accuracy: 0.3958 - val_precision: 0.3981 - val_recall: 0.5292 - val_auc: 0.5947 - val_true_positives: 127.0000 - val_true_negatives: 288.0000 - val_false_positives: 192.0000 - val_false_negatives: 113.0000
#
# Epoch 00008: val_precision improved from 0.38924 to 0.39812, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 9/20
# 23/23 [==============================] - 121s 5s/step - loss: 5.0949 - accuracy: 0.4283 - precision: 0.4299 - recall: 0.5662 - auc: 0.6195 - true_positives: 222.3333 - true_negatives: 498.9167 - false_positives: 295.5833 - false_negatives: 174.9167 - val_loss: 4.9971 - val_accuracy: 0.3917 - val_precision: 0.4000 - val_recall: 0.5417 - val_auc: 0.6001 - val_true_positives: 130.0000 - val_true_negatives: 285.0000 - val_false_positives: 195.0000 - val_false_negatives: 110.0000
#
# Epoch 00009: val_precision improved from 0.39812 to 0.40000, saving model to ../metricas/classificacao/7_d/tests/model/best_checkpoint_model_10.h5
# Epoch 10/20
# 23/23 [==============================] - 119s 5s/step - loss: 4.4438 - accuracy: 0.4089 - precision: 0.4389 - recall: 0.5823 - auc: 0.6276 - true_positives: 230.5833 - true_negatives: 499.4583 - false_positives: 295.0417 - false_negatives: 166.6667 - val_loss: 4.3974 - val_accuracy: 0.3833 - val_precision: 0.3958 - val_recall: 0.5458 - val_auc: 0.6068 - val_true_positives: 131.0000 - val_true_negatives: 280.0000 - val_false_positives: 200.0000 - val_false_negatives: 109.0000
#
# Epoch 00010: val_precision did not improve from 0.40000
# Epoch 11/20
# 23/23 [==============================] - 117s 5s/step - loss: 4.1500 - accuracy: 0.4297 - precision: 0.4451 - recall: 0.5767 - auc: 0.6469 - true_positives: 226.1250 - true_negatives: 505.2500 - false_positives: 289.2500 - false_negatives: 171.1250 - val_loss: 3.8488 - val_accuracy: 0.3708 - val_precision: 0.3940 - val_recall: 0.5500 - val_auc: 0.6110 - val_true_positives: 132.0000 - val_true_negatives: 277.0000 - val_false_positives: 203.0000 - val_false_negatives: 108.0000
#
# Epoch 00011: val_precision did not improve from 0.40000
# Epoch 12/20
# 23/23 [==============================] - 119s 5s/step - loss: 2.9136 - accuracy: 0.4067 - precision: 0.4453 - recall: 0.5840 - auc: 0.6453 - true_positives: 235.7083 - true_negatives: 501.8750 - false_positives: 292.6250 - false_negatives: 161.5417 - val_loss: 3.7498 - val_accuracy: 0.3708 - val_precision: 0.3994 - val_recall: 0.5542 - val_auc: 0.6122 - val_true_positives: 133.0000 - val_true_negatives: 280.0000 - val_false_positives: 200.0000 - val_false_negatives: 107.0000
#
# Epoch 00012: val_precision did not improve from 0.40000
# Epoch 13/20
# 23/23 [==============================] - 120s 5s/step - loss: 2.8347 - accuracy: 0.4176 - precision: 0.4464 - recall: 0.6035 - auc: 0.6441 - true_positives: 238.3750 - true_negatives: 495.6667 - false_positives: 298.8333 - false_negatives: 158.8750 - val_loss: 3.6495 - val_accuracy: 0.3667 - val_precision: 0.3958 - val_recall: 0.5542 - val_auc: 0.6131 - val_true_positives: 133.0000 - val_true_negatives: 277.0000 - val_false_positives: 203.0000 - val_false_negatives: 107.0000
#
# Epoch 00013: val_precision did not improve from 0.40000
# Epoch 14/20
# 23/23 [==============================] - 117s 5s/step - loss: 3.1126 - accuracy: 0.4388 - precision: 0.4408 - recall: 0.5892 - auc: 0.6444 - true_positives: 234.0417 - true_negatives: 498.2083 - false_positives: 296.2917 - false_negatives: 163.2083 - val_loss: 3.6281 - val_accuracy: 0.3708 - val_precision: 0.3958 - val_recall: 0.5542 - val_auc: 0.6135 - val_true_positives: 133.0000 - val_true_negatives: 277.0000 - val_false_positives: 203.0000 - val_false_negatives: 107.0000
#
# Epoch 00014: val_precision did not improve from 0.40000
# Epoch 15/20
# 23/23 [==============================] - 121s 5s/step - loss: 3.2302 - accuracy: 0.3970 - precision: 0.4492 - recall: 0.5964 - auc: 0.6468 - true_positives: 234.7083 - true_negatives: 498.7917 - false_positives: 295.7083 - false_negatives: 162.5417 - val_loss: 3.6082 - val_accuracy: 0.3708 - val_precision: 0.3958 - val_recall: 0.5542 - val_auc: 0.6138 - val_true_positives: 133.0000 - val_true_negatives: 277.0000 - val_false_positives: 203.0000 - val_false_negatives: 107.0000
# Epoch 00015: val_precision did not improve from 0.40000
# Epoch 16/20
# 23/23 [==============================] - 119s 5s/step - loss: 2.7203 - accuracy: 0.3767 - precision: 0.4440 - recall: 0.5923 - auc: 0.6434 - true_positives: 236.2917 - true_negatives: 499.2917 - false_positives: 295.2083 - false_negatives: 160.9583 - val_loss: 3.6027 - val_accuracy: 0.3708 - val_precision: 0.3958 - val_recall: 0.5542 - val_auc: 0.6138 - val_true_positives: 133.0000 - val_true_negatives: 277.0000 - val_false_positives: 203.0000 - val_false_negatives: 107.0000
#
# Epoch 00016: val_precision did not improve from 0.40000
# Epoch 17/20
# 23/23 [==============================] - 115s 5s/step - loss: 2.3269 - accuracy: 0.3947 - precision: 0.4327 - recall: 0.5797 - auc: 0.6415 - true_positives: 232.8333 - true_negatives: 495.2500 - false_positives: 299.2500 - false_negatives: 164.4167 - val_loss: 3.5980 - val_accuracy: 0.3708 - val_precision: 0.3947 - val_recall: 0.5542 - val_auc: 0.6138 - val_true_positives: 133.0000 - val_true_negatives: 276.0000 - val_false_positives: 204.0000 - val_false_negatives: 107.0000
#
# Epoch 00017: val_precision did not improve from 0.40000
# Epoch 18/20
# 23/23 [==============================] - 119s 5s/step - loss: 2.6180 - accuracy: 0.4173 - precision: 0.4421 - recall: 0.5937 - auc: 0.6431 - true_positives: 234.7500 - true_negatives: 497.1667 - false_positives: 297.3333 - false_negatives: 162.5000 - val_loss: 3.5926 - val_accuracy: 0.3708 - val_precision: 0.3947 - val_recall: 0.5542 - val_auc: 0.6141 - val_true_positives: 133.0000 - val_true_negatives: 276.0000 - val_false_positives: 204.0000 - val_false_negatives: 107.0000
#
# Epoch 00018: val_precision did not improve from 0.40000
# Epoch 19/20
# 23/23 [==============================] - 118s 5s/step - loss: 2.6976 - accuracy: 0.3929 - precision: 0.4325 - recall: 0.5742 - auc: 0.6373 - true_positives: 232.0000 - true_negatives: 494.7083 - false_positives: 299.7917 - false_negatives: 165.2500 - val_loss: 3.5875 - val_accuracy: 0.3667 - val_precision: 0.3947 - val_recall: 0.5542 - val_auc: 0.6142 - val_true_positives: 133.0000 - val_true_negatives: 276.0000 - val_false_positives: 204.0000 - val_false_negatives: 107.0000
#
# Epoch 00019: val_precision did not improve from 0.40000
# Epoch 20/20
# 23/23 [==============================] - 118s 5s/step - loss: 2.4983 - accuracy: 0.3943 - precision: 0.4383 - recall: 0.5970 - auc: 0.6407 - true_positives: 239.5417 - true_negatives: 492.2500 - false_positives: 302.2500 - false_negatives: 157.7083 - val_loss: 3.5822 - val_accuracy: 0.3667 - val_precision: 0.3964 - val_recall: 0.5583 - val_auc: 0.6142 - val_true_positives: 134.0000 - val_true_negatives: 276.0000 - val_false_positives: 204.0000 - val_false_negatives: 106.0000
#
# Epoch 00020: val_precision did not improve from 0.40000
# Scores for fold 10:
# loss of 2.246124744415283
# accuracy of 0.40566039085388184
# precision of 0.3986014127731323
# recall of 0.5377358198165894
# auc of 0.6036845445632935
# true_positives of 57.0
# true_negatives of 126.0
# false_positives of 86.0

# %% [markdown]
# ##### Loading the best model for testing

# %%
print("Acurácia média: ",np.mean(acc)/100)
print("Precisão média: ",np.mean(prec))
print("Recall médio: ",np.mean(rec))
print("Auc média: ",np.mean(auc))
# Out:
# Acurácia média:  0.3825251303613186
# Precisão média:  0.43734557926654816
# Recall médio:  0.4740521892905235
# Auc média:  0.571540454030037

# %% [markdown]
# ##### Testing the model

# %%
test_labels_1d = []
for label in test_labels:
    if (label == [1, 0, 0]).all():
        test_labels_1d.append(0)
    elif (label == [0, 1, 0]).all():
        test_labels_1d.append(1)
    else:
        test_labels_1d.append(2)

# %%
prediction = model.predict(test_images, batch_size=1)

prediction = tf.argmax(prediction, axis=-1)

# %%
import numpy as np
import matplotlib
import seaborn as sns

def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    ---------
    cf:            confusion matrix to be passed in
    group_names:   List of strings that represent the labels row by row to be shown in each square.
    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'
    count:         If True, show the raw number in the confusion matrix. Default is True.
    normalize:     If True, show the proportions for each category. Default is True.
    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.
    xyticks:       If True, show x and y ticks. Default is True.
    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.
    sum_stats:     If True, display summary statistics below the figure. Default is True.
    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.
    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html
                   
    title:         Title for the heatmap. Default is None.
    '''

    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)
    
    if title:
        plt.title(title)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

cm = metrics.confusion_matrix(test_labels_1d, prediction)

make_confusion_matrix(cm, figsize=(8,6), cbar=False)

# %%
print(metrics.classification_report(test_labels_1d, prediction, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.791     0.364     0.498       187
#            1      0.400     0.050     0.089        40
#            2      0.000     0.000     0.000        10
#
#     accuracy                          0.295       237
#    macro avg      0.397     0.138     0.196       237
# weighted avg      0.691     0.295     0.408       237

# %% [markdown]
# #### Visualizing model data
