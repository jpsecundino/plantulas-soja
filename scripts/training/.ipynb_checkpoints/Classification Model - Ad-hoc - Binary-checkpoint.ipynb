# %% [markdown]
# # Creating dataset

# %% [markdown]
# # Creating classification model

# %%
import os
import pickle
import numpy as np
import os
# import cv2
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import shutil
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# Using TensorFlow backend.

# %%
DATASET_PATH = '../../datasets/Classification/Dataset - 7 dias'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %% [markdown]
# ##### Read dataset

# %%
IMG_SIZE = 256
NUM_CLASSES = 2
def read_dataset():
    images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
    images = pickle.load(images_raw)

    labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
    labels = pickle.load(labels_raw)

    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels

# %% [markdown]
# ###### Turn it into a binary classification problem

# %%
def to_binary(labels):
    labels[labels == 2] = 1
    return labels

# %% [markdown]
# ###### Train Test split

# %%
def count_samples(train_labels, test_labels):
    print("In training:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')


def train_test_split(images, labels):

    from sklearn.model_selection import train_test_split

    train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.1, stratify=labels)
    
    print("In training:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')
        
    return train_images, test_images, train_labels, test_labels

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
# Trying class weights
# it does not work with one hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

def get_sample_weights(train_labels):
    from sklearn.utils import compute_sample_weight
    
    return compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
def to_one_hot(data):
    import pandas as pd
    data = pd.get_dummies(data)
    data = pd.DataFrame.to_numpy(data)
    return data

# %% [markdown]
# ##### Normalizing training images

# %%
def normalize_images(data):
    data = tf.keras.utils.normalize(data, axis=0, order=2)
    return data

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = None
TRAIN_TEST_SPLIT = None
BATCH_SIZE = None
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

METRICDIR = '../metricas/classificacao/7_d/tests-binary'

MODELDIR = os.path.join(METRICDIR, "adhoc")

CHECKPOINT_DIR = os.path.join(MODELDIR, "models") 

if os.path.exists(MODELDIR):
    shutil.rmtree(MODELDIR)
    os.makedirs(CHECKPOINT_DIR)
    
my_metrics = ["accuracy",
       tf.keras.metrics.Precision(),
       tf.keras.metrics.Recall(),
       tf.keras.metrics.AUC(),
       tf.keras.metrics.TruePositives(),
       tf.keras.metrics.TrueNegatives(),
       tf.keras.metrics.FalsePositives(),
       tf.keras.metrics.FalseNegatives(),]

# %%
def create_model():
       
    model = Sequential()

    model.add(   Conv2D(1, (3,3), input_shape=(IMG_SIZE,IMG_SIZE, 3))  )
    model.add(Activation("relu"))

#     model.add(Conv2D(4, (3,3)))
#     model.add(Dropout(rate=0.3))
#     model.add(Activation("relu"))
    
    model.add(Flatten())
    model.add(Dense(1))
    
    model.add(Activation("sigmoid"))
    
    opt = tf.keras.optimizers.Adam()
    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=my_metrics)
    
    return model

def get_model_name(k):
    return 'model_'+str(k)

def plot_metric(history,metric_name, chart_name, save_dir, save = False, show = False):
    plt.cla() 
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if save:
        plt.savefig(os.path.join(save_dir, metric_name))
    if show:
        plt.show()
        
def plot_cm(cf_matrix, save_dir, save):
    
    import seaborn as sns; sns.set_theme()
   
    group_names = ['True Pos','False Pos','False Neg','True Neg']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cf_matrix.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    
    plt.cla() 
    
    sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
    if save:
        plt.savefig(os.path.join(save_dir, "confusion matrix"))
    plt.show()

# %% [markdown]
# ##### Testing the model

# %%
def one_hot_to_1d(test_labels):
    
    test_labels_1d = []
    
    for label in test_labels:
        print()
        if (label == [1, 0]).all():
            test_labels_1d.append(0)
        elif (label == [0, 1]).all():
            test_labels_1d.append(1)
        else:
            test_labels_1d.append(2)
    
    return test_labels_1d
    
def get_predictions(model,test_images, test_labels):
    prediction = model.predict(test_images, batch_size=1)

    return tf.argmax(prediction, axis=-1)

# %%
def train_models(train_images, train_labels, num_folds=10):
    
    from sklearn.model_selection import StratifiedKFold
    
    kfold = StratifiedKFold(n_splits=num_folds)

    #metrics containers
    acc = []
    prec = []
    rec = []
    auc = []

    # K-fold Cross Validation model evaluation
    fold_no = 1
    for train, test in kfold.split(train_images, train_labels):

        count_samples(train_labels[train], train_labels[test])
        
#         from tf.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

        if fold_no - 1 == 0:
            idx_str = ""
        else:
            idx_str = f"_{fold_no}"
            
        fold_checkpoint_dir = os.path.join(CHECKPOINT_DIR, get_model_name(fold_no))
        
        if not os.path.exists(fold_checkpoint_dir):
            os.makedirs(fold_checkpoint_dir)
        
#         my_callbacks = [
# #             ModelCheckpoint(os.path.join(fold_checkpoint_dir,"model.h5"), monitor=f"val_precision", verbose=1, save_best_only=True, mode='max', save_freq='epoch'),
#             ReduceLROnPlateau(monitor=f'loss', factor=0.7, patience=2, min_lr=0.00000000001, mode='min'),
#         ]

        model = create_model()

        # Generate a print
        print('------------------------------------------------------------------------', end="\n\n")
        print(f'Training for fold {fold_no} ...')

#         # Fit data to model
#         history = model.fit(
#             train_images[train],
#             train_labels[train],
#             batch_size = BATCH_SIZE,
#             epochs = EPOCHS,
#             validation_split=TRAIN_TEST_SPLIT,
#             sample_weight=get_sample_weights(train_labels[train]),
#             callbacks=[my_callbacks])
        # Fit data to model
        history = model.fit(
            train_images[train],
            train_labels[train],
            batch_size = BATCH_SIZE,
            epochs = EPOCHS,
            validation_split=TRAIN_TEST_SPLIT,
            sample_weight=get_sample_weights(train_labels[train]))
        
        thresh = 0.5
        
        prediction = model.predict(train_images[test], batch_size=1)
        prediction[prediction > thresh] = 1
        prediction[prediction <= thresh] = 0
        
        cm = metrics.confusion_matrix(train_labels[test],prediction )
        
        plot_cm(cm, save_dir=fold_checkpoint_dir, save=True)
        
        #visualizing training
        NUM_METRICS = len(my_metrics) + 1
        for metric in list(history.history.keys())[:NUM_METRICS]:
            plot_metric(history, metric, metric + " for soybean classification", save_dir=fold_checkpoint_dir, save=True)

        # Generate generalization metrics
        scores = model.evaluate(images[test], labels[test], verbose=0)
        print(f'Scores for fold {fold_no}:')
        for i in range(len(my_metrics)):   
            print(f'{model.metrics_names[i]} of {scores[i]}')

        acc.append(scores[1])
        prec.append(scores[2])
        rec.append(scores[3])
        auc.append(scores[4])

        # Increase fold number
        fold_no = fold_no + 1
        
    return acc, prec, rec, auc

# %% [markdown]
# ##### Training

# %%
images, labels = read_dataset()

images = normalize_images(images)
labels = to_binary(labels)

# %%
EPOCHS = 10
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
acc, prec, rec, auc = train_models(images, labels)
# Out:
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 1 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 0.6175 - accuracy: 0.4386 - precision: 0.2612 - recall: 0.8779 - auc: 0.7662 - true_positives: 151.0000 - true_negatives: 199.0000 - false_positives: 427.0000 - false_negatives: 21.0000 - val_loss: 0.5276 - val_accuracy: 0.3858 - val_precision: 0.2383 - val_recall: 0.9808 - val_auc: 0.9349 - val_true_positives: 51.0000 - val_true_negatives: 52.0000 - val_false_positives: 163.0000 - val_false_negatives: 1.0000
# Epoch 2/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.4951 - accuracy: 0.5100 - precision: 0.3048 - recall: 0.9942 - auc: 0.9484 - true_positives: 171.0000 - true_negatives: 236.0000 - false_positives: 390.0000 - false_negatives: 1.0000 - val_loss: 0.4258 - val_accuracy: 0.7453 - val_precision: 0.4310 - val_recall: 0.9615 - val_auc: 0.9477 - val_true_positives: 50.0000 - val_true_negatives: 149.0000 - val_false_positives: 66.0000 - val_false_negatives: 2.0000
# Epoch 3/10
# 798/798 [==============================] - 1s 977us/sample - loss: 0.3907 - accuracy: 0.8346 - precision: 0.5735 - recall: 0.9070 - auc: 0.9428 - true_positives: 156.0000 - true_negatives: 510.0000 - false_positives: 116.0000 - false_negatives: 16.0000 - val_loss: 0.3389 - val_accuracy: 0.8652 - val_precision: 0.6053 - val_recall: 0.8846 - val_auc: 0.9418 - val_true_positives: 46.0000 - val_true_negatives: 185.0000 - val_false_positives: 30.0000 - val_false_negatives: 6.0000
# Epoch 4/10
# 798/798 [==============================] - 1s 951us/sample - loss: 0.2987 - accuracy: 0.8835 - precision: 0.6681 - recall: 0.9128 - auc: 0.9641 - true_positives: 157.0000 - true_negatives: 548.0000 - false_positives: 78.0000 - false_negatives: 15.0000 - val_loss: 0.3200 - val_accuracy: 0.8951 - val_precision: 0.7000 - val_recall: 0.8077 - val_auc: 0.9245 - val_true_positives: 42.0000 - val_true_negatives: 197.0000 - val_false_positives: 18.0000 - val_false_negatives: 10.0000
# Epoch 5/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.2398 - accuracy: 0.9073 - precision: 0.7269 - recall: 0.9128 - auc: 0.9772 - true_positives: 157.0000 - true_negatives: 567.0000 - false_positives: 59.0000 - false_negatives: 15.0000 - val_loss: 0.3021 - val_accuracy: 0.8277 - val_precision: 0.5341 - val_recall: 0.9038 - val_auc: 0.9492 - val_true_positives: 47.0000 - val_true_negatives: 174.0000 - val_false_positives: 41.0000 - val_false_negatives: 5.0000
# Epoch 6/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.1853 - accuracy: 0.9474 - precision: 0.8351 - recall: 0.9419 - auc: 0.9878 - true_positives: 162.0000 - true_negatives: 594.0000 - false_positives: 32.0000 - false_negatives: 10.0000 - val_loss: 0.2824 - val_accuracy: 0.8577 - val_precision: 0.5897 - val_recall: 0.8846 - val_auc: 0.9497 - val_true_positives: 46.0000 - val_true_negatives: 183.0000 - val_false_positives: 32.0000 - val_false_negatives: 6.0000
# Epoch 7/10
# 798/798 [==============================] - 1s 981us/sample - loss: 0.1491 - accuracy: 0.9574 - precision: 0.8557 - recall: 0.9651 - auc: 0.9925 - true_positives: 166.0000 - true_negatives: 598.0000 - false_positives: 28.0000 - false_negatives: 6.0000 - val_loss: 0.3060 - val_accuracy: 0.8427 - val_precision: 0.5595 - val_recall: 0.9038 - val_auc: 0.9458 - val_true_positives: 47.0000 - val_true_negatives: 178.0000 - val_false_positives: 37.0000 - val_false_negatives: 5.0000
# Epoch 8/10
# 798/798 [==============================] - 1s 975us/sample - loss: 0.1167 - accuracy: 0.9712 - precision: 0.8942 - recall: 0.9826 - auc: 0.9968 - true_positives: 169.0000 - true_negatives: 606.0000 - false_positives: 20.0000 - false_negatives: 3.0000 - val_loss: 0.2875 - val_accuracy: 0.8801 - val_precision: 0.6429 - val_recall: 0.8654 - val_auc: 0.9470 - val_true_positives: 45.0000 - val_true_negatives: 190.0000 - val_false_positives: 25.0000 - val_false_negatives: 7.0000
# Epoch 9/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.0889 - accuracy: 0.9774 - precision: 0.9140 - recall: 0.9884 - auc: 0.9990 - true_positives: 170.0000 - true_negatives: 610.0000 - false_positives: 16.0000 - false_negatives: 2.0000 - val_loss: 0.3333 - val_accuracy: 0.9064 - val_precision: 0.7213 - val_recall: 0.8462 - val_auc: 0.9313 - val_true_positives: 44.0000 - val_true_negatives: 198.0000 - val_false_positives: 17.0000 - val_false_negatives: 8.0000
# Epoch 10/10
# 798/798 [==============================] - 1s 956us/sample - loss: 0.0682 - accuracy: 0.9900 - precision: 0.9607 - recall: 0.9942 - auc: 0.9997 - true_positives: 171.0000 - true_negatives: 619.0000 - false_positives: 7.0000 - false_negatives: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.8839 - val_precision: 0.6522 - val_recall: 0.8654 - val_auc: 0.9364 - val_true_positives: 45.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 7.0000
# Scores for fold 1:
# loss of 0.37254941964349825
# accuracy of 0.8991596698760986
# precision of 0.7599999904632568
# recall of 0.7599999904632568
# auc of 0.8644680976867676
# true_positives of 19.0
# true_negatives of 88.0
# false_positives of 6.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 2 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 3s 4ms/sample - loss: 0.5929 - accuracy: 0.8371 - precision: 0.8182 - recall: 0.3140 - auc: 0.8570 - true_positives: 54.0000 - true_negatives: 614.0000 - false_positives: 12.0000 - false_negatives: 118.0000 - val_loss: 0.4134 - val_accuracy: 0.9363 - val_precision: 1.0000 - val_recall: 0.6731 - val_auc: 0.9774 - val_true_positives: 35.0000 - val_true_negatives: 215.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 17.0000
# Epoch 2/10
# 798/798 [==============================] - 1s 991us/sample - loss: 0.3504 - accuracy: 0.9236 - precision: 0.9111 - recall: 0.7151 - auc: 0.9582 - true_positives: 123.0000 - true_negatives: 614.0000 - false_positives: 12.0000 - false_negatives: 49.0000 - val_loss: 0.2609 - val_accuracy: 0.9026 - val_precision: 0.6912 - val_recall: 0.9038 - val_auc: 0.9691 - val_true_positives: 47.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 5.0000
# Epoch 3/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.2263 - accuracy: 0.9373 - precision: 0.8506 - recall: 0.8605 - auc: 0.9747 - true_positives: 148.0000 - true_negatives: 600.0000 - false_positives: 26.0000 - false_negatives: 24.0000 - val_loss: 0.2575 - val_accuracy: 0.8839 - val_precision: 0.6400 - val_recall: 0.9231 - val_auc: 0.9578 - val_true_positives: 48.0000 - val_true_negatives: 188.0000 - val_false_positives: 27.0000 - val_false_negatives: 4.0000
# Epoch 4/10
# 798/798 [==============================] - 1s 995us/sample - loss: 0.2074 - accuracy: 0.9411 - precision: 0.8531 - recall: 0.8779 - auc: 0.9786 - true_positives: 151.0000 - true_negatives: 600.0000 - false_positives: 26.0000 - false_negatives: 21.0000 - val_loss: 0.2137 - val_accuracy: 0.9513 - val_precision: 0.8824 - val_recall: 0.8654 - val_auc: 0.9638 - val_true_positives: 45.0000 - val_true_negatives: 209.0000 - val_false_positives: 6.0000 - val_false_negatives: 7.0000
# Epoch 5/10
# 798/798 [==============================] - 1s 984us/sample - loss: 0.2054 - accuracy: 0.9386 - precision: 0.8289 - recall: 0.9012 - auc: 0.9752 - true_positives: 155.0000 - true_negatives: 594.0000 - false_positives: 32.0000 - false_negatives: 17.0000 - val_loss: 0.2138 - val_accuracy: 0.9326 - val_precision: 0.7931 - val_recall: 0.8846 - val_auc: 0.9638 - val_true_positives: 46.0000 - val_true_negatives: 203.0000 - val_false_positives: 12.0000 - val_false_negatives: 6.0000
# Epoch 6/10
# 798/798 [==============================] - 1s 989us/sample - loss: 0.1728 - accuracy: 0.9586 - precision: 0.8927 - recall: 0.9186 - auc: 0.9859 - true_positives: 158.0000 - true_negatives: 607.0000 - false_positives: 19.0000 - false_negatives: 14.0000 - val_loss: 0.2020 - val_accuracy: 0.9513 - val_precision: 0.8980 - val_recall: 0.8462 - val_auc: 0.9703 - val_true_positives: 44.0000 - val_true_negatives: 210.0000 - val_false_positives: 5.0000 - val_false_negatives: 8.0000
# Epoch 7/10
# 798/798 [==============================] - 1s 993us/sample - loss: 0.1572 - accuracy: 0.9574 - precision: 0.8791 - recall: 0.9302 - auc: 0.9897 - true_positives: 160.0000 - true_negatives: 604.0000 - false_positives: 22.0000 - false_negatives: 12.0000 - val_loss: 0.2004 - val_accuracy: 0.9438 - val_precision: 0.8491 - val_recall: 0.8654 - val_auc: 0.9676 - val_true_positives: 45.0000 - val_true_negatives: 207.0000 - val_false_positives: 8.0000 - val_false_negatives: 7.0000
# Epoch 8/10
# 798/798 [==============================] - 1s 966us/sample - loss: 0.1585 - accuracy: 0.9612 - precision: 0.8939 - recall: 0.9302 - auc: 0.9874 - true_positives: 160.0000 - true_negatives: 607.0000 - false_positives: 19.0000 - false_negatives: 12.0000 - val_loss: 0.2148 - val_accuracy: 0.9101 - val_precision: 0.7121 - val_recall: 0.9038 - val_auc: 0.9646 - val_true_positives: 47.0000 - val_true_negatives: 196.0000 - val_false_positives: 19.0000 - val_false_negatives: 5.0000
# Epoch 9/10
# 798/798 [==============================] - 1s 988us/sample - loss: 0.1430 - accuracy: 0.9624 - precision: 0.8944 - recall: 0.9360 - auc: 0.9918 - true_positives: 161.0000 - true_negatives: 607.0000 - false_positives: 19.0000 - false_negatives: 11.0000 - val_loss: 0.1995 - val_accuracy: 0.9363 - val_precision: 0.8182 - val_recall: 0.8654 - val_auc: 0.9675 - val_true_positives: 45.0000 - val_true_negatives: 205.0000 - val_false_positives: 10.0000 - val_false_negatives: 7.0000
# Epoch 10/10
# 798/798 [==============================] - 1s 919us/sample - loss: 0.1490 - accuracy: 0.9524 - precision: 0.8641 - recall: 0.9244 - auc: 0.9898 - true_positives: 159.0000 - true_negatives: 601.0000 - false_positives: 25.0000 - false_negatives: 13.0000 - val_loss: 0.2096 - val_accuracy: 0.9363 - val_precision: 0.8182 - val_recall: 0.8654 - val_auc: 0.9650 - val_true_positives: 45.0000 - val_true_negatives: 205.0000 - val_false_positives: 10.0000 - val_false_negatives: 7.0000
# Scores for fold 2:
# loss of 0.23788715047495707
# accuracy of 0.8739495873451233
# precision of 0.7083333134651184
# recall of 0.6800000071525574
# auc of 0.9529787302017212
# true_positives of 17.0
# true_negatives of 87.0
# false_positives of 7.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 3 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 3s 4ms/sample - loss: 0.6753 - accuracy: 0.7594 - precision: 0.3864 - recall: 0.1977 - auc: 0.6686 - true_positives: 34.0000 - true_negatives: 572.0000 - false_positives: 54.0000 - false_negatives: 138.0000 - val_loss: 0.5758 - val_accuracy: 0.7715 - val_precision: 0.4444 - val_recall: 0.6923 - val_auc: 0.8330 - val_true_positives: 36.0000 - val_true_negatives: 170.0000 - val_false_positives: 45.0000 - val_false_negatives: 16.0000
# Epoch 2/10
# 798/798 [==============================] - 1s 986us/sample - loss: 0.5187 - accuracy: 0.8195 - precision: 0.5636 - recall: 0.7209 - auc: 0.8574 - true_positives: 124.0000 - true_negatives: 530.0000 - false_positives: 96.0000 - false_negatives: 48.0000 - val_loss: 0.3818 - val_accuracy: 0.9326 - val_precision: 1.0000 - val_recall: 0.6538 - val_auc: 0.9300 - val_true_positives: 34.0000 - val_true_negatives: 215.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 18.0000
# Epoch 3/10
# 798/798 [==============================] - 1s 984us/sample - loss: 0.3585 - accuracy: 0.9198 - precision: 0.8293 - recall: 0.7907 - auc: 0.9410 - true_positives: 136.0000 - true_negatives: 598.0000 - false_positives: 28.0000 - false_negatives: 36.0000 - val_loss: 0.3206 - val_accuracy: 0.9363 - val_precision: 0.9487 - val_recall: 0.7115 - val_auc: 0.9427 - val_true_positives: 37.0000 - val_true_negatives: 213.0000 - val_false_positives: 2.0000 - val_false_negatives: 15.0000
# Epoch 4/10
# 798/798 [==============================] - 1s 977us/sample - loss: 0.2928 - accuracy: 0.9348 - precision: 0.8704 - recall: 0.8198 - auc: 0.9600 - true_positives: 141.0000 - true_negatives: 605.0000 - false_positives: 21.0000 - false_negatives: 31.0000 - val_loss: 0.2995 - val_accuracy: 0.9251 - val_precision: 0.7857 - val_recall: 0.8462 - val_auc: 0.9339 - val_true_positives: 44.0000 - val_true_negatives: 203.0000 - val_false_positives: 12.0000 - val_false_negatives: 8.0000
# Epoch 5/10
# 798/798 [==============================] - 1s 989us/sample - loss: 0.2525 - accuracy: 0.9461 - precision: 0.8686 - recall: 0.8837 - auc: 0.9715 - true_positives: 152.0000 - true_negatives: 603.0000 - false_positives: 23.0000 - false_negatives: 20.0000 - val_loss: 0.2973 - val_accuracy: 0.8989 - val_precision: 0.6866 - val_recall: 0.8846 - val_auc: 0.9354 - val_true_positives: 46.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 6.0000
# Epoch 6/10
# 798/798 [==============================] - 1s 996us/sample - loss: 0.2290 - accuracy: 0.9449 - precision: 0.8636 - recall: 0.8837 - auc: 0.9755 - true_positives: 152.0000 - true_negatives: 602.0000 - false_positives: 24.0000 - false_negatives: 20.0000 - val_loss: 0.2649 - val_accuracy: 0.9401 - val_precision: 0.8600 - val_recall: 0.8269 - val_auc: 0.9432 - val_true_positives: 43.0000 - val_true_negatives: 208.0000 - val_false_positives: 7.0000 - val_false_negatives: 9.0000
# Epoch 7/10
# 798/798 [==============================] - 1s 987us/sample - loss: 0.2209 - accuracy: 0.9398 - precision: 0.8605 - recall: 0.8605 - auc: 0.9755 - true_positives: 148.0000 - true_negatives: 602.0000 - false_positives: 24.0000 - false_negatives: 24.0000 - val_loss: 0.2677 - val_accuracy: 0.9213 - val_precision: 0.7541 - val_recall: 0.8846 - val_auc: 0.9392 - val_true_positives: 46.0000 - val_true_negatives: 200.0000 - val_false_positives: 15.0000 - val_false_negatives: 6.0000
# Epoch 8/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.2069 - accuracy: 0.9373 - precision: 0.8211 - recall: 0.9070 - auc: 0.9777 - true_positives: 156.0000 - true_negatives: 592.0000 - false_positives: 34.0000 - false_negatives: 16.0000 - val_loss: 0.2582 - val_accuracy: 0.9438 - val_precision: 0.8936 - val_recall: 0.8077 - val_auc: 0.9465 - val_true_positives: 42.0000 - val_true_negatives: 210.0000 - val_false_positives: 5.0000 - val_false_negatives: 10.0000
# Epoch 9/10
# 798/798 [==============================] - 1s 998us/sample - loss: 0.2331 - accuracy: 0.9311 - precision: 0.8095 - recall: 0.8895 - auc: 0.9687 - true_positives: 153.0000 - true_negatives: 590.0000 - false_positives: 36.0000 - false_negatives: 19.0000 - val_loss: 0.2984 - val_accuracy: 0.9476 - val_precision: 0.9750 - val_recall: 0.7500 - val_auc: 0.9547 - val_true_positives: 39.0000 - val_true_negatives: 214.0000 - val_false_positives: 1.0000 - val_false_negatives: 13.0000
# Epoch 10/10
# 798/798 [==============================] - 1s 899us/sample - loss: 0.1892 - accuracy: 0.9549 - precision: 0.8656 - recall: 0.9360 - auc: 0.9844 - true_positives: 161.0000 - true_negatives: 601.0000 - false_positives: 25.0000 - false_negatives: 11.0000 - val_loss: 0.2497 - val_accuracy: 0.9401 - val_precision: 0.8333 - val_recall: 0.8654 - val_auc: 0.9464 - val_true_positives: 45.0000 - val_true_negatives: 206.0000 - val_false_positives: 9.0000 - val_false_negatives: 7.0000
# Scores for fold 3:
# loss of 0.17308443872367635
# accuracy of 0.9579831957817078
# precision of 0.9545454382896423
# recall of 0.8399999737739563
# auc of 0.9402127265930176
# true_positives of 21.0
# true_negatives of 93.0
# false_positives of 1.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 4 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 3s 4ms/sample - loss: 0.6814 - accuracy: 0.7456 - precision: 0.3604 - recall: 0.2326 - auc: 0.6576 - true_positives: 40.0000 - true_negatives: 555.0000 - false_positives: 71.0000 - false_negatives: 132.0000 - val_loss: 0.6090 - val_accuracy: 0.7228 - val_precision: 0.3900 - val_recall: 0.7500 - val_auc: 0.7912 - val_true_positives: 39.0000 - val_true_negatives: 154.0000 - val_false_positives: 61.0000 - val_false_negatives: 13.0000
# Epoch 2/10
# 798/798 [==============================] - 1s 990us/sample - loss: 0.5989 - accuracy: 0.7256 - precision: 0.4175 - recall: 0.6919 - auc: 0.7735 - true_positives: 119.0000 - true_negatives: 460.0000 - false_positives: 166.0000 - false_negatives: 53.0000 - val_loss: 0.5498 - val_accuracy: 0.6479 - val_precision: 0.3359 - val_recall: 0.8269 - val_auc: 0.7991 - val_true_positives: 43.0000 - val_true_negatives: 130.0000 - val_false_positives: 85.0000 - val_false_negatives: 9.0000
# Epoch 3/10
# 798/798 [==============================] - 1s 967us/sample - loss: 0.4934 - accuracy: 0.7945 - precision: 0.5167 - recall: 0.7209 - auc: 0.8554 - true_positives: 124.0000 - true_negatives: 510.0000 - false_positives: 116.0000 - false_negatives: 48.0000 - val_loss: 0.4330 - val_accuracy: 0.7640 - val_precision: 0.4421 - val_recall: 0.8077 - val_auc: 0.8962 - val_true_positives: 42.0000 - val_true_negatives: 162.0000 - val_false_positives: 53.0000 - val_false_negatives: 10.0000
# Epoch 4/10
# 798/798 [==============================] - 1s 972us/sample - loss: 0.3743 - accuracy: 0.8835 - precision: 0.7047 - recall: 0.7907 - auc: 0.9220 - true_positives: 136.0000 - true_negatives: 569.0000 - false_positives: 57.0000 - false_negatives: 36.0000 - val_loss: 0.3703 - val_accuracy: 0.8427 - val_precision: 0.5658 - val_recall: 0.8269 - val_auc: 0.9178 - val_true_positives: 43.0000 - val_true_negatives: 182.0000 - val_false_positives: 33.0000 - val_false_negatives: 9.0000
# Epoch 5/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.2966 - accuracy: 0.9323 - precision: 0.8278 - recall: 0.8663 - auc: 0.9573 - true_positives: 149.0000 - true_negatives: 595.0000 - false_positives: 31.0000 - false_negatives: 23.0000 - val_loss: 0.3145 - val_accuracy: 0.9401 - val_precision: 0.9500 - val_recall: 0.7308 - val_auc: 0.9394 - val_true_positives: 38.0000 - val_true_negatives: 213.0000 - val_false_positives: 2.0000 - val_false_negatives: 14.0000
# Epoch 6/10
# 798/798 [==============================] - 1s 987us/sample - loss: 0.2618 - accuracy: 0.9311 - precision: 0.8421 - recall: 0.8372 - auc: 0.9679 - true_positives: 144.0000 - true_negatives: 599.0000 - false_positives: 27.0000 - false_negatives: 28.0000 - val_loss: 0.2979 - val_accuracy: 0.9401 - val_precision: 0.9286 - val_recall: 0.7500 - val_auc: 0.9431 - val_true_positives: 39.0000 - val_true_negatives: 212.0000 - val_false_positives: 3.0000 - val_false_negatives: 13.0000
# Epoch 7/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.2215 - accuracy: 0.9536 - precision: 0.9091 - recall: 0.8721 - auc: 0.9798 - true_positives: 150.0000 - true_negatives: 611.0000 - false_positives: 15.0000 - false_negatives: 22.0000 - val_loss: 0.2842 - val_accuracy: 0.9326 - val_precision: 0.8148 - val_recall: 0.8462 - val_auc: 0.9355 - val_true_positives: 44.0000 - val_true_negatives: 205.0000 - val_false_positives: 10.0000 - val_false_negatives: 8.0000
# Epoch 8/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.1895 - accuracy: 0.9612 - precision: 0.9075 - recall: 0.9128 - auc: 0.9857 - true_positives: 157.0000 - true_negatives: 610.0000 - false_positives: 16.0000 - false_negatives: 15.0000 - val_loss: 0.2843 - val_accuracy: 0.9438 - val_precision: 0.9111 - val_recall: 0.7885 - val_auc: 0.9436 - val_true_positives: 41.0000 - val_true_negatives: 211.0000 - val_false_positives: 4.0000 - val_false_negatives: 11.0000
# Epoch 9/10
# 798/798 [==============================] - 1s 1ms/sample - loss: 0.1754 - accuracy: 0.9637 - precision: 0.9231 - recall: 0.9070 - auc: 0.9869 - true_positives: 156.0000 - true_negatives: 613.0000 - false_positives: 13.0000 - false_negatives: 16.0000 - val_loss: 0.2791 - val_accuracy: 0.9476 - val_precision: 0.9130 - val_recall: 0.8077 - val_auc: 0.9441 - val_true_positives: 42.0000 - val_true_negatives: 211.0000 - val_false_positives: 4.0000 - val_false_negatives: 10.0000
# Epoch 10/10
# 798/798 [==============================] - 1s 930us/sample - loss: 0.1988 - accuracy: 0.9449 - precision: 0.8596 - recall: 0.8895 - auc: 0.9793 - true_positives: 153.0000 - true_negatives: 601.0000 - false_positives: 25.0000 - false_negatives: 19.0000 - val_loss: 0.2637 - val_accuracy: 0.9551 - val_precision: 0.9167 - val_recall: 0.8462 - val_auc: 0.9449 - val_true_positives: 44.0000 - val_true_negatives: 211.0000 - val_false_positives: 4.0000 - val_false_negatives: 8.0000
# Scores for fold 4:
# loss of 0.2334516566841542
# accuracy of 0.9159663915634155
# precision of 0.9411764740943909
# recall of 0.6399999856948853
# auc of 0.9289361238479614
# true_positives of 16.0
# true_negatives of 93.0
# false_positives of 1.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 5 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 4s 5ms/sample - loss: 0.6643 - accuracy: 0.6896 - precision: 0.3516 - recall: 0.5233 - auc: 0.6902 - true_positives: 90.0000 - true_negatives: 461.0000 - false_positives: 166.0000 - false_negatives: 82.0000 - val_loss: 0.5533 - val_accuracy: 0.7790 - val_precision: 0.4426 - val_recall: 0.5192 - val_auc: 0.8114 - val_true_positives: 27.0000 - val_true_negatives: 181.0000 - val_false_positives: 34.0000 - val_false_negatives: 25.0000
# Epoch 2/10
# 799/799 [==============================] - 1s 950us/sample - loss: 0.6178 - accuracy: 0.6483 - precision: 0.3547 - recall: 0.7733 - auc: 0.7178 - true_positives: 133.0000 - true_negatives: 385.0000 - false_positives: 242.0000 - false_negatives: 39.0000 - val_loss: 0.5238 - val_accuracy: 0.7228 - val_precision: 0.3942 - val_recall: 0.7885 - val_auc: 0.8019 - val_true_positives: 41.0000 - val_true_negatives: 152.0000 - val_false_positives: 63.0000 - val_false_negatives: 11.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.5994 - accuracy: 0.6721 - precision: 0.3692 - recall: 0.7384 - auc: 0.7470 - true_positives: 127.0000 - true_negatives: 410.0000 - false_positives: 217.0000 - false_negatives: 45.0000 - val_loss: 0.5377 - val_accuracy: 0.6816 - val_precision: 0.3613 - val_recall: 0.8269 - val_auc: 0.7981 - val_true_positives: 43.0000 - val_true_negatives: 139.0000 - val_false_positives: 76.0000 - val_false_negatives: 9.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 976us/sample - loss: 0.5972 - accuracy: 0.7021 - precision: 0.3949 - recall: 0.7209 - auc: 0.7499 - true_positives: 124.0000 - true_negatives: 437.0000 - false_positives: 190.0000 - false_negatives: 48.0000 - val_loss: 0.5181 - val_accuracy: 0.7303 - val_precision: 0.4038 - val_recall: 0.8077 - val_auc: 0.8021 - val_true_positives: 42.0000 - val_true_negatives: 153.0000 - val_false_positives: 62.0000 - val_false_negatives: 10.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.5928 - accuracy: 0.6821 - precision: 0.3822 - recall: 0.7733 - auc: 0.7552 - true_positives: 133.0000 - true_negatives: 412.0000 - false_positives: 215.0000 - false_negatives: 39.0000 - val_loss: 0.5242 - val_accuracy: 0.7266 - val_precision: 0.3981 - val_recall: 0.7885 - val_auc: 0.7992 - val_true_positives: 41.0000 - val_true_negatives: 153.0000 - val_false_positives: 62.0000 - val_false_negatives: 11.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.5854 - accuracy: 0.6984 - precision: 0.3932 - recall: 0.7384 - auc: 0.7634 - true_positives: 127.0000 - true_negatives: 431.0000 - false_positives: 196.0000 - false_negatives: 45.0000 - val_loss: 0.5137 - val_accuracy: 0.7491 - val_precision: 0.4211 - val_recall: 0.7692 - val_auc: 0.8120 - val_true_positives: 40.0000 - val_true_negatives: 160.0000 - val_false_positives: 55.0000 - val_false_negatives: 12.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 965us/sample - loss: 0.4522 - accuracy: 0.8148 - precision: 0.5531 - recall: 0.7267 - auc: 0.8789 - true_positives: 125.0000 - true_negatives: 526.0000 - false_positives: 101.0000 - false_negatives: 47.0000 - val_loss: 0.3147 - val_accuracy: 0.9513 - val_precision: 0.9535 - val_recall: 0.7885 - val_auc: 0.9354 - val_true_positives: 41.0000 - val_true_negatives: 213.0000 - val_false_positives: 2.0000 - val_false_negatives: 11.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 997us/sample - loss: 0.2944 - accuracy: 0.9086 - precision: 0.7797 - recall: 0.8023 - auc: 0.9529 - true_positives: 138.0000 - true_negatives: 588.0000 - false_positives: 39.0000 - false_negatives: 34.0000 - val_loss: 0.2933 - val_accuracy: 0.9326 - val_precision: 0.8148 - val_recall: 0.8462 - val_auc: 0.9258 - val_true_positives: 44.0000 - val_true_negatives: 205.0000 - val_false_positives: 10.0000 - val_false_negatives: 8.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2705 - accuracy: 0.9362 - precision: 0.8623 - recall: 0.8372 - auc: 0.9589 - true_positives: 144.0000 - true_negatives: 604.0000 - false_positives: 23.0000 - false_negatives: 28.0000 - val_loss: 0.3111 - val_accuracy: 0.8839 - val_precision: 0.6522 - val_recall: 0.8654 - val_auc: 0.9237 - val_true_positives: 45.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 7.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2351 - accuracy: 0.9412 - precision: 0.8492 - recall: 0.8837 - auc: 0.9691 - true_positives: 152.0000 - true_negatives: 600.0000 - false_positives: 27.0000 - false_negatives: 20.0000 - val_loss: 0.2745 - val_accuracy: 0.9288 - val_precision: 0.7895 - val_recall: 0.8654 - val_auc: 0.9334 - val_true_positives: 45.0000 - val_true_negatives: 203.0000 - val_false_positives: 12.0000 - val_false_negatives: 7.0000
# Scores for fold 5:
# loss of 0.20144802736023726
# accuracy of 0.9152542352676392
# precision of 0.7586206793785095
# recall of 0.8799999952316284
# auc of 0.985806405544281
# true_positives of 22.0
# true_negatives of 86.0
# false_positives of 7.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 6 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 3s 4ms/sample - loss: 0.6537 - accuracy: 0.7610 - precision: 0.4317 - recall: 0.3488 - auc: 0.7139 - true_positives: 60.0000 - true_negatives: 548.0000 - false_positives: 79.0000 - false_negatives: 112.0000 - val_loss: 0.5583 - val_accuracy: 0.7191 - val_precision: 0.3945 - val_recall: 0.8269 - val_auc: 0.7936 - val_true_positives: 43.0000 - val_true_negatives: 149.0000 - val_false_positives: 66.0000 - val_false_negatives: 9.0000
# Epoch 2/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.5623 - accuracy: 0.7297 - precision: 0.4257 - recall: 0.7326 - auc: 0.7976 - true_positives: 126.0000 - true_negatives: 457.0000 - false_positives: 170.0000 - false_negatives: 46.0000 - val_loss: 0.3747 - val_accuracy: 0.9251 - val_precision: 0.8636 - val_recall: 0.7308 - val_auc: 0.9315 - val_true_positives: 38.0000 - val_true_negatives: 209.0000 - val_false_positives: 6.0000 - val_false_negatives: 14.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 986us/sample - loss: 0.4259 - accuracy: 0.8723 - precision: 0.7059 - recall: 0.6977 - auc: 0.8913 - true_positives: 120.0000 - true_negatives: 577.0000 - false_positives: 50.0000 - false_negatives: 52.0000 - val_loss: 0.4445 - val_accuracy: 0.6891 - val_precision: 0.3760 - val_recall: 0.9038 - val_auc: 0.9055 - val_true_positives: 47.0000 - val_true_negatives: 137.0000 - val_false_positives: 78.0000 - val_false_negatives: 5.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 942us/sample - loss: 0.3694 - accuracy: 0.8924 - precision: 0.7389 - recall: 0.7733 - auc: 0.9111 - true_positives: 133.0000 - true_negatives: 580.0000 - false_positives: 47.0000 - false_negatives: 39.0000 - val_loss: 0.3320 - val_accuracy: 0.8951 - val_precision: 0.6765 - val_recall: 0.8846 - val_auc: 0.9215 - val_true_positives: 46.0000 - val_true_negatives: 193.0000 - val_false_positives: 22.0000 - val_false_negatives: 6.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3044 - accuracy: 0.9262 - precision: 0.8229 - recall: 0.8372 - auc: 0.9539 - true_positives: 144.0000 - true_negatives: 596.0000 - false_positives: 31.0000 - false_negatives: 28.0000 - val_loss: 0.2855 - val_accuracy: 0.9625 - val_precision: 0.9565 - val_recall: 0.8462 - val_auc: 0.9409 - val_true_positives: 44.0000 - val_true_negatives: 213.0000 - val_false_positives: 2.0000 - val_false_negatives: 8.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2929 - accuracy: 0.9274 - precision: 0.8434 - recall: 0.8140 - auc: 0.9505 - true_positives: 140.0000 - true_negatives: 601.0000 - false_positives: 26.0000 - false_negatives: 32.0000 - val_loss: 0.2699 - val_accuracy: 0.9288 - val_precision: 0.8000 - val_recall: 0.8462 - val_auc: 0.9349 - val_true_positives: 44.0000 - val_true_negatives: 204.0000 - val_false_positives: 11.0000 - val_false_negatives: 8.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 969us/sample - loss: 0.2491 - accuracy: 0.9374 - precision: 0.8389 - recall: 0.8779 - auc: 0.9656 - true_positives: 151.0000 - true_negatives: 598.0000 - false_positives: 29.0000 - false_negatives: 21.0000 - val_loss: 0.2873 - val_accuracy: 0.8876 - val_precision: 0.6528 - val_recall: 0.9038 - val_auc: 0.9321 - val_true_positives: 47.0000 - val_true_negatives: 190.0000 - val_false_positives: 25.0000 - val_false_negatives: 5.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 937us/sample - loss: 0.2342 - accuracy: 0.9462 - precision: 0.8728 - recall: 0.8779 - auc: 0.9699 - true_positives: 151.0000 - true_negatives: 605.0000 - false_positives: 22.0000 - false_negatives: 21.0000 - val_loss: 0.2747 - val_accuracy: 0.8989 - val_precision: 0.6812 - val_recall: 0.9038 - val_auc: 0.9389 - val_true_positives: 47.0000 - val_true_negatives: 193.0000 - val_false_positives: 22.0000 - val_false_negatives: 5.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 997us/sample - loss: 0.2210 - accuracy: 0.9412 - precision: 0.8415 - recall: 0.8953 - auc: 0.9746 - true_positives: 154.0000 - true_negatives: 598.0000 - false_positives: 29.0000 - false_negatives: 18.0000 - val_loss: 0.2464 - val_accuracy: 0.9513 - val_precision: 0.8980 - val_recall: 0.8462 - val_auc: 0.9500 - val_true_positives: 44.0000 - val_true_negatives: 210.0000 - val_false_positives: 5.0000 - val_false_negatives: 8.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 912us/sample - loss: 0.2061 - accuracy: 0.9474 - precision: 0.8652 - recall: 0.8953 - auc: 0.9786 - true_positives: 154.0000 - true_negatives: 603.0000 - false_positives: 24.0000 - false_negatives: 18.0000 - val_loss: 0.2416 - val_accuracy: 0.9401 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9508 - val_true_positives: 44.0000 - val_true_negatives: 207.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000
# Scores for fold 6:
# loss of 0.15508741026712677
# accuracy of 0.9406779408454895
# precision of 0.9090909361839294
# recall of 0.800000011920929
# auc of 0.9898924827575684
# true_positives of 20.0
# true_negatives of 91.0
# false_positives of 2.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 7 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 3s 4ms/sample - loss: 0.5566 - accuracy: 0.2253 - precision: 0.2146 - recall: 0.9767 - auc: 0.8712 - true_positives: 168.0000 - true_negatives: 12.0000 - false_positives: 615.0000 - false_negatives: 4.0000 - val_loss: 0.4948 - val_accuracy: 0.2022 - val_precision: 0.1962 - val_recall: 1.0000 - val_auc: 0.9676 - val_true_positives: 52.0000 - val_true_negatives: 2.0000 - val_false_positives: 213.0000 - val_false_negatives: 0.0000e+00
# Epoch 2/10
# 799/799 [==============================] - 1s 960us/sample - loss: 0.5057 - accuracy: 0.3166 - precision: 0.2396 - recall: 1.0000 - auc: 0.9514 - true_positives: 172.0000 - true_negatives: 81.0000 - false_positives: 546.0000 - false_negatives: 0.0000e+00 - val_loss: 0.4701 - val_accuracy: 0.4831 - val_precision: 0.2713 - val_recall: 0.9808 - val_auc: 0.9564 - val_true_positives: 51.0000 - val_true_negatives: 78.0000 - val_false_positives: 137.0000 - val_false_negatives: 1.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 957us/sample - loss: 0.4609 - accuracy: 0.5745 - precision: 0.3346 - recall: 0.9884 - auc: 0.9587 - true_positives: 170.0000 - true_negatives: 289.0000 - false_positives: 338.0000 - false_negatives: 2.0000 - val_loss: 0.4319 - val_accuracy: 0.6404 - val_precision: 0.3451 - val_recall: 0.9423 - val_auc: 0.9425 - val_true_positives: 49.0000 - val_true_negatives: 122.0000 - val_false_positives: 93.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 986us/sample - loss: 0.3988 - accuracy: 0.7622 - precision: 0.4738 - recall: 0.9477 - auc: 0.9422 - true_positives: 163.0000 - true_negatives: 446.0000 - false_positives: 181.0000 - false_negatives: 9.0000 - val_loss: 0.3787 - val_accuracy: 0.7978 - val_precision: 0.4894 - val_recall: 0.8846 - val_auc: 0.9211 - val_true_positives: 46.0000 - val_true_negatives: 167.0000 - val_false_positives: 48.0000 - val_false_negatives: 6.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3123 - accuracy: 0.8461 - precision: 0.5946 - recall: 0.8953 - auc: 0.9518 - true_positives: 154.0000 - true_negatives: 522.0000 - false_positives: 105.0000 - false_negatives: 18.0000 - val_loss: 0.3218 - val_accuracy: 0.9026 - val_precision: 0.7097 - val_recall: 0.8462 - val_auc: 0.9186 - val_true_positives: 44.0000 - val_true_negatives: 197.0000 - val_false_positives: 18.0000 - val_false_negatives: 8.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2602 - accuracy: 0.8974 - precision: 0.6957 - recall: 0.9302 - auc: 0.9634 - true_positives: 160.0000 - true_negatives: 557.0000 - false_positives: 70.0000 - false_negatives: 12.0000 - val_loss: 0.3123 - val_accuracy: 0.8876 - val_precision: 0.6618 - val_recall: 0.8654 - val_auc: 0.9275 - val_true_positives: 45.0000 - val_true_negatives: 192.0000 - val_false_positives: 23.0000 - val_false_negatives: 7.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 987us/sample - loss: 0.2286 - accuracy: 0.9049 - precision: 0.7202 - recall: 0.9128 - auc: 0.9721 - true_positives: 157.0000 - true_negatives: 566.0000 - false_positives: 61.0000 - false_negatives: 15.0000 - val_loss: 0.3918 - val_accuracy: 0.7303 - val_precision: 0.4167 - val_recall: 0.9615 - val_auc: 0.9608 - val_true_positives: 50.0000 - val_true_negatives: 145.0000 - val_false_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 984us/sample - loss: 0.2334 - accuracy: 0.8999 - precision: 0.6983 - recall: 0.9419 - auc: 0.9706 - true_positives: 162.0000 - true_negatives: 557.0000 - false_positives: 70.0000 - false_negatives: 10.0000 - val_loss: 0.3169 - val_accuracy: 0.8689 - val_precision: 0.6197 - val_recall: 0.8462 - val_auc: 0.9299 - val_true_positives: 44.0000 - val_true_negatives: 188.0000 - val_false_positives: 27.0000 - val_false_negatives: 8.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 998us/sample - loss: 0.1754 - accuracy: 0.9262 - precision: 0.7653 - recall: 0.9477 - auc: 0.9887 - true_positives: 163.0000 - true_negatives: 577.0000 - false_positives: 50.0000 - false_negatives: 9.0000 - val_loss: 0.3299 - val_accuracy: 0.8315 - val_precision: 0.5376 - val_recall: 0.9615 - val_auc: 0.9543 - val_true_positives: 50.0000 - val_true_negatives: 172.0000 - val_false_positives: 43.0000 - val_false_negatives: 2.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 901us/sample - loss: 0.1825 - accuracy: 0.9074 - precision: 0.7076 - recall: 0.9709 - auc: 0.9888 - true_positives: 167.0000 - true_negatives: 558.0000 - false_positives: 69.0000 - false_negatives: 5.0000 - val_loss: 0.3151 - val_accuracy: 0.8839 - val_precision: 0.6522 - val_recall: 0.8654 - val_auc: 0.9351 - val_true_positives: 45.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 7.0000
# Scores for fold 7:
# loss of 0.32780354987766785
# accuracy of 0.8983050584793091
# precision of 0.7407407164573669
# recall of 0.800000011920929
# auc of 0.8875268697738647
# true_positives of 20.0
# true_negatives of 86.0
# false_positives of 7.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 8 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 4s 5ms/sample - loss: 0.6019 - accuracy: 0.4931 - precision: 0.2849 - recall: 0.8793 - auc: 0.7728 - true_positives: 153.0000 - true_negatives: 241.0000 - false_positives: 384.0000 - false_negatives: 21.0000 - val_loss: 0.4261 - val_accuracy: 0.7753 - val_precision: 0.4479 - val_recall: 0.8600 - val_auc: 0.9081 - val_true_positives: 43.0000 - val_true_negatives: 164.0000 - val_false_positives: 53.0000 - val_false_negatives: 7.0000
# Epoch 2/10
# 799/799 [==============================] - 1s 976us/sample - loss: 0.4301 - accuracy: 0.8023 - precision: 0.5296 - recall: 0.8218 - auc: 0.9075 - true_positives: 143.0000 - true_negatives: 498.0000 - false_positives: 127.0000 - false_negatives: 31.0000 - val_loss: 0.3691 - val_accuracy: 0.8801 - val_precision: 0.6406 - val_recall: 0.8200 - val_auc: 0.8943 - val_true_positives: 41.0000 - val_true_negatives: 194.0000 - val_false_positives: 23.0000 - val_false_negatives: 9.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3851 - accuracy: 0.8623 - precision: 0.6391 - recall: 0.8448 - auc: 0.9193 - true_positives: 147.0000 - true_negatives: 542.0000 - false_positives: 83.0000 - false_negatives: 27.0000 - val_loss: 0.3612 - val_accuracy: 0.9139 - val_precision: 0.7547 - val_recall: 0.8000 - val_auc: 0.8871 - val_true_positives: 40.0000 - val_true_negatives: 204.0000 - val_false_positives: 13.0000 - val_false_negatives: 10.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3349 - accuracy: 0.8723 - precision: 0.6579 - recall: 0.8621 - auc: 0.9391 - true_positives: 150.0000 - true_negatives: 547.0000 - false_positives: 78.0000 - false_negatives: 24.0000 - val_loss: 0.3566 - val_accuracy: 0.8801 - val_precision: 0.6406 - val_recall: 0.8200 - val_auc: 0.8988 - val_true_positives: 41.0000 - val_true_negatives: 194.0000 - val_false_positives: 23.0000 - val_false_negatives: 9.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 950us/sample - loss: 0.3129 - accuracy: 0.8924 - precision: 0.7157 - recall: 0.8391 - auc: 0.9498 - true_positives: 146.0000 - true_negatives: 567.0000 - false_positives: 58.0000 - false_negatives: 28.0000 - val_loss: 0.3315 - val_accuracy: 0.8764 - val_precision: 0.6232 - val_recall: 0.8600 - val_auc: 0.9221 - val_true_positives: 43.0000 - val_true_negatives: 191.0000 - val_false_positives: 26.0000 - val_false_negatives: 7.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 982us/sample - loss: 0.2782 - accuracy: 0.9036 - precision: 0.7299 - recall: 0.8851 - auc: 0.9654 - true_positives: 154.0000 - true_negatives: 568.0000 - false_positives: 57.0000 - false_negatives: 20.0000 - val_loss: 0.3378 - val_accuracy: 0.8577 - val_precision: 0.5833 - val_recall: 0.8400 - val_auc: 0.9205 - val_true_positives: 42.0000 - val_true_negatives: 187.0000 - val_false_positives: 30.0000 - val_false_negatives: 8.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2620 - accuracy: 0.9136 - precision: 0.7561 - recall: 0.8908 - auc: 0.9711 - true_positives: 155.0000 - true_negatives: 575.0000 - false_positives: 50.0000 - false_negatives: 19.0000 - val_loss: 0.3209 - val_accuracy: 0.8352 - val_precision: 0.5366 - val_recall: 0.8800 - val_auc: 0.9341 - val_true_positives: 44.0000 - val_true_negatives: 179.0000 - val_false_positives: 38.0000 - val_false_negatives: 6.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2397 - accuracy: 0.9199 - precision: 0.7644 - recall: 0.9138 - auc: 0.9792 - true_positives: 159.0000 - true_negatives: 576.0000 - false_positives: 49.0000 - false_negatives: 15.0000 - val_loss: 0.3130 - val_accuracy: 0.8951 - val_precision: 0.6774 - val_recall: 0.8400 - val_auc: 0.9179 - val_true_positives: 42.0000 - val_true_negatives: 197.0000 - val_false_positives: 20.0000 - val_false_negatives: 8.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2198 - accuracy: 0.9224 - precision: 0.7667 - recall: 0.9253 - auc: 0.9809 - true_positives: 161.0000 - true_negatives: 576.0000 - false_positives: 49.0000 - false_negatives: 13.0000 - val_loss: 0.3060 - val_accuracy: 0.9064 - val_precision: 0.7049 - val_recall: 0.8600 - val_auc: 0.9230 - val_true_positives: 43.0000 - val_true_negatives: 199.0000 - val_false_positives: 18.0000 - val_false_negatives: 7.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 903us/sample - loss: 0.2074 - accuracy: 0.9237 - precision: 0.7703 - recall: 0.9253 - auc: 0.9851 - true_positives: 161.0000 - true_negatives: 577.0000 - false_positives: 48.0000 - false_negatives: 13.0000 - val_loss: 0.3019 - val_accuracy: 0.9176 - val_precision: 0.7414 - val_recall: 0.8600 - val_auc: 0.9226 - val_true_positives: 43.0000 - val_true_negatives: 202.0000 - val_false_positives: 15.0000 - val_false_negatives: 7.0000
# Scores for fold 8:
# loss of 0.28742155129626645
# accuracy of 0.9152542352676392
# precision of 0.800000011920929
# recall of 0.800000011920929
# auc of 0.9234408736228943
# true_positives of 20.0
# true_negatives of 88.0
# false_positives of 5.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 9 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 4s 5ms/sample - loss: 0.6948 - accuracy: 0.4856 - precision: 0.2430 - recall: 0.6437 - auc: 0.5594 - true_positives: 112.0000 - true_negatives: 276.0000 - false_positives: 349.0000 - false_negatives: 62.0000 - val_loss: 0.5919 - val_accuracy: 0.8090 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8184 - val_true_positives: 0.0000e+00 - val_true_negatives: 216.0000 - val_false_positives: 1.0000 - val_false_negatives: 50.0000
# Epoch 2/10
# 799/799 [==============================] - 1s 952us/sample - loss: 0.6296 - accuracy: 0.7272 - precision: 0.4154 - recall: 0.6207 - auc: 0.7424 - true_positives: 108.0000 - true_negatives: 473.0000 - false_positives: 152.0000 - false_negatives: 66.0000 - val_loss: 0.5454 - val_accuracy: 0.6255 - val_precision: 0.3214 - val_recall: 0.9000 - val_auc: 0.8199 - val_true_positives: 45.0000 - val_true_negatives: 122.0000 - val_false_positives: 95.0000 - val_false_negatives: 5.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.5828 - accuracy: 0.7034 - precision: 0.4048 - recall: 0.7701 - auc: 0.7858 - true_positives: 134.0000 - true_negatives: 428.0000 - false_positives: 197.0000 - false_negatives: 40.0000 - val_loss: 0.5185 - val_accuracy: 0.5880 - val_precision: 0.3026 - val_recall: 0.9200 - val_auc: 0.8953 - val_true_positives: 46.0000 - val_true_negatives: 111.0000 - val_false_positives: 106.0000 - val_false_negatives: 4.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.4899 - accuracy: 0.8173 - precision: 0.5625 - recall: 0.7241 - auc: 0.8553 - true_positives: 126.0000 - true_negatives: 527.0000 - false_positives: 98.0000 - false_negatives: 48.0000 - val_loss: 0.3552 - val_accuracy: 0.8652 - val_precision: 0.6029 - val_recall: 0.8200 - val_auc: 0.9318 - val_true_positives: 41.0000 - val_true_negatives: 190.0000 - val_false_positives: 27.0000 - val_false_negatives: 9.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3890 - accuracy: 0.8548 - precision: 0.6318 - recall: 0.7989 - auc: 0.9160 - true_positives: 139.0000 - true_negatives: 544.0000 - false_positives: 81.0000 - false_negatives: 35.0000 - val_loss: 0.2873 - val_accuracy: 0.9401 - val_precision: 0.8696 - val_recall: 0.8000 - val_auc: 0.9498 - val_true_positives: 40.0000 - val_true_negatives: 211.0000 - val_false_positives: 6.0000 - val_false_negatives: 10.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3177 - accuracy: 0.9299 - precision: 0.8512 - recall: 0.8218 - auc: 0.9506 - true_positives: 143.0000 - true_negatives: 600.0000 - false_positives: 25.0000 - false_negatives: 31.0000 - val_loss: 0.2624 - val_accuracy: 0.9513 - val_precision: 0.9512 - val_recall: 0.7800 - val_auc: 0.9555 - val_true_positives: 39.0000 - val_true_negatives: 215.0000 - val_false_positives: 2.0000 - val_false_negatives: 11.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 951us/sample - loss: 0.2950 - accuracy: 0.9199 - precision: 0.8161 - recall: 0.8161 - auc: 0.9534 - true_positives: 142.0000 - true_negatives: 593.0000 - false_positives: 32.0000 - false_negatives: 32.0000 - val_loss: 0.2413 - val_accuracy: 0.9438 - val_precision: 0.8889 - val_recall: 0.8000 - val_auc: 0.9575 - val_true_positives: 40.0000 - val_true_negatives: 212.0000 - val_false_positives: 5.0000 - val_false_negatives: 10.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2445 - accuracy: 0.9487 - precision: 0.8800 - recall: 0.8851 - auc: 0.9730 - true_positives: 154.0000 - true_negatives: 604.0000 - false_positives: 21.0000 - false_negatives: 20.0000 - val_loss: 0.2418 - val_accuracy: 0.9288 - val_precision: 0.8039 - val_recall: 0.8200 - val_auc: 0.9556 - val_true_positives: 41.0000 - val_true_negatives: 207.0000 - val_false_positives: 10.0000 - val_false_negatives: 9.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2249 - accuracy: 0.9449 - precision: 0.8652 - recall: 0.8851 - auc: 0.9765 - true_positives: 154.0000 - true_negatives: 601.0000 - false_positives: 24.0000 - false_negatives: 20.0000 - val_loss: 0.2244 - val_accuracy: 0.9363 - val_precision: 0.8367 - val_recall: 0.8200 - val_auc: 0.9593 - val_true_positives: 41.0000 - val_true_negatives: 209.0000 - val_false_positives: 8.0000 - val_false_negatives: 9.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 962us/sample - loss: 0.2169 - accuracy: 0.9462 - precision: 0.8659 - recall: 0.8908 - auc: 0.9767 - true_positives: 155.0000 - true_negatives: 601.0000 - false_positives: 24.0000 - false_negatives: 19.0000 - val_loss: 0.2189 - val_accuracy: 0.9438 - val_precision: 0.8889 - val_recall: 0.8000 - val_auc: 0.9649 - val_true_positives: 40.0000 - val_true_negatives: 212.0000 - val_false_positives: 5.0000 - val_false_negatives: 10.0000
# Scores for fold 9:
# loss of 0.23112757352449126
# accuracy of 0.9237288236618042
# precision of 0.8999999761581421
# recall of 0.7200000286102295
# auc of 0.9139785170555115
# true_positives of 18.0
# true_negatives of 91.0
# false_positives of 2.0
# In training:
# Class 0: 78.89%
# Class 1: 21.11%
# In test:
# Class 0: 79.66%
# Class 1: 20.34%
# ------------------------------------------------------------------------
#
# Training for fold 10 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 4s 5ms/sample - loss: 0.5641 - accuracy: 0.3630 - precision: 0.2435 - recall: 0.9138 - auc: 0.8320 - true_positives: 159.0000 - true_negatives: 131.0000 - false_positives: 494.0000 - false_negatives: 15.0000 - val_loss: 0.5129 - val_accuracy: 0.4831 - val_precision: 0.2674 - val_recall: 0.9804 - val_auc: 0.9209 - val_true_positives: 50.0000 - val_true_negatives: 79.0000 - val_false_positives: 137.0000 - val_false_negatives: 1.0000
# Epoch 2/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.4927 - accuracy: 0.5707 - precision: 0.3340 - recall: 0.9770 - auc: 0.9227 - true_positives: 170.0000 - true_negatives: 286.0000 - false_positives: 339.0000 - false_negatives: 4.0000 - val_loss: 0.4775 - val_accuracy: 0.7828 - val_precision: 0.4624 - val_recall: 0.8431 - val_auc: 0.8704 - val_true_positives: 43.0000 - val_true_negatives: 166.0000 - val_false_positives: 50.0000 - val_false_negatives: 8.0000
# Epoch 3/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.4062 - accuracy: 0.8023 - precision: 0.5260 - recall: 0.9310 - auc: 0.9427 - true_positives: 162.0000 - true_negatives: 479.0000 - false_positives: 146.0000 - false_negatives: 12.0000 - val_loss: 0.3835 - val_accuracy: 0.8240 - val_precision: 0.5244 - val_recall: 0.8431 - val_auc: 0.9161 - val_true_positives: 43.0000 - val_true_negatives: 177.0000 - val_false_positives: 39.0000 - val_false_negatives: 8.0000
# Epoch 4/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.3065 - accuracy: 0.8661 - precision: 0.6390 - recall: 0.8851 - auc: 0.9577 - true_positives: 154.0000 - true_negatives: 538.0000 - false_positives: 87.0000 - false_negatives: 20.0000 - val_loss: 0.3480 - val_accuracy: 0.8577 - val_precision: 0.5915 - val_recall: 0.8235 - val_auc: 0.9155 - val_true_positives: 42.0000 - val_true_negatives: 187.0000 - val_false_positives: 29.0000 - val_false_negatives: 9.0000
# Epoch 5/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.2417 - accuracy: 0.9011 - precision: 0.7056 - recall: 0.9368 - auc: 0.9770 - true_positives: 163.0000 - true_negatives: 557.0000 - false_positives: 68.0000 - false_negatives: 11.0000 - val_loss: 0.3344 - val_accuracy: 0.8652 - val_precision: 0.6056 - val_recall: 0.8431 - val_auc: 0.9251 - val_true_positives: 43.0000 - val_true_negatives: 188.0000 - val_false_positives: 28.0000 - val_false_negatives: 8.0000
# Epoch 6/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.1911 - accuracy: 0.9324 - precision: 0.7913 - recall: 0.9368 - auc: 0.9850 - true_positives: 163.0000 - true_negatives: 582.0000 - false_positives: 43.0000 - false_negatives: 11.0000 - val_loss: 0.3407 - val_accuracy: 0.8240 - val_precision: 0.5233 - val_recall: 0.8824 - val_auc: 0.9347 - val_true_positives: 45.0000 - val_true_negatives: 175.0000 - val_false_positives: 41.0000 - val_false_negatives: 6.0000
# Epoch 7/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.1677 - accuracy: 0.9324 - precision: 0.7679 - recall: 0.9885 - auc: 0.9920 - true_positives: 172.0000 - true_negatives: 573.0000 - false_positives: 52.0000 - false_negatives: 2.0000 - val_loss: 0.3474 - val_accuracy: 0.8876 - val_precision: 0.6721 - val_recall: 0.8039 - val_auc: 0.9218 - val_true_positives: 41.0000 - val_true_negatives: 196.0000 - val_false_positives: 20.0000 - val_false_negatives: 10.0000
# Epoch 8/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.1447 - accuracy: 0.9437 - precision: 0.8116 - recall: 0.9655 - auc: 0.9910 - true_positives: 168.0000 - true_negatives: 586.0000 - false_positives: 39.0000 - false_negatives: 6.0000 - val_loss: 0.3255 - val_accuracy: 0.8764 - val_precision: 0.6250 - val_recall: 0.8824 - val_auc: 0.9365 - val_true_positives: 45.0000 - val_true_negatives: 189.0000 - val_false_positives: 27.0000 - val_false_negatives: 6.0000
# Epoch 9/10
# 799/799 [==============================] - 1s 1ms/sample - loss: 0.1136 - accuracy: 0.9487 - precision: 0.8152 - recall: 0.9885 - auc: 0.9978 - true_positives: 172.0000 - true_negatives: 586.0000 - false_positives: 39.0000 - false_negatives: 2.0000 - val_loss: 0.3988 - val_accuracy: 0.9139 - val_precision: 0.7800 - val_recall: 0.7647 - val_auc: 0.9160 - val_true_positives: 39.0000 - val_true_negatives: 205.0000 - val_false_positives: 11.0000 - val_false_negatives: 12.0000
# Epoch 10/10
# 799/799 [==============================] - 1s 942us/sample - loss: 0.1037 - accuracy: 0.9650 - precision: 0.8883 - recall: 0.9598 - auc: 0.9966 - true_positives: 167.0000 - true_negatives: 604.0000 - false_positives: 21.0000 - false_negatives: 7.0000 - val_loss: 0.3542 - val_accuracy: 0.8614 - val_precision: 0.5972 - val_recall: 0.8431 - val_auc: 0.9353 - val_true_positives: 43.0000 - val_true_negatives: 187.0000 - val_false_positives: 29.0000 - val_false_negatives: 8.0000
# Scores for fold 10:
# loss of 0.4794699352676586
# accuracy of 0.8389830589294434
# precision of 0.5641025900840759
# recall of 0.9166666865348816
# auc of 0.9625443816184998
# true_positives of 22.0
# true_negatives of 77.0
# false_positives of 17.0

# %%
print("Acurácia média: ",np.mean(acc))
print("Precisão média: ",np.mean(prec))
print("Recall médio: ",np.mean(rec))
print("Auc média: ",np.mean(auc))
# Out:
# Acurácia média:  0.9079262
# Precisão média:  0.803661
# Recall médio:  0.7836667
# Auc média:  0.9349785
