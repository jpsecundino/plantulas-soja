# %% [markdown]
# # Creating dataset

# %% [markdown]
# # Creating classification model

# %%
import os
import pickle
import numpy as np
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import shutil
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# Using TensorFlow backend.

# %%
DATASET_PATH = '../../datasets/Classification/Dataset - 7 dias'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %% [markdown]
# ##### Read dataset

# %%
IMG_SIZE = 256
NUM_CLASSES = 2
def read_dataset():
    images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
    images = pickle.load(images_raw)

    labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
    labels = pickle.load(labels_raw)

    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels

# %% [markdown]
# ###### Turn it into a binary classification problem

# %%
def to_binary(labels):
    labels[labels == 2] = 1
    return labels

# %% [markdown]
# ###### Train Test split

# %%
def count_samples(train_labels, test_labels):
    print("In training:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')


def train_test_split(images, labels):

    from sklearn.model_selection import train_test_split

    train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.1, stratify=labels)
    
    print("In training:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')
        
    return train_images, test_images, train_labels, test_labels

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
# Trying class weights
# it does not work with one hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

def get_sample_weights(train_labels):
    from sklearn.utils import compute_sample_weight
    
    return compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
def to_one_hot(data):
    import pandas as pd
    data = pd.get_dummies(data)
    data = pd.DataFrame.to_numpy(data)
    return data

# %% [markdown]
# ##### Normalizing training images

# %%
def normalize_images(data):
    data = tf.keras.utils.normalize(data, axis=0, order=2)
    return data

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = None
TRAIN_TEST_SPLIT = None
BATCH_SIZE = None
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

METRICDIR = '../metricas/classificacao/7_d/tests-binary'

MODELDIR = os.path.join(METRICDIR, "adhoc")

CHECKPOINT_DIR = os.path.join(MODELDIR, "models") 

if os.path.exists(MODELDIR):
    shutil.rmtree(MODELDIR)
    os.makedirs(CHECKPOINT_DIR)
    
my_metrics = ["accuracy",
       tf.keras.metrics.Precision(),
       tf.keras.metrics.Recall(),
       tf.keras.metrics.AUC(),
       tf.keras.metrics.TruePositives(),
       tf.keras.metrics.TrueNegatives(),
       tf.keras.metrics.FalsePositives(),
       tf.keras.metrics.FalseNegatives(),]

# %%
def create_model():
       
    model = Sequential()

    model.add(   Conv2D(8, (3,3), input_shape=(IMG_SIZE,IMG_SIZE, 3))  )
    model.add(Dropout(rate=0.3))
    model.add(Activation("relu"))

    model.add(Conv2D(6, (3,3)))
    model.add(Dropout(rate=0.3))
    model.add(Activation("relu"))
    
    model.add(Conv2D(2, (3,3)))
    model.add(Dropout(rate=0.4))
    model.add(Activation("relu"))
    
    model.add(Flatten())
    model.add(Dense(1))
    
    model.add(Activation("sigmoid"))
    
    opt = tf.keras.optimizers.Adam()
    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=my_metrics)
    
    return model

def get_model_name(k):
    return 'model_'+str(k)

def plot_metric(history,metric_name, chart_name, save_dir, save = False, show = False):
    plt.cla() 
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if save:
        plt.savefig(os.path.join(save_dir, metric_name))
    if show:
        plt.show()
        
def plot_cm(cf_matrix, save_dir, save):
    
    import seaborn as sns; sns.set_theme()
   
    group_names = ['True Pos','False Pos','False Neg','True Neg']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cf_matrix.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    
    plt.cla() 
    
    sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
    if save:
        plt.savefig(os.path.join(save_dir, "confusion matrix"))
    plt.show()

# %% [markdown]
# ##### Testing the model

# %%
def one_hot_to_1d(test_labels):
    
    test_labels_1d = []
    
    for label in test_labels:
        print()
        if (label == [1, 0]).all():
            test_labels_1d.append(0)
        elif (label == [0, 1]).all():
            test_labels_1d.append(1)
        else:
            test_labels_1d.append(2)
    
    return test_labels_1d
    
def get_predictions(model,test_images, test_labels):
    prediction = model.predict(test_images, batch_size=1)

    return tf.argmax(prediction, axis=-1)

# %%
def train_models(train_images, train_labels, num_folds=10):
    
    from sklearn.model_selection import StratifiedKFold
    
    kfold = StratifiedKFold(n_splits=num_folds)

    #metrics containers
    acc = []
    prec = []
    rec = []
    auc = []

    # K-fold Cross Validation model evaluation
    fold_no = 1
    for train, test in kfold.split(train_images, train_labels):

        count_samples(train_labels[train], train_labels[test])
        
#         from tf.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

        if fold_no - 1 == 0:
            idx_str = ""
        else:
            idx_str = f"_{fold_no}"
            
        fold_checkpoint_dir = os.path.join(CHECKPOINT_DIR, get_model_name(fold_no))
        
        if not os.path.exists(fold_checkpoint_dir):
            os.makedirs(fold_checkpoint_dir)
        
#         my_callbacks = [
# #             ModelCheckpoint(os.path.join(fold_checkpoint_dir,"model.h5"), monitor=f"val_precision", verbose=1, save_best_only=True, mode='max', save_freq='epoch'),
#             ReduceLROnPlateau(monitor=f'loss', factor=0.7, patience=2, min_lr=0.00000000001, mode='min'),
#         ]

        model = create_model()

        # Generate a print
        print('------------------------------------------------------------------------', end="\n\n")
        print(f'Training for fold {fold_no} ...')

#         # Fit data to model
#         history = model.fit(
#             train_images[train],
#             train_labels[train],
#             batch_size = BATCH_SIZE,
#             epochs = EPOCHS,
#             validation_split=TRAIN_TEST_SPLIT,
#             sample_weight=get_sample_weights(train_labels[train]),
#             callbacks=[my_callbacks])
        # Fit data to model
        history = model.fit(
            train_images[train],
            train_labels[train],
            batch_size = BATCH_SIZE,
            epochs = EPOCHS,
            validation_split=TRAIN_TEST_SPLIT,
            sample_weight=get_sample_weights(train_labels[train]))
        
        thresh = 0.5
        
        prediction = model.predict(train_images[test], batch_size=1)
        prediction[prediction > thresh] = 1
        prediction[prediction <= thresh] = 0
        
        cm = metrics.confusion_matrix(train_labels[test],prediction )
        
        plot_cm(cm, save_dir=fold_checkpoint_dir, save=True)
        
        #visualizing training
        NUM_METRICS = len(my_metrics) + 1
        for metric in list(history.history.keys())[:NUM_METRICS]:
            plot_metric(history, metric, metric + " for soybean classification", save_dir=fold_checkpoint_dir, save=True)

        # Generate generalization metrics
        scores = model.evaluate(train_images[test], train_labels[test], verbose=0)
        print(f'Scores for fold {fold_no}:')
        for i in range(len(my_metrics)):   
            print(f'{model.metrics_names[i]} of {scores[i]}')

        acc.append(scores[1])
        prec.append(scores[2])
        rec.append(scores[3])
        auc.append(scores[4])

        # Increase fold number
        fold_no = fold_no + 1
        
    return acc, prec, rec, auc

# %% [markdown]
# ##### Training

# %%
images, labels = read_dataset()

images = normalize_images(images)
labels = to_binary(labels)

# %%
EPOCHS = 10
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
acc, prec, rec, auc = train_models(images, labels)
# Out:
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 1 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 8s 10ms/sample - loss: 0.6813 - accuracy: 0.4549 - precision: 0.2343 - recall: 0.6744 - auc: 0.6346 - true_positives: 116.0000 - true_negatives: 247.0000 - false_positives: 379.0000 - false_negatives: 56.0000 - val_loss: 0.6746 - val_accuracy: 0.1948 - val_precision: 0.1948 - val_recall: 1.0000 - val_auc: 0.4560 - val_true_positives: 52.0000 - val_true_negatives: 0.0000e+00 - val_false_positives: 215.0000 - val_false_negatives: 0.0000e+00
# Epoch 2/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.5865 - accuracy: 0.2155 - precision: 0.2155 - recall: 1.0000 - auc: 0.8814 - true_positives: 172.0000 - true_negatives: 0.0000e+00 - false_positives: 626.0000 - false_negatives: 0.0000e+00 - val_loss: 0.6738 - val_accuracy: 0.6142 - val_precision: 0.2617 - val_recall: 0.5385 - val_auc: 0.5324 - val_true_positives: 28.0000 - val_true_negatives: 136.0000 - val_false_positives: 79.0000 - val_false_negatives: 24.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.5495 - accuracy: 0.2155 - precision: 0.2155 - recall: 1.0000 - auc: 0.9184 - true_positives: 172.0000 - true_negatives: 0.0000e+00 - false_positives: 626.0000 - false_negatives: 0.0000e+00 - val_loss: 0.6532 - val_accuracy: 0.7041 - val_precision: 0.3579 - val_recall: 0.6538 - val_auc: 0.7483 - val_true_positives: 34.0000 - val_true_negatives: 154.0000 - val_false_positives: 61.0000 - val_false_negatives: 18.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.5208 - accuracy: 0.2556 - precision: 0.2245 - recall: 1.0000 - auc: 0.9447 - true_positives: 172.0000 - true_negatives: 32.0000 - false_positives: 594.0000 - false_negatives: 0.0000e+00 - val_loss: 0.5519 - val_accuracy: 0.7266 - val_precision: 0.4103 - val_recall: 0.9231 - val_auc: 0.9209 - val_true_positives: 48.0000 - val_true_negatives: 146.0000 - val_false_positives: 69.0000 - val_false_negatives: 4.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4922 - accuracy: 0.3885 - precision: 0.2591 - recall: 0.9884 - auc: 0.9615 - true_positives: 170.0000 - true_negatives: 140.0000 - false_positives: 486.0000 - false_negatives: 2.0000 - val_loss: 0.4735 - val_accuracy: 0.6255 - val_precision: 0.3400 - val_recall: 0.9808 - val_auc: 0.9649 - val_true_positives: 51.0000 - val_true_negatives: 116.0000 - val_false_positives: 99.0000 - val_false_negatives: 1.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4608 - accuracy: 0.5689 - precision: 0.3327 - recall: 0.9942 - auc: 0.9670 - true_positives: 171.0000 - true_negatives: 283.0000 - false_positives: 343.0000 - false_negatives: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.8689 - val_precision: 0.6104 - val_recall: 0.9038 - val_auc: 0.9344 - val_true_positives: 47.0000 - val_true_negatives: 185.0000 - val_false_positives: 30.0000 - val_false_negatives: 5.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4039 - accuracy: 0.7782 - precision: 0.4924 - recall: 0.9360 - auc: 0.9363 - true_positives: 161.0000 - true_negatives: 460.0000 - false_positives: 166.0000 - false_negatives: 11.0000 - val_loss: 0.3799 - val_accuracy: 0.7341 - val_precision: 0.4188 - val_recall: 0.9423 - val_auc: 0.9405 - val_true_positives: 49.0000 - val_true_negatives: 147.0000 - val_false_positives: 68.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1930 - accuracy: 0.9223 - precision: 0.7696 - recall: 0.9128 - auc: 0.9776 - true_positives: 157.0000 - true_negatives: 579.0000 - false_positives: 47.0000 - false_negatives: 15.0000 - val_loss: 0.2464 - val_accuracy: 0.8839 - val_precision: 0.6364 - val_recall: 0.9423 - val_auc: 0.9733 - val_true_positives: 49.0000 - val_true_negatives: 187.0000 - val_false_positives: 28.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1164 - accuracy: 0.9561 - precision: 0.8586 - recall: 0.9535 - auc: 0.9899 - true_positives: 164.0000 - true_negatives: 599.0000 - false_positives: 27.0000 - false_negatives: 8.0000 - val_loss: 0.2724 - val_accuracy: 0.8727 - val_precision: 0.6125 - val_recall: 0.9423 - val_auc: 0.9642 - val_true_positives: 49.0000 - val_true_negatives: 184.0000 - val_false_positives: 31.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0686 - accuracy: 0.9825 - precision: 0.9341 - recall: 0.9884 - auc: 0.9941 - true_positives: 170.0000 - true_negatives: 614.0000 - false_positives: 12.0000 - false_negatives: 2.0000 - val_loss: 0.2896 - val_accuracy: 0.8652 - val_precision: 0.5976 - val_recall: 0.9423 - val_auc: 0.9607 - val_true_positives: 49.0000 - val_true_negatives: 182.0000 - val_false_positives: 33.0000 - val_false_negatives: 3.0000
# Scores for fold 1:
# loss of 0.33831506366489317
# accuracy of 0.8907563090324402
# precision of 0.6875
# recall of 0.8799999952316284
# auc of 0.9257447123527527
# true_positives of 22.0
# true_negatives of 84.0
# false_positives of 10.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 2 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 0.5461 - accuracy: 0.2732 - precision: 0.2251 - recall: 0.9709 - auc: 0.9000 - true_positives: 167.0000 - true_negatives: 51.0000 - false_positives: 575.0000 - false_negatives: 5.0000 - val_loss: 0.4809 - val_accuracy: 0.3708 - val_precision: 0.2364 - val_recall: 1.0000 - val_auc: 0.9657 - val_true_positives: 52.0000 - val_true_negatives: 47.0000 - val_false_positives: 168.0000 - val_false_negatives: 0.0000e+00
# Epoch 2/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4710 - accuracy: 0.5313 - precision: 0.3123 - recall: 0.9767 - auc: 0.9480 - true_positives: 168.0000 - true_negatives: 256.0000 - false_positives: 370.0000 - false_negatives: 4.0000 - val_loss: 0.4274 - val_accuracy: 0.7303 - val_precision: 0.4138 - val_recall: 0.9231 - val_auc: 0.9308 - val_true_positives: 48.0000 - val_true_negatives: 147.0000 - val_false_positives: 68.0000 - val_false_negatives: 4.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.3777 - accuracy: 0.8033 - precision: 0.5258 - recall: 0.8895 - auc: 0.9223 - true_positives: 153.0000 - true_negatives: 488.0000 - false_positives: 138.0000 - false_negatives: 19.0000 - val_loss: 0.3815 - val_accuracy: 0.7828 - val_precision: 0.4712 - val_recall: 0.9423 - val_auc: 0.9533 - val_true_positives: 49.0000 - val_true_negatives: 160.0000 - val_false_positives: 55.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.2867 - accuracy: 0.8797 - precision: 0.6583 - recall: 0.9186 - auc: 0.9535 - true_positives: 158.0000 - true_negatives: 544.0000 - false_positives: 82.0000 - false_negatives: 14.0000 - val_loss: 0.2470 - val_accuracy: 0.9176 - val_precision: 0.7500 - val_recall: 0.8654 - val_auc: 0.9549 - val_true_positives: 45.0000 - val_true_negatives: 200.0000 - val_false_positives: 15.0000 - val_false_negatives: 7.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1800 - accuracy: 0.9323 - precision: 0.7921 - recall: 0.9302 - auc: 0.9797 - true_positives: 160.0000 - true_negatives: 584.0000 - false_positives: 42.0000 - false_negatives: 12.0000 - val_loss: 0.2029 - val_accuracy: 0.9101 - val_precision: 0.7059 - val_recall: 0.9231 - val_auc: 0.9733 - val_true_positives: 48.0000 - val_true_negatives: 195.0000 - val_false_positives: 20.0000 - val_false_negatives: 4.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1619 - accuracy: 0.9398 - precision: 0.8100 - recall: 0.9419 - auc: 0.9827 - true_positives: 162.0000 - true_negatives: 588.0000 - false_positives: 38.0000 - false_negatives: 10.0000 - val_loss: 0.2055 - val_accuracy: 0.9101 - val_precision: 0.7000 - val_recall: 0.9423 - val_auc: 0.9738 - val_true_positives: 49.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0846 - accuracy: 0.9699 - precision: 0.9022 - recall: 0.9651 - auc: 0.9953 - true_positives: 166.0000 - true_negatives: 608.0000 - false_positives: 18.0000 - false_negatives: 6.0000 - val_loss: 0.1872 - val_accuracy: 0.9476 - val_precision: 0.8167 - val_recall: 0.9423 - val_auc: 0.9730 - val_true_positives: 49.0000 - val_true_negatives: 204.0000 - val_false_positives: 11.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0506 - accuracy: 0.9837 - precision: 0.9441 - recall: 0.9826 - auc: 0.9990 - true_positives: 169.0000 - true_negatives: 616.0000 - false_positives: 10.0000 - false_negatives: 3.0000 - val_loss: 0.1948 - val_accuracy: 0.9551 - val_precision: 0.8448 - val_recall: 0.9423 - val_auc: 0.9697 - val_true_positives: 49.0000 - val_true_negatives: 206.0000 - val_false_positives: 9.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0350 - accuracy: 0.9925 - precision: 0.9716 - recall: 0.9942 - auc: 0.9993 - true_positives: 171.0000 - true_negatives: 621.0000 - false_positives: 5.0000 - false_negatives: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9551 - val_precision: 0.8448 - val_recall: 0.9423 - val_auc: 0.9709 - val_true_positives: 49.0000 - val_true_negatives: 206.0000 - val_false_positives: 9.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0205 - accuracy: 0.9950 - precision: 0.9828 - recall: 0.9942 - auc: 0.9999 - true_positives: 171.0000 - true_negatives: 623.0000 - false_positives: 3.0000 - false_negatives: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9551 - val_precision: 0.8704 - val_recall: 0.9038 - val_auc: 0.9663 - val_true_positives: 47.0000 - val_true_negatives: 208.0000 - val_false_positives: 7.0000 - val_false_negatives: 5.0000
# Scores for fold 2:
# loss of 0.2316632121957901
# accuracy of 0.9159663915634155
# precision of 0.9411764740943909
# recall of 0.6399999856948853
# auc of 0.9527660608291626
# true_positives of 16.0
# true_negatives of 93.0
# false_positives of 1.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 3 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 0.6288 - accuracy: 0.3571 - precision: 0.2323 - recall: 0.8605 - auc: 0.7149 - true_positives: 148.0000 - true_negatives: 137.0000 - false_positives: 489.0000 - false_negatives: 24.0000 - val_loss: 0.5736 - val_accuracy: 0.5768 - val_precision: 0.3152 - val_recall: 1.0000 - val_auc: 0.9323 - val_true_positives: 52.0000 - val_true_negatives: 102.0000 - val_false_positives: 113.0000 - val_false_negatives: 0.0000e+00
# Epoch 2/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.5143 - accuracy: 0.3935 - precision: 0.2615 - recall: 0.9942 - auc: 0.9279 - true_positives: 171.0000 - true_negatives: 143.0000 - false_positives: 483.0000 - false_negatives: 1.0000 - val_loss: 0.3951 - val_accuracy: 0.8951 - val_precision: 0.6667 - val_recall: 0.9231 - val_auc: 0.9716 - val_true_positives: 48.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 4.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.2968 - accuracy: 0.9110 - precision: 0.7672 - recall: 0.8430 - auc: 0.9417 - true_positives: 145.0000 - true_negatives: 582.0000 - false_positives: 44.0000 - false_negatives: 27.0000 - val_loss: 0.1878 - val_accuracy: 0.9401 - val_precision: 0.7903 - val_recall: 0.9423 - val_auc: 0.9719 - val_true_positives: 49.0000 - val_true_negatives: 202.0000 - val_false_positives: 13.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1748 - accuracy: 0.9386 - precision: 0.8254 - recall: 0.9070 - auc: 0.9816 - true_positives: 156.0000 - true_negatives: 593.0000 - false_positives: 33.0000 - false_negatives: 16.0000 - val_loss: 0.1801 - val_accuracy: 0.9700 - val_precision: 0.9074 - val_recall: 0.9423 - val_auc: 0.9698 - val_true_positives: 49.0000 - val_true_negatives: 210.0000 - val_false_positives: 5.0000 - val_false_negatives: 3.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1290 - accuracy: 0.9549 - precision: 0.8542 - recall: 0.9535 - auc: 0.9877 - true_positives: 164.0000 - true_negatives: 598.0000 - false_positives: 28.0000 - false_negatives: 8.0000 - val_loss: 0.2109 - val_accuracy: 0.9326 - val_precision: 0.7656 - val_recall: 0.9423 - val_auc: 0.9692 - val_true_positives: 49.0000 - val_true_negatives: 200.0000 - val_false_positives: 15.0000 - val_false_negatives: 3.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.1062 - accuracy: 0.9699 - precision: 0.9022 - recall: 0.9651 - auc: 0.9912 - true_positives: 166.0000 - true_negatives: 608.0000 - false_positives: 18.0000 - false_negatives: 6.0000 - val_loss: 0.2028 - val_accuracy: 0.9438 - val_precision: 0.8033 - val_recall: 0.9423 - val_auc: 0.9700 - val_true_positives: 49.0000 - val_true_negatives: 203.0000 - val_false_positives: 12.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0821 - accuracy: 0.9737 - precision: 0.9037 - recall: 0.9826 - auc: 0.9949 - true_positives: 169.0000 - true_negatives: 608.0000 - false_positives: 18.0000 - false_negatives: 3.0000 - val_loss: 0.2496 - val_accuracy: 0.9288 - val_precision: 0.7538 - val_recall: 0.9423 - val_auc: 0.9700 - val_true_positives: 49.0000 - val_true_negatives: 199.0000 - val_false_positives: 16.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0720 - accuracy: 0.9762 - precision: 0.9180 - recall: 0.9767 - auc: 0.9969 - true_positives: 168.0000 - true_negatives: 611.0000 - false_positives: 15.0000 - false_negatives: 4.0000 - val_loss: 0.3054 - val_accuracy: 0.8951 - val_precision: 0.6622 - val_recall: 0.9423 - val_auc: 0.9648 - val_true_positives: 49.0000 - val_true_negatives: 190.0000 - val_false_positives: 25.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0469 - accuracy: 0.9937 - precision: 0.9771 - recall: 0.9942 - auc: 0.9982 - true_positives: 171.0000 - true_negatives: 622.0000 - false_positives: 4.0000 - false_negatives: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9213 - val_precision: 0.7313 - val_recall: 0.9423 - val_auc: 0.9616 - val_true_positives: 49.0000 - val_true_negatives: 197.0000 - val_false_positives: 18.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0392 - accuracy: 0.9850 - precision: 0.9494 - recall: 0.9826 - auc: 0.9993 - true_positives: 169.0000 - true_negatives: 617.0000 - false_positives: 9.0000 - false_negatives: 3.0000 - val_loss: 0.3152 - val_accuracy: 0.9176 - val_precision: 0.7206 - val_recall: 0.9423 - val_auc: 0.9623 - val_true_positives: 49.0000 - val_true_negatives: 196.0000 - val_false_positives: 19.0000 - val_false_negatives: 3.0000
# Scores for fold 3:
# loss of 0.2503217662833318
# accuracy of 0.9495798349380493
# precision of 0.8518518805503845
# recall of 0.9200000166893005
# auc of 0.9619148969650269
# true_positives of 23.0
# true_negatives of 90.0
# false_positives of 4.0
# In training:
# Class 0: 78.97%
# Class 1: 21.03%
# In test:
# Class 0: 78.99%
# Class 1: 21.01%
# ------------------------------------------------------------------------
#
# Training for fold 4 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 0.5710 - accuracy: 0.2581 - precision: 0.2230 - recall: 0.9826 - auc: 0.8489 - true_positives: 169.0000 - true_negatives: 37.0000 - false_positives: 589.0000 - false_negatives: 3.0000 - val_loss: 0.5354 - val_accuracy: 0.6217 - val_precision: 0.3377 - val_recall: 0.9808 - val_auc: 0.9432 - val_true_positives: 51.0000 - val_true_negatives: 115.0000 - val_false_positives: 100.0000 - val_false_negatives: 1.0000
# Epoch 2/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4761 - accuracy: 0.5251 - precision: 0.3094 - recall: 0.9767 - auc: 0.9401 - true_positives: 168.0000 - true_negatives: 251.0000 - false_positives: 375.0000 - false_negatives: 4.0000 - val_loss: 0.4178 - val_accuracy: 0.7191 - val_precision: 0.4050 - val_recall: 0.9423 - val_auc: 0.9417 - val_true_positives: 49.0000 - val_true_negatives: 143.0000 - val_false_positives: 72.0000 - val_false_negatives: 3.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.3968 - accuracy: 0.8058 - precision: 0.5292 - recall: 0.8953 - auc: 0.9207 - true_positives: 154.0000 - true_negatives: 489.0000 - false_positives: 137.0000 - false_negatives: 18.0000 - val_loss: 0.4078 - val_accuracy: 0.8202 - val_precision: 0.5233 - val_recall: 0.8654 - val_auc: 0.8954 - val_true_positives: 45.0000 - val_true_negatives: 174.0000 - val_false_positives: 41.0000 - val_false_negatives: 7.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.4245 - accuracy: 0.7431 - precision: 0.4543 - recall: 0.9535 - auc: 0.9411 - true_positives: 164.0000 - true_negatives: 429.0000 - false_positives: 197.0000 - false_negatives: 8.0000 - val_loss: 0.4354 - val_accuracy: 0.7341 - val_precision: 0.4174 - val_recall: 0.9231 - val_auc: 0.9266 - val_true_positives: 48.0000 - val_true_negatives: 148.0000 - val_false_positives: 67.0000 - val_false_negatives: 4.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.3378 - accuracy: 0.8033 - precision: 0.5246 - recall: 0.9302 - auc: 0.9567 - true_positives: 160.0000 - true_negatives: 481.0000 - false_positives: 145.0000 - false_negatives: 12.0000 - val_loss: 0.3840 - val_accuracy: 0.8390 - val_precision: 0.5556 - val_recall: 0.8654 - val_auc: 0.9071 - val_true_positives: 45.0000 - val_true_negatives: 179.0000 - val_false_positives: 36.0000 - val_false_negatives: 7.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.2594 - accuracy: 0.8747 - precision: 0.6475 - recall: 0.9186 - auc: 0.9625 - true_positives: 158.0000 - true_negatives: 540.0000 - false_positives: 86.0000 - false_negatives: 14.0000 - val_loss: 0.3812 - val_accuracy: 0.8390 - val_precision: 0.5584 - val_recall: 0.8269 - val_auc: 0.9125 - val_true_positives: 43.0000 - val_true_negatives: 181.0000 - val_false_positives: 34.0000 - val_false_negatives: 9.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.2072 - accuracy: 0.9110 - precision: 0.7327 - recall: 0.9244 - auc: 0.9754 - true_positives: 159.0000 - true_negatives: 568.0000 - false_positives: 58.0000 - false_negatives: 13.0000 - val_loss: 0.2935 - val_accuracy: 0.8764 - val_precision: 0.6338 - val_recall: 0.8654 - val_auc: 0.9427 - val_true_positives: 45.0000 - val_true_negatives: 189.0000 - val_false_positives: 26.0000 - val_false_negatives: 7.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0993 - accuracy: 0.9599 - precision: 0.8571 - recall: 0.9767 - auc: 0.9964 - true_positives: 168.0000 - true_negatives: 598.0000 - false_positives: 28.0000 - false_negatives: 4.0000 - val_loss: 0.2811 - val_accuracy: 0.8951 - val_precision: 0.6579 - val_recall: 0.9615 - val_auc: 0.9670 - val_true_positives: 50.0000 - val_true_negatives: 189.0000 - val_false_positives: 26.0000 - val_false_negatives: 2.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0929 - accuracy: 0.9599 - precision: 0.8646 - recall: 0.9651 - auc: 0.9948 - true_positives: 166.0000 - true_negatives: 600.0000 - false_positives: 26.0000 - false_negatives: 6.0000 - val_loss: 0.3928 - val_accuracy: 0.9476 - val_precision: 0.9318 - val_recall: 0.7885 - val_auc: 0.9541 - val_true_positives: 41.0000 - val_true_negatives: 212.0000 - val_false_positives: 3.0000 - val_false_negatives: 11.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 2ms/sample - loss: 0.0940 - accuracy: 0.9649 - precision: 0.8871 - recall: 0.9593 - auc: 0.9950 - true_positives: 165.0000 - true_negatives: 605.0000 - false_positives: 21.0000 - false_negatives: 7.0000 - val_loss: 0.4378 - val_accuracy: 0.8352 - val_precision: 0.5444 - val_recall: 0.9423 - val_auc: 0.9528 - val_true_positives: 49.0000 - val_true_negatives: 174.0000 - val_false_positives: 41.0000 - val_false_negatives: 3.0000
# Scores for fold 4:
# loss of 0.7685736658192482
# accuracy of 0.8151260614395142
# precision of 0.5365853905677795
# recall of 0.8799999952316284
# auc of 0.8812766075134277
# true_positives of 22.0
# true_negatives of 75.0
# false_positives of 19.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 5 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 6s 8ms/sample - loss: 0.5013 - accuracy: 0.6458 - precision: 0.3595 - recall: 0.8256 - auc: 0.8381 - true_positives: 142.0000 - true_negatives: 374.0000 - false_positives: 253.0000 - false_negatives: 30.0000 - val_loss: 0.3707 - val_accuracy: 0.7828 - val_precision: 0.4722 - val_recall: 0.9808 - val_auc: 0.9735 - val_true_positives: 51.0000 - val_true_negatives: 158.0000 - val_false_positives: 57.0000 - val_false_negatives: 1.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2319 - accuracy: 0.9249 - precision: 0.8043 - recall: 0.8605 - auc: 0.9675 - true_positives: 148.0000 - true_negatives: 591.0000 - false_positives: 36.0000 - false_negatives: 24.0000 - val_loss: 0.2404 - val_accuracy: 0.8539 - val_precision: 0.5747 - val_recall: 0.9615 - val_auc: 0.9712 - val_true_positives: 50.0000 - val_true_negatives: 178.0000 - val_false_positives: 37.0000 - val_false_negatives: 2.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1478 - accuracy: 0.9462 - precision: 0.8377 - recall: 0.9302 - auc: 0.9874 - true_positives: 160.0000 - true_negatives: 596.0000 - false_positives: 31.0000 - false_negatives: 12.0000 - val_loss: 0.1844 - val_accuracy: 0.9401 - val_precision: 0.7903 - val_recall: 0.9423 - val_auc: 0.9698 - val_true_positives: 49.0000 - val_true_negatives: 202.0000 - val_false_positives: 13.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1477 - accuracy: 0.9524 - precision: 0.8602 - recall: 0.9302 - auc: 0.9852 - true_positives: 160.0000 - true_negatives: 601.0000 - false_positives: 26.0000 - false_negatives: 12.0000 - val_loss: 0.4349 - val_accuracy: 0.7566 - val_precision: 0.4425 - val_recall: 0.9615 - val_auc: 0.9643 - val_true_positives: 50.0000 - val_true_negatives: 152.0000 - val_false_positives: 63.0000 - val_false_negatives: 2.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1052 - accuracy: 0.9662 - precision: 0.8919 - recall: 0.9593 - auc: 0.9941 - true_positives: 165.0000 - true_negatives: 607.0000 - false_positives: 20.0000 - false_negatives: 7.0000 - val_loss: 0.3129 - val_accuracy: 0.8502 - val_precision: 0.5698 - val_recall: 0.9423 - val_auc: 0.9610 - val_true_positives: 49.0000 - val_true_negatives: 178.0000 - val_false_positives: 37.0000 - val_false_negatives: 3.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0730 - accuracy: 0.9825 - precision: 0.9438 - recall: 0.9767 - auc: 0.9960 - true_positives: 168.0000 - true_negatives: 617.0000 - false_positives: 10.0000 - false_negatives: 4.0000 - val_loss: 0.2641 - val_accuracy: 0.9101 - val_precision: 0.7000 - val_recall: 0.9423 - val_auc: 0.9610 - val_true_positives: 49.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0511 - accuracy: 0.9900 - precision: 0.9607 - recall: 0.9942 - auc: 0.9983 - true_positives: 171.0000 - true_negatives: 620.0000 - false_positives: 7.0000 - false_negatives: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.8764 - val_precision: 0.6203 - val_recall: 0.9423 - val_auc: 0.9580 - val_true_positives: 49.0000 - val_true_negatives: 185.0000 - val_false_positives: 30.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0437 - accuracy: 0.9900 - precision: 0.9713 - recall: 0.9826 - auc: 0.9990 - true_positives: 169.0000 - true_negatives: 622.0000 - false_positives: 5.0000 - false_negatives: 3.0000 - val_loss: 0.2696 - val_accuracy: 0.9026 - val_precision: 0.6806 - val_recall: 0.9423 - val_auc: 0.9643 - val_true_positives: 49.0000 - val_true_negatives: 192.0000 - val_false_positives: 23.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0327 - accuracy: 0.9950 - precision: 0.9828 - recall: 0.9942 - auc: 0.9994 - true_positives: 171.0000 - true_negatives: 624.0000 - false_positives: 3.0000 - false_negatives: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9176 - val_precision: 0.7206 - val_recall: 0.9423 - val_auc: 0.9650 - val_true_positives: 49.0000 - val_true_negatives: 196.0000 - val_false_positives: 19.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0199 - accuracy: 0.9975 - precision: 0.9942 - recall: 0.9942 - auc: 0.9999 - true_positives: 171.0000 - true_negatives: 626.0000 - false_positives: 1.0000 - false_negatives: 1.0000 - val_loss: 0.3479 - val_accuracy: 0.8876 - val_precision: 0.6447 - val_recall: 0.9423 - val_auc: 0.9567 - val_true_positives: 49.0000 - val_true_negatives: 188.0000 - val_false_positives: 27.0000 - val_false_negatives: 3.0000
# Scores for fold 5:
# loss of 0.37009262533511145
# accuracy of 0.8813559412956238
# precision of 0.6410256624221802
# recall of 1.0
# auc of 0.9870968461036682
# true_positives of 25.0
# true_negatives of 79.0
# false_positives of 14.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 6 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.4833 - accuracy: 0.6708 - precision: 0.3787 - recall: 0.8256 - auc: 0.8530 - true_positives: 142.0000 - true_negatives: 394.0000 - false_positives: 233.0000 - false_negatives: 30.0000 - val_loss: 0.2452 - val_accuracy: 0.8876 - val_precision: 0.6571 - val_recall: 0.8846 - val_auc: 0.9605 - val_true_positives: 46.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 6.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2672 - accuracy: 0.9161 - precision: 0.7838 - recall: 0.8430 - auc: 0.9590 - true_positives: 145.0000 - true_negatives: 587.0000 - false_positives: 40.0000 - false_negatives: 27.0000 - val_loss: 0.1884 - val_accuracy: 0.9326 - val_precision: 0.7656 - val_recall: 0.9423 - val_auc: 0.9710 - val_true_positives: 49.0000 - val_true_negatives: 200.0000 - val_false_positives: 15.0000 - val_false_negatives: 3.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1748 - accuracy: 0.9487 - precision: 0.8619 - recall: 0.9070 - auc: 0.9808 - true_positives: 156.0000 - true_negatives: 602.0000 - false_positives: 25.0000 - false_negatives: 16.0000 - val_loss: 0.2603 - val_accuracy: 0.8502 - val_precision: 0.5682 - val_recall: 0.9615 - val_auc: 0.9760 - val_true_positives: 50.0000 - val_true_negatives: 177.0000 - val_false_positives: 38.0000 - val_false_negatives: 2.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1612 - accuracy: 0.9424 - precision: 0.8281 - recall: 0.9244 - auc: 0.9842 - true_positives: 159.0000 - true_negatives: 594.0000 - false_positives: 33.0000 - false_negatives: 13.0000 - val_loss: 0.2111 - val_accuracy: 0.9026 - val_precision: 0.6806 - val_recall: 0.9423 - val_auc: 0.9695 - val_true_positives: 49.0000 - val_true_negatives: 192.0000 - val_false_positives: 23.0000 - val_false_negatives: 3.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1226 - accuracy: 0.9574 - precision: 0.8710 - recall: 0.9419 - auc: 0.9903 - true_positives: 162.0000 - true_negatives: 603.0000 - false_positives: 24.0000 - false_negatives: 10.0000 - val_loss: 0.3311 - val_accuracy: 0.8352 - val_precision: 0.5444 - val_recall: 0.9423 - val_auc: 0.9641 - val_true_positives: 49.0000 - val_true_negatives: 174.0000 - val_false_positives: 41.0000 - val_false_negatives: 3.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1006 - accuracy: 0.9612 - precision: 0.8730 - recall: 0.9593 - auc: 0.9934 - true_positives: 165.0000 - true_negatives: 603.0000 - false_positives: 24.0000 - false_negatives: 7.0000 - val_loss: 0.2516 - val_accuracy: 0.8989 - val_precision: 0.6712 - val_recall: 0.9423 - val_auc: 0.9622 - val_true_positives: 49.0000 - val_true_negatives: 191.0000 - val_false_positives: 24.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0645 - accuracy: 0.9850 - precision: 0.9444 - recall: 0.9884 - auc: 0.9972 - true_positives: 170.0000 - true_negatives: 617.0000 - false_positives: 10.0000 - false_negatives: 2.0000 - val_loss: 0.2532 - val_accuracy: 0.9101 - val_precision: 0.7000 - val_recall: 0.9423 - val_auc: 0.9647 - val_true_positives: 49.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0528 - accuracy: 0.9912 - precision: 0.9661 - recall: 0.9942 - auc: 0.9973 - true_positives: 171.0000 - true_negatives: 621.0000 - false_positives: 6.0000 - false_negatives: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9438 - val_precision: 0.8033 - val_recall: 0.9423 - val_auc: 0.9660 - val_true_positives: 49.0000 - val_true_negatives: 203.0000 - val_false_positives: 12.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0439 - accuracy: 0.9875 - precision: 0.9551 - recall: 0.9884 - auc: 0.9992 - true_positives: 170.0000 - true_negatives: 619.0000 - false_positives: 8.0000 - false_negatives: 2.0000 - val_loss: 0.2860 - val_accuracy: 0.9101 - val_precision: 0.7000 - val_recall: 0.9423 - val_auc: 0.9622 - val_true_positives: 49.0000 - val_true_negatives: 194.0000 - val_false_positives: 21.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0385 - accuracy: 0.9875 - precision: 0.9551 - recall: 0.9884 - auc: 0.9994 - true_positives: 170.0000 - true_negatives: 619.0000 - false_positives: 8.0000 - false_negatives: 2.0000 - val_loss: 0.3492 - val_accuracy: 0.8914 - val_precision: 0.6533 - val_recall: 0.9423 - val_auc: 0.9636 - val_true_positives: 49.0000 - val_true_negatives: 189.0000 - val_false_positives: 26.0000 - val_false_negatives: 3.0000
# Scores for fold 6:
# loss of 0.21024312382027255
# accuracy of 0.9152542352676392
# precision of 0.7419354915618896
# recall of 0.9200000166893005
# auc of 0.9793548583984375
# true_positives of 23.0
# true_negatives of 85.0
# false_positives of 8.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 7 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.6038 - accuracy: 0.2591 - precision: 0.2244 - recall: 0.9942 - auc: 0.8002 - true_positives: 171.0000 - true_negatives: 36.0000 - false_positives: 591.0000 - false_negatives: 1.0000 - val_loss: 0.6154 - val_accuracy: 0.6554 - val_precision: 0.3485 - val_recall: 0.8846 - val_auc: 0.8374 - val_true_positives: 46.0000 - val_true_negatives: 129.0000 - val_false_positives: 86.0000 - val_false_negatives: 6.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.4271 - accuracy: 0.7084 - precision: 0.4173 - recall: 0.8953 - auc: 0.9007 - true_positives: 154.0000 - true_negatives: 412.0000 - false_positives: 215.0000 - false_negatives: 18.0000 - val_loss: 0.2156 - val_accuracy: 0.9513 - val_precision: 0.9333 - val_recall: 0.8077 - val_auc: 0.9734 - val_true_positives: 42.0000 - val_true_negatives: 212.0000 - val_false_positives: 3.0000 - val_false_negatives: 10.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2237 - accuracy: 0.9487 - precision: 0.8876 - recall: 0.8721 - auc: 0.9641 - true_positives: 150.0000 - true_negatives: 608.0000 - false_positives: 19.0000 - false_negatives: 22.0000 - val_loss: 0.2679 - val_accuracy: 0.8464 - val_precision: 0.5618 - val_recall: 0.9615 - val_auc: 0.9749 - val_true_positives: 50.0000 - val_true_negatives: 176.0000 - val_false_positives: 39.0000 - val_false_negatives: 2.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1984 - accuracy: 0.9274 - precision: 0.7850 - recall: 0.9128 - auc: 0.9734 - true_positives: 157.0000 - true_negatives: 584.0000 - false_positives: 43.0000 - false_negatives: 15.0000 - val_loss: 0.2325 - val_accuracy: 0.8839 - val_precision: 0.6364 - val_recall: 0.9423 - val_auc: 0.9702 - val_true_positives: 49.0000 - val_true_negatives: 187.0000 - val_false_positives: 28.0000 - val_false_negatives: 3.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1242 - accuracy: 0.9549 - precision: 0.8656 - recall: 0.9360 - auc: 0.9901 - true_positives: 161.0000 - true_negatives: 602.0000 - false_positives: 25.0000 - false_negatives: 11.0000 - val_loss: 0.1753 - val_accuracy: 0.9513 - val_precision: 0.8305 - val_recall: 0.9423 - val_auc: 0.9734 - val_true_positives: 49.0000 - val_true_negatives: 205.0000 - val_false_positives: 10.0000 - val_false_negatives: 3.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0804 - accuracy: 0.9775 - precision: 0.9278 - recall: 0.9709 - auc: 0.9937 - true_positives: 167.0000 - true_negatives: 614.0000 - false_positives: 13.0000 - false_negatives: 5.0000 - val_loss: 0.2789 - val_accuracy: 0.8539 - val_precision: 0.5765 - val_recall: 0.9423 - val_auc: 0.9736 - val_true_positives: 49.0000 - val_true_negatives: 179.0000 - val_false_positives: 36.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0583 - accuracy: 0.9837 - precision: 0.9441 - recall: 0.9826 - auc: 0.9979 - true_positives: 169.0000 - true_negatives: 617.0000 - false_positives: 10.0000 - false_negatives: 3.0000 - val_loss: 0.3509 - val_accuracy: 0.8165 - val_precision: 0.5158 - val_recall: 0.9423 - val_auc: 0.9649 - val_true_positives: 49.0000 - val_true_negatives: 169.0000 - val_false_positives: 46.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0684 - accuracy: 0.9750 - precision: 0.9176 - recall: 0.9709 - auc: 0.9973 - true_positives: 167.0000 - true_negatives: 612.0000 - false_positives: 15.0000 - false_negatives: 5.0000 - val_loss: 0.2915 - val_accuracy: 0.8914 - val_precision: 0.6533 - val_recall: 0.9423 - val_auc: 0.9633 - val_true_positives: 49.0000 - val_true_negatives: 189.0000 - val_false_positives: 26.0000 - val_false_negatives: 3.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0339 - accuracy: 0.9962 - precision: 0.9884 - recall: 0.9942 - auc: 0.9985 - true_positives: 171.0000 - true_negatives: 625.0000 - false_positives: 2.0000 - false_negatives: 1.0000 - val_loss: 0.3397 - val_accuracy: 0.8951 - val_precision: 0.6622 - val_recall: 0.9423 - val_auc: 0.9594 - val_true_positives: 49.0000 - val_true_negatives: 190.0000 - val_false_positives: 25.0000 - val_false_negatives: 3.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0347 - accuracy: 0.9887 - precision: 0.9657 - recall: 0.9826 - auc: 0.9995 - true_positives: 169.0000 - true_negatives: 621.0000 - false_positives: 6.0000 - false_negatives: 3.0000 - val_loss: 0.2672 - val_accuracy: 0.9064 - val_precision: 0.6901 - val_recall: 0.9423 - val_auc: 0.9719 - val_true_positives: 49.0000 - val_true_negatives: 193.0000 - val_false_positives: 22.0000 - val_false_negatives: 3.0000
# Scores for fold 7:
# loss of 0.28090216194169
# accuracy of 0.8898305296897888
# precision of 0.699999988079071
# recall of 0.8399999737739563
# auc of 0.9307527542114258
# true_positives of 21.0
# true_negatives of 84.0
# false_positives of 9.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 8 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.5915 - accuracy: 0.2228 - precision: 0.2131 - recall: 0.9540 - auc: 0.8229 - true_positives: 166.0000 - true_negatives: 12.0000 - false_positives: 613.0000 - false_negatives: 8.0000 - val_loss: 0.5207 - val_accuracy: 0.2247 - val_precision: 0.1946 - val_recall: 1.0000 - val_auc: 0.9527 - val_true_positives: 50.0000 - val_true_negatives: 10.0000 - val_false_positives: 207.0000 - val_false_negatives: 0.0000e+00
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.5144 - accuracy: 0.2929 - precision: 0.2347 - recall: 0.9943 - auc: 0.9400 - true_positives: 173.0000 - true_negatives: 61.0000 - false_positives: 564.0000 - false_negatives: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.3820 - val_precision: 0.2326 - val_recall: 1.0000 - val_auc: 0.9750 - val_true_positives: 50.0000 - val_true_negatives: 52.0000 - val_false_positives: 165.0000 - val_false_negatives: 0.0000e+00
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.4575 - accuracy: 0.5657 - precision: 0.3307 - recall: 0.9713 - auc: 0.9475 - true_positives: 169.0000 - true_negatives: 283.0000 - false_positives: 342.0000 - false_negatives: 5.0000 - val_loss: 0.4015 - val_accuracy: 0.7041 - val_precision: 0.3821 - val_recall: 0.9400 - val_auc: 0.9460 - val_true_positives: 47.0000 - val_true_negatives: 141.0000 - val_false_positives: 76.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.3418 - accuracy: 0.8348 - precision: 0.5766 - recall: 0.9080 - auc: 0.9359 - true_positives: 158.0000 - true_negatives: 509.0000 - false_positives: 116.0000 - false_negatives: 16.0000 - val_loss: 0.3014 - val_accuracy: 0.8427 - val_precision: 0.5488 - val_recall: 0.9000 - val_auc: 0.9437 - val_true_positives: 45.0000 - val_true_negatives: 180.0000 - val_false_positives: 37.0000 - val_false_negatives: 5.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2167 - accuracy: 0.9337 - precision: 0.8103 - recall: 0.9080 - auc: 0.9680 - true_positives: 158.0000 - true_negatives: 588.0000 - false_positives: 37.0000 - false_negatives: 16.0000 - val_loss: 0.1822 - val_accuracy: 0.9176 - val_precision: 0.7188 - val_recall: 0.9200 - val_auc: 0.9767 - val_true_positives: 46.0000 - val_true_negatives: 199.0000 - val_false_positives: 18.0000 - val_false_negatives: 4.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1279 - accuracy: 0.9675 - precision: 0.9066 - recall: 0.9483 - auc: 0.9874 - true_positives: 165.0000 - true_negatives: 608.0000 - false_positives: 17.0000 - false_negatives: 9.0000 - val_loss: 0.1944 - val_accuracy: 0.9401 - val_precision: 0.7833 - val_recall: 0.9400 - val_auc: 0.9698 - val_true_positives: 47.0000 - val_true_negatives: 204.0000 - val_false_positives: 13.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0859 - accuracy: 0.9762 - precision: 0.9189 - recall: 0.9770 - auc: 0.9932 - true_positives: 170.0000 - true_negatives: 610.0000 - false_positives: 15.0000 - false_negatives: 4.0000 - val_loss: 0.1871 - val_accuracy: 0.9288 - val_precision: 0.7460 - val_recall: 0.9400 - val_auc: 0.9729 - val_true_positives: 47.0000 - val_true_negatives: 201.0000 - val_false_positives: 16.0000 - val_false_negatives: 3.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0592 - accuracy: 0.9762 - precision: 0.9235 - recall: 0.9713 - auc: 0.9974 - true_positives: 169.0000 - true_negatives: 611.0000 - false_positives: 14.0000 - false_negatives: 5.0000 - val_loss: 0.1944 - val_accuracy: 0.9625 - val_precision: 0.8846 - val_recall: 0.9200 - val_auc: 0.9678 - val_true_positives: 46.0000 - val_true_negatives: 211.0000 - val_false_positives: 6.0000 - val_false_negatives: 4.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0441 - accuracy: 0.9850 - precision: 0.9500 - recall: 0.9828 - auc: 0.9990 - true_positives: 171.0000 - true_negatives: 616.0000 - false_positives: 9.0000 - false_negatives: 3.0000 - val_loss: 0.2339 - val_accuracy: 0.9588 - val_precision: 0.8679 - val_recall: 0.9200 - val_auc: 0.9677 - val_true_positives: 46.0000 - val_true_negatives: 210.0000 - val_false_positives: 7.0000 - val_false_negatives: 4.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0246 - accuracy: 0.9950 - precision: 0.9830 - recall: 0.9943 - auc: 0.9998 - true_positives: 173.0000 - true_negatives: 622.0000 - false_positives: 3.0000 - false_negatives: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9551 - val_precision: 0.8800 - val_recall: 0.8800 - val_auc: 0.9680 - val_true_positives: 44.0000 - val_true_negatives: 211.0000 - val_false_positives: 6.0000 - val_false_negatives: 6.0000
# Scores for fold 8:
# loss of 0.22710870332637076
# accuracy of 0.9491525292396545
# precision of 0.9130434989929199
# recall of 0.8399999737739563
# auc of 0.9630107879638672
# true_positives of 21.0
# true_negatives of 91.0
# false_positives of 2.0
# In training:
# Class 0: 78.99%
# Class 1: 21.01%
# In test:
# Class 0: 78.81%
# Class 1: 21.19%
# ------------------------------------------------------------------------
#
# Training for fold 9 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.5417 - accuracy: 0.6471 - precision: 0.3541 - recall: 0.7529 - auc: 0.7941 - true_positives: 131.0000 - true_negatives: 386.0000 - false_positives: 239.0000 - false_negatives: 43.0000 - val_loss: 0.3359 - val_accuracy: 0.9401 - val_precision: 1.0000 - val_recall: 0.6800 - val_auc: 0.9689 - val_true_positives: 34.0000 - val_true_negatives: 217.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 16.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.3358 - accuracy: 0.9011 - precision: 0.7684 - recall: 0.7816 - auc: 0.9244 - true_positives: 136.0000 - true_negatives: 584.0000 - false_positives: 41.0000 - false_negatives: 38.0000 - val_loss: 0.1435 - val_accuracy: 0.9476 - val_precision: 0.8214 - val_recall: 0.9200 - val_auc: 0.9912 - val_true_positives: 46.0000 - val_true_negatives: 207.0000 - val_false_positives: 10.0000 - val_false_negatives: 4.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2169 - accuracy: 0.9249 - precision: 0.7879 - recall: 0.8966 - auc: 0.9727 - true_positives: 156.0000 - true_negatives: 583.0000 - false_positives: 42.0000 - false_negatives: 18.0000 - val_loss: 0.1294 - val_accuracy: 0.9401 - val_precision: 0.7833 - val_recall: 0.9400 - val_auc: 0.9917 - val_true_positives: 47.0000 - val_true_negatives: 204.0000 - val_false_positives: 13.0000 - val_false_negatives: 3.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1351 - accuracy: 0.9537 - precision: 0.8586 - recall: 0.9425 - auc: 0.9890 - true_positives: 164.0000 - true_negatives: 598.0000 - false_positives: 27.0000 - false_negatives: 10.0000 - val_loss: 0.1289 - val_accuracy: 0.9476 - val_precision: 0.8214 - val_recall: 0.9200 - val_auc: 0.9895 - val_true_positives: 46.0000 - val_true_negatives: 207.0000 - val_false_positives: 10.0000 - val_false_negatives: 4.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1259 - accuracy: 0.9587 - precision: 0.8730 - recall: 0.9483 - auc: 0.9886 - true_positives: 165.0000 - true_negatives: 601.0000 - false_positives: 24.0000 - false_negatives: 9.0000 - val_loss: 0.1594 - val_accuracy: 0.9139 - val_precision: 0.6957 - val_recall: 0.9600 - val_auc: 0.9903 - val_true_positives: 48.0000 - val_true_negatives: 196.0000 - val_false_positives: 21.0000 - val_false_negatives: 2.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1170 - accuracy: 0.9650 - precision: 0.8967 - recall: 0.9483 - auc: 0.9908 - true_positives: 165.0000 - true_negatives: 606.0000 - false_positives: 19.0000 - false_negatives: 9.0000 - val_loss: 0.1474 - val_accuracy: 0.9363 - val_precision: 0.7705 - val_recall: 0.9400 - val_auc: 0.9882 - val_true_positives: 47.0000 - val_true_negatives: 203.0000 - val_false_positives: 14.0000 - val_false_negatives: 3.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0981 - accuracy: 0.9712 - precision: 0.9081 - recall: 0.9655 - auc: 0.9922 - true_positives: 168.0000 - true_negatives: 608.0000 - false_positives: 17.0000 - false_negatives: 6.0000 - val_loss: 0.1641 - val_accuracy: 0.9588 - val_precision: 0.8679 - val_recall: 0.9200 - val_auc: 0.9878 - val_true_positives: 46.0000 - val_true_negatives: 210.0000 - val_false_positives: 7.0000 - val_false_negatives: 4.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0657 - accuracy: 0.9787 - precision: 0.9243 - recall: 0.9828 - auc: 0.9967 - true_positives: 171.0000 - true_negatives: 611.0000 - false_positives: 14.0000 - false_negatives: 3.0000 - val_loss: 0.2002 - val_accuracy: 0.9064 - val_precision: 0.6761 - val_recall: 0.9600 - val_auc: 0.9857 - val_true_positives: 48.0000 - val_true_negatives: 194.0000 - val_false_positives: 23.0000 - val_false_negatives: 2.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0539 - accuracy: 0.9875 - precision: 0.9505 - recall: 0.9943 - auc: 0.9982 - true_positives: 173.0000 - true_negatives: 616.0000 - false_positives: 9.0000 - false_negatives: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9326 - val_precision: 0.7667 - val_recall: 0.9200 - val_auc: 0.9860 - val_true_positives: 46.0000 - val_true_negatives: 203.0000 - val_false_positives: 14.0000 - val_false_negatives: 4.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0443 - accuracy: 0.9925 - precision: 0.9773 - recall: 0.9885 - auc: 0.9984 - true_positives: 172.0000 - true_negatives: 621.0000 - false_positives: 4.0000 - false_negatives: 2.0000 - val_loss: 0.2190 - val_accuracy: 0.9251 - val_precision: 0.7273 - val_recall: 0.9600 - val_auc: 0.9829 - val_true_positives: 48.0000 - val_true_negatives: 199.0000 - val_false_positives: 18.0000 - val_false_negatives: 2.0000
# Scores for fold 9:
# loss of 0.3526978730145147
# accuracy of 0.9237288236618042
# precision of 0.7857142686843872
# recall of 0.8799999952316284
# auc of 0.9288171529769897
# true_positives of 22.0
# true_negatives of 87.0
# false_positives of 6.0
# In training:
# Class 0: 78.89%
# Class 1: 21.11%
# In test:
# Class 0: 79.66%
# Class 1: 20.34%
# ------------------------------------------------------------------------
#
# Training for fold 10 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 7ms/sample - loss: 0.4628 - accuracy: 0.7009 - precision: 0.4095 - recall: 0.8448 - auc: 0.8731 - true_positives: 147.0000 - true_negatives: 413.0000 - false_positives: 212.0000 - false_negatives: 27.0000 - val_loss: 0.2500 - val_accuracy: 0.9513 - val_precision: 0.9750 - val_recall: 0.7647 - val_auc: 0.9682 - val_true_positives: 39.0000 - val_true_negatives: 215.0000 - val_false_positives: 1.0000 - val_false_negatives: 12.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.2543 - accuracy: 0.9237 - precision: 0.7989 - recall: 0.8678 - auc: 0.9601 - true_positives: 151.0000 - true_negatives: 587.0000 - false_positives: 38.0000 - false_negatives: 23.0000 - val_loss: 0.2107 - val_accuracy: 0.9476 - val_precision: 0.8364 - val_recall: 0.9020 - val_auc: 0.9647 - val_true_positives: 46.0000 - val_true_negatives: 207.0000 - val_false_positives: 9.0000 - val_false_negatives: 5.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1708 - accuracy: 0.9437 - precision: 0.8342 - recall: 0.9253 - auc: 0.9833 - true_positives: 161.0000 - true_negatives: 593.0000 - false_positives: 32.0000 - false_negatives: 13.0000 - val_loss: 0.3790 - val_accuracy: 0.9476 - val_precision: 1.0000 - val_recall: 0.7255 - val_auc: 0.9646 - val_true_positives: 37.0000 - val_true_negatives: 216.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 14.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1992 - accuracy: 0.9237 - precision: 0.7729 - recall: 0.9195 - auc: 0.9740 - true_positives: 160.0000 - true_negatives: 578.0000 - false_positives: 47.0000 - false_negatives: 14.0000 - val_loss: 0.2324 - val_accuracy: 0.9513 - val_precision: 0.9318 - val_recall: 0.8039 - val_auc: 0.9633 - val_true_positives: 41.0000 - val_true_negatives: 213.0000 - val_false_positives: 3.0000 - val_false_negatives: 10.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.1181 - accuracy: 0.9662 - precision: 0.8973 - recall: 0.9540 - auc: 0.9916 - true_positives: 166.0000 - true_negatives: 606.0000 - false_positives: 19.0000 - false_negatives: 8.0000 - val_loss: 0.2275 - val_accuracy: 0.9251 - val_precision: 0.7541 - val_recall: 0.9020 - val_auc: 0.9601 - val_true_positives: 46.0000 - val_true_negatives: 201.0000 - val_false_positives: 15.0000 - val_false_negatives: 5.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0917 - accuracy: 0.9650 - precision: 0.8763 - recall: 0.9770 - auc: 0.9954 - true_positives: 170.0000 - true_negatives: 601.0000 - false_positives: 24.0000 - false_negatives: 4.0000 - val_loss: 0.2540 - val_accuracy: 0.9551 - val_precision: 0.8980 - val_recall: 0.8627 - val_auc: 0.9622 - val_true_positives: 44.0000 - val_true_negatives: 211.0000 - val_false_positives: 5.0000 - val_false_negatives: 7.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.0701 - accuracy: 0.9812 - precision: 0.9392 - recall: 0.9770 - auc: 0.9968 - true_positives: 170.0000 - true_negatives: 614.0000 - false_positives: 11.0000 - false_negatives: 4.0000 - val_loss: 0.2763 - val_accuracy: 0.9401 - val_precision: 0.8302 - val_recall: 0.8627 - val_auc: 0.9626 - val_true_positives: 44.0000 - val_true_negatives: 207.0000 - val_false_positives: 9.0000 - val_false_negatives: 7.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0564 - accuracy: 0.9862 - precision: 0.9503 - recall: 0.9885 - auc: 0.9978 - true_positives: 172.0000 - true_negatives: 616.0000 - false_positives: 9.0000 - false_negatives: 2.0000 - val_loss: 0.2637 - val_accuracy: 0.9401 - val_precision: 0.8302 - val_recall: 0.8627 - val_auc: 0.9580 - val_true_positives: 44.0000 - val_true_negatives: 207.0000 - val_false_positives: 9.0000 - val_false_negatives: 7.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0495 - accuracy: 0.9912 - precision: 0.9718 - recall: 0.9885 - auc: 0.9983 - true_positives: 172.0000 - true_negatives: 620.0000 - false_positives: 5.0000 - false_negatives: 2.0000 - val_loss: 0.2982 - val_accuracy: 0.9401 - val_precision: 0.8302 - val_recall: 0.8627 - val_auc: 0.9567 - val_true_positives: 44.0000 - val_true_negatives: 207.0000 - val_false_positives: 9.0000 - val_false_negatives: 7.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 2ms/sample - loss: 0.0356 - accuracy: 0.9950 - precision: 0.9830 - recall: 0.9943 - auc: 0.9992 - true_positives: 173.0000 - true_negatives: 622.0000 - false_positives: 3.0000 - false_negatives: 1.0000 - val_loss: 0.3454 - val_accuracy: 0.9401 - val_precision: 0.8302 - val_recall: 0.8627 - val_auc: 0.9560 - val_true_positives: 44.0000 - val_true_negatives: 207.0000 - val_false_positives: 9.0000 - val_false_negatives: 7.0000
# Scores for fold 10:
# loss of 0.1102715500835645
# accuracy of 0.9576271176338196
# precision of 0.8275862336158752
# recall of 1.0
# auc of 0.9971187114715576
# true_positives of 24.0
# true_negatives of 89.0
# false_positives of 5.0

# %%
print("Acurácia média: ",np.mean(acc), np.std(acc))
print("Precisão média: ",np.mean(prec), np.std(prec))
print("Recall médio: ",np.mean(rec), np.std(rec))
print("Auc média: ",np.mean(auc), np.std(auc))
# Out:
# Acurácia média:  0.9088378 0.040255032
# Precisão média:  0.76264185 0.119622275
# Recall médio:  0.88 0.09633276
# Auc média:  0.95078534 0.03301693

# %%
for model in os.listdir("../metricas/classificacao/7_d/tests-binary/adhoc/models"):
    metric_path = os.path.join("../metricas/classificacao/7_d/tests-binary/adhoc/models", model, "loss.png")
    img = plt.imread(metric_path)
    plt.imshow(img)
    plt.show()
