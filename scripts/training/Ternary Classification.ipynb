# %% [markdown]
# # Creating dataset

# %% [markdown]
# # Creating classification model

# %%
import os
import pickle
import numpy as np
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import shutil
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# Using TensorFlow backend.

# %%
DATASET_PATH = '../../datasets/Classification/Dataset - 7 dias/'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %% [markdown]
# ##### Read dataset

# %%
IMG_SIZE = 256
NUM_CLASSES = 2
def read_dataset():
    images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
    images = pickle.load(images_raw)

    labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
    labels = pickle.load(labels_raw)

    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels

# %% [markdown]
# ###### Turn it into a binary classification problem

# %%
def to_binary(labels):
    labels[labels == 2] = 1
    return labels

# %% [markdown]
# ###### Train Test split

# %%
def count_samples(train_labels, test_labels):
    print("In training:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,NUM_CLASSES):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')


def train_test_split(images, labels):

    from sklearn.model_selection import train_test_split

    train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.1, stratify=labels)
    
    print("In training:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(train_labels) == i) / len(train_labels), 2)}%')
    print("In test:")
    for i in range(0,len(np.unique(labels))):
        print(f'Class {i}: {round(100 * np.count_nonzero(np.array(test_labels) == i) / len(test_labels), 2)}%')
        
    return train_images, test_images, train_labels, test_labels

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
# Trying class weights
# it does not work with one hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

def get_sample_weights(train_labels):
    from sklearn.utils import compute_sample_weight
    
    return compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
def to_one_hot(data):
    import pandas as pd
    data = pd.get_dummies(data)
    data = pd.DataFrame.to_numpy(data)
    return data

# %% [markdown]
# ##### Normalizing training images

# %%
def normalize_images(data):
    data = tf.keras.utils.normalize(data, axis=0, order=2)
    return data

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = None
TRAIN_TEST_SPLIT = None
BATCH_SIZE = None
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

METRICDIR = '../metricas/classificacao/7_d/tests-binary'

MODELDIR = os.path.join(METRICDIR, "adhoc")

CHECKPOINT_DIR = os.path.join(MODELDIR, "models") 

if os.path.exists(MODELDIR):
    shutil.rmtree(MODELDIR)
    os.makedirs(CHECKPOINT_DIR)
    
my_metrics = ["accuracy",
       tf.keras.metrics.Precision(),
       tf.keras.metrics.Recall(),
       tf.keras.metrics.AUC(),
       tf.keras.metrics.TruePositives(),
       tf.keras.metrics.TrueNegatives(),
       tf.keras.metrics.FalsePositives(),
       tf.keras.metrics.FalseNegatives(),]

# %%
def create_model():
       
    model = Sequential()

    model.add(   Conv2D(8, (3,3), input_shape=(IMG_SIZE,IMG_SIZE, 3))  )
    model.add(Dropout(rate=0.3))
    model.add(Activation("relu"))

    model.add(Conv2D(12, (3,3)))
    model.add(Dropout(rate=0.3))
    model.add(Activation("relu"))
    
    model.add(Conv2D(2, (3,3)))
    model.add(Dropout(rate=0.4))
    model.add(Activation("relu"))
    
    model.add(Flatten())
    model.add(Dense(3))
    
    model.add(Activation("softmax"))
    
    opt = tf.keras.optimizers.Adam()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)
    
    return model

def get_model_name(k):
    return 'model_'+str(k)

def plot_metric(history,metric_name, chart_name, save_dir, save = False, show = False):
    plt.cla() 
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if save:
        plt.savefig(os.path.join(save_dir, metric_name))
    if show:
        plt.show()
        
def plot_cm(cf_matrix, save_dir, save):
    
    import seaborn as sns; sns.set_theme()
   
    group_names = ['True Pos','False Pos','False Neg','True Neg']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cf_matrix.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    
    plt.cla() 
    
    sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
    if save:
        plt.savefig(os.path.join(save_dir, "confusion matrix"))
    plt.show()

# %% [markdown]
# ##### Testing the model

# %%
def one_hot_to_1d(test_labels):
    
    test_labels_1d = []
    
    for label in test_labels:
        print()
        if (label == [1, 0]).all():
            test_labels_1d.append(0)
        elif (label == [0, 1]).all():
            test_labels_1d.append(1)
        else:
            test_labels_1d.append(2)
    
    return test_labels_1d
    
def get_predictions(model,test_images, test_labels):
    prediction = model.predict(test_images, batch_size=1)

    return tf.argmax(prediction, axis=-1)

# %%
def train_models(train_images, train_labels, num_folds=10):
    
    from sklearn.model_selection import StratifiedKFold
    
    kfold = StratifiedKFold(n_splits=num_folds)

    #metrics containers
    acc = []
    prec = []
    rec = []
    auc = []

    # K-fold Cross Validation model evaluation
    fold_no = 1
    for train, test in kfold.split(train_images, train_labels):

        count_samples(train_labels[train], train_labels[test])
        
#         from tf.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

        if fold_no - 1 == 0:
            idx_str = ""
        else:
            idx_str = f"_{fold_no}"
            
        fold_checkpoint_dir = os.path.join(CHECKPOINT_DIR, get_model_name(fold_no))
        
        if not os.path.exists(fold_checkpoint_dir):
            os.makedirs(fold_checkpoint_dir)
        
#         my_callbacks = [
# #             ModelCheckpoint(os.path.join(fold_checkpoint_dir,"model.h5"), monitor=f"val_precision", verbose=1, save_best_only=True, mode='max', save_freq='epoch'),
#             ReduceLROnPlateau(monitor=f'loss', factor=0.7, patience=2, min_lr=0.00000000001, mode='min'),
#         ]

        model = create_model()

        # Generate a print
        print('------------------------------------------------------------------------', end="\n\n")
        print(f'Training for fold {fold_no} ...')

#         # Fit data to model
#         history = model.fit(
#             train_images[train],
#             train_labels[train],
#             batch_size = BATCH_SIZE,
#             epochs = EPOCHS,
#             validation_split=TRAIN_TEST_SPLIT,
#             sample_weight=get_sample_weights(train_labels[train]),
#             callbacks=[my_callbacks])
        # Fit data to model
        history = model.fit(
            train_images[train],
            to_one_hot(train_labels[train]),
            batch_size = BATCH_SIZE,
            epochs = EPOCHS,
            validation_split=TRAIN_TEST_SPLIT,
            sample_weight=get_sample_weights(train_labels[train]))
        
        thresh = 0.5
        
        prediction = model.predict(train_images[test], batch_size=1)
        prediction = np.argmax(prediction, axis=1)
        
        #visualizing training
        NUM_METRICS = len(my_metrics) + 1
        for metric in list(history.history.keys())[:NUM_METRICS]:
            plot_metric(history, metric, metric + " for soybean classification", save_dir=fold_checkpoint_dir, save=True)
        
        print(metrics.confusion_matrix(train_labels[test], prediction))
            
        # Generate generalization metrics
        scores = model.evaluate(train_images[test], to_one_hot(train_labels[test]), verbose=0)
        print(f'Scores for fold {fold_no}:')
        for i in range(len(my_metrics)):   
            print(f'{model.metrics_names[i]} of {scores[i]}')

        acc.append(scores[1])
        prec.append(scores[2])
        rec.append(scores[3])
        auc.append(scores[4])

        # Increase fold number
        fold_no = fold_no + 1
        
    return acc, prec, rec, auc

# %% [markdown]
# ##### Training

# %%
images, labels = read_dataset()

images = normalize_images(images)

# %%
EPOCHS = 10
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
acc, prec, rec, auc = train_models(images, labels)
# Out:
# In training:
# Class 0: 79.06%
# Class 1: 16.9%
# In test:
# Class 0: 78.15%
# Class 1: 17.65%
# ------------------------------------------------------------------------
#
# Training for fold 1 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 9s 11ms/sample - loss: 0.9313 - accuracy: 0.1341 - precision: 0.5088 - recall: 0.0363 - auc: 0.2993 - true_positives: 29.0000 - true_negatives: 1568.0000 - false_positives: 28.0000 - false_negatives: 769.0000 - val_loss: 0.7997 - val_accuracy: 0.3483 - val_precision: 0.4348 - val_recall: 0.0375 - val_auc: 0.4399 - val_true_positives: 10.0000 - val_true_negatives: 521.0000 - val_false_positives: 13.0000 - val_false_negatives: 257.0000
# Epoch 2/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.7905 - accuracy: 0.1629 - precision: 0.5059 - recall: 0.0539 - auc: 0.3698 - true_positives: 43.0000 - true_negatives: 1554.0000 - false_positives: 42.0000 - false_negatives: 755.0000 - val_loss: 0.7739 - val_accuracy: 0.5693 - val_precision: 0.5455 - val_recall: 0.0449 - val_auc: 0.6594 - val_true_positives: 12.0000 - val_true_negatives: 524.0000 - val_false_positives: 10.0000 - val_false_negatives: 255.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.7424 - accuracy: 0.3271 - precision: 0.5670 - recall: 0.0689 - auc: 0.5282 - true_positives: 55.0000 - true_negatives: 1554.0000 - false_positives: 42.0000 - false_negatives: 743.0000 - val_loss: 0.6889 - val_accuracy: 0.3895 - val_precision: 0.5385 - val_recall: 0.0787 - val_auc: 0.5795 - val_true_positives: 21.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 246.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.7360 - accuracy: 0.3108 - precision: 0.5467 - recall: 0.1028 - auc: 0.5645 - true_positives: 82.0000 - true_negatives: 1528.0000 - false_positives: 68.0000 - false_negatives: 716.0000 - val_loss: 0.7087 - val_accuracy: 0.7978 - val_precision: 0.5769 - val_recall: 0.0562 - val_auc: 0.8563 - val_true_positives: 15.0000 - val_true_negatives: 523.0000 - val_false_positives: 11.0000 - val_false_negatives: 252.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.6639 - accuracy: 0.7005 - precision: 0.7521 - recall: 0.1103 - auc: 0.8069 - true_positives: 88.0000 - true_negatives: 1567.0000 - false_positives: 29.0000 - false_negatives: 710.0000 - val_loss: 0.6953 - val_accuracy: 0.4457 - val_precision: 0.4900 - val_recall: 0.1835 - val_auc: 0.7109 - val_true_positives: 49.0000 - val_true_negatives: 483.0000 - val_false_positives: 51.0000 - val_false_negatives: 218.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.5999 - accuracy: 0.6905 - precision: 0.7422 - recall: 0.6241 - auc: 0.8871 - true_positives: 498.0000 - true_negatives: 1423.0000 - false_positives: 173.0000 - false_negatives: 300.0000 - val_loss: 0.8175 - val_accuracy: 0.3933 - val_precision: 0.3452 - val_recall: 0.1086 - val_auc: 0.5993 - val_true_positives: 29.0000 - val_true_negatives: 479.0000 - val_false_positives: 55.0000 - val_false_negatives: 238.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.4211 - accuracy: 0.8383 - precision: 0.8636 - recall: 0.7619 - auc: 0.9411 - true_positives: 608.0000 - true_negatives: 1500.0000 - false_positives: 96.0000 - false_negatives: 190.0000 - val_loss: 0.2692 - val_accuracy: 0.9213 - val_precision: 0.9213 - val_recall: 0.9213 - val_auc: 0.9715 - val_true_positives: 246.0000 - val_true_negatives: 513.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.4072 - accuracy: 0.9060 - precision: 0.9105 - recall: 0.9048 - auc: 0.9748 - true_positives: 722.0000 - true_negatives: 1525.0000 - false_positives: 71.0000 - false_negatives: 76.0000 - val_loss: 0.4200 - val_accuracy: 0.8951 - val_precision: 0.8985 - val_recall: 0.8951 - val_auc: 0.9741 - val_true_positives: 239.0000 - val_true_negatives: 507.0000 - val_false_positives: 27.0000 - val_false_negatives: 28.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2745 - accuracy: 0.8722 - precision: 0.8747 - recall: 0.8571 - auc: 0.9663 - true_positives: 684.0000 - true_negatives: 1498.0000 - false_positives: 98.0000 - false_negatives: 114.0000 - val_loss: 0.4190 - val_accuracy: 0.9064 - val_precision: 0.9087 - val_recall: 0.8951 - val_auc: 0.9639 - val_true_positives: 239.0000 - val_true_negatives: 510.0000 - val_false_positives: 24.0000 - val_false_negatives: 28.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2241 - accuracy: 0.9386 - precision: 0.9385 - recall: 0.9373 - auc: 0.9877 - true_positives: 748.0000 - true_negatives: 1547.0000 - false_positives: 49.0000 - false_negatives: 50.0000 - val_loss: 0.4568 - val_accuracy: 0.8165 - val_precision: 0.8189 - val_recall: 0.8127 - val_auc: 0.9399 - val_true_positives: 217.0000 - val_true_negatives: 486.0000 - val_false_positives: 48.0000 - val_false_negatives: 50.0000
# [[81 12  0]
#  [ 6 10  5]
#  [ 0  0  5]]
# Scores for fold 1:
# loss of 0.45388097923342924
# accuracy of 0.8067227005958557
# precision of 0.8135592937469482
# recall of 0.8067227005958557
# auc of 0.9388108849525452
# true_positives of 96.0
# true_negatives of 216.0
# false_positives of 22.0
# In training:
# Class 0: 78.97%
# Class 1: 17.0%
# In test:
# Class 0: 78.99%
# Class 1: 16.81%
# ------------------------------------------------------------------------
#
# Training for fold 2 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 1.1722 - accuracy: 0.1366 - precision: 0.4875 - recall: 0.0489 - auc: 0.3417 - true_positives: 39.0000 - true_negatives: 1555.0000 - false_positives: 41.0000 - false_negatives: 759.0000 - val_loss: 1.0519 - val_accuracy: 0.8015 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 2/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.8895 - accuracy: 0.0564 - precision: 0.3143 - recall: 0.0414 - auc: 0.2250 - true_positives: 33.0000 - true_negatives: 1524.0000 - false_positives: 72.0000 - false_negatives: 765.0000 - val_loss: 1.0518 - val_accuracy: 0.7790 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8643 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.8265 - accuracy: 0.1404 - precision: 0.4694 - recall: 0.0576 - auc: 0.3074 - true_positives: 46.0000 - true_negatives: 1544.0000 - false_positives: 52.0000 - false_negatives: 752.0000 - val_loss: 1.0367 - val_accuracy: 0.7303 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8140 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.7686 - accuracy: 0.2719 - precision: 0.4615 - recall: 0.0752 - auc: 0.4488 - true_positives: 60.0000 - true_negatives: 1526.0000 - false_positives: 70.0000 - false_negatives: 738.0000 - val_loss: 0.9816 - val_accuracy: 0.7678 - val_precision: 0.3333 - val_recall: 0.0075 - val_auc: 0.8590 - val_true_positives: 2.0000 - val_true_negatives: 530.0000 - val_false_positives: 4.0000 - val_false_negatives: 265.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.7382 - accuracy: 0.3759 - precision: 0.4753 - recall: 0.0965 - auc: 0.5705 - true_positives: 77.0000 - true_negatives: 1511.0000 - false_positives: 85.0000 - false_negatives: 721.0000 - val_loss: 0.7999 - val_accuracy: 0.7154 - val_precision: 0.5652 - val_recall: 0.0487 - val_auc: 0.8201 - val_true_positives: 13.0000 - val_true_negatives: 524.0000 - val_false_positives: 10.0000 - val_false_negatives: 254.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.6892 - accuracy: 0.6140 - precision: 0.6164 - recall: 0.1228 - auc: 0.7661 - true_positives: 98.0000 - true_negatives: 1535.0000 - false_positives: 61.0000 - false_negatives: 700.0000 - val_loss: 0.6729 - val_accuracy: 0.6592 - val_precision: 0.5357 - val_recall: 0.1124 - val_auc: 0.8075 - val_true_positives: 30.0000 - val_true_negatives: 508.0000 - val_false_positives: 26.0000 - val_false_negatives: 237.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.6030 - accuracy: 0.6892 - precision: 0.7628 - recall: 0.2982 - auc: 0.8449 - true_positives: 238.0000 - true_negatives: 1522.0000 - false_positives: 74.0000 - false_negatives: 560.0000 - val_loss: 0.6344 - val_accuracy: 0.7191 - val_precision: 0.7107 - val_recall: 0.3221 - val_auc: 0.8383 - val_true_positives: 86.0000 - val_true_negatives: 499.0000 - val_false_positives: 35.0000 - val_false_negatives: 181.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.4906 - accuracy: 0.8571 - precision: 0.8847 - recall: 0.7882 - auc: 0.9527 - true_positives: 629.0000 - true_negatives: 1514.0000 - false_positives: 82.0000 - false_negatives: 169.0000 - val_loss: 0.5660 - val_accuracy: 0.8614 - val_precision: 0.8789 - val_recall: 0.8427 - val_auc: 0.9465 - val_true_positives: 225.0000 - val_true_negatives: 503.0000 - val_false_positives: 31.0000 - val_false_negatives: 42.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.4321 - accuracy: 0.8885 - precision: 0.9040 - recall: 0.8734 - auc: 0.9668 - true_positives: 697.0000 - true_negatives: 1522.0000 - false_positives: 74.0000 - false_negatives: 101.0000 - val_loss: 0.5858 - val_accuracy: 0.7978 - val_precision: 0.8061 - val_recall: 0.7940 - val_auc: 0.8962 - val_true_positives: 212.0000 - val_true_negatives: 483.0000 - val_false_positives: 51.0000 - val_false_negatives: 55.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2249 - accuracy: 0.9273 - precision: 0.9273 - recall: 0.9273 - auc: 0.9812 - true_positives: 740.0000 - true_negatives: 1538.0000 - false_positives: 58.0000 - false_negatives: 58.0000 - val_loss: 0.2555 - val_accuracy: 0.9401 - val_precision: 0.9401 - val_recall: 0.9401 - val_auc: 0.9862 - val_true_positives: 251.0000 - val_true_negatives: 518.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000
# [[91  3  0]
#  [ 8 11  1]
#  [ 0  0  5]]
# Scores for fold 2:
# loss of 0.22941718745131454
# accuracy of 0.8991596698760986
# precision of 0.8991596698760986
# recall of 0.8991596698760986
# auc of 0.9842349290847778
# true_positives of 107.0
# true_negatives of 226.0
# false_positives of 12.0
# In training:
# Class 0: 78.97%
# Class 1: 17.0%
# In test:
# Class 0: 78.99%
# Class 1: 16.81%
# ------------------------------------------------------------------------
#
# Training for fold 3 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 6ms/sample - loss: 0.6515 - accuracy: 0.7293 - precision: 0.8303 - recall: 0.6316 - auc: 0.9042 - true_positives: 504.0000 - true_negatives: 1493.0000 - false_positives: 103.0000 - false_negatives: 294.0000 - val_loss: 0.4464 - val_accuracy: 0.7453 - val_precision: 0.7453 - val_recall: 0.7453 - val_auc: 0.8887 - val_true_positives: 199.0000 - val_true_negatives: 466.0000 - val_false_positives: 68.0000 - val_false_negatives: 68.0000
# Epoch 2/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.3924 - accuracy: 0.8860 - precision: 0.8869 - recall: 0.8847 - auc: 0.9702 - true_positives: 706.0000 - true_negatives: 1506.0000 - false_positives: 90.0000 - false_negatives: 92.0000 - val_loss: 0.3387 - val_accuracy: 0.8614 - val_precision: 0.8614 - val_recall: 0.8614 - val_auc: 0.9646 - val_true_positives: 230.0000 - val_true_negatives: 497.0000 - val_false_positives: 37.0000 - val_false_negatives: 37.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2609 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9768 - true_positives: 706.0000 - true_negatives: 1504.0000 - false_positives: 92.0000 - false_negatives: 92.0000 - val_loss: 0.2545 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9879 - val_true_positives: 254.0000 - val_true_negatives: 521.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1707 - accuracy: 0.9348 - precision: 0.9348 - recall: 0.9348 - auc: 0.9920 - true_positives: 746.0000 - true_negatives: 1544.0000 - false_positives: 52.0000 - false_negatives: 52.0000 - val_loss: 0.3043 - val_accuracy: 0.8315 - val_precision: 0.8315 - val_recall: 0.8315 - val_auc: 0.9579 - val_true_positives: 222.0000 - val_true_negatives: 489.0000 - val_false_positives: 45.0000 - val_false_negatives: 45.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1468 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9914 - true_positives: 755.0000 - true_negatives: 1553.0000 - false_positives: 43.0000 - false_negatives: 43.0000 - val_loss: 0.3512 - val_accuracy: 0.9476 - val_precision: 0.9476 - val_recall: 0.9476 - val_auc: 0.9833 - val_true_positives: 253.0000 - val_true_negatives: 520.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2269 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9811 - true_positives: 719.0000 - true_negatives: 1517.0000 - false_positives: 79.0000 - false_negatives: 79.0000 - val_loss: 0.3021 - val_accuracy: 0.9288 - val_precision: 0.9288 - val_recall: 0.9288 - val_auc: 0.9870 - val_true_positives: 248.0000 - val_true_negatives: 515.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1415 - accuracy: 0.9449 - precision: 0.9449 - recall: 0.9449 - auc: 0.9937 - true_positives: 754.0000 - true_negatives: 1552.0000 - false_positives: 44.0000 - false_negatives: 44.0000 - val_loss: 0.3560 - val_accuracy: 0.8052 - val_precision: 0.8052 - val_recall: 0.8052 - val_auc: 0.9310 - val_true_positives: 215.0000 - val_true_negatives: 482.0000 - val_false_positives: 52.0000 - val_false_negatives: 52.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0952 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9963 - true_positives: 760.0000 - true_negatives: 1558.0000 - false_positives: 38.0000 - false_negatives: 38.0000 - val_loss: 0.3225 - val_accuracy: 0.8801 - val_precision: 0.8801 - val_recall: 0.8801 - val_auc: 0.9705 - val_true_positives: 235.0000 - val_true_negatives: 502.0000 - val_false_positives: 32.0000 - val_false_negatives: 32.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0620 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9983 - true_positives: 781.0000 - true_negatives: 1579.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - val_loss: 0.3584 - val_accuracy: 0.9363 - val_precision: 0.9363 - val_recall: 0.9363 - val_auc: 0.9855 - val_true_positives: 250.0000 - val_true_negatives: 517.0000 - val_false_positives: 17.0000 - val_false_negatives: 17.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0475 - accuracy: 0.9862 - precision: 0.9862 - recall: 0.9862 - auc: 0.9991 - true_positives: 787.0000 - true_negatives: 1585.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - val_loss: 0.3876 - val_accuracy: 0.9476 - val_precision: 0.9476 - val_recall: 0.9476 - val_auc: 0.9869 - val_true_positives: 253.0000 - val_true_negatives: 520.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
# [[91  3  0]
#  [ 4 14  2]
#  [ 0  0  5]]
# Scores for fold 3:
# loss of 0.22878178941602467
# accuracy of 0.924369752407074
# precision of 0.924369752407074
# recall of 0.924369752407074
# auc of 0.9806864261627197
# true_positives of 110.0
# true_negatives of 229.0
# false_positives of 9.0
# In training:
# Class 0: 78.97%
# Class 1: 17.0%
# In test:
# Class 0: 78.99%
# Class 1: 16.81%
# ------------------------------------------------------------------------
#
# Training for fold 4 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 798 samples, validate on 267 samples
# Epoch 1/10
# 798/798 [==============================] - 5s 7ms/sample - loss: 1.0307 - accuracy: 0.7782 - precision: 0.9045 - recall: 0.3797 - auc: 0.8867 - true_positives: 303.0000 - true_negatives: 1564.0000 - false_positives: 32.0000 - false_negatives: 495.0000 - val_loss: 0.8285 - val_accuracy: 0.8801 - val_precision: 0.9502 - val_recall: 0.7865 - val_auc: 0.9506 - val_true_positives: 210.0000 - val_true_negatives: 523.0000 - val_false_positives: 11.0000 - val_false_negatives: 57.0000
# Epoch 2/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.4016 - accuracy: 0.8734 - precision: 0.8807 - recall: 0.8509 - auc: 0.9595 - true_positives: 679.0000 - true_negatives: 1504.0000 - false_positives: 92.0000 - false_negatives: 119.0000 - val_loss: 0.7262 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9835 - val_true_positives: 245.0000 - val_true_negatives: 512.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000
# Epoch 3/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.2944 - accuracy: 0.8784 - precision: 0.8784 - recall: 0.8784 - auc: 0.9771 - true_positives: 701.0000 - true_negatives: 1499.0000 - false_positives: 97.0000 - false_negatives: 97.0000 - val_loss: 0.2777 - val_accuracy: 0.9476 - val_precision: 0.9476 - val_recall: 0.9476 - val_auc: 0.9920 - val_true_positives: 253.0000 - val_true_negatives: 520.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
# Epoch 4/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1994 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9852 - true_positives: 727.0000 - true_negatives: 1525.0000 - false_positives: 71.0000 - false_negatives: 71.0000 - val_loss: 0.3970 - val_accuracy: 0.9326 - val_precision: 0.9326 - val_recall: 0.9326 - val_auc: 0.9818 - val_true_positives: 249.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000
# Epoch 5/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1938 - accuracy: 0.9261 - precision: 0.9261 - recall: 0.9261 - auc: 0.9890 - true_positives: 739.0000 - true_negatives: 1537.0000 - false_positives: 59.0000 - false_negatives: 59.0000 - val_loss: 0.5367 - val_accuracy: 0.9101 - val_precision: 0.9101 - val_recall: 0.9101 - val_auc: 0.9768 - val_true_positives: 243.0000 - val_true_negatives: 510.0000 - val_false_positives: 24.0000 - val_false_negatives: 24.0000
# Epoch 6/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1599 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9919 - true_positives: 749.0000 - true_negatives: 1547.0000 - false_positives: 49.0000 - false_negatives: 49.0000 - val_loss: 0.4176 - val_accuracy: 0.9139 - val_precision: 0.9139 - val_recall: 0.9139 - val_auc: 0.9800 - val_true_positives: 244.0000 - val_true_negatives: 511.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000
# Epoch 7/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.1681 - accuracy: 0.9411 - precision: 0.9411 - recall: 0.9411 - auc: 0.9922 - true_positives: 751.0000 - true_negatives: 1549.0000 - false_positives: 47.0000 - false_negatives: 47.0000 - val_loss: 0.4642 - val_accuracy: 0.9476 - val_precision: 0.9476 - val_recall: 0.9476 - val_auc: 0.9872 - val_true_positives: 253.0000 - val_true_negatives: 520.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
# Epoch 8/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0785 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9981 - true_positives: 775.0000 - true_negatives: 1573.0000 - false_positives: 23.0000 - false_negatives: 23.0000 - val_loss: 0.4448 - val_accuracy: 0.9401 - val_precision: 0.9401 - val_recall: 0.9401 - val_auc: 0.9851 - val_true_positives: 251.0000 - val_true_negatives: 518.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000
# Epoch 9/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0543 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9987 - true_positives: 778.0000 - true_negatives: 1576.0000 - false_positives: 20.0000 - false_negatives: 20.0000 - val_loss: 0.4275 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9867 - val_true_positives: 252.0000 - val_true_negatives: 519.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000
# Epoch 10/10
# 798/798 [==============================] - 2s 3ms/sample - loss: 0.0647 - accuracy: 0.9662 - precision: 0.9662 - recall: 0.9662 - auc: 0.9969 - true_positives: 771.0000 - true_negatives: 1569.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - val_loss: 0.5239 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9851 - val_true_positives: 252.0000 - val_true_negatives: 519.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000
# [[94  0  0]
#  [ 6 13  1]
#  [ 0  1  4]]
# Scores for fold 4:
# loss of 0.36254931501105053
# accuracy of 0.9327731132507324
# precision of 0.9327731132507324
# recall of 0.9327731132507324
# auc of 0.9758668541908264
# true_positives of 111.0
# true_negatives of 230.0
# false_positives of 8.0
# In training:
# Class 0: 78.89%
# Class 1: 16.98%
# In test:
# Class 0: 79.66%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 5 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 6s 8ms/sample - loss: 1.1223 - accuracy: 0.1026 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4965 - true_positives: 0.0000e+00 - true_negatives: 1598.0000 - false_positives: 0.0000e+00 - false_negatives: 799.0000 - val_loss: 1.0455 - val_accuracy: 0.1124 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4869 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 1.0047 - accuracy: 0.0426 - precision: 0.4167 - recall: 0.0250 - auc: 0.2444 - true_positives: 20.0000 - true_negatives: 1570.0000 - false_positives: 28.0000 - false_negatives: 779.0000 - val_loss: 0.8941 - val_accuracy: 0.0487 - val_precision: 0.6923 - val_recall: 0.0337 - val_auc: 0.2294 - val_true_positives: 9.0000 - val_true_negatives: 530.0000 - val_false_positives: 4.0000 - val_false_negatives: 258.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8381 - accuracy: 0.1176 - precision: 0.4486 - recall: 0.0601 - auc: 0.2918 - true_positives: 48.0000 - true_negatives: 1539.0000 - false_positives: 59.0000 - false_negatives: 751.0000 - val_loss: 0.8029 - val_accuracy: 0.1461 - val_precision: 0.3061 - val_recall: 0.0562 - val_auc: 0.3557 - val_true_positives: 15.0000 - val_true_negatives: 500.0000 - val_false_positives: 34.0000 - val_false_negatives: 252.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7798 - accuracy: 0.2966 - precision: 0.4460 - recall: 0.0776 - auc: 0.4898 - true_positives: 62.0000 - true_negatives: 1521.0000 - false_positives: 77.0000 - false_negatives: 737.0000 - val_loss: 0.7371 - val_accuracy: 0.4120 - val_precision: 0.4186 - val_recall: 0.0674 - val_auc: 0.6137 - val_true_positives: 18.0000 - val_true_negatives: 509.0000 - val_false_positives: 25.0000 - val_false_negatives: 249.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.6615 - accuracy: 0.4869 - precision: 0.5635 - recall: 0.1389 - auc: 0.7013 - true_positives: 111.0000 - true_negatives: 1512.0000 - false_positives: 86.0000 - false_negatives: 688.0000 - val_loss: 0.6831 - val_accuracy: 0.6030 - val_precision: 0.5361 - val_recall: 0.1948 - val_auc: 0.7679 - val_true_positives: 52.0000 - val_true_negatives: 489.0000 - val_false_positives: 45.0000 - val_false_negatives: 215.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.5534 - accuracy: 0.7697 - precision: 0.8418 - recall: 0.5394 - auc: 0.8936 - true_positives: 431.0000 - true_negatives: 1517.0000 - false_positives: 81.0000 - false_negatives: 368.0000 - val_loss: 0.6141 - val_accuracy: 0.7228 - val_precision: 0.7703 - val_recall: 0.6404 - val_auc: 0.8880 - val_true_positives: 171.0000 - val_true_negatives: 483.0000 - val_false_positives: 51.0000 - val_false_negatives: 96.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.4589 - accuracy: 0.7847 - precision: 0.8622 - recall: 0.6658 - auc: 0.9197 - true_positives: 532.0000 - true_negatives: 1513.0000 - false_positives: 85.0000 - false_negatives: 267.0000 - val_loss: 0.7221 - val_accuracy: 0.6404 - val_precision: 0.7179 - val_recall: 0.4195 - val_auc: 0.8148 - val_true_positives: 112.0000 - val_true_negatives: 490.0000 - val_false_positives: 44.0000 - val_false_negatives: 155.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3730 - accuracy: 0.8235 - precision: 0.8627 - recall: 0.7710 - auc: 0.9479 - true_positives: 616.0000 - true_negatives: 1500.0000 - false_positives: 98.0000 - false_negatives: 183.0000 - val_loss: 0.7949 - val_accuracy: 0.7116 - val_precision: 0.7379 - val_recall: 0.6854 - val_auc: 0.8955 - val_true_positives: 183.0000 - val_true_negatives: 469.0000 - val_false_positives: 65.0000 - val_false_negatives: 84.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3551 - accuracy: 0.8886 - precision: 0.9050 - recall: 0.8586 - auc: 0.9694 - true_positives: 686.0000 - true_negatives: 1526.0000 - false_positives: 72.0000 - false_negatives: 113.0000 - val_loss: 0.7687 - val_accuracy: 0.7828 - val_precision: 0.8088 - val_recall: 0.7603 - val_auc: 0.9120 - val_true_positives: 203.0000 - val_true_negatives: 486.0000 - val_false_positives: 48.0000 - val_false_negatives: 64.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2138 - accuracy: 0.9337 - precision: 0.9378 - recall: 0.9249 - auc: 0.9886 - true_positives: 739.0000 - true_negatives: 1549.0000 - false_positives: 49.0000 - false_negatives: 60.0000 - val_loss: 0.8184 - val_accuracy: 0.8652 - val_precision: 0.8652 - val_recall: 0.8652 - val_auc: 0.9590 - val_true_positives: 231.0000 - val_true_negatives: 498.0000 - val_false_positives: 36.0000 - val_false_negatives: 36.0000
# [[79 15  0]
#  [ 3 16  1]
#  [ 0  3  1]]
# Scores for fold 5:
# loss of 0.8915615617218664
# accuracy of 0.8135592937469482
# precision of 0.8135592937469482
# recall of 0.8135592937469482
# auc of 0.9338193535804749
# true_positives of 96.0
# true_negatives of 214.0
# false_positives of 22.0
# In training:
# Class 0: 78.89%
# Class 1: 16.98%
# In test:
# Class 0: 79.66%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 6 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.9940 - accuracy: 0.3254 - precision: 0.2832 - recall: 0.0401 - auc: 0.4442 - true_positives: 32.0000 - true_negatives: 1517.0000 - false_positives: 81.0000 - false_negatives: 767.0000 - val_loss: 0.9975 - val_accuracy: 0.7228 - val_precision: 1.0000 - val_recall: 0.0075 - val_auc: 0.7706 - val_true_positives: 2.0000 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 265.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8283 - accuracy: 0.4718 - precision: 0.5072 - recall: 0.0438 - auc: 0.5180 - true_positives: 35.0000 - true_negatives: 1564.0000 - false_positives: 34.0000 - false_negatives: 764.0000 - val_loss: 0.9507 - val_accuracy: 0.7266 - val_precision: 0.8000 - val_recall: 0.0150 - val_auc: 0.7997 - val_true_positives: 4.0000 - val_true_negatives: 533.0000 - val_false_positives: 1.0000 - val_false_negatives: 263.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7805 - accuracy: 0.4768 - precision: 0.5119 - recall: 0.0538 - auc: 0.5616 - true_positives: 43.0000 - true_negatives: 1557.0000 - false_positives: 41.0000 - false_negatives: 756.0000 - val_loss: 0.9052 - val_accuracy: 0.7753 - val_precision: 0.5455 - val_recall: 0.0225 - val_auc: 0.8200 - val_true_positives: 6.0000 - val_true_negatives: 529.0000 - val_false_positives: 5.0000 - val_false_negatives: 261.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7700 - accuracy: 0.4693 - precision: 0.5046 - recall: 0.0688 - auc: 0.5814 - true_positives: 55.0000 - true_negatives: 1544.0000 - false_positives: 54.0000 - false_negatives: 744.0000 - val_loss: 0.8079 - val_accuracy: 0.7528 - val_precision: 0.5882 - val_recall: 0.0375 - val_auc: 0.8373 - val_true_positives: 10.0000 - val_true_negatives: 527.0000 - val_false_positives: 7.0000 - val_false_negatives: 257.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.5385 - accuracy: 0.8110 - precision: 0.8415 - recall: 0.4718 - auc: 0.9142 - true_positives: 377.0000 - true_negatives: 1527.0000 - false_positives: 71.0000 - false_negatives: 422.0000 - val_loss: 0.3592 - val_accuracy: 0.9363 - val_precision: 0.9363 - val_recall: 0.9363 - val_auc: 0.9857 - val_true_positives: 250.0000 - val_true_negatives: 517.0000 - val_false_positives: 17.0000 - val_false_negatives: 17.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3907 - accuracy: 0.8961 - precision: 0.8972 - recall: 0.8961 - auc: 0.9762 - true_positives: 716.0000 - true_negatives: 1516.0000 - false_positives: 82.0000 - false_negatives: 83.0000 - val_loss: 0.3086 - val_accuracy: 0.8989 - val_precision: 0.8989 - val_recall: 0.8989 - val_auc: 0.9765 - val_true_positives: 240.0000 - val_true_negatives: 507.0000 - val_false_positives: 27.0000 - val_false_negatives: 27.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2592 - accuracy: 0.9362 - precision: 0.9362 - recall: 0.9362 - auc: 0.9875 - true_positives: 748.0000 - true_negatives: 1547.0000 - false_positives: 51.0000 - false_negatives: 51.0000 - val_loss: 0.3353 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9744 - val_true_positives: 238.0000 - val_true_negatives: 505.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2140 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9884 - true_positives: 746.0000 - true_negatives: 1545.0000 - false_positives: 53.0000 - false_negatives: 53.0000 - val_loss: 0.4247 - val_accuracy: 0.8277 - val_precision: 0.8277 - val_recall: 0.8277 - val_auc: 0.9511 - val_true_positives: 221.0000 - val_true_negatives: 488.0000 - val_false_positives: 46.0000 - val_false_negatives: 46.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1624 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9934 - true_positives: 761.0000 - true_negatives: 1560.0000 - false_positives: 38.0000 - false_negatives: 38.0000 - val_loss: 0.2649 - val_accuracy: 0.9551 - val_precision: 0.9551 - val_recall: 0.9551 - val_auc: 0.9901 - val_true_positives: 255.0000 - val_true_negatives: 522.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1089 - accuracy: 0.9662 - precision: 0.9662 - recall: 0.9662 - auc: 0.9961 - true_positives: 772.0000 - true_negatives: 1571.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - val_loss: 0.2682 - val_accuracy: 0.9326 - val_precision: 0.9326 - val_recall: 0.9326 - val_auc: 0.9859 - val_true_positives: 249.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000
# [[90  4  0]
#  [ 1 16  3]
#  [ 0  0  4]]
# Scores for fold 6:
# loss of 0.18502638526892257
# accuracy of 0.9322034120559692
# precision of 0.9322034120559692
# recall of 0.9322034120559692
# auc of 0.990106999874115
# true_positives of 110.0
# true_negatives of 228.0
# false_positives of 8.0
# In training:
# Class 0: 78.99%
# Class 1: 16.98%
# In test:
# Class 0: 78.81%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 7 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 1.0752 - accuracy: 0.5282 - precision: 0.9021 - recall: 0.1615 - auc: 0.7815 - true_positives: 129.0000 - true_negatives: 1584.0000 - false_positives: 14.0000 - false_negatives: 670.0000 - val_loss: 0.8180 - val_accuracy: 0.8352 - val_precision: 0.9132 - val_recall: 0.7491 - val_auc: 0.9515 - val_true_positives: 200.0000 - val_true_negatives: 515.0000 - val_false_positives: 19.0000 - val_false_negatives: 67.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.6708 - accuracy: 0.7397 - precision: 0.7537 - recall: 0.7046 - auc: 0.9051 - true_positives: 563.0000 - true_negatives: 1414.0000 - false_positives: 184.0000 - false_negatives: 236.0000 - val_loss: 0.4768 - val_accuracy: 0.5618 - val_precision: 0.5623 - val_recall: 0.5581 - val_auc: 0.8031 - val_true_positives: 149.0000 - val_true_negatives: 418.0000 - val_false_positives: 116.0000 - val_false_negatives: 118.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.4533 - accuracy: 0.7785 - precision: 0.7786 - recall: 0.7747 - auc: 0.9313 - true_positives: 619.0000 - true_negatives: 1422.0000 - false_positives: 176.0000 - false_negatives: 180.0000 - val_loss: 0.3694 - val_accuracy: 0.8951 - val_precision: 0.8977 - val_recall: 0.8876 - val_auc: 0.9797 - val_true_positives: 237.0000 - val_true_negatives: 507.0000 - val_false_positives: 27.0000 - val_false_negatives: 30.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3572 - accuracy: 0.8673 - precision: 0.8703 - recall: 0.8648 - auc: 0.9688 - true_positives: 691.0000 - true_negatives: 1495.0000 - false_positives: 103.0000 - false_negatives: 108.0000 - val_loss: 0.3518 - val_accuracy: 0.8689 - val_precision: 0.8684 - val_recall: 0.8652 - val_auc: 0.9582 - val_true_positives: 231.0000 - val_true_negatives: 499.0000 - val_false_positives: 35.0000 - val_false_negatives: 36.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3312 - accuracy: 0.8461 - precision: 0.8471 - recall: 0.8461 - auc: 0.9656 - true_positives: 676.0000 - true_negatives: 1476.0000 - false_positives: 122.0000 - false_negatives: 123.0000 - val_loss: 0.3917 - val_accuracy: 0.7041 - val_precision: 0.7041 - val_recall: 0.7041 - val_auc: 0.8999 - val_true_positives: 188.0000 - val_true_negatives: 455.0000 - val_false_positives: 79.0000 - val_false_negatives: 79.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2926 - accuracy: 0.8936 - precision: 0.8957 - recall: 0.8924 - auc: 0.9768 - true_positives: 713.0000 - true_negatives: 1515.0000 - false_positives: 83.0000 - false_negatives: 86.0000 - val_loss: 0.3469 - val_accuracy: 0.7640 - val_precision: 0.7640 - val_recall: 0.7640 - val_auc: 0.9275 - val_true_positives: 204.0000 - val_true_negatives: 471.0000 - val_false_positives: 63.0000 - val_false_negatives: 63.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2513 - accuracy: 0.9074 - precision: 0.9085 - recall: 0.9074 - auc: 0.9790 - true_positives: 725.0000 - true_negatives: 1525.0000 - false_positives: 73.0000 - false_negatives: 74.0000 - val_loss: 0.3475 - val_accuracy: 0.8989 - val_precision: 0.8989 - val_recall: 0.8989 - val_auc: 0.9697 - val_true_positives: 240.0000 - val_true_negatives: 507.0000 - val_false_positives: 27.0000 - val_false_negatives: 27.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2413 - accuracy: 0.9149 - precision: 0.9160 - recall: 0.9149 - auc: 0.9843 - true_positives: 731.0000 - true_negatives: 1531.0000 - false_positives: 67.0000 - false_negatives: 68.0000 - val_loss: 0.3020 - val_accuracy: 0.9176 - val_precision: 0.9211 - val_recall: 0.9176 - val_auc: 0.9829 - val_true_positives: 245.0000 - val_true_negatives: 513.0000 - val_false_positives: 21.0000 - val_false_negatives: 22.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2648 - accuracy: 0.8573 - precision: 0.8584 - recall: 0.8573 - auc: 0.9705 - true_positives: 685.0000 - true_negatives: 1485.0000 - false_positives: 113.0000 - false_negatives: 114.0000 - val_loss: 0.3741 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9868 - val_true_positives: 245.0000 - val_true_negatives: 512.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1821 - accuracy: 0.9224 - precision: 0.9223 - recall: 0.9212 - auc: 0.9889 - true_positives: 736.0000 - true_negatives: 1536.0000 - false_positives: 62.0000 - false_negatives: 63.0000 - val_loss: 0.3518 - val_accuracy: 0.9139 - val_precision: 0.9139 - val_recall: 0.9139 - val_auc: 0.9836 - val_true_positives: 244.0000 - val_true_negatives: 511.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000
# [[86  7  0]
#  [ 7 13  0]
#  [ 0  0  5]]
# Scores for fold 7:
# loss of 0.30524443569829907
# accuracy of 0.8813559412956238
# precision of 0.8813559412956238
# recall of 0.8813559412956238
# auc of 0.9727808237075806
# true_positives of 104.0
# true_negatives of 222.0
# false_positives of 14.0
# In training:
# Class 0: 78.99%
# Class 1: 16.98%
# In test:
# Class 0: 78.81%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 8 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 1.1241 - accuracy: 0.1715 - precision: 0.3611 - recall: 0.0163 - auc: 0.4172 - true_positives: 13.0000 - true_negatives: 1575.0000 - false_positives: 23.0000 - false_negatives: 786.0000 - val_loss: 1.1042 - val_accuracy: 0.7828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6398 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8942 - accuracy: 0.0638 - precision: 0.3444 - recall: 0.0388 - auc: 0.2258 - true_positives: 31.0000 - true_negatives: 1539.0000 - false_positives: 59.0000 - false_negatives: 768.0000 - val_loss: 1.1052 - val_accuracy: 0.7940 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8764 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8160 - accuracy: 0.2553 - precision: 0.5357 - recall: 0.0563 - auc: 0.3865 - true_positives: 45.0000 - true_negatives: 1559.0000 - false_positives: 39.0000 - false_negatives: 754.0000 - val_loss: 1.0535 - val_accuracy: 0.7678 - val_precision: 0.6667 - val_recall: 0.0075 - val_auc: 0.8634 - val_true_positives: 2.0000 - val_true_negatives: 533.0000 - val_false_positives: 1.0000 - val_false_negatives: 265.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7347 - accuracy: 0.3805 - precision: 0.4895 - recall: 0.0876 - auc: 0.5228 - true_positives: 70.0000 - true_negatives: 1525.0000 - false_positives: 73.0000 - false_negatives: 729.0000 - val_loss: 0.8182 - val_accuracy: 0.7191 - val_precision: 0.6800 - val_recall: 0.0637 - val_auc: 0.8398 - val_true_positives: 17.0000 - val_true_negatives: 526.0000 - val_false_positives: 8.0000 - val_false_negatives: 250.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7636 - accuracy: 0.6483 - precision: 0.5899 - recall: 0.1026 - auc: 0.7645 - true_positives: 82.0000 - true_negatives: 1541.0000 - false_positives: 57.0000 - false_negatives: 717.0000 - val_loss: 1.0532 - val_accuracy: 0.8277 - val_precision: 0.6667 - val_recall: 0.0075 - val_auc: 0.8910 - val_true_positives: 2.0000 - val_true_negatives: 533.0000 - val_false_positives: 1.0000 - val_false_negatives: 265.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7378 - accuracy: 0.7910 - precision: 0.7525 - recall: 0.1865 - auc: 0.8732 - true_positives: 149.0000 - true_negatives: 1549.0000 - false_positives: 49.0000 - false_negatives: 650.0000 - val_loss: 1.0134 - val_accuracy: 0.8315 - val_precision: 0.8555 - val_recall: 0.8202 - val_auc: 0.9547 - val_true_positives: 219.0000 - val_true_negatives: 497.0000 - val_false_positives: 37.0000 - val_false_negatives: 48.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.4381 - accuracy: 0.7960 - precision: 0.8317 - recall: 0.7547 - auc: 0.9268 - true_positives: 603.0000 - true_negatives: 1476.0000 - false_positives: 122.0000 - false_negatives: 196.0000 - val_loss: 0.3822 - val_accuracy: 0.9288 - val_precision: 0.9286 - val_recall: 0.9251 - val_auc: 0.9860 - val_true_positives: 247.0000 - val_true_negatives: 515.0000 - val_false_positives: 19.0000 - val_false_negatives: 20.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2008 - accuracy: 0.9312 - precision: 0.9312 - recall: 0.9312 - auc: 0.9873 - true_positives: 744.0000 - true_negatives: 1543.0000 - false_positives: 55.0000 - false_negatives: 55.0000 - val_loss: 1.1114 - val_accuracy: 0.8240 - val_precision: 0.8240 - val_recall: 0.8240 - val_auc: 0.9415 - val_true_positives: 220.0000 - val_true_negatives: 487.0000 - val_false_positives: 47.0000 - val_false_negatives: 47.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1482 - accuracy: 0.9449 - precision: 0.9449 - recall: 0.9449 - auc: 0.9927 - true_positives: 755.0000 - true_negatives: 1554.0000 - false_positives: 44.0000 - false_negatives: 44.0000 - val_loss: 0.5949 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9852 - val_true_positives: 252.0000 - val_true_negatives: 519.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2025 - accuracy: 0.9562 - precision: 0.9562 - recall: 0.9562 - auc: 0.9911 - true_positives: 764.0000 - true_negatives: 1563.0000 - false_positives: 35.0000 - false_negatives: 35.0000 - val_loss: 0.2379 - val_accuracy: 0.9326 - val_precision: 0.9326 - val_recall: 0.9326 - val_auc: 0.9863 - val_true_positives: 249.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000
# [[89  4  0]
#  [ 5 15  0]
#  [ 0  3  2]]
# Scores for fold 8:
# loss of 0.43161026855646556
# accuracy of 0.8983050584793091
# precision of 0.8983050584793091
# recall of 0.8983050584793091
# auc of 0.9480573534965515
# true_positives of 106.0
# true_negatives of 224.0
# false_positives of 12.0
# In training:
# Class 0: 78.99%
# Class 1: 16.98%
# In test:
# Class 0: 78.81%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 9 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 7ms/sample - loss: 1.2947 - accuracy: 0.1615 - precision: 0.4430 - recall: 0.0876 - auc: 0.3710 - true_positives: 70.0000 - true_negatives: 1510.0000 - false_positives: 88.0000 - false_negatives: 729.0000 - val_loss: 1.0923 - val_accuracy: 0.8127 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7163 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8734 - accuracy: 0.1051 - precision: 0.3663 - recall: 0.0463 - auc: 0.2628 - true_positives: 37.0000 - true_negatives: 1534.0000 - false_positives: 64.0000 - false_negatives: 762.0000 - val_loss: 1.0932 - val_accuracy: 0.7940 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8782 - val_true_positives: 0.0000e+00 - val_true_negatives: 534.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 267.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.8098 - accuracy: 0.1489 - precision: 0.4538 - recall: 0.0676 - auc: 0.3867 - true_positives: 54.0000 - true_negatives: 1533.0000 - false_positives: 65.0000 - false_negatives: 745.0000 - val_loss: 1.0743 - val_accuracy: 0.7603 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8521 - val_true_positives: 0.0000e+00 - val_true_negatives: 532.0000 - val_false_positives: 2.0000 - val_false_negatives: 267.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7573 - accuracy: 0.2053 - precision: 0.4474 - recall: 0.0851 - auc: 0.4579 - true_positives: 68.0000 - true_negatives: 1514.0000 - false_positives: 84.0000 - false_negatives: 731.0000 - val_loss: 1.1063 - val_accuracy: 0.7790 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8736 - val_true_positives: 0.0000e+00 - val_true_negatives: 533.0000 - val_false_positives: 1.0000 - val_false_negatives: 267.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.7475 - accuracy: 0.3229 - precision: 0.5062 - recall: 0.1026 - auc: 0.5921 - true_positives: 82.0000 - true_negatives: 1518.0000 - false_positives: 80.0000 - false_negatives: 717.0000 - val_loss: 0.8797 - val_accuracy: 0.6367 - val_precision: 0.5000 - val_recall: 0.0674 - val_auc: 0.7559 - val_true_positives: 18.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 249.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.6857 - accuracy: 0.5307 - precision: 0.5115 - recall: 0.1114 - auc: 0.7124 - true_positives: 89.0000 - true_negatives: 1513.0000 - false_positives: 85.0000 - false_negatives: 710.0000 - val_loss: 1.1550 - val_accuracy: 0.6704 - val_precision: 0.5111 - val_recall: 0.0861 - val_auc: 0.7850 - val_true_positives: 23.0000 - val_true_negatives: 512.0000 - val_false_positives: 22.0000 - val_false_negatives: 244.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.6080 - accuracy: 0.5757 - precision: 0.6417 - recall: 0.2040 - auc: 0.7827 - true_positives: 163.0000 - true_negatives: 1507.0000 - false_positives: 91.0000 - false_negatives: 636.0000 - val_loss: 1.0807 - val_accuracy: 0.6779 - val_precision: 0.5333 - val_recall: 0.1199 - val_auc: 0.8049 - val_true_positives: 32.0000 - val_true_negatives: 506.0000 - val_false_positives: 28.0000 - val_false_negatives: 235.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.5019 - accuracy: 0.7660 - precision: 0.8423 - recall: 0.5682 - auc: 0.9080 - true_positives: 454.0000 - true_negatives: 1513.0000 - false_positives: 85.0000 - false_negatives: 345.0000 - val_loss: 1.2692 - val_accuracy: 0.7154 - val_precision: 0.7377 - val_recall: 0.6742 - val_auc: 0.8655 - val_true_positives: 180.0000 - val_true_negatives: 470.0000 - val_false_positives: 64.0000 - val_false_negatives: 87.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3082 - accuracy: 0.8924 - precision: 0.8966 - recall: 0.8786 - auc: 0.9748 - true_positives: 702.0000 - true_negatives: 1517.0000 - false_positives: 81.0000 - false_negatives: 97.0000 - val_loss: 0.8329 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9656 - val_true_positives: 238.0000 - val_true_negatives: 505.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.3489 - accuracy: 0.9199 - precision: 0.9209 - recall: 0.9174 - auc: 0.9776 - true_positives: 733.0000 - true_negatives: 1535.0000 - false_positives: 63.0000 - false_negatives: 66.0000 - val_loss: 1.3254 - val_accuracy: 0.8951 - val_precision: 0.8951 - val_recall: 0.8951 - val_auc: 0.9633 - val_true_positives: 239.0000 - val_true_negatives: 506.0000 - val_false_positives: 28.0000 - val_false_negatives: 28.0000
# [[88  5  0]
#  [ 6 14  0]
#  [ 0  3  2]]
# Scores for fold 9:
# loss of 0.38509784361063426
# accuracy of 0.8813559412956238
# precision of 0.8813559412956238
# recall of 0.8813559412956238
# auc of 0.9634444117546082
# true_positives of 104.0
# true_negatives of 222.0
# false_positives of 14.0
# In training:
# Class 0: 78.99%
# Class 1: 16.98%
# In test:
# Class 0: 78.81%
# Class 1: 16.95%
# ------------------------------------------------------------------------
#
# Training for fold 10 ...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 799 samples, validate on 267 samples
# Epoch 1/10
# 799/799 [==============================] - 5s 6ms/sample - loss: 0.9302 - accuracy: 0.6358 - precision: 0.7630 - recall: 0.2578 - auc: 0.7679 - true_positives: 206.0000 - true_negatives: 1534.0000 - false_positives: 64.0000 - false_negatives: 593.0000 - val_loss: 0.5974 - val_accuracy: 0.4607 - val_precision: 0.4730 - val_recall: 0.4270 - val_auc: 0.6982 - val_true_positives: 114.0000 - val_true_negatives: 407.0000 - val_false_positives: 127.0000 - val_false_negatives: 153.0000
# Epoch 2/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.4475 - accuracy: 0.8173 - precision: 0.8168 - recall: 0.8148 - auc: 0.9396 - true_positives: 651.0000 - true_negatives: 1452.0000 - false_positives: 146.0000 - false_negatives: 148.0000 - val_loss: 0.3333 - val_accuracy: 0.8202 - val_precision: 0.8202 - val_recall: 0.8202 - val_auc: 0.9433 - val_true_positives: 219.0000 - val_true_negatives: 486.0000 - val_false_positives: 48.0000 - val_false_negatives: 48.0000
# Epoch 3/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2553 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9788 - true_positives: 717.0000 - true_negatives: 1516.0000 - false_positives: 82.0000 - false_negatives: 82.0000 - val_loss: 0.4305 - val_accuracy: 0.9139 - val_precision: 0.9139 - val_recall: 0.9139 - val_auc: 0.9836 - val_true_positives: 244.0000 - val_true_negatives: 511.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000
# Epoch 4/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1885 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9917 - true_positives: 752.0000 - true_negatives: 1551.0000 - false_positives: 47.0000 - false_negatives: 47.0000 - val_loss: 0.3173 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9858 - val_true_positives: 245.0000 - val_true_negatives: 512.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000
# Epoch 5/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1640 - accuracy: 0.9349 - precision: 0.9349 - recall: 0.9349 - auc: 0.9913 - true_positives: 747.0000 - true_negatives: 1546.0000 - false_positives: 52.0000 - false_negatives: 52.0000 - val_loss: 0.4056 - val_accuracy: 0.9326 - val_precision: 0.9326 - val_recall: 0.9326 - val_auc: 0.9854 - val_true_positives: 249.0000 - val_true_negatives: 516.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000
# Epoch 6/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1995 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9901 - true_positives: 746.0000 - true_negatives: 1545.0000 - false_positives: 53.0000 - false_negatives: 53.0000 - val_loss: 0.7481 - val_accuracy: 0.7753 - val_precision: 0.7782 - val_recall: 0.7753 - val_auc: 0.9069 - val_true_positives: 207.0000 - val_true_negatives: 475.0000 - val_false_positives: 59.0000 - val_false_negatives: 60.0000
# Epoch 7/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.2536 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9849 - true_positives: 740.0000 - true_negatives: 1539.0000 - false_positives: 59.0000 - false_negatives: 59.0000 - val_loss: 0.3551 - val_accuracy: 0.8614 - val_precision: 0.8614 - val_recall: 0.8614 - val_auc: 0.9659 - val_true_positives: 230.0000 - val_true_negatives: 497.0000 - val_false_positives: 37.0000 - val_false_negatives: 37.0000
# Epoch 8/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.1216 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9943 - true_positives: 757.0000 - true_negatives: 1556.0000 - false_positives: 42.0000 - false_negatives: 42.0000 - val_loss: 0.7169 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9796 - val_true_positives: 245.0000 - val_true_negatives: 512.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000
# Epoch 9/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.0797 - accuracy: 0.9637 - precision: 0.9637 - recall: 0.9637 - auc: 0.9966 - true_positives: 770.0000 - true_negatives: 1569.0000 - false_positives: 29.0000 - false_negatives: 29.0000 - val_loss: 0.7208 - val_accuracy: 0.9064 - val_precision: 0.9064 - val_recall: 0.9064 - val_auc: 0.9767 - val_true_positives: 242.0000 - val_true_negatives: 509.0000 - val_false_positives: 25.0000 - val_false_negatives: 25.0000
# Epoch 10/10
# 799/799 [==============================] - 2s 3ms/sample - loss: 0.0592 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9990 - true_positives: 784.0000 - true_negatives: 1583.0000 - false_positives: 15.0000 - false_negatives: 15.0000 - val_loss: 0.8379 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9668 - val_true_positives: 237.0000 - val_true_negatives: 504.0000 - val_false_positives: 30.0000 - val_false_negatives: 30.0000
# [[82 11  0]
#  [ 0 19  1]
#  [ 0  0  5]]
# Scores for fold 10:
# loss of 0.21131449331671504
# accuracy of 0.8983050584793091
# precision of 0.8983050584793091
# recall of 0.8983050584793091
# auc of 0.9879702925682068
# true_positives of 106.0
# true_negatives of 224.0
# false_positives of 12.0

# %%
print("Acurácia média: ",np.mean(acc), np.std(acc))
print("Precisão média: ",np.mean(prec), np.std(prec))
print("Recall médio: ",np.mean(rec), np.std(rec))
print("Auc média: ",np.mean(auc), np.std(auc))
# Out:
# Acurácia média:  0.88681096 0.04223722
# Precisão média:  0.8874947 0.040971734
# Recall médio:  0.88681096 0.04223722
# Auc média:  0.9675778 0.019580081

# %%
for model in os.listdir("../metricas/classificacao/7_d/tests-binary/adhoc/models"):
    metric_path = os.path.join("../metricas/classificacao/7_d/tests-binary/adhoc/models", model, "loss.png")
    img = plt.imread(metric_path)
    plt.imshow(img)
    plt.show()
