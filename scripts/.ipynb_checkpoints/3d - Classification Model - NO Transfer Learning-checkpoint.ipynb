# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 3 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1101

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 3 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "3_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "3_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classificatin model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU
# ##### Characteristics
#  - Sequencial Model
#  - Fully trained on this dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading and preparing the dataset

# %%
import imutils
def pad_image(image, size_x, size_y):
    shape = image.shape
    res = []
    
    pad_image = np.zeros((size_x,size_y,3), np.uint8)
    
    if shape[0] > shape[1]:
        res = imutils.resize(image, height=size_x)
        res = center_image(res, pad_image)
    else:
        res = imutils.resize(image, width=size_y)
        res = center_image(res, pad_image)
    
    return res
    
def center_image(image, background):
    img_shape = image.shape
    bck_shape = background.shape
    
    x_diff = round((bck_shape[0] - img_shape[0])/2)
    y_diff = round((bck_shape[1] - img_shape[1])/2)
    
#     print(image.shape, background.shape, x_diff, y_diff)
    
    res = background.copy()
    
    res[x_diff:x_diff + img_shape[0],y_diff:y_diff + img_shape[1]] = image
    
    return res

# %%
images_raw = open(os.path.join(DATASET_PATH, "3_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "3_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 256

# %% [markdown]
# ##### Padding Images in Memory

# %%
for i in range(len(images)):
    images[i] = pad_image(images[i], IMG_SIZE, IMG_SIZE)
    plt.imshow(images[i])

# %% [markdown]
# ##### Labels one hot enconding

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2)

# %%
print(test_images.shape)
# Out:
# (221, 256, 256, 3)

# %% [markdown]
# ###### Ajustando o dataset desbalanceado

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure


## Trying class weights
#it does not work withone hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

from sklearn.utils import compute_sample_weight
sample_weights = compute_sample_weight('balanced', train_labels)

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd

train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %% [markdown]
# #### Creating the model

# %%
EPOCHS = 150
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = round( (1 - TRAIN_TEST_SPLIT) * train_images.shape[0] / 32)
print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)
# Out:
# 660.0 21

# %%
base_model = keras.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False
)

base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE,IMG_SIZE, 3))
# We make sure that the base_model is running in inference mode here,
# by passing `training=False`. This is important for fine-tuning, as you will
# learn in a few paragraphs.
x = base_model(inputs, training=False)
# Convert features of shape `base_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier 
outputs = keras.layers.Dense(3, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

opt = keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)

# %%
from keras.callbacks import ModelCheckpoint
METRICDIR = './metricas/classificacao/3_d/pre_trained_weighted/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")
checkpoint = ModelCheckpoint(CHECKPOINT_DIR, monitor="val_precision", verbose=1,
    save_best_only=True, mode='max', save_freq='epoch')

# %%
history = model.fit(train_images, train_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT, sample_weight=sample_weights, callbacks=[checkpoint])
# Out:
# Epoch 1/150
# 32/32 [==============================] - 63s 2s/step - loss: 10.3170 - accuracy: 0.1296 - precision: 0.2631 - recall: 0.5616 - auc: 0.3925 - true_positives: 204.2727 - true_negatives: 154.5455 - false_positives: 556.7273 - false_negatives: 151.3636 - val_loss: 8.8092 - val_accuracy: 0.1364 - val_precision: 0.2872 - val_recall: 0.6318 - val_auc: 0.4264 - val_true_positives: 139.0000 - val_true_negatives: 95.0000 - val_false_positives: 345.0000 - val_false_negatives: 81.0000
#
# Epoch 00001: val_precision improved from -inf to 0.28719, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 2/150
# 32/32 [==============================] - 59s 2s/step - loss: 7.6327 - accuracy: 0.1488 - precision: 0.2936 - recall: 0.6313 - auc: 0.4462 - true_positives: 226.6970 - true_negatives: 168.9394 - false_positives: 542.3333 - false_negatives: 128.9394 - val_loss: 8.2107 - val_accuracy: 0.1591 - val_precision: 0.3143 - val_recall: 0.7000 - val_auc: 0.4551 - val_true_positives: 154.0000 - val_true_negatives: 104.0000 - val_false_positives: 336.0000 - val_false_negatives: 66.0000
#
# Epoch 00002: val_precision improved from 0.28719 to 0.31429, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 3/150
# 32/32 [==============================] - 63s 2s/step - loss: 7.5544 - accuracy: 0.1363 - precision: 0.3139 - recall: 0.6902 - auc: 0.4597 - true_positives: 248.2424 - true_negatives: 172.0909 - false_positives: 539.1818 - false_negatives: 107.3939 - val_loss: 8.0236 - val_accuracy: 0.1773 - val_precision: 0.3226 - val_recall: 0.7273 - val_auc: 0.4730 - val_true_positives: 160.0000 - val_true_negatives: 104.0000 - val_false_positives: 336.0000 - val_false_negatives: 60.0000
#
# Epoch 00003: val_precision improved from 0.31429 to 0.32258, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 4/150
# 32/32 [==============================] - 64s 2s/step - loss: 7.0515 - accuracy: 0.1628 - precision: 0.3243 - recall: 0.7305 - auc: 0.4685 - true_positives: 263.3939 - true_negatives: 172.6970 - false_positives: 538.5758 - false_negatives: 92.2424 - val_loss: 7.9495 - val_accuracy: 0.1864 - val_precision: 0.3393 - val_recall: 0.7727 - val_auc: 0.4898 - val_true_positives: 170.0000 - val_true_negatives: 109.0000 - val_false_positives: 331.0000 - val_false_negatives: 50.0000
#
# Epoch 00004: val_precision improved from 0.32258 to 0.33932, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 5/150
# 32/32 [==============================] - 64s 2s/step - loss: 6.0773 - accuracy: 0.1952 - precision: 0.3430 - recall: 0.7863 - auc: 0.4926 - true_positives: 277.1818 - true_negatives: 178.5758 - false_positives: 532.6970 - false_negatives: 78.4545 - val_loss: 7.7481 - val_accuracy: 0.1955 - val_precision: 0.3459 - val_recall: 0.7909 - val_auc: 0.5027 - val_true_positives: 174.0000 - val_true_negatives: 111.0000 - val_false_positives: 329.0000 - val_false_negatives: 46.0000
#
# Epoch 00005: val_precision improved from 0.33932 to 0.34592, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 6/150
# 32/32 [==============================] - 65s 2s/step - loss: 5.9081 - accuracy: 0.2155 - precision: 0.3513 - recall: 0.8157 - auc: 0.4939 - true_positives: 288.0606 - true_negatives: 176.1515 - false_positives: 535.1212 - false_negatives: 67.5758 - val_loss: 7.7662 - val_accuracy: 0.2227 - val_precision: 0.3588 - val_recall: 0.8318 - val_auc: 0.5154 - val_true_positives: 183.0000 - val_true_negatives: 113.0000 - val_false_positives: 327.0000 - val_false_negatives: 37.0000
#
# Epoch 00006: val_precision improved from 0.34592 to 0.35882, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 7/150
# 32/32 [==============================] - 89s 3s/step - loss: 4.8975 - accuracy: 0.2351 - precision: 0.3550 - recall: 0.8141 - auc: 0.5089 - true_positives: 289.9697 - true_negatives: 182.6970 - false_positives: 528.5758 - false_negatives: 65.6667 - val_loss: 7.4420 - val_accuracy: 0.2682 - val_precision: 0.3620 - val_recall: 0.8409 - val_auc: 0.5250 - val_true_positives: 185.0000 - val_true_negatives: 114.0000 - val_false_positives: 326.0000 - val_false_negatives: 35.0000
#
# Epoch 00007: val_precision improved from 0.35882 to 0.36204, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 8/150
# 32/32 [==============================] - 70s 2s/step - loss: 5.6786 - accuracy: 0.2739 - precision: 0.3617 - recall: 0.8531 - auc: 0.5161 - true_positives: 301.1818 - true_negatives: 181.0606 - false_positives: 530.2121 - false_negatives: 54.4545 - val_loss: 7.1864 - val_accuracy: 0.2955 - val_precision: 0.3669 - val_recall: 0.8455 - val_auc: 0.5374 - val_true_positives: 186.0000 - val_true_negatives: 119.0000 - val_false_positives: 321.0000 - val_false_negatives: 34.0000
#
# Epoch 00008: val_precision improved from 0.36204 to 0.36686, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 9/150
# 32/32 [==============================] - 72s 2s/step - loss: 4.5120 - accuracy: 0.3026 - precision: 0.3710 - recall: 0.8557 - auc: 0.5353 - true_positives: 303.1212 - true_negatives: 191.1212 - false_positives: 520.1515 - false_negatives: 52.5152 - val_loss: 7.1061 - val_accuracy: 0.3273 - val_precision: 0.3740 - val_recall: 0.8636 - val_auc: 0.5484 - val_true_positives: 190.0000 - val_true_negatives: 122.0000 - val_false_positives: 318.0000 - val_false_negatives: 30.0000
#
# Epoch 00009: val_precision improved from 0.36686 to 0.37402, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 10/150
# 32/32 [==============================] - 64s 2s/step - loss: 6.3263 - accuracy: 0.3025 - precision: 0.3710 - recall: 0.8749 - auc: 0.5383 - true_positives: 311.0000 - true_negatives: 183.6970 - false_positives: 527.5758 - false_negatives: 44.6364 - val_loss: 6.8433 - val_accuracy: 0.3455 - val_precision: 0.3816 - val_recall: 0.8864 - val_auc: 0.5567 - val_true_positives: 195.0000 - val_true_negatives: 124.0000 - val_false_positives: 316.0000 - val_false_negatives: 25.0000
#
# Epoch 00010: val_precision improved from 0.37402 to 0.38160, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 11/150
# 32/32 [==============================] - 65s 2s/step - loss: 5.2643 - accuracy: 0.3251 - precision: 0.3754 - recall: 0.8965 - auc: 0.5428 - true_positives: 317.9091 - true_negatives: 188.9394 - false_positives: 522.3333 - false_negatives: 37.7273 - val_loss: 6.6934 - val_accuracy: 0.3636 - val_precision: 0.3860 - val_recall: 0.9000 - val_auc: 0.5660 - val_true_positives: 198.0000 - val_true_negatives: 125.0000 - val_false_positives: 315.0000 - val_false_negatives: 22.0000
#
# Epoch 00011: val_precision improved from 0.38160 to 0.38596, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 12/150
# 32/32 [==============================] - 66s 2s/step - loss: 5.5887 - accuracy: 0.3458 - precision: 0.3775 - recall: 0.8834 - auc: 0.5565 - true_positives: 318.7879 - true_negatives: 194.8182 - false_positives: 516.4545 - false_negatives: 36.8485 - val_loss: 6.6738 - val_accuracy: 0.3955 - val_precision: 0.3891 - val_recall: 0.9091 - val_auc: 0.5721 - val_true_positives: 200.0000 - val_true_negatives: 126.0000 - val_false_positives: 314.0000 - val_false_negatives: 20.0000
#
# Epoch 00012: val_precision improved from 0.38596 to 0.38911, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 13/150
# 32/32 [==============================] - 69s 2s/step - loss: 5.2635 - accuracy: 0.3962 - precision: 0.3868 - recall: 0.9100 - auc: 0.5636 - true_positives: 326.1212 - true_negatives: 198.6667 - false_positives: 512.6061 - false_negatives: 29.5152 - val_loss: 6.4461 - val_accuracy: 0.4364 - val_precision: 0.3926 - val_recall: 0.9136 - val_auc: 0.5875 - val_true_positives: 201.0000 - val_true_negatives: 129.0000 - val_false_positives: 311.0000 - val_false_negatives: 19.0000
#
# Epoch 00013: val_precision improved from 0.38911 to 0.39258, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 14/150
# 32/32 [==============================] - 65s 2s/step - loss: 4.9332 - accuracy: 0.4141 - precision: 0.3949 - recall: 0.9378 - auc: 0.5787 - true_positives: 332.3636 - true_negatives: 197.9697 - false_positives: 513.3030 - false_negatives: 23.2727 - val_loss: 6.4315 - val_accuracy: 0.4591 - val_precision: 0.3945 - val_recall: 0.9182 - val_auc: 0.5987 - val_true_positives: 202.0000 - val_true_negatives: 130.0000 - val_false_positives: 310.0000 - val_false_negatives: 18.0000
#
# Epoch 00014: val_precision improved from 0.39258 to 0.39453, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 15/150
# 32/32 [==============================] - 55s 2s/step - loss: 3.9781 - accuracy: 0.4277 - precision: 0.3922 - recall: 0.9251 - auc: 0.5739 - true_positives: 332.6667 - true_negatives: 201.8788 - false_positives: 509.3939 - false_negatives: 22.9697 - val_loss: 6.2670 - val_accuracy: 0.4864 - val_precision: 0.4004 - val_recall: 0.9318 - val_auc: 0.6054 - val_true_positives: 205.0000 - val_true_negatives: 133.0000 - val_false_positives: 307.0000 - val_false_negatives: 15.0000
#
# Epoch 00015: val_precision improved from 0.39453 to 0.40039, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 16/150
# 32/32 [==============================] - 55s 2s/step - loss: 4.1116 - accuracy: 0.4838 - precision: 0.3992 - recall: 0.9468 - auc: 0.5904 - true_positives: 336.3636 - true_negatives: 205.8182 - false_positives: 505.4545 - false_negatives: 19.2727 - val_loss: 6.0229 - val_accuracy: 0.4955 - val_precision: 0.4039 - val_recall: 0.9455 - val_auc: 0.6088 - val_true_positives: 208.0000 - val_true_negatives: 133.0000 - val_false_positives: 307.0000 - val_false_negatives: 12.0000
#
# Epoch 00016: val_precision improved from 0.40039 to 0.40388, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 17/150
# 32/32 [==============================] - 56s 2s/step - loss: 4.2571 - accuracy: 0.4772 - precision: 0.3971 - recall: 0.9460 - auc: 0.5946 - true_positives: 337.1515 - true_negatives: 205.7576 - false_positives: 505.5152 - false_negatives: 18.4848 - val_loss: 6.0556 - val_accuracy: 0.5136 - val_precision: 0.4055 - val_recall: 0.9455 - val_auc: 0.6154 - val_true_positives: 208.0000 - val_true_negatives: 135.0000 - val_false_positives: 305.0000 - val_false_negatives: 12.0000
#
# Epoch 00017: val_precision improved from 0.40388 to 0.40546, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 18/150
# 32/32 [==============================] - 70s 2s/step - loss: 3.3504 - accuracy: 0.4896 - precision: 0.4026 - recall: 0.9502 - auc: 0.6106 - true_positives: 339.4242 - true_negatives: 206.9091 - false_positives: 504.3636 - false_negatives: 16.2121 - val_loss: 5.9822 - val_accuracy: 0.5273 - val_precision: 0.4125 - val_recall: 0.9636 - val_auc: 0.6232 - val_true_positives: 212.0000 - val_true_negatives: 138.0000 - val_false_positives: 302.0000 - val_false_negatives: 8.0000
#
# Epoch 00018: val_precision improved from 0.40546 to 0.41245, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 19/150
# 32/32 [==============================] - 74s 2s/step - loss: 4.0140 - accuracy: 0.5188 - precision: 0.3985 - recall: 0.9552 - auc: 0.6087 - true_positives: 340.3939 - true_negatives: 205.9697 - false_positives: 505.3030 - false_negatives: 15.2424 - val_loss: 5.8550 - val_accuracy: 0.5364 - val_precision: 0.4133 - val_recall: 0.9636 - val_auc: 0.6328 - val_true_positives: 212.0000 - val_true_negatives: 139.0000 - val_false_positives: 301.0000 - val_false_negatives: 8.0000
#
# Epoch 00019: val_precision improved from 0.41245 to 0.41326, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 20/150
# 32/32 [==============================] - 74s 2s/step - loss: 3.6861 - accuracy: 0.5549 - precision: 0.4102 - recall: 0.9708 - auc: 0.6260 - true_positives: 344.0303 - true_negatives: 218.4848 - false_positives: 492.7879 - false_negatives: 11.6061 - val_loss: 5.7884 - val_accuracy: 0.5545 - val_precision: 0.4149 - val_recall: 0.9636 - val_auc: 0.6395 - val_true_positives: 212.0000 - val_true_negatives: 141.0000 - val_false_positives: 299.0000 - val_false_negatives: 8.0000
#
# Epoch 00020: val_precision improved from 0.41326 to 0.41487, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 21/150
# 32/32 [==============================] - 74s 2s/step - loss: 3.9450 - accuracy: 0.5862 - precision: 0.4197 - recall: 0.9690 - auc: 0.6371 - true_positives: 344.3636 - true_negatives: 224.7273 - false_positives: 486.5455 - false_negatives: 11.2727 - val_loss: 5.6212 - val_accuracy: 0.5682 - val_precision: 0.4149 - val_recall: 0.9636 - val_auc: 0.6435 - val_true_positives: 212.0000 - val_true_negatives: 141.0000 - val_false_positives: 299.0000 - val_false_negatives: 8.0000
#
# Epoch 00021: val_precision did not improve from 0.41487
# Epoch 22/150
# 32/32 [==============================] - 69s 2s/step - loss: 3.4340 - accuracy: 0.5520 - precision: 0.4225 - recall: 0.9687 - auc: 0.6487 - true_positives: 344.7273 - true_negatives: 237.0606 - false_positives: 474.2121 - false_negatives: 10.9091 - val_loss: 5.6909 - val_accuracy: 0.5682 - val_precision: 0.4176 - val_recall: 0.9682 - val_auc: 0.6458 - val_true_positives: 213.0000 - val_true_negatives: 143.0000 - val_false_positives: 297.0000 - val_false_negatives: 7.0000
#
# Epoch 00022: val_precision improved from 0.41487 to 0.41765, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 23/150
# 32/32 [==============================] - 58s 2s/step - loss: 3.7590 - accuracy: 0.5820 - precision: 0.4163 - recall: 0.9728 - auc: 0.6469 - true_positives: 346.0000 - true_negatives: 226.8485 - false_positives: 484.4242 - false_negatives: 9.6364 - val_loss: 5.5051 - val_accuracy: 0.5818 - val_precision: 0.4213 - val_recall: 0.9727 - val_auc: 0.6519 - val_true_positives: 214.0000 - val_true_negatives: 146.0000 - val_false_positives: 294.0000 - val_false_negatives: 6.0000
#
# Epoch 00023: val_precision improved from 0.41765 to 0.42126, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 24/150
# 32/32 [==============================] - 62s 2s/step - loss: 3.4152 - accuracy: 0.6015 - precision: 0.4127 - recall: 0.9746 - auc: 0.6437 - true_positives: 347.0000 - true_negatives: 223.3636 - false_positives: 487.9091 - false_negatives: 8.6364 - val_loss: 5.4620 - val_accuracy: 0.6000 - val_precision: 0.4269 - val_recall: 0.9818 - val_auc: 0.6569 - val_true_positives: 216.0000 - val_true_negatives: 150.0000 - val_false_positives: 290.0000 - val_false_negatives: 4.0000
#
# Epoch 00024: val_precision improved from 0.42126 to 0.42688, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 25/150
# 32/32 [==============================] - 65s 2s/step - loss: 3.5562 - accuracy: 0.6041 - precision: 0.4135 - recall: 0.9789 - auc: 0.6388 - true_positives: 348.1212 - true_negatives: 219.6061 - false_positives: 491.6667 - false_negatives: 7.5152 - val_loss: 5.3921 - val_accuracy: 0.6091 - val_precision: 0.4277 - val_recall: 0.9818 - val_auc: 0.6602 - val_true_positives: 216.0000 - val_true_negatives: 151.0000 - val_false_positives: 289.0000 - val_false_negatives: 4.0000
#
# Epoch 00025: val_precision improved from 0.42688 to 0.42772, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 26/150
# 32/32 [==============================] - 54s 2s/step - loss: 3.4507 - accuracy: 0.5797 - precision: 0.4154 - recall: 0.9784 - auc: 0.6575 - true_positives: 349.3636 - true_negatives: 221.4848 - false_positives: 489.7879 - false_negatives: 6.2727 - val_loss: 5.3536 - val_accuracy: 0.6136 - val_precision: 0.4277 - val_recall: 0.9818 - val_auc: 0.6635 - val_true_positives: 216.0000 - val_true_negatives: 151.0000 - val_false_positives: 289.0000 - val_false_negatives: 4.0000
#
# Epoch 00026: val_precision did not improve from 0.42772
# Epoch 27/150
# 32/32 [==============================] - 54s 2s/step - loss: 3.4088 - accuracy: 0.6117 - precision: 0.4205 - recall: 0.9904 - auc: 0.6425 - true_positives: 351.6667 - true_negatives: 224.3636 - false_positives: 486.9091 - false_negatives: 3.9697 - val_loss: 5.2565 - val_accuracy: 0.6273 - val_precision: 0.4277 - val_recall: 0.9818 - val_auc: 0.6664 - val_true_positives: 216.0000 - val_true_negatives: 151.0000 - val_false_positives: 289.0000 - val_false_negatives: 4.0000
#
# Epoch 00027: val_precision did not improve from 0.42772
# Epoch 28/150
# 32/32 [==============================] - 53s 2s/step - loss: 3.1242 - accuracy: 0.6148 - precision: 0.4184 - recall: 0.9856 - auc: 0.6589 - true_positives: 350.3939 - true_negatives: 226.4848 - false_positives: 484.7879 - false_negatives: 5.2424 - val_loss: 5.2372 - val_accuracy: 0.6455 - val_precision: 0.4277 - val_recall: 0.9818 - val_auc: 0.6675 - val_true_positives: 216.0000 - val_true_negatives: 151.0000 - val_false_positives: 289.0000 - val_false_negatives: 4.0000
#
# Epoch 00028: val_precision did not improve from 0.42772
# Epoch 29/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.5196 - accuracy: 0.6302 - precision: 0.4264 - recall: 0.9848 - auc: 0.6735 - true_positives: 350.6061 - true_negatives: 235.0909 - false_positives: 476.1818 - false_negatives: 5.0303 - val_loss: 5.2416 - val_accuracy: 0.6409 - val_precision: 0.4286 - val_recall: 0.9818 - val_auc: 0.6703 - val_true_positives: 216.0000 - val_true_negatives: 152.0000 - val_false_positives: 288.0000 - val_false_negatives: 4.0000
#
# Epoch 00029: val_precision improved from 0.42772 to 0.42857, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 30/150
# 32/32 [==============================] - 53s 2s/step - loss: 3.6944 - accuracy: 0.6295 - precision: 0.4178 - recall: 0.9855 - auc: 0.6616 - true_positives: 350.9697 - true_negatives: 231.9394 - false_positives: 479.3333 - false_negatives: 4.6667 - val_loss: 5.1625 - val_accuracy: 0.6364 - val_precision: 0.4286 - val_recall: 0.9818 - val_auc: 0.6769 - val_true_positives: 216.0000 - val_true_negatives: 152.0000 - val_false_positives: 288.0000 - val_false_negatives: 4.0000
#
# Epoch 00030: val_precision did not improve from 0.42857
# Epoch 31/150
# 32/32 [==============================] - 53s 2s/step - loss: 3.3336 - accuracy: 0.6402 - precision: 0.4226 - recall: 0.9921 - auc: 0.6688 - true_positives: 352.7273 - true_negatives: 231.6970 - false_positives: 479.5758 - false_negatives: 2.9091 - val_loss: 5.1383 - val_accuracy: 0.6455 - val_precision: 0.4294 - val_recall: 0.9818 - val_auc: 0.6803 - val_true_positives: 216.0000 - val_true_negatives: 153.0000 - val_false_positives: 287.0000 - val_false_negatives: 4.0000
#
# Epoch 00031: val_precision improved from 0.42857 to 0.42942, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 32/150
# 32/32 [==============================] - 53s 2s/step - loss: 3.4620 - accuracy: 0.6314 - precision: 0.4200 - recall: 0.9948 - auc: 0.6612 - true_positives: 353.2727 - true_negatives: 228.4545 - false_positives: 482.8182 - false_negatives: 2.3636 - val_loss: 5.0703 - val_accuracy: 0.6636 - val_precision: 0.4303 - val_recall: 0.9818 - val_auc: 0.6823 - val_true_positives: 216.0000 - val_true_negatives: 154.0000 - val_false_positives: 286.0000 - val_false_negatives: 4.0000
#
# Epoch 00032: val_precision improved from 0.42942 to 0.43028, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 33/150
# 32/32 [==============================] - 52s 2s/step - loss: 2.4551 - accuracy: 0.6507 - precision: 0.4302 - recall: 0.9972 - auc: 0.6912 - true_positives: 354.3333 - true_negatives: 236.2424 - false_positives: 475.0303 - false_negatives: 1.3030 - val_loss: 5.1332 - val_accuracy: 0.6636 - val_precision: 0.4329 - val_recall: 0.9818 - val_auc: 0.6843 - val_true_positives: 216.0000 - val_true_negatives: 157.0000 - val_false_positives: 283.0000 - val_false_negatives: 4.0000
#
# Epoch 00033: val_precision improved from 0.43028 to 0.43287, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 34/150
# 32/32 [==============================] - 52s 2s/step - loss: 2.9215 - accuracy: 0.6734 - precision: 0.4327 - recall: 0.9945 - auc: 0.6845 - true_positives: 353.5152 - true_negatives: 244.8182 - false_positives: 466.4545 - false_negatives: 2.1212 - val_loss: 4.9705 - val_accuracy: 0.6818 - val_precision: 0.4323 - val_recall: 0.9864 - val_auc: 0.6876 - val_true_positives: 217.0000 - val_true_negatives: 155.0000 - val_false_positives: 285.0000 - val_false_negatives: 3.0000
#
# Epoch 00034: val_precision did not improve from 0.43287
# Epoch 35/150
# 32/32 [==============================] - 52s 2s/step - loss: 2.5112 - accuracy: 0.6746 - precision: 0.4345 - recall: 0.9928 - auc: 0.6976 - true_positives: 353.6667 - true_negatives: 244.8788 - false_positives: 466.3939 - false_negatives: 1.9697 - val_loss: 4.9867 - val_accuracy: 0.6818 - val_precision: 0.4331 - val_recall: 0.9864 - val_auc: 0.6872 - val_true_positives: 217.0000 - val_true_negatives: 156.0000 - val_false_positives: 284.0000 - val_false_negatives: 3.0000
#
# Epoch 00035: val_precision improved from 0.43287 to 0.43313, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 36/150
# 32/32 [==============================] - 52s 2s/step - loss: 2.8205 - accuracy: 0.6621 - precision: 0.4350 - recall: 0.9955 - auc: 0.6895 - true_positives: 353.7273 - true_negatives: 245.7273 - false_positives: 465.5455 - false_negatives: 1.9091 - val_loss: 5.0194 - val_accuracy: 0.6818 - val_precision: 0.4357 - val_recall: 0.9864 - val_auc: 0.6878 - val_true_positives: 217.0000 - val_true_negatives: 159.0000 - val_false_positives: 281.0000 - val_false_negatives: 3.0000
#
# Epoch 00036: val_precision improved from 0.43313 to 0.43574, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 37/150
# 32/32 [==============================] - 55s 2s/step - loss: 2.2463 - accuracy: 0.6630 - precision: 0.4256 - recall: 0.9964 - auc: 0.6785 - true_positives: 354.2424 - true_negatives: 239.5758 - false_positives: 471.6970 - false_negatives: 1.3939 - val_loss: 4.9870 - val_accuracy: 0.6818 - val_precision: 0.4404 - val_recall: 0.9909 - val_auc: 0.6936 - val_true_positives: 218.0000 - val_true_negatives: 163.0000 - val_false_positives: 277.0000 - val_false_negatives: 2.0000
#
# Epoch 00037: val_precision improved from 0.43574 to 0.44040, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 38/150
# 32/32 [==============================] - 55s 2s/step - loss: 3.2739 - accuracy: 0.6754 - precision: 0.4310 - recall: 0.9937 - auc: 0.6925 - true_positives: 353.9394 - true_negatives: 241.7879 - false_positives: 469.4848 - false_negatives: 1.6970 - val_loss: 4.9026 - val_accuracy: 0.6818 - val_precision: 0.4404 - val_recall: 0.9909 - val_auc: 0.6973 - val_true_positives: 218.0000 - val_true_negatives: 163.0000 - val_false_positives: 277.0000 - val_false_negatives: 2.0000
#
# Epoch 00038: val_precision did not improve from 0.44040
# Epoch 39/150
# 32/32 [==============================] - 56s 2s/step - loss: 3.0456 - accuracy: 0.6799 - precision: 0.4305 - recall: 0.9993 - auc: 0.6972 - true_positives: 355.2121 - true_negatives: 241.6667 - false_positives: 469.6061 - false_negatives: 0.4242 - val_loss: 4.9210 - val_accuracy: 0.6818 - val_precision: 0.4413 - val_recall: 0.9909 - val_auc: 0.6968 - val_true_positives: 218.0000 - val_true_negatives: 164.0000 - val_false_positives: 276.0000 - val_false_negatives: 2.0000
#
# Epoch 00039: val_precision improved from 0.44040 to 0.44130, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 40/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.6492 - accuracy: 0.6959 - precision: 0.4382 - recall: 0.9980 - auc: 0.7034 - true_positives: 354.8182 - true_negatives: 248.9394 - false_positives: 462.3333 - false_negatives: 0.8182 - val_loss: 4.8809 - val_accuracy: 0.6864 - val_precision: 0.4413 - val_recall: 0.9909 - val_auc: 0.6987 - val_true_positives: 218.0000 - val_true_negatives: 164.0000 - val_false_positives: 276.0000 - val_false_negatives: 2.0000
#
# Epoch 00040: val_precision did not improve from 0.44130
# Epoch 41/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.5126 - accuracy: 0.6982 - precision: 0.4276 - recall: 0.9977 - auc: 0.6961 - true_positives: 354.7273 - true_negatives: 238.9091 - false_positives: 472.3636 - false_negatives: 0.9091 - val_loss: 4.9002 - val_accuracy: 0.6864 - val_precision: 0.4424 - val_recall: 0.9955 - val_auc: 0.6993 - val_true_positives: 219.0000 - val_true_negatives: 164.0000 - val_false_positives: 276.0000 - val_false_negatives: 1.0000
#
# Epoch 00041: val_precision improved from 0.44130 to 0.44242, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 42/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.0684 - accuracy: 0.7017 - precision: 0.4343 - recall: 0.9908 - auc: 0.6976 - true_positives: 353.7273 - true_negatives: 254.0909 - false_positives: 457.1818 - false_negatives: 1.9091 - val_loss: 4.8397 - val_accuracy: 0.6909 - val_precision: 0.4424 - val_recall: 0.9955 - val_auc: 0.7024 - val_true_positives: 219.0000 - val_true_negatives: 164.0000 - val_false_positives: 276.0000 - val_false_negatives: 1.0000
#
# Epoch 00042: val_precision did not improve from 0.44242
# Epoch 43/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.5535 - accuracy: 0.7001 - precision: 0.4325 - recall: 0.9969 - auc: 0.6968 - true_positives: 354.3030 - true_negatives: 245.5455 - false_positives: 465.7273 - false_negatives: 1.3333 - val_loss: 4.7871 - val_accuracy: 0.6909 - val_precision: 0.4433 - val_recall: 0.9955 - val_auc: 0.7033 - val_true_positives: 219.0000 - val_true_negatives: 165.0000 - val_false_positives: 275.0000 - val_false_negatives: 1.0000
#
# Epoch 00043: val_precision improved from 0.44242 to 0.44332, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 44/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.4523 - accuracy: 0.6960 - precision: 0.4301 - recall: 0.9952 - auc: 0.6965 - true_positives: 354.0000 - true_negatives: 244.9697 - false_positives: 466.3030 - false_negatives: 1.6364 - val_loss: 4.8195 - val_accuracy: 0.6909 - val_precision: 0.4444 - val_recall: 1.0000 - val_auc: 0.7035 - val_true_positives: 220.0000 - val_true_negatives: 165.0000 - val_false_positives: 275.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00044: val_precision improved from 0.44332 to 0.44444, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 45/150
# 32/32 [==============================] - 53s 2s/step - loss: 3.3070 - accuracy: 0.6907 - precision: 0.4310 - recall: 0.9978 - auc: 0.6988 - true_positives: 354.8485 - true_negatives: 246.7273 - false_positives: 464.5455 - false_negatives: 0.7879 - val_loss: 4.7716 - val_accuracy: 0.6909 - val_precision: 0.4444 - val_recall: 1.0000 - val_auc: 0.7038 - val_true_positives: 220.0000 - val_true_negatives: 165.0000 - val_false_positives: 275.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00045: val_precision did not improve from 0.44444
# Epoch 46/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.4919 - accuracy: 0.6806 - precision: 0.4452 - recall: 0.9994 - auc: 0.7042 - true_positives: 355.2727 - true_negatives: 262.1515 - false_positives: 449.1212 - false_negatives: 0.3636 - val_loss: 4.8204 - val_accuracy: 0.7000 - val_precision: 0.4453 - val_recall: 1.0000 - val_auc: 0.7078 - val_true_positives: 220.0000 - val_true_negatives: 166.0000 - val_false_positives: 274.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00046: val_precision improved from 0.44444 to 0.44534, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 47/150
# 32/32 [==============================] - 52s 2s/step - loss: 3.6842 - accuracy: 0.6751 - precision: 0.4370 - recall: 1.0000 - auc: 0.6996 - true_positives: 355.6364 - true_negatives: 251.4242 - false_positives: 459.8485 - false_negatives: 0.0000e+00 - val_loss: 4.7267 - val_accuracy: 0.7000 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7093 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00047: val_precision improved from 0.44534 to 0.44625, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 48/150
# 32/32 [==============================] - 52s 2s/step - loss: 2.3351 - accuracy: 0.7022 - precision: 0.4345 - recall: 1.0000 - auc: 0.6967 - true_positives: 355.6364 - true_negatives: 243.1515 - false_positives: 468.1212 - false_negatives: 0.0000e+00 - val_loss: 4.8159 - val_accuracy: 0.7000 - val_precision: 0.4453 - val_recall: 1.0000 - val_auc: 0.7094 - val_true_positives: 220.0000 - val_true_negatives: 166.0000 - val_false_positives: 274.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00048: val_precision did not improve from 0.44625
# Epoch 49/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.2854 - accuracy: 0.6928 - precision: 0.4384 - recall: 1.0000 - auc: 0.7126 - true_positives: 355.6364 - true_negatives: 254.5758 - false_positives: 456.6970 - false_negatives: 0.0000e+00 - val_loss: 4.7267 - val_accuracy: 0.7000 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7131 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00049: val_precision did not improve from 0.44625
# Epoch 50/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.0681 - accuracy: 0.7087 - precision: 0.4398 - recall: 1.0000 - auc: 0.7127 - true_positives: 355.6364 - true_negatives: 254.6667 - false_positives: 456.6061 - false_negatives: 0.0000e+00 - val_loss: 4.6258 - val_accuracy: 0.7045 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7174 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00050: val_precision did not improve from 0.44625
# Epoch 51/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.0893 - accuracy: 0.6933 - precision: 0.4371 - recall: 1.0000 - auc: 0.7099 - true_positives: 355.6364 - true_negatives: 257.2121 - false_positives: 454.0606 - false_negatives: 0.0000e+00 - val_loss: 4.6772 - val_accuracy: 0.7045 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7181 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00051: val_precision did not improve from 0.44625
# Epoch 52/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.8779 - accuracy: 0.7200 - precision: 0.4458 - recall: 1.0000 - auc: 0.7197 - true_positives: 355.6364 - true_negatives: 260.7576 - false_positives: 450.5152 - false_negatives: 0.0000e+00 - val_loss: 4.6108 - val_accuracy: 0.7045 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7192 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00052: val_precision did not improve from 0.44625
# Epoch 53/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.8519 - accuracy: 0.6993 - precision: 0.4348 - recall: 1.0000 - auc: 0.7064 - true_positives: 355.6364 - true_negatives: 252.6061 - false_positives: 458.6667 - false_negatives: 0.0000e+00 - val_loss: 4.6415 - val_accuracy: 0.7045 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7195 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00053: val_precision did not improve from 0.44625
# Epoch 54/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.5273 - accuracy: 0.7121 - precision: 0.4450 - recall: 1.0000 - auc: 0.7272 - true_positives: 355.6364 - true_negatives: 261.8485 - false_positives: 449.4242 - false_negatives: 0.0000e+00 - val_loss: 4.6738 - val_accuracy: 0.7091 - val_precision: 0.4462 - val_recall: 1.0000 - val_auc: 0.7201 - val_true_positives: 220.0000 - val_true_negatives: 167.0000 - val_false_positives: 273.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00054: val_precision did not improve from 0.44625
# Epoch 55/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.1390 - accuracy: 0.7264 - precision: 0.4434 - recall: 1.0000 - auc: 0.7266 - true_positives: 355.6364 - true_negatives: 258.3939 - false_positives: 452.8788 - false_negatives: 0.0000e+00 - val_loss: 4.5899 - val_accuracy: 0.7091 - val_precision: 0.4481 - val_recall: 1.0000 - val_auc: 0.7224 - val_true_positives: 220.0000 - val_true_negatives: 169.0000 - val_false_positives: 271.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00055: val_precision improved from 0.44625 to 0.44807, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 56/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.8519 - accuracy: 0.6902 - precision: 0.4392 - recall: 1.0000 - auc: 0.7156 - true_positives: 355.6364 - true_negatives: 256.3030 - false_positives: 454.9697 - false_negatives: 0.0000e+00 - val_loss: 4.5736 - val_accuracy: 0.7091 - val_precision: 0.4481 - val_recall: 1.0000 - val_auc: 0.7224 - val_true_positives: 220.0000 - val_true_negatives: 169.0000 - val_false_positives: 271.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00056: val_precision did not improve from 0.44807
# Epoch 57/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.6045 - accuracy: 0.6910 - precision: 0.4339 - recall: 1.0000 - auc: 0.7131 - true_positives: 355.6364 - true_negatives: 253.8182 - false_positives: 457.4545 - false_negatives: 0.0000e+00 - val_loss: 4.5512 - val_accuracy: 0.7091 - val_precision: 0.4481 - val_recall: 1.0000 - val_auc: 0.7250 - val_true_positives: 220.0000 - val_true_negatives: 169.0000 - val_false_positives: 271.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00057: val_precision did not improve from 0.44807
# Epoch 58/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.1077 - accuracy: 0.7180 - precision: 0.4339 - recall: 1.0000 - auc: 0.7174 - true_positives: 355.6364 - true_negatives: 254.0303 - false_positives: 457.2424 - false_negatives: 0.0000e+00 - val_loss: 4.5592 - val_accuracy: 0.7136 - val_precision: 0.4481 - val_recall: 1.0000 - val_auc: 0.7284 - val_true_positives: 220.0000 - val_true_negatives: 169.0000 - val_false_positives: 271.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00058: val_precision did not improve from 0.44807
# Epoch 59/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.4976 - accuracy: 0.7060 - precision: 0.4370 - recall: 1.0000 - auc: 0.7191 - true_positives: 355.6364 - true_negatives: 254.4545 - false_positives: 456.8182 - false_negatives: 0.0000e+00 - val_loss: 4.4400 - val_accuracy: 0.7136 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7306 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00059: val_precision improved from 0.44807 to 0.44898, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 60/150
# 32/32 [==============================] - 53s 2s/step - loss: 2.0961 - accuracy: 0.7205 - precision: 0.4423 - recall: 1.0000 - auc: 0.7291 - true_positives: 355.6364 - true_negatives: 259.0606 - false_positives: 452.2121 - false_negatives: 0.0000e+00 - val_loss: 4.4709 - val_accuracy: 0.7136 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7297 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
# Epoch 00060: val_precision did not improve from 0.44898
# Epoch 61/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.1230 - accuracy: 0.6878 - precision: 0.4431 - recall: 1.0000 - auc: 0.7204 - true_positives: 355.6364 - true_negatives: 265.6970 - false_positives: 445.5758 - false_negatives: 0.0000e+00 - val_loss: 4.4848 - val_accuracy: 0.7136 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7299 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00061: val_precision did not improve from 0.44898
# Epoch 62/150
# 32/32 [==============================] - 54s 2s/step - loss: 1.6718 - accuracy: 0.7273 - precision: 0.4455 - recall: 1.0000 - auc: 0.7356 - true_positives: 355.6364 - true_negatives: 270.9394 - false_positives: 440.3333 - false_negatives: 0.0000e+00 - val_loss: 4.5140 - val_accuracy: 0.7136 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7314 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00062: val_precision did not improve from 0.44898
# Epoch 63/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.6537 - accuracy: 0.7185 - precision: 0.4344 - recall: 1.0000 - auc: 0.7221 - true_positives: 355.6364 - true_negatives: 256.4242 - false_positives: 454.8485 - false_negatives: 0.0000e+00 - val_loss: 4.4203 - val_accuracy: 0.7136 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7335 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00063: val_precision did not improve from 0.44898
# Epoch 64/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.4246 - accuracy: 0.7128 - precision: 0.4429 - recall: 1.0000 - auc: 0.7272 - true_positives: 355.6364 - true_negatives: 266.8788 - false_positives: 444.3939 - false_negatives: 0.0000e+00 - val_loss: 4.4194 - val_accuracy: 0.7182 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7336 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00064: val_precision did not improve from 0.44898
# Epoch 65/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.0551 - accuracy: 0.7045 - precision: 0.4405 - recall: 1.0000 - auc: 0.7194 - true_positives: 355.6364 - true_negatives: 261.0909 - false_positives: 450.1818 - false_negatives: 0.0000e+00 - val_loss: 4.4174 - val_accuracy: 0.7227 - val_precision: 0.4490 - val_recall: 1.0000 - val_auc: 0.7329 - val_true_positives: 220.0000 - val_true_negatives: 170.0000 - val_false_positives: 270.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00065: val_precision did not improve from 0.44898
# Epoch 66/150
# 32/32 [==============================] - 54s 2s/step - loss: 1.6407 - accuracy: 0.7339 - precision: 0.4464 - recall: 1.0000 - auc: 0.7359 - true_positives: 355.6364 - true_negatives: 262.5455 - false_positives: 448.7273 - false_negatives: 0.0000e+00 - val_loss: 4.3840 - val_accuracy: 0.7227 - val_precision: 0.4499 - val_recall: 1.0000 - val_auc: 0.7363 - val_true_positives: 220.0000 - val_true_negatives: 171.0000 - val_false_positives: 269.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00066: val_precision improved from 0.44898 to 0.44990, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 67/150
# 32/32 [==============================] - 54s 2s/step - loss: 1.8083 - accuracy: 0.7272 - precision: 0.4521 - recall: 1.0000 - auc: 0.7468 - true_positives: 355.6364 - true_negatives: 271.4848 - false_positives: 439.7879 - false_negatives: 0.0000e+00 - val_loss: 4.3510 - val_accuracy: 0.7227 - val_precision: 0.4499 - val_recall: 1.0000 - val_auc: 0.7365 - val_true_positives: 220.0000 - val_true_negatives: 171.0000 - val_false_positives: 269.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00067: val_precision did not improve from 0.44990
# Epoch 68/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.2046 - accuracy: 0.7026 - precision: 0.4399 - recall: 1.0000 - auc: 0.7281 - true_positives: 355.6364 - true_negatives: 265.9091 - false_positives: 445.3636 - false_negatives: 0.0000e+00 - val_loss: 4.3547 - val_accuracy: 0.7227 - val_precision: 0.4499 - val_recall: 1.0000 - val_auc: 0.7355 - val_true_positives: 220.0000 - val_true_negatives: 171.0000 - val_false_positives: 269.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00068: val_precision did not improve from 0.44990
# Epoch 69/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.0378 - accuracy: 0.7121 - precision: 0.4444 - recall: 1.0000 - auc: 0.7284 - true_positives: 355.6364 - true_negatives: 267.0606 - false_positives: 444.2121 - false_negatives: 0.0000e+00 - val_loss: 4.3327 - val_accuracy: 0.7227 - val_precision: 0.4517 - val_recall: 1.0000 - val_auc: 0.7379 - val_true_positives: 220.0000 - val_true_negatives: 173.0000 - val_false_positives: 267.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00069: val_precision improved from 0.44990 to 0.45175, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 70/150
# 32/32 [==============================] - 54s 2s/step - loss: 2.2008 - accuracy: 0.7197 - precision: 0.4425 - recall: 1.0000 - auc: 0.7293 - true_positives: 355.6364 - true_negatives: 265.6364 - false_positives: 445.6364 - false_negatives: 0.0000e+00 - val_loss: 4.3470 - val_accuracy: 0.7227 - val_precision: 0.4517 - val_recall: 1.0000 - val_auc: 0.7390 - val_true_positives: 220.0000 - val_true_negatives: 173.0000 - val_false_positives: 267.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00070: val_precision did not improve from 0.45175
# Epoch 71/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.8710 - accuracy: 0.7049 - precision: 0.4427 - recall: 1.0000 - auc: 0.7217 - true_positives: 355.6364 - true_negatives: 262.9697 - false_positives: 448.3030 - false_negatives: 0.0000e+00 - val_loss: 4.2153 - val_accuracy: 0.7227 - val_precision: 0.4517 - val_recall: 1.0000 - val_auc: 0.7391 - val_true_positives: 220.0000 - val_true_negatives: 173.0000 - val_false_positives: 267.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00071: val_precision did not improve from 0.45175
# Epoch 72/150
# 32/32 [==============================] - 54s 2s/step - loss: 1.6748 - accuracy: 0.7516 - precision: 0.4464 - recall: 1.0000 - auc: 0.7406 - true_positives: 355.6364 - true_negatives: 272.3939 - false_positives: 438.8788 - false_negatives: 0.0000e+00 - val_loss: 4.3854 - val_accuracy: 0.7227 - val_precision: 0.4527 - val_recall: 1.0000 - val_auc: 0.7384 - val_true_positives: 220.0000 - val_true_negatives: 174.0000 - val_false_positives: 266.0000 - val_false_negatives: 0.0000e+00
#
# ...
#
# Epoch 00122: val_precision did not improve from 0.45738
# Epoch 123/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.4256 - accuracy: 0.7796 - precision: 0.4533 - recall: 1.0000 - auc: 0.7570 - true_positives: 355.6364 - true_negatives: 280.5152 - false_positives: 430.7576 - false_negatives: 0.0000e+00 - val_loss: 3.5472 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7508 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00123: val_precision did not improve from 0.45738
# Epoch 124/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.9759 - accuracy: 0.7602 - precision: 0.4456 - recall: 1.0000 - auc: 0.7390 - true_positives: 355.6364 - true_negatives: 275.1212 - false_positives: 436.1515 - false_negatives: 0.0000e+00 - val_loss: 3.5731 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7509 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00124: val_precision did not improve from 0.45738
# Epoch 125/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.1994 - accuracy: 0.7623 - precision: 0.4537 - recall: 1.0000 - auc: 0.7610 - true_positives: 355.6364 - true_negatives: 277.1818 - false_positives: 434.0909 - false_negatives: 0.0000e+00 - val_loss: 3.4386 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7498 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00125: val_precision did not improve from 0.45738
# Epoch 126/150
# 32/32 [==============================] - 56s 2s/step - loss: 1.3826 - accuracy: 0.7627 - precision: 0.4540 - recall: 1.0000 - auc: 0.7490 - true_positives: 355.6364 - true_negatives: 280.3939 - false_positives: 430.8788 - false_negatives: 0.0000e+00 - val_loss: 3.5296 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7521 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00126: val_precision did not improve from 0.45738
# Epoch 127/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.4071 - accuracy: 0.7432 - precision: 0.4503 - recall: 1.0000 - auc: 0.7534 - true_positives: 355.6364 - true_negatives: 278.1212 - false_positives: 433.1515 - false_negatives: 0.0000e+00 - val_loss: 3.5082 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7520 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00127: val_precision did not improve from 0.45738
# Epoch 128/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.5225 - accuracy: 0.7413 - precision: 0.4509 - recall: 1.0000 - auc: 0.7601 - true_positives: 355.6364 - true_negatives: 278.1212 - false_positives: 433.1515 - false_negatives: 0.0000e+00 - val_loss: 3.4773 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7532 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00128: val_precision did not improve from 0.45738
# Epoch 129/150
# 32/32 [==============================] - 56s 2s/step - loss: 1.2543 - accuracy: 0.7745 - precision: 0.4609 - recall: 1.0000 - auc: 0.7586 - true_positives: 355.6364 - true_negatives: 283.0303 - false_positives: 428.2424 - false_negatives: 0.0000e+00 - val_loss: 3.5528 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7531 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00129: val_precision did not improve from 0.45738
# Epoch 130/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.0689 - accuracy: 0.7625 - precision: 0.4530 - recall: 1.0000 - auc: 0.7570 - true_positives: 355.6364 - true_negatives: 282.4545 - false_positives: 428.8182 - false_negatives: 0.0000e+00 - val_loss: 3.4596 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7542 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00130: val_precision did not improve from 0.45738
# Epoch 131/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.2024 - accuracy: 0.7661 - precision: 0.4479 - recall: 1.0000 - auc: 0.7543 - true_positives: 355.6364 - true_negatives: 274.4848 - false_positives: 436.7879 - false_negatives: 0.0000e+00 - val_loss: 3.4011 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7530 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
# Epoch 00131: val_precision did not improve from 0.45738
# Epoch 132/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.0777 - accuracy: 0.7268 - precision: 0.4464 - recall: 1.0000 - auc: 0.7455 - true_positives: 355.6364 - true_negatives: 277.2424 - false_positives: 434.0303 - false_negatives: 0.0000e+00 - val_loss: 3.4603 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7542 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00132: val_precision did not improve from 0.45738
# Epoch 133/150
# 32/32 [==============================] - 54s 2s/step - loss: 1.0820 - accuracy: 0.7444 - precision: 0.4490 - recall: 1.0000 - auc: 0.7447 - true_positives: 355.6364 - true_negatives: 277.2424 - false_positives: 434.0303 - false_negatives: 0.0000e+00 - val_loss: 3.4553 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7553 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00133: val_precision did not improve from 0.45738
# Epoch 134/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3784 - accuracy: 0.7465 - precision: 0.4539 - recall: 1.0000 - auc: 0.7449 - true_positives: 355.6364 - true_negatives: 281.5152 - false_positives: 429.7576 - false_negatives: 0.0000e+00 - val_loss: 3.4155 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7552 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00134: val_precision did not improve from 0.45738
# Epoch 135/150
# 32/32 [==============================] - 56s 2s/step - loss: 1.3207 - accuracy: 0.7634 - precision: 0.4466 - recall: 1.0000 - auc: 0.7476 - true_positives: 355.6364 - true_negatives: 271.0909 - false_positives: 440.1818 - false_negatives: 0.0000e+00 - val_loss: 3.4562 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7555 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00135: val_precision did not improve from 0.45738
# Epoch 136/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.2076 - accuracy: 0.7697 - precision: 0.4639 - recall: 1.0000 - auc: 0.7660 - true_positives: 355.6364 - true_negatives: 291.1212 - false_positives: 420.1515 - false_negatives: 0.0000e+00 - val_loss: 3.4357 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7541 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00136: val_precision improved from 0.45738 to 0.45833, saving model to ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/best_checkpoint/assets
# Epoch 137/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3399 - accuracy: 0.7612 - precision: 0.4486 - recall: 1.0000 - auc: 0.7515 - true_positives: 355.6364 - true_negatives: 270.9091 - false_positives: 440.3636 - false_negatives: 0.0000e+00 - val_loss: 3.4078 - val_accuracy: 0.7455 - val_precision: 0.4574 - val_recall: 1.0000 - val_auc: 0.7554 - val_true_positives: 220.0000 - val_true_negatives: 179.0000 - val_false_positives: 261.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00137: val_precision did not improve from 0.45833
# Epoch 138/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3128 - accuracy: 0.7482 - precision: 0.4520 - recall: 1.0000 - auc: 0.7487 - true_positives: 355.6364 - true_negatives: 278.1818 - false_positives: 433.0909 - false_negatives: 0.0000e+00 - val_loss: 3.4166 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7554 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00138: val_precision did not improve from 0.45833
# Epoch 139/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.5162 - accuracy: 0.7380 - precision: 0.4422 - recall: 1.0000 - auc: 0.7331 - true_positives: 355.6364 - true_negatives: 274.8182 - false_positives: 436.4545 - false_negatives: 0.0000e+00 - val_loss: 3.3959 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7532 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00139: val_precision did not improve from 0.45833
# Epoch 140/150
# 32/32 [==============================] - 56s 2s/step - loss: 1.4896 - accuracy: 0.7470 - precision: 0.4477 - recall: 1.0000 - auc: 0.7573 - true_positives: 355.6364 - true_negatives: 273.6667 - false_positives: 437.6061 - false_negatives: 0.0000e+00 - val_loss: 3.4051 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7533 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00140: val_precision did not improve from 0.45833
# Epoch 141/150
# 32/32 [==============================] - 56s 2s/step - loss: 1.5505 - accuracy: 0.7378 - precision: 0.4471 - recall: 1.0000 - auc: 0.7479 - true_positives: 355.6364 - true_negatives: 274.6061 - false_positives: 436.6667 - false_negatives: 0.0000e+00 - val_loss: 3.4117 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7556 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00141: val_precision did not improve from 0.45833
# Epoch 142/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3460 - accuracy: 0.7464 - precision: 0.4538 - recall: 1.0000 - auc: 0.7423 - true_positives: 355.6364 - true_negatives: 282.0606 - false_positives: 429.2121 - false_negatives: 0.0000e+00 - val_loss: 3.3800 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7556 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00142: val_precision did not improve from 0.45833
# Epoch 143/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.0737 - accuracy: 0.7454 - precision: 0.4550 - recall: 1.0000 - auc: 0.7558 - true_positives: 355.6364 - true_negatives: 282.3030 - false_positives: 428.9697 - false_negatives: 0.0000e+00 - val_loss: 3.3544 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7556 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00143: val_precision did not improve from 0.45833
# Epoch 144/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.1423 - accuracy: 0.7568 - precision: 0.4522 - recall: 1.0000 - auc: 0.7458 - true_positives: 355.6364 - true_negatives: 280.5758 - false_positives: 430.6970 - false_negatives: 0.0000e+00 - val_loss: 3.3790 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7535 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00144: val_precision did not improve from 0.45833
# Epoch 145/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3634 - accuracy: 0.7537 - precision: 0.4621 - recall: 1.0000 - auc: 0.7622 - true_positives: 355.6364 - true_negatives: 288.5455 - false_positives: 422.7273 - false_negatives: 0.0000e+00 - val_loss: 3.3713 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7534 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00145: val_precision did not improve from 0.45833
# Epoch 146/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.9576 - accuracy: 0.7703 - precision: 0.4537 - recall: 1.0000 - auc: 0.7552 - true_positives: 355.6364 - true_negatives: 280.3939 - false_positives: 430.8788 - false_negatives: 0.0000e+00 - val_loss: 3.3512 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7534 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00146: val_precision did not improve from 0.45833
# Epoch 147/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.1914 - accuracy: 0.7808 - precision: 0.4594 - recall: 1.0000 - auc: 0.7636 - true_positives: 355.6364 - true_negatives: 287.3030 - false_positives: 423.9697 - false_negatives: 0.0000e+00 - val_loss: 3.3659 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7536 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00147: val_precision did not improve from 0.45833
# Epoch 148/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.9807 - accuracy: 0.7491 - precision: 0.4523 - recall: 1.0000 - auc: 0.7440 - true_positives: 355.6364 - true_negatives: 281.9697 - false_positives: 429.3030 - false_negatives: 0.0000e+00 - val_loss: 3.3502 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7525 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00148: val_precision did not improve from 0.45833
# Epoch 149/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.0710 - accuracy: 0.7314 - precision: 0.4504 - recall: 1.0000 - auc: 0.7451 - true_positives: 355.6364 - true_negatives: 283.0303 - false_positives: 428.2424 - false_negatives: 0.0000e+00 - val_loss: 3.3883 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7526 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00149: val_precision did not improve from 0.45833
# Epoch 150/150
# 32/32 [==============================] - 55s 2s/step - loss: 1.3564 - accuracy: 0.7481 - precision: 0.4519 - recall: 1.0000 - auc: 0.7532 - true_positives: 355.6364 - true_negatives: 277.4848 - false_positives: 433.7879 - false_negatives: 0.0000e+00 - val_loss: 3.3162 - val_accuracy: 0.7455 - val_precision: 0.4583 - val_recall: 1.0000 - val_auc: 0.7536 - val_true_positives: 220.0000 - val_true_negatives: 180.0000 - val_false_positives: 260.0000 - val_false_negatives: 0.0000e+00
#
# Epoch 00150: val_precision did not improve from 0.45833

# %% [markdown]
# ##### Loading the best model for testing

# %%
model = keras.models.load_model(CHECKPOINT_DIR)

# %% [markdown]
# ##### Testing the model

# %%
model.evaluate(test_images, test_labels, batch_size=1)
# Out:
# 221/221 [==============================] - 17s 73ms/step - loss: 1.2264 - accuracy: 0.7330 - precision: 0.4490 - recall: 0.9955 - auc: 0.7442 - true_positives: 220.0000 - true_negatives: 172.0000 - false_positives: 270.0000 - false_negatives: 1.0000
# [1.2264466285705566,
#  0.733031690120697,
#  0.44897958636283875,
#  0.9954751133918762,
#  0.7441596984863281,
#  220.0,
#  172.0,
#  270.0,
#  1.0]

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics) + 1

SAVE = False

def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")

# %%
if SAVE and not os.path.exists(MODELDIR):
    os.mkdir(MODELDIR)
model.save(MODELDIR)
# Out:
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/pre_trained_weighted/model/assets
