# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 3 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1101

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 3 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "3_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "3_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classification model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU
# ##### Characteristics
#  - Sequencial Model
#  - Fully trained on this dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading and preparing the dataset

# %%
import imutils
def pad_image(image, size_x, size_y):
    shape = image.shape
    res = []
    
    pad_image = np.zeros((size_x,size_y,3), np.uint8)
    
    if shape[0] > shape[1]:
        res = imutils.resize(image, height=size_x)
        res = center_image(res, pad_image)
    else:
        res = imutils.resize(image, width=size_y)
        res = center_image(res, pad_image)
    
    return res
    
def center_image(image, background):
    img_shape = image.shape
    bck_shape = background.shape
    
    x_diff = round((bck_shape[0] - img_shape[0])/2)
    y_diff = round((bck_shape[1] - img_shape[1])/2)
    
#     print(image.shape, background.shape, x_diff, y_diff)
    
    res = background.copy()
    
    res[x_diff:x_diff + img_shape[0],y_diff:y_diff + img_shape[1]] = image
    
    return res

# %%
images_raw = open(os.path.join(DATASET_PATH, "3_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "3_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 256

# %% [markdown]
# ##### Padding Images in Memory

# %%
for i in range(len(images)):
    images[i] = pad_image(images[i], IMG_SIZE, IMG_SIZE)
    plt.imshow(images[i])

# %% [markdown]
# ##### Labels one hot enconding

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2)

# %%
print(test_images.shape)
# Out:
# (221, 256, 256, 3)

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
## Trying class weights
#it does not work withone hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

# from sklearn.utils import compute_sample_weight
# sample_weights = compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
classes, counts = np.unique(train_labels, return_counts=True)
print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")
# Out:
# The number of elements for each class in training now are
# Class 0: 673
# Class 1 178
# Class 2 29

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)

train_images_shape = train_images.shape
train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
train_images_shape = train_images.shape
train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
classes, counts = np.unique(train_labels, return_counts=True)
print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")
# Out:
# The number of elements for each class in training now are
# Class 0: 673
# Class 1 673
# Class 2 673

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd

train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = 15
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

# %%
model = Sequential()

model.add(   Conv2D(2, (3,3), input_shape=train_images.shape[1:])  )
model.add(Activation("relu"))
model.add(Dropout(0.2, input_shape=images.shape[1:]))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(2, (2,2)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(8))

model.add(Dense(3))
model.add(Activation("sigmoid"))


my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

opt = keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)

# %%
from keras.callbacks import ModelCheckpoint
METRICDIR = './metricas/classificacao/3_d/smote/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")
checkpoint = ModelCheckpoint(CHECKPOINT_DIR, monitor="val_precision", verbose=1,
    save_best_only=True, mode='max', save_freq='epoch')

# %%
history = model.fit(train_images, train_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT, callbacks=[checkpoint])
# Out:
# Epoch 1/15
# 48/48 [==============================] - 11s 197ms/step - loss: 7.5793 - accuracy: 0.4128 - precision: 0.3839 - recall: 0.3755 - auc: 0.5474 - true_positives: 305.5306 - true_negatives: 1089.6531 - false_positives: 507.2449 - false_negatives: 492.9184 - val_loss: 11.9718 - val_accuracy: 0.2198 - val_precision: 0.3432 - val_recall: 0.3663 - val_auc: 0.5216 - val_true_positives: 185.0000 - val_true_negatives: 656.0000 - val_false_positives: 354.0000 - val_false_negatives: 320.0000
#
# Epoch 00001: val_precision improved from -inf to 0.34323, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 2/15
# 48/48 [==============================] - 8s 176ms/step - loss: 4.5152 - accuracy: 0.4259 - precision: 0.3658 - recall: 0.4397 - auc: 0.5612 - true_positives: 348.2245 - true_negatives: 976.0612 - false_positives: 620.8367 - false_negatives: 450.2245 - val_loss: 11.0107 - val_accuracy: 0.2396 - val_precision: 0.3800 - val_recall: 0.4733 - val_auc: 0.5622 - val_true_positives: 239.0000 - val_true_negatives: 620.0000 - val_false_positives: 390.0000 - val_false_negatives: 266.0000
#
# Epoch 00002: val_precision improved from 0.34323 to 0.37997, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 3/15
# 48/48 [==============================] - 8s 167ms/step - loss: 3.8466 - accuracy: 0.4101 - precision: 0.3385 - recall: 0.4590 - auc: 0.5634 - true_positives: 369.4286 - true_negatives: 878.1224 - false_positives: 718.7755 - false_negatives: 429.0204 - val_loss: 11.0197 - val_accuracy: 0.2297 - val_precision: 0.3955 - val_recall: 0.5208 - val_auc: 0.5738 - val_true_positives: 263.0000 - val_true_negatives: 608.0000 - val_false_positives: 402.0000 - val_false_negatives: 242.0000
#
# Epoch 00003: val_precision improved from 0.37997 to 0.39549, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 4/15
# 48/48 [==============================] - 8s 169ms/step - loss: 3.4170 - accuracy: 0.4259 - precision: 0.3529 - recall: 0.4831 - auc: 0.5738 - true_positives: 388.9184 - true_negatives: 902.1429 - false_positives: 694.7551 - false_negatives: 409.5306 - val_loss: 10.6285 - val_accuracy: 0.2277 - val_precision: 0.3997 - val_recall: 0.5327 - val_auc: 0.5841 - val_true_positives: 269.0000 - val_true_negatives: 606.0000 - val_false_positives: 404.0000 - val_false_negatives: 236.0000
#
# Epoch 00004: val_precision improved from 0.39549 to 0.39970, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 5/15
# 48/48 [==============================] - 8s 164ms/step - loss: 3.8534 - accuracy: 0.4367 - precision: 0.3685 - recall: 0.5108 - auc: 0.5861 - true_positives: 415.7755 - true_negatives: 895.6327 - false_positives: 701.2653 - false_negatives: 382.6735 - val_loss: 10.4519 - val_accuracy: 0.2317 - val_precision: 0.3986 - val_recall: 0.5446 - val_auc: 0.5897 - val_true_positives: 275.0000 - val_true_negatives: 595.0000 - val_false_positives: 415.0000 - val_false_negatives: 230.0000
#
# Epoch 00005: val_precision did not improve from 0.39970
# Epoch 6/15
# 48/48 [==============================] - 8s 168ms/step - loss: 3.5140 - accuracy: 0.4601 - precision: 0.3621 - recall: 0.5128 - auc: 0.5872 - true_positives: 412.7755 - true_negatives: 885.9796 - false_positives: 710.9184 - false_negatives: 385.6735 - val_loss: 9.9777 - val_accuracy: 0.2574 - val_precision: 0.4000 - val_recall: 0.5426 - val_auc: 0.5948 - val_true_positives: 274.0000 - val_true_negatives: 599.0000 - val_false_positives: 411.0000 - val_false_negatives: 231.0000
#
# Epoch 00006: val_precision improved from 0.39970 to 0.40000, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 7/15
# 48/48 [==============================] - 8s 164ms/step - loss: 3.1328 - accuracy: 0.4701 - precision: 0.3684 - recall: 0.5051 - auc: 0.5929 - true_positives: 404.4694 - true_negatives: 917.9388 - false_positives: 678.9592 - false_negatives: 393.9796 - val_loss: 9.4530 - val_accuracy: 0.2812 - val_precision: 0.4101 - val_recall: 0.5604 - val_auc: 0.6022 - val_true_positives: 283.0000 - val_true_negatives: 603.0000 - val_false_positives: 407.0000 - val_false_negatives: 222.0000
#
# Epoch 00007: val_precision improved from 0.40000 to 0.41014, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 8/15
# 48/48 [==============================] - 8s 171ms/step - loss: 2.8683 - accuracy: 0.4655 - precision: 0.4013 - recall: 0.5420 - auc: 0.6193 - true_positives: 433.0816 - true_negatives: 940.3265 - false_positives: 656.5714 - false_negatives: 365.3673 - val_loss: 9.1102 - val_accuracy: 0.2950 - val_precision: 0.4158 - val_recall: 0.5723 - val_auc: 0.6085 - val_true_positives: 289.0000 - val_true_negatives: 604.0000 - val_false_positives: 406.0000 - val_false_negatives: 216.0000
#
# Epoch 00008: val_precision improved from 0.41014 to 0.41583, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 9/15
# 48/48 [==============================] - 8s 176ms/step - loss: 2.7920 - accuracy: 0.4882 - precision: 0.4060 - recall: 0.5598 - auc: 0.6213 - true_positives: 446.3469 - true_negatives: 933.8980 - false_positives: 663.0000 - false_negatives: 352.1020 - val_loss: 8.9998 - val_accuracy: 0.2990 - val_precision: 0.4206 - val_recall: 0.5822 - val_auc: 0.6145 - val_true_positives: 294.0000 - val_true_negatives: 605.0000 - val_false_positives: 405.0000 - val_false_negatives: 211.0000
#
# Epoch 00009: val_precision improved from 0.41583 to 0.42060, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 10/15
# 48/48 [==============================] - 9s 184ms/step - loss: 3.2213 - accuracy: 0.5027 - precision: 0.3948 - recall: 0.5652 - auc: 0.6228 - true_positives: 450.7347 - true_negatives: 913.7959 - false_positives: 683.1020 - false_negatives: 347.7143 - val_loss: 8.9887 - val_accuracy: 0.2990 - val_precision: 0.4238 - val_recall: 0.5782 - val_auc: 0.6106 - val_true_positives: 292.0000 - val_true_negatives: 613.0000 - val_false_positives: 397.0000 - val_false_negatives: 213.0000
#
# Epoch 00010: val_precision improved from 0.42060 to 0.42380, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 11/15
# 48/48 [==============================] - 8s 176ms/step - loss: 2.4074 - accuracy: 0.5330 - precision: 0.4148 - recall: 0.5747 - auc: 0.6390 - true_positives: 450.3673 - true_negatives: 949.8367 - false_positives: 647.0612 - false_negatives: 348.0816 - val_loss: 9.0494 - val_accuracy: 0.2970 - val_precision: 0.4225 - val_recall: 0.5723 - val_auc: 0.6082 - val_true_positives: 289.0000 - val_true_negatives: 615.0000 - val_false_positives: 395.0000 - val_false_negatives: 216.0000
#
# Epoch 00011: val_precision did not improve from 0.42380
# Epoch 12/15
# 48/48 [==============================] - 9s 181ms/step - loss: 2.6321 - accuracy: 0.5112 - precision: 0.4176 - recall: 0.5710 - auc: 0.6425 - true_positives: 456.5102 - true_negatives: 961.6327 - false_positives: 635.2653 - false_negatives: 341.9388 - val_loss: 8.6342 - val_accuracy: 0.3089 - val_precision: 0.4204 - val_recall: 0.5644 - val_auc: 0.6093 - val_true_positives: 285.0000 - val_true_negatives: 617.0000 - val_false_positives: 393.0000 - val_false_negatives: 220.0000
#
# Epoch 00012: val_precision did not improve from 0.42380
# Epoch 13/15
# 48/48 [==============================] - 8s 175ms/step - loss: 2.1997 - accuracy: 0.5197 - precision: 0.4177 - recall: 0.5647 - auc: 0.6439 - true_positives: 452.6735 - true_negatives: 966.7755 - false_positives: 630.1224 - false_negatives: 345.7755 - val_loss: 8.4691 - val_accuracy: 0.3168 - val_precision: 0.4220 - val_recall: 0.5624 - val_auc: 0.6100 - val_true_positives: 284.0000 - val_true_negatives: 621.0000 - val_false_positives: 389.0000 - val_false_negatives: 221.0000
#
# Epoch 00013: val_precision did not improve from 0.42380
# Epoch 14/15
# 48/48 [==============================] - 9s 189ms/step - loss: 2.3524 - accuracy: 0.5219 - precision: 0.4241 - recall: 0.5803 - auc: 0.6505 - true_positives: 462.6939 - true_negatives: 961.4694 - false_positives: 635.4286 - false_negatives: 335.7551 - val_loss: 8.2994 - val_accuracy: 0.3109 - val_precision: 0.4298 - val_recall: 0.5881 - val_auc: 0.6222 - val_true_positives: 297.0000 - val_true_negatives: 616.0000 - val_false_positives: 394.0000 - val_false_negatives: 208.0000
#
# Epoch 00014: val_precision improved from 0.42380 to 0.42981, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets
# Epoch 15/15
# 48/48 [==============================] - 8s 174ms/step - loss: 2.1993 - accuracy: 0.5485 - precision: 0.4284 - recall: 0.5733 - auc: 0.6527 - true_positives: 457.2245 - true_negatives: 974.1224 - false_positives: 622.7755 - false_negatives: 341.2245 - val_loss: 8.2388 - val_accuracy: 0.3149 - val_precision: 0.4329 - val_recall: 0.5881 - val_auc: 0.6194 - val_true_positives: 297.0000 - val_true_negatives: 621.0000 - val_false_positives: 389.0000 - val_false_negatives: 208.0000
#
# Epoch 00015: val_precision improved from 0.42981 to 0.43294, saving model to ./metricas/classificacao/3_d/smote/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/best_checkpoint/assets

# %% [markdown]
# ##### Loading the best model for testing

# %%
model = keras.models.load_model(CHECKPOINT_DIR)

# %% [markdown]
# ##### Testing the model

# %%
model.evaluate(test_images, test_labels, batch_size=1)
# Out:
# 221/221 [==============================] - 2s 6ms/step - loss: 1.4402 - accuracy: 0.4118 - precision: 0.3368 - recall: 0.4344 - auc: 0.4955 - true_positives: 96.0000 - true_negatives: 253.0000 - false_positives: 189.0000 - false_negatives: 125.0000
# [1.4401631355285645,
#  0.4117647111415863,
#  0.3368421196937561,
#  0.4343891441822052,
#  0.49554678797721863,
#  96.0,
#  253.0,
#  189.0,
#  125.0]

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics) + 1

SAVE = True

def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")

# %%
# Out:
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote/model/assets
