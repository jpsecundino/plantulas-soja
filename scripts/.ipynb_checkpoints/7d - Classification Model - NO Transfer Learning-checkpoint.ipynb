# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 7 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1185

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 7 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "7_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "7_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classification model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU
# ##### Characteristics
#  - Sequencial Model
#  - Fully trained on this dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading and preparing the dataset

# %%
import imutils
def pad_image(image, size_x, size_y):
    shape = image.shape
    res = []
    
    pad_image = np.zeros((size_x,size_y,3), np.uint8)
    
    if shape[0] > shape[1]:
        res = imutils.resize(image, height=size_x)
        res = center_image(res, pad_image)
    else:
        res = imutils.resize(image, width=size_y)
        res = center_image(res, pad_image)
    
    return res
    
def center_image(image, background):
    img_shape = image.shape
    bck_shape = background.shape
    
    x_diff = round((bck_shape[0] - img_shape[0])/2)
    y_diff = round((bck_shape[1] - img_shape[1])/2)
    
#     print(image.shape, background.shape, x_diff, y_diff)
    
    res = background.copy()
    
    res[x_diff:x_diff + img_shape[0],y_diff:y_diff + img_shape[1]] = image
    
    return res

# %%
images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 512

# %% [markdown]
# ##### Padding Images in Memory

# %%
for i in range(len(images)):
    images[i] = pad_image(images[i], IMG_SIZE, IMG_SIZE)
    plt.imshow(images[i])

# %% [markdown]
# ##### Labels one hot enconding

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2)

# %%
print(train_images.shape[0] + test_images.shape[0])
# Out:
# 1185

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
## Trying class weights
#it does not work withone hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

# from sklearn.utils import compute_sample_weight
# sample_weights = compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd

train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels_1d = test_labels

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = 15
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

# %%
model = Sequential()

model.add(   Conv2D(1, (3,3), input_shape=train_images.shape[1:])  )
model.add(Activation("relu"))
model.add(Dropout(0.2, input_shape=images.shape[1:]))
model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Conv2D(1, (2,2)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(16))

model.add(Dense(3))
model.add(Activation("sigmoid"))

import keras.backend as K

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)

# %%
from keras.callbacks import ModelCheckpoint
METRICDIR = './metricas/classificacao/7_d/no_tl_model_01/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")
checkpoint = ModelCheckpoint(CHECKPOINT_DIR, monitor="val_precision", verbose=1,
    save_best_only=True, mode='max', save_freq='epoch')

# %%
history = model.fit(train_images, train_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT, callbacks=[checkpoint])
# Out:
# Epoch 1/15
# 23/23 [==============================] - 16s 637ms/step - loss: 5.0172 - accuracy: 0.4948 - precision: 0.4581 - recall: 0.7311 - auc: 0.7034 - true_positives: 301.0833 - true_negatives: 454.6667 - false_positives: 338.5000 - false_negatives: 95.5000 - val_loss: 3.2956 - val_accuracy: 0.6540 - val_precision: 0.5523 - val_recall: 0.8017 - val_auc: 0.8020 - val_true_positives: 190.0000 - val_true_negatives: 320.0000 - val_false_positives: 154.0000 - val_false_negatives: 47.0000
#
# Epoch 00001: val_precision improved from -inf to 0.55233, saving model to ./metricas/classificacao/7_d/no_tl_model_01/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_01/model/best_checkpoint/assets
# Epoch 2/15
# 23/23 [==============================] - 14s 598ms/step - loss: 1.9667 - accuracy: 0.8391 - precision: 0.6724 - recall: 0.9025 - auc: 0.9066 - true_positives: 357.6667 - true_negatives: 608.3750 - false_positives: 184.7917 - false_negatives: 38.9167 - val_loss: 2.7547 - val_accuracy: 0.4768 - val_precision: 0.4788 - val_recall: 0.7637 - val_auc: 0.7205 - val_true_positives: 181.0000 - val_true_negatives: 277.0000 - val_false_positives: 197.0000 - val_false_negatives: 56.0000
#
# Epoch 00002: val_precision did not improve from 0.55233
# Epoch 3/15
# 23/23 [==============================] - 14s 607ms/step - loss: 0.3507 - accuracy: 0.9106 - precision: 0.6617 - recall: 0.9556 - auc: 0.9344 - true_positives: 380.6250 - true_negatives: 605.9167 - false_positives: 187.2500 - false_negatives: 15.9583 - val_loss: 2.7496 - val_accuracy: 0.4810 - val_precision: 0.4721 - val_recall: 0.7511 - val_auc: 0.7128 - val_true_positives: 178.0000 - val_true_negatives: 275.0000 - val_false_positives: 199.0000 - val_false_negatives: 59.0000
#
# Epoch 00003: val_precision did not improve from 0.55233
# Epoch 4/15
# 23/23 [==============================] - 14s 617ms/step - loss: 0.1266 - accuracy: 0.9457 - precision: 0.6465 - recall: 0.9740 - auc: 0.9245 - true_positives: 385.4583 - true_negatives: 587.1250 - false_positives: 206.0417 - false_negatives: 11.1250 - val_loss: 1.9841 - val_accuracy: 0.6245 - val_precision: 0.5200 - val_recall: 0.8228 - val_auc: 0.7880 - val_true_positives: 195.0000 - val_true_negatives: 294.0000 - val_false_positives: 180.0000 - val_false_negatives: 42.0000
#
# Epoch 00004: val_precision did not improve from 0.55233
# Epoch 5/15
# 23/23 [==============================] - 14s 612ms/step - loss: 0.0359 - accuracy: 0.9869 - precision: 0.6837 - recall: 0.9816 - auc: 0.9548 - true_positives: 388.7083 - true_negatives: 608.7500 - false_positives: 184.4167 - false_negatives: 7.8750 - val_loss: 2.3680 - val_accuracy: 0.5612 - val_precision: 0.5026 - val_recall: 0.8059 - val_auc: 0.7645 - val_true_positives: 191.0000 - val_true_negatives: 285.0000 - val_false_positives: 189.0000 - val_false_negatives: 46.0000
#
# Epoch 00005: val_precision did not improve from 0.55233
# Epoch 6/15
# 23/23 [==============================] - 14s 629ms/step - loss: 0.0276 - accuracy: 0.9866 - precision: 0.7331 - recall: 0.9843 - auc: 0.9613 - true_positives: 391.8333 - true_negatives: 650.0833 - false_positives: 143.0833 - false_negatives: 4.7500 - val_loss: 2.0879 - val_accuracy: 0.6329 - val_precision: 0.5273 - val_recall: 0.8143 - val_auc: 0.7959 - val_true_positives: 193.0000 - val_true_negatives: 301.0000 - val_false_positives: 173.0000 - val_false_negatives: 44.0000
#
# Epoch 00006: val_precision did not improve from 0.55233
# Epoch 7/15
# 23/23 [==============================] - 14s 606ms/step - loss: 0.0073 - accuracy: 0.9902 - precision: 0.7330 - recall: 0.9909 - auc: 0.9608 - true_positives: 393.2083 - true_negatives: 648.2083 - false_positives: 144.9583 - false_negatives: 3.3750 - val_loss: 2.0802 - val_accuracy: 0.6203 - val_precision: 0.5163 - val_recall: 0.8017 - val_auc: 0.7916 - val_true_positives: 190.0000 - val_true_negatives: 296.0000 - val_false_positives: 178.0000 - val_false_negatives: 47.0000
#
# Epoch 00007: val_precision did not improve from 0.55233
# Epoch 8/15
# 23/23 [==============================] - 14s 622ms/step - loss: 0.0046 - accuracy: 0.9927 - precision: 0.7248 - recall: 0.9961 - auc: 0.9690 - true_positives: 395.0417 - true_negatives: 641.3750 - false_positives: 151.7917 - false_negatives: 1.5417 - val_loss: 2.0556 - val_accuracy: 0.6414 - val_precision: 0.5205 - val_recall: 0.8017 - val_auc: 0.7981 - val_true_positives: 190.0000 - val_true_negatives: 299.0000 - val_false_positives: 175.0000 - val_false_negatives: 47.0000
#
# Epoch 00008: val_precision did not improve from 0.55233
# Epoch 9/15
# 23/23 [==============================] - 14s 610ms/step - loss: 0.0054 - accuracy: 0.9823 - precision: 0.7334 - recall: 0.9967 - auc: 0.9663 - true_positives: 395.1250 - true_negatives: 651.9583 - false_positives: 141.2083 - false_negatives: 1.4583 - val_loss: 2.0523 - val_accuracy: 0.6456 - val_precision: 0.5234 - val_recall: 0.8017 - val_auc: 0.8014 - val_true_positives: 190.0000 - val_true_negatives: 301.0000 - val_false_positives: 173.0000 - val_false_negatives: 47.0000
#
# Epoch 00009: val_precision did not improve from 0.55233
# Epoch 10/15
# 23/23 [==============================] - 14s 620ms/step - loss: 0.0032 - accuracy: 0.9899 - precision: 0.7414 - recall: 0.9981 - auc: 0.9708 - true_positives: 395.7083 - true_negatives: 653.0000 - false_positives: 140.1667 - false_negatives: 0.8750 - val_loss: 2.0502 - val_accuracy: 0.6498 - val_precision: 0.5260 - val_recall: 0.8101 - val_auc: 0.8029 - val_true_positives: 192.0000 - val_true_negatives: 301.0000 - val_false_positives: 173.0000 - val_false_negatives: 45.0000
#
# Epoch 00010: val_precision did not improve from 0.55233
# Epoch 11/15
# 23/23 [==============================] - 14s 627ms/step - loss: 0.0026 - accuracy: 0.9824 - precision: 0.7381 - recall: 0.9997 - auc: 0.9695 - true_positives: 396.3750 - true_negatives: 656.2500 - false_positives: 136.9167 - false_negatives: 0.2083 - val_loss: 2.0534 - val_accuracy: 0.6456 - val_precision: 0.5275 - val_recall: 0.8101 - val_auc: 0.8054 - val_true_positives: 192.0000 - val_true_negatives: 302.0000 - val_false_positives: 172.0000 - val_false_negatives: 45.0000
#
# Epoch 00011: val_precision did not improve from 0.55233
# Epoch 12/15
# 23/23 [==============================] - 14s 618ms/step - loss: 0.0026 - accuracy: 0.9923 - precision: 0.7393 - recall: 0.9989 - auc: 0.9699 - true_positives: 395.9583 - true_negatives: 655.6667 - false_positives: 137.5000 - false_negatives: 0.6250 - val_loss: 2.0621 - val_accuracy: 0.6456 - val_precision: 0.5302 - val_recall: 0.8143 - val_auc: 0.8077 - val_true_positives: 193.0000 - val_true_negatives: 303.0000 - val_false_positives: 171.0000 - val_false_negatives: 44.0000
#
# Epoch 00012: val_precision did not improve from 0.55233
# Epoch 13/15
# 23/23 [==============================] - 14s 612ms/step - loss: 0.0025 - accuracy: 0.9882 - precision: 0.7614 - recall: 1.0000 - auc: 0.9745 - true_positives: 396.5833 - true_negatives: 663.9583 - false_positives: 129.2083 - false_negatives: 0.0000e+00 - val_loss: 2.0682 - val_accuracy: 0.6498 - val_precision: 0.5317 - val_recall: 0.8143 - val_auc: 0.8094 - val_true_positives: 193.0000 - val_true_negatives: 304.0000 - val_false_positives: 170.0000 - val_false_negatives: 44.0000
#
# Epoch 00013: val_precision did not improve from 0.55233
# Epoch 14/15
# 23/23 [==============================] - 14s 629ms/step - loss: 0.0020 - accuracy: 0.9835 - precision: 0.7531 - recall: 0.9987 - auc: 0.9688 - true_positives: 395.8750 - true_negatives: 664.7500 - false_positives: 128.4167 - false_negatives: 0.7083 - val_loss: 2.0738 - val_accuracy: 0.6498 - val_precision: 0.5317 - val_recall: 0.8143 - val_auc: 0.8096 - val_true_positives: 193.0000 - val_true_negatives: 304.0000 - val_false_positives: 170.0000 - val_false_negatives: 44.0000
#
# Epoch 00014: val_precision did not improve from 0.55233
# Epoch 15/15
# 23/23 [==============================] - 14s 620ms/step - loss: 0.0017 - accuracy: 0.9893 - precision: 0.7361 - recall: 0.9975 - auc: 0.9727 - true_positives: 395.7083 - true_negatives: 656.7917 - false_positives: 136.3750 - false_negatives: 0.8750 - val_loss: 2.0785 - val_accuracy: 0.6498 - val_precision: 0.5331 - val_recall: 0.8143 - val_auc: 0.8094 - val_true_positives: 193.0000 - val_true_negatives: 305.0000 - val_false_positives: 169.0000 - val_false_negatives: 44.0000
# Epoch 00015: val_precision did not improve from 0.55233

# %% [markdown]
# ##### Loading the best model for testing

# %%
model = keras.models.load_model(CHECKPOINT_DIR)

# %% [markdown]
# ##### Testing the model

# %%
#  [1.00000000e+00 1.00000000e+00 3.52850632e-17]
#  [9.98317122e-01 9.50768232e-01 1.98488235e-02]
#  [9.78933811e-01 7.13823795e-01 4.61394548e-01]
#  [8.82515192e-01 8.64461303e-01 9.88584757e-03]
#  [9.99999821e-01 9.82567906e-01 6.38979147e-12]
#  [9.99495149e-01 7.27403164e-03 3.78920539e-09]
#  [9.99987125e-01 1.43360913e-01 8.52346420e-04]
#  [5.07389605e-01 9.89804626e-01 5.77924848e-02]
#  [9.92490053e-01 9.97991502e-01 1.17748685e-04]
#  [9.95684862e-01 2.18332916e-01 8.10401252e-06]
#  [9.99981403e-01 7.89346099e-01 1.00231767e-02]
#  [3.06383669e-02 9.97178137e-01 9.94957209e-01]
#  [9.83307242e-01 2.22457945e-02 5.03361225e-04]
#  [9.86522555e-01 8.68707895e-04 3.97793110e-06]
#  [9.99901533e-01 1.37925148e-03 1.82932745e-08]
#  [9.99767780e-01 4.00165617e-02 4.81477976e-02]
#  [1.00000000e+00 1.00000000e+00 9.08066598e-20]
#  [9.94636416e-01 1.25446022e-02 1.05606887e-05]
#  [9.72104430e-01 4.46905792e-02 1.05806939e-04]
#  [4.86310691e-01 4.67926264e-03 7.69597650e-01]
#  [9.24836040e-01 2.12161243e-01 5.15043736e-04]
#  [2.95360982e-02 9.48076904e-01 3.76019776e-02]
#  [9.99764442e-01 3.49073172e-01 2.25344300e-03]
#  [1.62657201e-02 9.99534130e-01 1.17521340e-05]
#  [9.99940872e-01 1.40857697e-03 5.19973946e-05]
#  [9.99737799e-01 9.99688029e-01 5.67416294e-07]
#  [9.99846399e-01 9.76652384e-01 1.03067769e-05]
#  [6.48042440e-01 6.97604418e-02 1.91179934e-05]
#  [9.99999702e-01 3.84542346e-03 1.79425292e-08]
#  [9.95787680e-01 9.59897876e-01 3.78013253e-02]
#  [8.58438194e-01 1.34513885e-01 1.35272741e-04]
#  [5.78653693e-01 6.29385829e-01 6.77433133e-01]
#  [9.95260179e-01 1.06066674e-01 5.61002053e-05]
#  [9.94815230e-01 9.80671644e-01 5.21644727e-09]
#  [9.90944982e-01 6.27168119e-02 1.96196437e-02]
#  [9.56777692e-01 3.40913594e-01 1.85534373e-05]
#  [9.99836564e-01 6.79719448e-03 1.65224075e-04]
#  [1.39339864e-02 9.61756468e-01 2.81903283e-08]
#  [8.71803939e-01 1.78846121e-02 2.74865746e-01]]

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics) + 1

SAVE = True

def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")
