# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 3 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1101

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 3 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "3_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "3_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classificatin model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading the dataset

# %%
images_raw = open(os.path.join(DATASET_PATH, "3_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "3_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 256

for i in range(0, len(images)):
    images[i] = cv2.resize(images[i], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_CUBIC)
    images[i] = np.array(images[i])
    labels[i] = np.array(labels[i])

images = np.array(images)
labels = np.array(labels)
labels_test = labels.reshape(-1,1)

##one hot 
import pandas as pd

labels = pd.get_dummies(labels)
labels = pd.DataFrame.to_numpy(labels)

#normalizing images    
images = tf.keras.utils.normalize(images, axis=0, order=2)

# %%
print(labels[0].shape)
# Out:
# (3,)

# %% [markdown]
# #### Creating the model

# %%
BATCH_SIZE = 32
EPOCHS = 15
TRAIN_TEST_SPLIT = 0.25

# %%
model = Sequential()

model.add(   Conv2D(64, (3,3), input_shape=images.shape[1:])   )
model.add(Activation("relu"))
model.add(Dropout(0.2, input_shape=images.shape[1:]))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))

model.add(Dense(3))
model.add(Activation("sigmoid"))

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=my_metrics)

# %%
history = model.fit(images, labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 63s 2s/step - loss: 0.5411 - accuracy: 0.7531 - precision_2: 0.5981 - recall_2: 0.8923 - auc_2: 0.8962 - true_positives: 411.1111 - true_negatives: 667.4815 - false_positives: 225.1111 - false_negatives: 35.1852 - val_loss: 0.3727 - val_accuracy: 0.7790 - val_precision_2: 0.7373 - val_recall_2: 0.8949 - val_auc_2: 0.9595 - val_true_positives: 247.0000 - val_true_negatives: 464.0000 - val_false_positives: 88.0000 - val_false_negatives: 29.0000
# Epoch 2/15
# 26/26 [==============================] - 60s 2s/step - loss: 0.2351 - accuracy: 0.9048 - precision_2: 0.7949 - recall_2: 0.9587 - auc_2: 0.9799 - true_positives: 427.7778 - true_negatives: 771.3704 - false_positives: 121.2222 - false_negatives: 18.5185 - val_loss: 0.2619 - val_accuracy: 0.8804 - val_precision_2: 0.6397 - val_recall_2: 0.9457 - val_auc_2: 0.9584 - val_true_positives: 261.0000 - val_true_negatives: 405.0000 - val_false_positives: 147.0000 - val_false_negatives: 15.0000
# Epoch 3/15
# 26/26 [==============================] - 60s 2s/step - loss: 0.2414 - accuracy: 0.8819 - precision_2: 0.6126 - recall_2: 0.9554 - auc_2: 0.9565 - true_positives: 428.4815 - true_negatives: 593.9630 - false_positives: 298.6296 - false_negatives: 17.8148 - val_loss: 0.2757 - val_accuracy: 0.8877 - val_precision_2: 0.5087 - val_recall_2: 0.9493 - val_auc_2: 0.9069 - val_true_positives: 262.0000 - val_true_negatives: 299.0000 - val_false_positives: 253.0000 - val_false_negatives: 14.0000
# Epoch 4/15
# 26/26 [==============================] - 63s 2s/step - loss: 0.1864 - accuracy: 0.9336 - precision_2: 0.5234 - recall_2: 0.9707 - auc_2: 0.9354 - true_positives: 435.6667 - true_negatives: 497.6667 - false_positives: 394.9259 - false_negatives: 10.6296 - val_loss: 0.2544 - val_accuracy: 0.8841 - val_precision_2: 0.5184 - val_recall_2: 0.9674 - val_auc_2: 0.8901 - val_true_positives: 267.0000 - val_true_negatives: 304.0000 - val_false_positives: 248.0000 - val_false_negatives: 9.0000
# Epoch 5/15
# 26/26 [==============================] - 65s 3s/step - loss: 0.1469 - accuracy: 0.9479 - precision_2: 0.5219 - recall_2: 0.9839 - auc_2: 0.9022 - true_positives: 439.5556 - true_negatives: 487.8148 - false_positives: 404.7778 - false_negatives: 6.7407 - val_loss: 0.2712 - val_accuracy: 0.8913 - val_precision_2: 0.5066 - val_recall_2: 0.9674 - val_auc_2: 0.8464 - val_true_positives: 267.0000 - val_true_negatives: 292.0000 - val_false_positives: 260.0000 - val_false_negatives: 9.0000
# Epoch 6/15
# 26/26 [==============================] - 67s 3s/step - loss: 0.1372 - accuracy: 0.9404 - precision_2: 0.5302 - recall_2: 0.9913 - auc_2: 0.8308 - true_positives: 442.5926 - true_negatives: 494.3333 - false_positives: 398.2593 - false_negatives: 3.7037 - val_loss: 0.2422 - val_accuracy: 0.9022 - val_precision_2: 0.5094 - val_recall_2: 0.9855 - val_auc_2: 0.8330 - val_true_positives: 272.0000 - val_true_negatives: 290.0000 - val_false_positives: 262.0000 - val_false_negatives: 4.0000
# Epoch 7/15
# 26/26 [==============================] - 68s 3s/step - loss: 0.1462 - accuracy: 0.9325 - precision_2: 0.5177 - recall_2: 0.9877 - auc_2: 0.8364 - true_positives: 440.8519 - true_negatives: 483.8889 - false_positives: 408.7037 - false_negatives: 5.4444 - val_loss: 0.2588 - val_accuracy: 0.8949 - val_precision_2: 0.5219 - val_recall_2: 0.9493 - val_auc_2: 0.9193 - val_true_positives: 262.0000 - val_true_negatives: 312.0000 - val_false_positives: 240.0000 - val_false_negatives: 14.0000
# Epoch 8/15
# 26/26 [==============================] - 68s 3s/step - loss: 0.1171 - accuracy: 0.9528 - precision_2: 0.5276 - recall_2: 0.9888 - auc_2: 0.8981 - true_positives: 441.6667 - true_negatives: 492.4444 - false_positives: 400.1481 - false_negatives: 4.6296 - val_loss: 0.2725 - val_accuracy: 0.8877 - val_precision_2: 0.5164 - val_recall_2: 0.9710 - val_auc_2: 0.7914 - val_true_positives: 268.0000 - val_true_negatives: 301.0000 - val_false_positives: 251.0000 - val_false_negatives: 8.0000
# Epoch 9/15
# 26/26 [==============================] - 69s 3s/step - loss: 0.0816 - accuracy: 0.9695 - precision_2: 0.5192 - recall_2: 0.9984 - auc_2: 0.7961 - true_positives: 445.4815 - true_negatives: 483.8889 - false_positives: 408.7037 - false_negatives: 0.8148 - val_loss: 0.3351 - val_accuracy: 0.8804 - val_precision_2: 0.5134 - val_recall_2: 0.9746 - val_auc_2: 0.7740 - val_true_positives: 269.0000 - val_true_negatives: 297.0000 - val_false_positives: 255.0000 - val_false_negatives: 7.0000
# Epoch 10/15
# 26/26 [==============================] - 69s 3s/step - loss: 0.0717 - accuracy: 0.9647 - precision_2: 0.5249 - recall_2: 1.0000 - auc_2: 0.8205 - true_positives: 446.2963 - true_negatives: 490.3704 - false_positives: 402.2222 - false_negatives: 0.0000e+00 - val_loss: 0.2668 - val_accuracy: 0.9022 - val_precision_2: 0.5047 - val_recall_2: 0.9783 - val_auc_2: 0.8460 - val_true_positives: 270.0000 - val_true_negatives: 287.0000 - val_false_positives: 265.0000 - val_false_negatives: 6.0000
# Epoch 11/15
# 26/26 [==============================] - 70s 3s/step - loss: 0.0675 - accuracy: 0.9718 - precision_2: 0.5233 - recall_2: 0.9972 - auc_2: 0.8216 - true_positives: 445.3704 - true_negatives: 490.0370 - false_positives: 402.5556 - false_negatives: 0.9259 - val_loss: 0.3033 - val_accuracy: 0.8986 - val_precision_2: 0.5104 - val_recall_2: 0.9819 - val_auc_2: 0.7871 - val_true_positives: 271.0000 - val_true_negatives: 292.0000 - val_false_positives: 260.0000 - val_false_negatives: 5.0000
# Epoch 12/15
# 26/26 [==============================] - 73s 3s/step - loss: 0.0298 - accuracy: 0.9913 - precision_2: 0.5233 - recall_2: 1.0000 - auc_2: 0.7985 - true_positives: 446.2963 - true_negatives: 488.5926 - false_positives: 404.0000 - false_negatives: 0.0000e+00 - val_loss: 0.3668 - val_accuracy: 0.9058 - val_precision_2: 0.5085 - val_recall_2: 0.9746 - val_auc_2: 0.7758 - val_true_positives: 269.0000 - val_true_negatives: 292.0000 - val_false_positives: 260.0000 - val_false_negatives: 7.0000
# Epoch 13/15
# 26/26 [==============================] - 70s 3s/step - loss: 0.0103 - accuracy: 0.9947 - precision_2: 0.5246 - recall_2: 1.0000 - auc_2: 0.8000 - true_positives: 446.2963 - true_negatives: 490.4074 - false_positives: 402.1852 - false_negatives: 0.0000e+00 - val_loss: 0.3963 - val_accuracy: 0.8949 - val_precision_2: 0.5144 - val_recall_2: 0.9710 - val_auc_2: 0.7792 - val_true_positives: 268.0000 - val_true_negatives: 299.0000 - val_false_positives: 253.0000 - val_false_negatives: 8.0000
# Epoch 14/15
# 26/26 [==============================] - 69s 3s/step - loss: 0.0088 - accuracy: 1.0000 - precision_2: 0.5220 - recall_2: 1.0000 - auc_2: 0.8008 - true_positives: 446.2963 - true_negatives: 487.1111 - false_positives: 405.4815 - false_negatives: 0.0000e+00 - val_loss: 0.4936 - val_accuracy: 0.8949 - val_precision_2: 0.5123 - val_recall_2: 0.9783 - val_auc_2: 0.7736 - val_true_positives: 270.0000 - val_true_negatives: 295.0000 - val_false_positives: 257.0000 - val_false_negatives: 6.0000
# Epoch 15/15
# 26/26 [==============================] - 68s 3s/step - loss: 0.0043 - accuracy: 1.0000 - precision_2: 0.5288 - recall_2: 1.0000 - auc_2: 0.8047 - true_positives: 446.2963 - true_negatives: 492.9259 - false_positives: 399.6667 - false_negatives: 0.0000e+00 - val_loss: 0.4267 - val_accuracy: 0.8986 - val_precision_2: 0.5094 - val_recall_2: 0.9783 - val_auc_2: 0.7747 - val_true_positives: 270.0000 - val_true_negatives: 292.0000 - val_false_positives: 260.0000 - val_false_negatives: 6.0000

# %%
model.evaluate(images, labels)
# Out:
# 35/35 [==============================] - 13s 381ms/step - loss: 0.1095 - accuracy: 0.9746 - precision_2: 0.5227 - recall_2: 0.9946 - auc_2: 0.7951 - true_positives: 1095.0000 - true_negatives: 1202.0000 - false_positives: 1000.0000 - false_negatives: 6.0000
# [0.10953854024410248,
#  0.9745685458183289,
#  0.5226730108261108,
#  0.9945504069328308,
#  0.7950736284255981,
#  1095.0,
#  1202.0,
#  1000.0,
#  6.0]

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics)
def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")
