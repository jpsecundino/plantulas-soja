# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 7 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1185

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 7 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "7_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "7_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classification model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU
# ##### Characteristics
#  - Sequencial Model
#  - Fully trained on this dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading and preparing the dataset

# %%
import imutils
def pad_image(image, size_x, size_y):
    shape = image.shape
    res = []
    
    pad_image = np.zeros((size_x,size_y,3), np.uint8)
    
    if shape[0] > shape[1]:
        res = imutils.resize(image, height=size_x)
        res = center_image(res, pad_image)
    else:
        res = imutils.resize(image, width=size_y)
        res = center_image(res, pad_image)
    
    return res
    
def center_image(image, background):
    img_shape = image.shape
    bck_shape = background.shape
    
    x_diff = round((bck_shape[0] - img_shape[0])/2)
    y_diff = round((bck_shape[1] - img_shape[1])/2)
    
#     print(image.shape, background.shape, x_diff, y_diff)
    
    res = background.copy()
    
    res[x_diff:x_diff + img_shape[0],y_diff:y_diff + img_shape[1]] = image
    
    return res

# %%
images_raw = open(os.path.join(DATASET_PATH, "7_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "7_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 512

# %% [markdown]
# ##### Padding Images in Memory

# %%
for i in range(len(images)):
    images[i] = pad_image(images[i], IMG_SIZE, IMG_SIZE)
    plt.imshow(images[i])

# %% [markdown]
# ##### Labels one hot enconding

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2)

# %%
print(train_images.shape[0] + test_images.shape[0])
# Out:
# 1185

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
## Trying class weights
#it does not work withone hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

# from sklearn.utils import compute_sample_weight
# sample_weights = compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=42)

# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
# train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
# train_images_shape = train_images.shape
# train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
# classes, counts = np.unique(train_labels, return_counts=True)
# print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd

train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels_1d = test_labels

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = 50
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

# %%
model = Sequential()

model.add(   Conv2D(2, (2,2), input_shape=train_images.shape[1:])  )
model.add(Activation("relu"))
model.add(Dropout(0.3, input_shape=images.shape[1:]))
model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Conv2D(1, (2,2)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(2))

model.add(Dense(3))
model.add(Activation("softmax"))

import keras.backend as K

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

opt = keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)

# %%
from keras.callbacks import ModelCheckpoint
METRICDIR = './metricas/classificacao/7_d/no_tl_model_02/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")
checkpoint = ModelCheckpoint(CHECKPOINT_DIR, monitor="val_precision", verbose=1,
    save_best_only=True, mode='max', save_freq='epoch')

# %%
history = model.fit(train_images, train_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 23/23 [==============================] - 15s 607ms/step - loss: 5.6413 - accuracy: 0.3360 - precision: 0.3320 - recall: 0.3275 - auc: 0.4830 - true_positives: 134.9167 - true_negatives: 537.7083 - false_positives: 255.4583 - false_negatives: 261.6667 - val_loss: 1.9115 - val_accuracy: 0.6076 - val_precision: 0.6104 - val_recall: 0.5949 - val_auc: 0.7804 - val_true_positives: 141.0000 - val_true_negatives: 384.0000 - val_false_positives: 90.0000 - val_false_negatives: 96.0000
#
# Epoch 00001: val_precision improved from -inf to 0.61039, saving model to ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint/assets
# Epoch 2/50
# 23/23 [==============================] - 13s 578ms/step - loss: 2.3370 - accuracy: 0.6608 - precision: 0.6619 - recall: 0.6608 - auc: 0.8065 - true_positives: 265.1250 - true_negatives: 662.4583 - false_positives: 130.7083 - false_negatives: 131.4583 - val_loss: 1.5883 - val_accuracy: 0.7426 - val_precision: 0.7415 - val_recall: 0.7384 - val_auc: 0.8449 - val_true_positives: 175.0000 - val_true_negatives: 413.0000 - val_false_positives: 61.0000 - val_false_negatives: 62.0000
#
# Epoch 00002: val_precision improved from 0.61039 to 0.74153, saving model to ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint/assets
# Epoch 3/50
# 23/23 [==============================] - 13s 582ms/step - loss: 1.8450 - accuracy: 0.7334 - precision: 0.7334 - recall: 0.7334 - auc: 0.8597 - true_positives: 290.9167 - true_negatives: 687.5000 - false_positives: 105.6667 - false_negatives: 105.6667 - val_loss: 1.4540 - val_accuracy: 0.7300 - val_precision: 0.7319 - val_recall: 0.7257 - val_auc: 0.8558 - val_true_positives: 172.0000 - val_true_negatives: 411.0000 - val_false_positives: 63.0000 - val_false_negatives: 65.0000
#
# Epoch 00003: val_precision did not improve from 0.74153
# Epoch 4/50
# 23/23 [==============================] - 13s 582ms/step - loss: 1.6216 - accuracy: 0.7451 - precision: 0.7455 - recall: 0.7392 - auc: 0.8659 - true_positives: 291.2917 - true_negatives: 690.5000 - false_positives: 102.6667 - false_negatives: 105.2917 - val_loss: 1.3929 - val_accuracy: 0.7300 - val_precision: 0.7319 - val_recall: 0.7257 - val_auc: 0.8588 - val_true_positives: 172.0000 - val_true_negatives: 411.0000 - val_false_positives: 63.0000 - val_false_negatives: 65.0000
#
# Epoch 00004: val_precision did not improve from 0.74153
# Epoch 5/50
# 23/23 [==============================] - 14s 603ms/step - loss: 1.1788 - accuracy: 0.7830 - precision: 0.7874 - recall: 0.7794 - auc: 0.8954 - true_positives: 305.8333 - true_negatives: 706.3750 - false_positives: 86.7917 - false_negatives: 90.7500 - val_loss: 1.3526 - val_accuracy: 0.7215 - val_precision: 0.7203 - val_recall: 0.7173 - val_auc: 0.8654 - val_true_positives: 170.0000 - val_true_negatives: 408.0000 - val_false_positives: 66.0000 - val_false_negatives: 67.0000
#
# Epoch 00005: val_precision did not improve from 0.74153
# Epoch 6/50
# 23/23 [==============================] - 13s 584ms/step - loss: 0.9594 - accuracy: 0.8002 - precision: 0.8023 - recall: 0.7977 - auc: 0.9151 - true_positives: 318.5833 - true_negatives: 717.5000 - false_positives: 75.6667 - false_negatives: 78.0000 - val_loss: 1.3547 - val_accuracy: 0.7089 - val_precision: 0.7094 - val_recall: 0.7004 - val_auc: 0.8629 - val_true_positives: 166.0000 - val_true_negatives: 406.0000 - val_false_positives: 68.0000 - val_false_negatives: 71.0000
#
# Epoch 00006: val_precision did not improve from 0.74153
# Epoch 7/50
# 23/23 [==============================] - 14s 591ms/step - loss: 0.8626 - accuracy: 0.8194 - precision: 0.8239 - recall: 0.8192 - auc: 0.9242 - true_positives: 326.5417 - true_negatives: 724.6250 - false_positives: 68.5417 - false_negatives: 70.0417 - val_loss: 1.2945 - val_accuracy: 0.7215 - val_precision: 0.7308 - val_recall: 0.7215 - val_auc: 0.8705 - val_true_positives: 171.0000 - val_true_negatives: 411.0000 - val_false_positives: 63.0000 - val_false_negatives: 66.0000
#
# Epoch 00007: val_precision did not improve from 0.74153
# Epoch 8/50
# 23/23 [==============================] - 14s 591ms/step - loss: 0.5976 - accuracy: 0.8653 - precision: 0.8666 - recall: 0.8591 - auc: 0.9477 - true_positives: 339.1667 - true_negatives: 739.5000 - false_positives: 53.6667 - false_negatives: 57.4167 - val_loss: 1.2830 - val_accuracy: 0.7173 - val_precision: 0.7203 - val_recall: 0.7173 - val_auc: 0.8722 - val_true_positives: 170.0000 - val_true_negatives: 408.0000 - val_false_positives: 66.0000 - val_false_negatives: 67.0000
#
# Epoch 00008: val_precision did not improve from 0.74153
# Epoch 9/50
# 23/23 [==============================] - 14s 603ms/step - loss: 0.4248 - accuracy: 0.8755 - precision: 0.8759 - recall: 0.8729 - auc: 0.9633 - true_positives: 348.2917 - true_negatives: 746.2083 - false_positives: 46.9583 - false_negatives: 48.2917 - val_loss: 1.2788 - val_accuracy: 0.7215 - val_precision: 0.7234 - val_recall: 0.7173 - val_auc: 0.8723 - val_true_positives: 170.0000 - val_true_negatives: 409.0000 - val_false_positives: 65.0000 - val_false_negatives: 67.0000
#
# Epoch 00009: val_precision did not improve from 0.74153
# Epoch 10/50
# 23/23 [==============================] - 13s 581ms/step - loss: 0.2213 - accuracy: 0.9225 - precision: 0.9224 - recall: 0.9217 - auc: 0.9852 - true_positives: 362.5417 - true_negatives: 759.5833 - false_positives: 33.5833 - false_negatives: 34.0417 - val_loss: 1.2724 - val_accuracy: 0.7257 - val_precision: 0.7246 - val_recall: 0.7215 - val_auc: 0.8741 - val_true_positives: 171.0000 - val_true_negatives: 409.0000 - val_false_positives: 65.0000 - val_false_negatives: 66.0000
#
# Epoch 00010: val_precision did not improve from 0.74153
# Epoch 11/50
# 23/23 [==============================] - 13s 587ms/step - loss: 0.2941 - accuracy: 0.8851 - precision: 0.8877 - recall: 0.8851 - auc: 0.9787 - true_positives: 351.9583 - true_negatives: 749.8333 - false_positives: 43.3333 - false_negatives: 44.6250 - val_loss: 1.2638 - val_accuracy: 0.7300 - val_precision: 0.7277 - val_recall: 0.7215 - val_auc: 0.8747 - val_true_positives: 171.0000 - val_true_negatives: 410.0000 - val_false_positives: 64.0000 - val_false_negatives: 66.0000
#
# Epoch 00011: val_precision did not improve from 0.74153
# Epoch 12/50
# 23/23 [==============================] - 14s 597ms/step - loss: 0.2429 - accuracy: 0.9236 - precision: 0.9283 - recall: 0.9167 - auc: 0.9813 - true_positives: 365.1667 - true_negatives: 765.0417 - false_positives: 28.1250 - false_negatives: 31.4167 - val_loss: 1.2484 - val_accuracy: 0.7342 - val_precision: 0.7350 - val_recall: 0.7257 - val_auc: 0.8772 - val_true_positives: 172.0000 - val_true_negatives: 412.0000 - val_false_positives: 62.0000 - val_false_negatives: 65.0000
#
# Epoch 00012: val_precision did not improve from 0.74153
# Epoch 13/50
# 23/23 [==============================] - 13s 585ms/step - loss: 0.1439 - accuracy: 0.9479 - precision: 0.9482 - recall: 0.9476 - auc: 0.9935 - true_positives: 374.7083 - true_negatives: 771.7500 - false_positives: 21.4167 - false_negatives: 21.8750 - val_loss: 1.2606 - val_accuracy: 0.7215 - val_precision: 0.7191 - val_recall: 0.7131 - val_auc: 0.8739 - val_true_positives: 169.0000 - val_true_negatives: 408.0000 - val_false_positives: 66.0000 - val_false_negatives: 68.0000
#
# Epoch 00013: val_precision did not improve from 0.74153
# Epoch 14/50
# 23/23 [==============================] - 13s 590ms/step - loss: 0.1119 - accuracy: 0.9655 - precision: 0.9666 - recall: 0.9553 - auc: 0.9953 - true_positives: 378.9583 - true_negatives: 778.5000 - false_positives: 14.6667 - false_negatives: 17.6250 - val_loss: 1.2417 - val_accuracy: 0.7300 - val_precision: 0.7308 - val_recall: 0.7215 - val_auc: 0.8783 - val_true_positives: 171.0000 - val_true_negatives: 411.0000 - val_false_positives: 63.0000 - val_false_negatives: 66.0000
#
# Epoch 00014: val_precision did not improve from 0.74153
# Epoch 15/50
# 23/23 [==============================] - 14s 591ms/step - loss: 0.1210 - accuracy: 0.9552 - precision: 0.9584 - recall: 0.9535 - auc: 0.9949 - true_positives: 379.7083 - true_negatives: 778.2500 - false_positives: 14.9167 - false_negatives: 16.8750 - val_loss: 1.2500 - val_accuracy: 0.7257 - val_precision: 0.7265 - val_recall: 0.7173 - val_auc: 0.8747 - val_true_positives: 170.0000 - val_true_negatives: 410.0000 - val_false_positives: 64.0000 - val_false_negatives: 67.0000
#
# Epoch 00015: val_precision did not improve from 0.74153
# Epoch 16/50
# 23/23 [==============================] - 13s 587ms/step - loss: 0.1099 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - auc: 0.9952 - true_positives: 384.5000 - true_negatives: 781.0833 - false_positives: 12.0833 - false_negatives: 12.0833 - val_loss: 1.2312 - val_accuracy: 0.7384 - val_precision: 0.7362 - val_recall: 0.7300 - val_auc: 0.8788 - val_true_positives: 173.0000 - val_true_negatives: 412.0000 - val_false_positives: 62.0000 - val_false_negatives: 64.0000
#
# Epoch 00016: val_precision did not improve from 0.74153
# Epoch 17/50
# 23/23 [==============================] - 13s 578ms/step - loss: 0.0773 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9978 - true_positives: 385.3750 - true_negatives: 781.9583 - false_positives: 11.2083 - false_negatives: 11.2083 - val_loss: 1.2343 - val_accuracy: 0.7384 - val_precision: 0.7362 - val_recall: 0.7300 - val_auc: 0.8762 - val_true_positives: 173.0000 - val_true_negatives: 412.0000 - val_false_positives: 62.0000 - val_false_negatives: 64.0000
#
# Epoch 00017: val_precision did not improve from 0.74153
# Epoch 18/50
# 23/23 [==============================] - 13s 590ms/step - loss: 0.0552 - accuracy: 0.9755 - precision: 0.9770 - recall: 0.9755 - auc: 0.9993 - true_positives: 387.2083 - true_negatives: 784.7083 - false_positives: 8.4583 - false_negatives: 9.3750 - val_loss: 1.2491 - val_accuracy: 0.7300 - val_precision: 0.7253 - val_recall: 0.7131 - val_auc: 0.8740 - val_true_positives: 169.0000 - val_true_negatives: 410.0000 - val_false_positives: 64.0000 - val_false_negatives: 68.0000
#
# Epoch 00018: val_precision did not improve from 0.74153
# Epoch 19/50
# 23/23 [==============================] - 14s 591ms/step - loss: 0.0675 - accuracy: 0.9696 - precision: 0.9696 - recall: 0.9696 - auc: 0.9988 - true_positives: 385.1667 - true_negatives: 781.7500 - false_positives: 11.4167 - false_negatives: 11.4167 - val_loss: 1.2346 - val_accuracy: 0.7384 - val_precision: 0.7350 - val_recall: 0.7257 - val_auc: 0.8777 - val_true_positives: 172.0000 - val_true_negatives: 412.0000 - val_false_positives: 62.0000 - val_false_negatives: 65.0000
#
# Epoch 00019: val_precision did not improve from 0.74153
# Epoch 20/50
# 23/23 [==============================] - 14s 595ms/step - loss: 0.0661 - accuracy: 0.9776 - precision: 0.9810 - recall: 0.9776 - auc: 0.9987 - true_positives: 387.4167 - true_negatives: 785.2500 - false_positives: 7.9167 - false_negatives: 9.1667 - val_loss: 1.2256 - val_accuracy: 0.7511 - val_precision: 0.7554 - val_recall: 0.7426 - val_auc: 0.8847 - val_true_positives: 176.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 61.0000
#
# Epoch 00020: val_precision improved from 0.74153 to 0.75536, saving model to ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint/assets
# Epoch 21/50
# 23/23 [==============================] - 13s 590ms/step - loss: 0.0396 - accuracy: 0.9914 - precision: 0.9936 - recall: 0.9906 - auc: 0.9997 - true_positives: 391.5417 - true_negatives: 789.6667 - false_positives: 3.5000 - false_negatives: 5.0417 - val_loss: 1.2257 - val_accuracy: 0.7468 - val_precision: 0.7500 - val_recall: 0.7342 - val_auc: 0.8845 - val_true_positives: 174.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 63.0000
#
# Epoch 00021: val_precision did not improve from 0.75536
# Epoch 22/50
# 23/23 [==============================] - 14s 592ms/step - loss: 0.0354 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9998 - true_positives: 392.1250 - true_negatives: 788.7083 - false_positives: 4.4583 - false_negatives: 4.4583 - val_loss: 1.2304 - val_accuracy: 0.7426 - val_precision: 0.7447 - val_recall: 0.7384 - val_auc: 0.8817 - val_true_positives: 175.0000 - val_true_negatives: 414.0000 - val_false_positives: 60.0000 - val_false_negatives: 62.0000
#
# Epoch 00022: val_precision did not improve from 0.75536
# Epoch 23/50
# 23/23 [==============================] - 13s 586ms/step - loss: 0.0312 - accuracy: 0.9895 - precision: 0.9895 - recall: 0.9895 - auc: 0.9998 - true_positives: 391.8333 - true_negatives: 788.4167 - false_positives: 4.7500 - false_negatives: 4.7500 - val_loss: 1.2369 - val_accuracy: 0.7468 - val_precision: 0.7479 - val_recall: 0.7384 - val_auc: 0.8817 - val_true_positives: 175.0000 - val_true_negatives: 415.0000 - val_false_positives: 59.0000 - val_false_negatives: 62.0000
#
# Epoch 00023: val_precision did not improve from 0.75536
# Epoch 24/50
# 23/23 [==============================] - 13s 588ms/step - loss: 0.0672 - accuracy: 0.9733 - precision: 0.9780 - recall: 0.9733 - auc: 0.9986 - true_positives: 389.8750 - true_negatives: 787.4583 - false_positives: 5.7083 - false_negatives: 6.7083 - val_loss: 1.2342 - val_accuracy: 0.7426 - val_precision: 0.7511 - val_recall: 0.7384 - val_auc: 0.8843 - val_true_positives: 175.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 62.0000
#
# Epoch 00024: val_precision did not improve from 0.75536
# Epoch 25/50
# 23/23 [==============================] - 13s 589ms/step - loss: 0.0283 - accuracy: 0.9926 - precision: 0.9926 - recall: 0.9926 - auc: 0.9997 - true_positives: 393.5417 - true_negatives: 790.1250 - false_positives: 3.0417 - false_negatives: 3.0417 - val_loss: 1.2363 - val_accuracy: 0.7426 - val_precision: 0.7479 - val_recall: 0.7384 - val_auc: 0.8814 - val_true_positives: 175.0000 - val_true_negatives: 415.0000 - val_false_positives: 59.0000 - val_false_negatives: 62.0000
#
# Epoch 00025: val_precision did not improve from 0.75536
# Epoch 26/50
# 23/23 [==============================] - 14s 621ms/step - loss: 0.0238 - accuracy: 0.9963 - precision: 0.9963 - recall: 0.9963 - auc: 1.0000 - true_positives: 394.9583 - true_negatives: 791.5417 - false_positives: 1.6250 - false_negatives: 1.6250 - val_loss: 1.2379 - val_accuracy: 0.7553 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8818 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00026: val_precision did not improve from 0.75536
# Epoch 27/50
# 23/23 [==============================] - 13s 585ms/step - loss: 0.0131 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9970 - auc: 1.0000 - true_positives: 395.6667 - true_negatives: 792.2500 - false_positives: 0.9167 - false_negatives: 0.9167 - val_loss: 1.2302 - val_accuracy: 0.7468 - val_precision: 0.7543 - val_recall: 0.7384 - val_auc: 0.8832 - val_true_positives: 175.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 62.0000
#
# Epoch 00027: val_precision did not improve from 0.75536
# Epoch 28/50
# 23/23 [==============================] - 13s 588ms/step - loss: 0.0259 - accuracy: 0.9913 - precision: 0.9913 - recall: 0.9913 - auc: 0.9998 - true_positives: 393.6667 - true_negatives: 790.2500 - false_positives: 2.9167 - false_negatives: 2.9167 - val_loss: 1.2335 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8832 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00028: val_precision did not improve from 0.75536
# Epoch 29/50
# 23/23 [==============================] - 14s 622ms/step - loss: 0.0272 - accuracy: 0.9877 - precision: 0.9877 - recall: 0.9877 - auc: 0.9999 - true_positives: 392.4167 - true_negatives: 789.0000 - false_positives: 4.1667 - false_negatives: 4.1667 - val_loss: 1.2230 - val_accuracy: 0.7553 - val_precision: 0.7617 - val_recall: 0.7553 - val_auc: 0.8844 - val_true_positives: 179.0000 - val_true_negatives: 418.0000 - val_false_positives: 56.0000 - val_false_negatives: 58.0000
# Epoch 00029: val_precision improved from 0.75536 to 0.76170, saving model to ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint/assets
# Epoch 30/50
# 23/23 [==============================] - 13s 588ms/step - loss: 0.0170 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9996 - auc: 1.0000 - true_positives: 396.3333 - true_negatives: 792.9167 - false_positives: 0.2500 - false_negatives: 0.2500 - val_loss: 1.2223 - val_accuracy: 0.7553 - val_precision: 0.7607 - val_recall: 0.7511 - val_auc: 0.8843 - val_true_positives: 178.0000 - val_true_negatives: 418.0000 - val_false_positives: 56.0000 - val_false_negatives: 59.0000
#
# Epoch 00030: val_precision did not improve from 0.76170
# Epoch 31/50
# 23/23 [==============================] - 14s 593ms/step - loss: 0.0148 - accuracy: 0.9955 - precision: 0.9955 - recall: 0.9955 - auc: 1.0000 - true_positives: 394.9583 - true_negatives: 791.5417 - false_positives: 1.6250 - false_negatives: 1.6250 - val_loss: 1.2258 - val_accuracy: 0.7468 - val_precision: 0.7521 - val_recall: 0.7426 - val_auc: 0.8835 - val_true_positives: 176.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 61.0000
#
# Epoch 00031: val_precision did not improve from 0.76170
# Epoch 32/50
# 23/23 [==============================] - 13s 575ms/step - loss: 0.0108 - accuracy: 0.9991 - precision: 0.9991 - recall: 0.9991 - auc: 1.0000 - true_positives: 396.0833 - true_negatives: 792.6667 - false_positives: 0.5000 - false_negatives: 0.5000 - val_loss: 1.2244 - val_accuracy: 0.7595 - val_precision: 0.7650 - val_recall: 0.7553 - val_auc: 0.8847 - val_true_positives: 179.0000 - val_true_negatives: 419.0000 - val_false_positives: 55.0000 - val_false_negatives: 58.0000
#
# Epoch 00032: val_precision improved from 0.76170 to 0.76496, saving model to ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/7_d/no_tl_model_02/model/best_checkpoint/assets
# Epoch 33/50
# 23/23 [==============================] - 14s 631ms/step - loss: 0.0084 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - auc: 1.0000 - true_positives: 396.5000 - true_negatives: 793.0833 - false_positives: 0.0833 - false_negatives: 0.0833 - val_loss: 1.2269 - val_accuracy: 0.7468 - val_precision: 0.7521 - val_recall: 0.7426 - val_auc: 0.8837 - val_true_positives: 176.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 61.0000
#
# Epoch 00033: val_precision did not improve from 0.76496
# Epoch 34/50
# 23/23 [==============================] - 14s 594ms/step - loss: 0.0300 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9997 - true_positives: 392.3333 - true_negatives: 788.9167 - false_positives: 4.2500 - false_negatives: 4.2500 - val_loss: 1.2322 - val_accuracy: 0.7468 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8850 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00034: val_precision did not improve from 0.76496
# Epoch 35/50
# 23/23 [==============================] - 13s 585ms/step - loss: 0.0131 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - auc: 1.0000 - true_positives: 396.4167 - true_negatives: 793.0000 - false_positives: 0.1667 - false_negatives: 0.1667 - val_loss: 1.2239 - val_accuracy: 0.7595 - val_precision: 0.7639 - val_recall: 0.7511 - val_auc: 0.8866 - val_true_positives: 178.0000 - val_true_negatives: 419.0000 - val_false_positives: 55.0000 - val_false_negatives: 59.0000
#
# Epoch 00035: val_precision did not improve from 0.76496
# Epoch 36/50
# 23/23 [==============================] - 15s 641ms/step - loss: 0.0105 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9996 - auc: 1.0000 - true_positives: 396.2917 - true_negatives: 792.8750 - false_positives: 0.2917 - false_negatives: 0.2917 - val_loss: 1.2234 - val_accuracy: 0.7595 - val_precision: 0.7607 - val_recall: 0.7511 - val_auc: 0.8874 - val_true_positives: 178.0000 - val_true_negatives: 418.0000 - val_false_positives: 56.0000 - val_false_negatives: 59.0000
#
# Epoch 00036: val_precision did not improve from 0.76496
# Epoch 37/50
# 23/23 [==============================] - 15s 669ms/step - loss: 0.0147 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9921 - auc: 1.0000 - true_positives: 394.4167 - true_negatives: 791.0000 - false_positives: 2.1667 - false_negatives: 2.1667 - val_loss: 1.2283 - val_accuracy: 0.7553 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8862 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00037: val_precision did not improve from 0.76496
# Epoch 38/50
# 23/23 [==============================] - 13s 582ms/step - loss: 0.0086 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2285 - val_accuracy: 0.7553 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8851 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00038: val_precision did not improve from 0.76496
# Epoch 39/50
# 23/23 [==============================] - 13s 581ms/step - loss: 0.0235 - accuracy: 0.9940 - precision: 0.9940 - recall: 0.9940 - auc: 0.9997 - true_positives: 395.0000 - true_negatives: 791.5833 - false_positives: 1.5833 - false_negatives: 1.5833 - val_loss: 1.2238 - val_accuracy: 0.7511 - val_precision: 0.7564 - val_recall: 0.7468 - val_auc: 0.8867 - val_true_positives: 177.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 60.0000
#
# Epoch 00039: val_precision did not improve from 0.76496
# Epoch 40/50
# 23/23 [==============================] - 13s 564ms/step - loss: 0.0129 - accuracy: 0.9982 - precision: 0.9982 - recall: 0.9982 - auc: 1.0000 - true_positives: 395.6250 - true_negatives: 792.2083 - false_positives: 0.9583 - false_negatives: 0.9583 - val_loss: 1.2265 - val_accuracy: 0.7553 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8869 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00040: val_precision did not improve from 0.76496
# Epoch 41/50
# 23/23 [==============================] - 15s 647ms/step - loss: 0.0074 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2341 - val_accuracy: 0.7553 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8855 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00041: val_precision did not improve from 0.76496
# Epoch 42/50
# 23/23 [==============================] - 13s 569ms/step - loss: 0.0065 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2372 - val_accuracy: 0.7553 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8845 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00042: val_precision did not improve from 0.76496
# Epoch 43/50
# 23/23 [==============================] - 13s 580ms/step - loss: 0.0154 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9970 - auc: 0.9999 - true_positives: 395.2083 - true_negatives: 791.7917 - false_positives: 1.3750 - false_negatives: 1.3750 - val_loss: 1.2273 - val_accuracy: 0.7511 - val_precision: 0.7521 - val_recall: 0.7426 - val_auc: 0.8872 - val_true_positives: 176.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 61.0000
#
# Epoch 00043: val_precision did not improve from 0.76496
# Epoch 44/50
# 23/23 [==============================] - 13s 572ms/step - loss: 0.0112 - accuracy: 0.9986 - precision: 0.9986 - recall: 0.9986 - auc: 1.0000 - true_positives: 395.9167 - true_negatives: 792.5000 - false_positives: 0.6667 - false_negatives: 0.6667 - val_loss: 1.2268 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8878 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00044: val_precision did not improve from 0.76496
# Epoch 45/50
# 23/23 [==============================] - 13s 588ms/step - loss: 0.0087 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951 - auc: 1.0000 - true_positives: 395.5833 - true_negatives: 792.1667 - false_positives: 1.0000 - false_negatives: 1.0000 - val_loss: 1.2258 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8880 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00045: val_precision did not improve from 0.76496
# Epoch 46/50
# 23/23 [==============================] - 13s 579ms/step - loss: 0.0055 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2255 - val_accuracy: 0.7511 - val_precision: 0.7521 - val_recall: 0.7426 - val_auc: 0.8871 - val_true_positives: 176.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 61.0000
#
# Epoch 00046: val_precision did not improve from 0.76496
# Epoch 47/50
# 23/23 [==============================] - 13s 568ms/step - loss: 0.0056 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2249 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8871 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00047: val_precision did not improve from 0.76496
# Epoch 48/50
# 23/23 [==============================] - 13s 577ms/step - loss: 0.0034 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2241 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8873 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00048: val_precision did not improve from 0.76496
# Epoch 49/50
# 23/23 [==============================] - 13s 572ms/step - loss: 0.0055 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - true_positives: 396.5833 - true_negatives: 793.1667 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 1.2239 - val_accuracy: 0.7511 - val_precision: 0.7532 - val_recall: 0.7468 - val_auc: 0.8872 - val_true_positives: 177.0000 - val_true_negatives: 416.0000 - val_false_positives: 58.0000 - val_false_negatives: 60.0000
#
# Epoch 00049: val_precision did not improve from 0.76496
# Epoch 50/50
# 23/23 [==============================] - 13s 568ms/step - loss: 0.0067 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - auc: 1.0000 - true_positives: 396.4583 - true_negatives: 793.0417 - false_positives: 0.1250 - false_negatives: 0.1250 - val_loss: 1.2248 - val_accuracy: 0.7595 - val_precision: 0.7574 - val_recall: 0.7511 - val_auc: 0.8878 - val_true_positives: 178.0000 - val_true_negatives: 417.0000 - val_false_positives: 57.0000 - val_false_negatives: 59.0000
#
# Epoch 00050: val_precision did not improve from 0.76496

# %% [markdown]
# ##### Loading the best model for testing

# %%
model = keras.models.load_model(CHECKPOINT_DIR)

# %% [markdown]
# ##### Testing the model

# %%
prediction = model.predict(test_images, batch_size=1)

prediction = tf.argmax(prediction, axis=-1)

from sklearn import metrics
print(metrics.classification_report(test_labels_1d, prediction, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.791     0.916     0.849       178
#            1      0.385     0.185     0.250        54
#            2      0.400     0.400     0.400         5
#
#     accuracy                          0.738       237
#    macro avg      0.525     0.500     0.500       237
# weighted avg      0.690     0.738     0.703       237

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics) + 1

SAVE = True

def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")
