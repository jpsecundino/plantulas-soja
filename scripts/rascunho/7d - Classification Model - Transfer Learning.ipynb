# %% [markdown]
# # Creating dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = '../datasets/Classification/Dataset - 3 dias/Images'
CATEGORIES = ["Normal", "Anormal", "Morta"]

# %%
def create_training_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
            ## add images to training data with its label
            training_data.append([img_array, class_num])
    return training_data
            
training_data = create_training_data()

# %%
print(len(training_data))
# Out:
# 1101

# %%
#mix data for better learning
import random
random.shuffle(training_data)

# %%
images = []
labels = []

for image, label in training_data:
    images.append(image)
    labels.append(label)

# %%
##saving dataset
import pickle
DATASET_PATH = "../datasets/Classification/Dataset - 3 dias/"

pickle_out = open(os.path.join(DATASET_PATH, "3_days_images.pickle"), "wb")
pickle.dump(images, pickle_out)
pickle_out.close()

pickle_out = open(os.path.join(DATASET_PATH, "3_days_labels.pickle"), "wb")
pickle.dump(labels, pickle_out)
pickle_out.close()

# %% [markdown]
# # Creating classification model
# ##### Following this tutorial
#        www.youtube.com/watch?v=WvoLTXIjBYU
# ##### Characteristics
#  - Sequencial Model
#  - Fully trained on this dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import keras
import os

# %% [markdown]
# #### Reading and preparing the dataset

# %%
import imutils
def pad_image(image, size_x, size_y):
    shape = image.shape
    res = []
    
    pad_image = np.zeros((size_x,size_y,3), np.uint8)
    
    if shape[0] > shape[1]:
        res = imutils.resize(image, height=size_x)
        res = center_image(res, pad_image)
    else:
        res = imutils.resize(image, width=size_y)
        res = center_image(res, pad_image)
    
    return res
    
def center_image(image, background):
    img_shape = image.shape
    bck_shape = background.shape
    
    x_diff = round((bck_shape[0] - img_shape[0])/2)
    y_diff = round((bck_shape[1] - img_shape[1])/2)
    
#     print(image.shape, background.shape, x_diff, y_diff)
    
    res = background.copy()
    
    res[x_diff:x_diff + img_shape[0],y_diff:y_diff + img_shape[1]] = image
    
    return res

# %%
images_raw = open(os.path.join(DATASET_PATH, "3_days_images.pickle" ), "rb")
images = pickle.load(images_raw)

labels_raw = open(os.path.join(DATASET_PATH, "3_days_labels.pickle" ), "rb")
labels = pickle.load(labels_raw)

#reshape images
IMG_SIZE = 256

# %% [markdown]
# ##### Padding Images in Memory

# %%
for i in range(len(images)):
    images[i] = pad_image(images[i], IMG_SIZE, IMG_SIZE)
    plt.imshow(images[i])

# %% [markdown]
# ##### Labels one hot enconding

# %% [markdown]
# ###### Train Test split

# %%
images = np.array(images)

from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2)

# %%
print(test_images.shape)
# Out:
# (221, 256, 256, 3)

# %% [markdown]
# #### Ajustando o dataset desbalanceado

# %% [markdown]
# ###### Data augmentation -> data generator

# %%
# data augmentation with ImageDataGenerator -> did not go well
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=False,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True,
#     validation_split=0.25
# )
# datagen.fit(train_images)

# # it = datagen.flow(train_images, batch_size=1, save_to_dir="test", shuffle= True)

# # # generate samples and plot
# # for i in range(50):
# #      # generate batch of images
# #     batch = it.next()
# #     # convert to unsigned integers for viewing
# #     image = batch[0].astype('uint8')
# #     # plot raw pixel data
# #     plt.imshow(image, cmap="gray")
# #     plt.show()
# # show the figure

# %% [markdown]
# ###### Weighted Classes

# %%
## Trying class weights
#it does not work withone hot encoded data
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_labels),
#                                                  train_labels)

# from sklearn.utils import compute_sample_weight
# sample_weights = compute_sample_weight('balanced', train_labels)  #->>>> remember to add the weights in model.fit

# %% [markdown]
# ###### SMOTE

# %%
classes, counts = np.unique(train_labels, return_counts=True)
print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")
# Out:
# The number of elements for each class in training now are
# Class 0: 675
# Class 1 176
# Class 2 29

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)

train_images_shape = train_images.shape
train_images = train_images.reshape((train_images_shape[0], IMG_SIZE * IMG_SIZE * 3))
train_images, train_labels = sm.fit_resample(train_images, train_labels)

# %%
train_images_shape = train_images.shape
train_images = train_images.reshape((train_images_shape[0], IMG_SIZE, IMG_SIZE, 3))

# %%
classes, counts = np.unique(train_labels, return_counts=True)
print(f"The number of elements for each class in training now are\nClass 0: {counts[0]}\nClass 1 {counts[1]}\nClass 2 {counts[2]}\n")
# Out:
# The number of elements for each class in training now are
# Class 0: 675
# Class 1 675
# Class 2 675

# %% [markdown]
# ##### One hot label encoding

# %%
import pandas as pd

train_labels = pd.get_dummies(train_labels)
train_labels = pd.DataFrame.to_numpy(train_labels)

test_labels = pd.get_dummies(test_labels)
test_labels = pd.DataFrame.to_numpy(test_labels)

# %% [markdown]
# ##### Normalizing training images

# %%
# train_images = tf.keras.utils.normalize(train_images, axis=0, order=2)

# %% [markdown]
# ### Creating the model

# %%
EPOCHS = 15
TRAIN_TEST_SPLIT = 0.25
BATCH_SIZE = 32
# print((1 - TRAIN_TEST_SPLIT) * train_images.shape[0],BATCH_SIZE)

# %%
base_model = keras.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False
)

base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE,IMG_SIZE, 3))
# We make sure that the base_model is running in inference mode here,
# by passing `training=False`. This is important for fine-tuning, as you will
# learn in a few paragraphs.
x = base_model(inputs, training=False)
# Convert features of shape `base_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier 
outputs = keras.layers.Dense(3, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

my_metrics = ["accuracy",
           tf.keras.metrics.Precision(),
           tf.keras.metrics.Recall(),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives(),]

opt = keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=my_metrics)

# %%
from keras.callbacks import ModelCheckpoint
METRICDIR = './metricas/classificacao/3_d/smote_transfer_learning/'
MODELDIR = os.path.join(METRICDIR, "model")
CHECKPOINT_DIR = os.path.join(MODELDIR, "best_checkpoint")
checkpoint = ModelCheckpoint(CHECKPOINT_DIR, monitor="val_precision", verbose=1,
    save_best_only=True, mode='max', save_freq='epoch')

# %%
history = model.fit(train_images, train_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split=TRAIN_TEST_SPLIT, callbacks=[checkpoint])
# Out:
# Epoch 1/15
# 48/48 [==============================] - 149s 3s/step - loss: 21.5756 - accuracy: 0.4480 - precision: 0.4548 - recall: 0.4691 - auc: 0.6393 - true_positives: 376.9592 - true_negatives: 1154.6735 - false_positives: 442.5510 - false_negatives: 421.6531 - val_loss: 59.5489 - val_accuracy: 0.0000e+00 - val_precision: 0.1916 - val_recall: 0.2525 - val_auc: 0.3230 - val_true_positives: 128.0000 - val_true_negatives: 474.0000 - val_false_positives: 540.0000 - val_false_negatives: 379.0000
#
# Epoch 00001: val_precision improved from -inf to 0.19162, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 2/15
# 48/48 [==============================] - 132s 3s/step - loss: 16.6805 - accuracy: 0.4835 - precision: 0.4782 - recall: 0.5003 - auc: 0.6730 - true_positives: 398.3878 - true_negatives: 1159.5714 - false_positives: 437.6531 - false_negatives: 400.2245 - val_loss: 53.1400 - val_accuracy: 0.0000e+00 - val_precision: 0.2351 - val_recall: 0.3432 - val_auc: 0.3296 - val_true_positives: 174.0000 - val_true_negatives: 448.0000 - val_false_positives: 566.0000 - val_false_negatives: 333.0000
#
# Epoch 00002: val_precision improved from 0.19162 to 0.23514, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 3/15
# 48/48 [==============================] - 137s 3s/step - loss: 14.8584 - accuracy: 0.4962 - precision: 0.4816 - recall: 0.5182 - auc: 0.6806 - true_positives: 415.3469 - true_negatives: 1140.3265 - false_positives: 456.8980 - false_negatives: 383.2653 - val_loss: 46.6737 - val_accuracy: 0.0000e+00 - val_precision: 0.2533 - val_recall: 0.4122 - val_auc: 0.3426 - val_true_positives: 209.0000 - val_true_negatives: 398.0000 - val_false_positives: 616.0000 - val_false_negatives: 298.0000
#
# Epoch 00003: val_precision improved from 0.23514 to 0.25333, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 4/15
# 48/48 [==============================] - 196s 4s/step - loss: 12.5780 - accuracy: 0.5388 - precision: 0.4732 - recall: 0.5676 - auc: 0.6778 - true_positives: 455.8571 - true_negatives: 1096.0204 - false_positives: 501.2041 - false_negatives: 342.7551 - val_loss: 40.2413 - val_accuracy: 0.0000e+00 - val_precision: 0.2788 - val_recall: 0.5108 - val_auc: 0.3616 - val_true_positives: 259.0000 - val_true_negatives: 344.0000 - val_false_positives: 670.0000 - val_false_negatives: 248.0000
#
# Epoch 00004: val_precision improved from 0.25333 to 0.27879, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 5/15
# 48/48 [==============================] - 143s 3s/step - loss: 9.8538 - accuracy: 0.5698 - precision: 0.4759 - recall: 0.6214 - auc: 0.6838 - true_positives: 504.5306 - true_negatives: 1040.4490 - false_positives: 556.7755 - false_negatives: 294.0816 - val_loss: 33.9461 - val_accuracy: 0.0020 - val_precision: 0.2778 - val_recall: 0.5759 - val_auc: 0.3744 - val_true_positives: 292.0000 - val_true_negatives: 255.0000 - val_false_positives: 759.0000 - val_false_negatives: 215.0000
#
# Epoch 00005: val_precision did not improve from 0.27879
# Epoch 6/15
# 48/48 [==============================] - 196s 4s/step - loss: 7.9764 - accuracy: 0.5945 - precision: 0.4589 - recall: 0.6861 - auc: 0.6805 - true_positives: 557.6122 - true_negatives: 950.4082 - false_positives: 646.8163 - false_negatives: 241.0000 - val_loss: 28.1547 - val_accuracy: 0.0158 - val_precision: 0.2874 - val_recall: 0.6785 - val_auc: 0.3876 - val_true_positives: 344.0000 - val_true_negatives: 161.0000 - val_false_positives: 853.0000 - val_false_negatives: 163.0000
#
# Epoch 00006: val_precision improved from 0.27879 to 0.28739, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 7/15
# 48/48 [==============================] - 135s 3s/step - loss: 5.6789 - accuracy: 0.6320 - precision: 0.4521 - recall: 0.7721 - auc: 0.6913 - true_positives: 625.3469 - true_negatives: 845.3265 - false_positives: 751.8980 - false_negatives: 173.2653 - val_loss: 23.0429 - val_accuracy: 0.0513 - val_precision: 0.2929 - val_recall: 0.7535 - val_auc: 0.3970 - val_true_positives: 382.0000 - val_true_negatives: 92.0000 - val_false_positives: 922.0000 - val_false_negatives: 125.0000
#
# Epoch 00007: val_precision improved from 0.28739 to 0.29294, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 8/15
# 48/48 [==============================] - 132s 3s/step - loss: 4.0614 - accuracy: 0.6857 - precision: 0.4494 - recall: 0.8657 - auc: 0.6906 - true_positives: 693.5102 - true_negatives: 736.5714 - false_positives: 860.6531 - false_negatives: 105.1020 - val_loss: 18.7848 - val_accuracy: 0.1164 - val_precision: 0.3029 - val_recall: 0.8304 - val_auc: 0.4194 - val_true_positives: 421.0000 - val_true_negatives: 45.0000 - val_false_positives: 969.0000 - val_false_negatives: 86.0000
#
# Epoch 00008: val_precision improved from 0.29294 to 0.30288, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 9/15
# 48/48 [==============================] - 131s 3s/step - loss: 3.4863 - accuracy: 0.6646 - precision: 0.4309 - recall: 0.9093 - auc: 0.6672 - true_positives: 729.0000 - true_negatives: 638.8776 - false_positives: 958.3469 - false_negatives: 69.6122 - val_loss: 15.7870 - val_accuracy: 0.1302 - val_precision: 0.3076 - val_recall: 0.8659 - val_auc: 0.4283 - val_true_positives: 439.0000 - val_true_negatives: 26.0000 - val_false_positives: 988.0000 - val_false_negatives: 68.0000
#
# Epoch 00009: val_precision improved from 0.30288 to 0.30764, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 10/15
# 48/48 [==============================] - 127s 3s/step - loss: 3.0252 - accuracy: 0.6579 - precision: 0.4243 - recall: 0.9241 - auc: 0.6616 - true_positives: 740.3878 - true_negatives: 596.6939 - false_positives: 1000.5306 - false_negatives: 58.2245 - val_loss: 13.8688 - val_accuracy: 0.1519 - val_precision: 0.3137 - val_recall: 0.8915 - val_auc: 0.4430 - val_true_positives: 452.0000 - val_true_negatives: 25.0000 - val_false_positives: 989.0000 - val_false_negatives: 55.0000
#
# Epoch 00010: val_precision improved from 0.30764 to 0.31367, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 11/15
# 48/48 [==============================] - 136s 3s/step - loss: 2.8420 - accuracy: 0.6134 - precision: 0.4199 - recall: 0.9453 - auc: 0.6507 - true_positives: 755.7143 - true_negatives: 554.5306 - false_positives: 1042.6939 - false_negatives: 42.8980 - val_loss: 12.6097 - val_accuracy: 0.1598 - val_precision: 0.3170 - val_recall: 0.9073 - val_auc: 0.4478 - val_true_positives: 460.0000 - val_true_negatives: 23.0000 - val_false_positives: 991.0000 - val_false_negatives: 47.0000
#
# Epoch 00011: val_precision improved from 0.31367 to 0.31702, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 12/15
# 48/48 [==============================] - 124s 3s/step - loss: 2.5207 - accuracy: 0.6413 - precision: 0.4212 - recall: 0.9475 - auc: 0.6503 - true_positives: 760.4082 - true_negatives: 555.8980 - false_positives: 1041.3265 - false_negatives: 38.2041 - val_loss: 12.1657 - val_accuracy: 0.1657 - val_precision: 0.3184 - val_recall: 0.9132 - val_auc: 0.4552 - val_true_positives: 463.0000 - val_true_negatives: 23.0000 - val_false_positives: 991.0000 - val_false_negatives: 44.0000
#
# Epoch 00012: val_precision improved from 0.31702 to 0.31843, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 13/15
# 48/48 [==============================] - 125s 3s/step - loss: 2.6018 - accuracy: 0.6394 - precision: 0.4243 - recall: 0.9481 - auc: 0.6519 - true_positives: 760.2857 - true_negatives: 557.0408 - false_positives: 1040.1837 - false_negatives: 38.3265 - val_loss: 11.7407 - val_accuracy: 0.1657 - val_precision: 0.3198 - val_recall: 0.9191 - val_auc: 0.4643 - val_true_positives: 466.0000 - val_true_negatives: 23.0000 - val_false_positives: 991.0000 - val_false_negatives: 41.0000
#
# Epoch 00013: val_precision improved from 0.31843 to 0.31984, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 14/15
# 48/48 [==============================] - 127s 3s/step - loss: 2.4000 - accuracy: 0.6354 - precision: 0.4251 - recall: 0.9661 - auc: 0.6568 - true_positives: 769.2245 - true_negatives: 559.8367 - false_positives: 1037.3878 - false_negatives: 29.3878 - val_loss: 11.4377 - val_accuracy: 0.1677 - val_precision: 0.3205 - val_recall: 0.9231 - val_auc: 0.4661 - val_true_positives: 468.0000 - val_true_negatives: 22.0000 - val_false_positives: 992.0000 - val_false_negatives: 39.0000
#
# Epoch 00014: val_precision improved from 0.31984 to 0.32055, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets
# Epoch 15/15
# 48/48 [==============================] - 127s 3s/step - loss: 2.4238 - accuracy: 0.6397 - precision: 0.4252 - recall: 0.9606 - auc: 0.6459 - true_positives: 768.0612 - true_negatives: 566.3673 - false_positives: 1030.8571 - false_negatives: 30.5510 - val_loss: 11.0651 - val_accuracy: 0.1677 - val_precision: 0.3217 - val_recall: 0.9270 - val_auc: 0.4717 - val_true_positives: 470.0000 - val_true_negatives: 23.0000 - val_false_positives: 991.0000 - val_false_negatives: 37.0000
#
# Epoch 00015: val_precision improved from 0.32055 to 0.32170, saving model to ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint
# INFO:tensorflow:Assets written to: ./metricas/classificacao/3_d/smote_transfer_learning/model/best_checkpoint/assets

# %% [markdown]
# ##### Loading the best model for testing

# %%
model = keras.models.load_model(CHECKPOINT_DIR)

# %% [markdown]
# ##### Testing the model

# %%
model.evaluate(test_images, test_labels, batch_size=1)
# Out:
# 221/221 [==============================] - 18s 77ms/step - loss: 2.0694 - accuracy: 0.6968 - precision: 0.5073 - recall: 0.9412 - auc: 0.7403 - true_positives: 208.0000 - true_negatives: 240.0000 - false_positives: 202.0000 - false_negatives: 13.0000
# [2.0693724155426025,
#  0.6968325972557068,
#  0.507317066192627,
#  0.9411764740943909,
#  0.74032062292099,
#  208.0,
#  240.0,
#  202.0,
#  13.0]

# %% [markdown]
# #### Visualizing model data

# %%
import matplotlib.pyplot as plt

# %%
NUM_METRICS = len(my_metrics) + 1

SAVE = True

def plot_metric(metric_name, chart_name):
    plt.plot(history.history[metric_name], label = metric_name + ' (training data)')
    plt.plot(history.history['val_' + metric_name], label = metric_name + ' (validation data)')
    plt.title(chart_name)
    plt.ylabel( metric_name + ' value')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    if SAVE and not os.path.exists(METRICDIR):
        os.mkdir(METRICDIR)
    if SAVE:
        plt.savefig(os.path.join(METRICDIR, metric_name))
    plt.show()

# %%
for metric in list(history.history.keys())[:NUM_METRICS]:
    plot_metric(metric, metric + " for soybean classification")
